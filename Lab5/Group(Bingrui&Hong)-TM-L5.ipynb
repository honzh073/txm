# %% [markdown]
# # L5: Information extraction

# %% [markdown]
# Information extraction (IE) is the task of identifying named entities and semantic relations between these entities in text data. In this lab we will focus on two sub-tasks in IE, **named entity recognition** (identifying mentions of entities) and **entity linking** (matching these mentions to entities in a knowledge base).

# %% [markdown]
# **Reminder about our [Rules for hand-in assignments](https://www.ida.liu.se/~TDDE16/exam.en.shtml#handins) and the [Policy on cheating and plagiarism](https://www.ida.liu.se/~TDDE16/exam.en.shtml#cheating)**

# %% [markdown]
# We start by loading spaCy:

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# The data that we will be using has been tokenized following the conventions of the [Penn Treebank](ftp://ftp.cis.upenn.edu/pub/treebank/public_html/tokenization.html), and we need to prevent spaCy from using its own tokenizer on top of this. We therefore override spaCy&rsquo;s tokenizer with one that simply splits on space.

# %%
from spacy.tokens import Doc

class WhitespaceTokenizer(object):
    def __init__(self, vocab):
        self.vocab = vocab

    def __call__(self, text):
        return Doc(self.vocab, words=text.split(' '))

nlp.tokenizer = WhitespaceTokenizer(nlp.vocab)

# %% [markdown]
# ## Data set

# %% [markdown]
# The main data set for this lab is a collection of news wire articles in which mentions of named entities have been annotated with page names from the [English Wikipedia](https://en.wikipedia.org/wiki/). The next code cell loads the training and the development parts of the data into Pandas data frames.

# %%
import bz2
import csv
import pandas as pd

with bz2.open('ner-train.tsv.bz2', 'rt') as source:
    df_train = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

with bz2.open('ner-dev.tsv.bz2', 'rt') as source:
    df_dev = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# Each row in these two data frames corresponds to one mention of a named entity and has five columns:
#
# 1. a unique identifier for the sentence containing the entity mention
# 2. the pre-tokenized sentence, with tokens separated by spaces
# 3. the start position of the token span containing the entity mention
# 4. the end position of the token span (exclusive, as in Python list indexing)
# 5. the entity label; either a Wikipedia page name or the generic label `--NME--`
#
# The following cell prints the first five samples from the training data:

# %%
df_train.head()
# Out:
#   sentence_id                                          sentence  beg  end  \
# 0    0000-000  EU rejects German call to boycott British lamb .    0    1
# 1    0000-000  EU rejects German call to boycott British lamb .    2    3
# 2    0000-000  EU rejects German call to boycott British lamb .    6    7
# 3    0000-001                                   Peter Blackburn    0    2
# 4    0000-002                               BRUSSELS 1996-08-22    0    1
#
#             label
# 0         --NME--
# 1         Germany
# 2  United_Kingdom
# 3         --NME--
# 4        Brussels

# %% [markdown]
# In this sample, we see that the first sentence is annotated with three entity mentions:
#
# * the span 0–1 &lsquo;EU&rsquo; is annotated as a mention but only labelled with the generic `--NME--`
# * the span 2–3 &lsquo;German&rsquo; is annotated with the page [Germany](http://en.wikipedia.org/wiki/Germany)
# * the span 6–7 &lsquo;British&rsquo; is annotated with the page [United_Kingdom](http://en.wikipedia.org/wiki/United_Kingdom)

# %% [markdown]
# ## Problem 1: Evaluation measures

# %% [markdown]
# To warm up, we ask you to write code to print the three measures that you will be using for evaluation:

# %%
def evaluation_report(gold, pred):
    """Print precision, recall, and F1 score.
    
    Args:
        gold: The set with the gold-standard values.
        pred: The set with the predicted values.
    
    Returns:
        Nothing, but prints the precision, recall, and F1 values computed
        based on the specified sets.
    """
    # TODO: Replace the next line with your own code
    TP = len(gold & pred) # intersection
    TN = 0
    FP = len(pred - gold)
    FN = len(gold - pred)

    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    F1_score = (2 * precision * recall) / (precision + recall)
    
    print("precission: ",precision, ", recall: ", recall, ", F1_score: ", F1_score )

# %% [markdown]
# To test your code, you can run the following cell:

# %%
evaluation_report(set(range(3)), set(range(5)))
# Out:
# precission:  0.6 , recall:  1.0 , F1_score:  0.7499999999999999

# %% [markdown]
# This should give you a precision of 60%, a recall of 100%, and an F1-value of 75%.

# %% [markdown]
# ## Problem 2: Span recognition

# %% [markdown]
# One of the first tasks that an information extraction system has to solve is to locate and classify (mentions of) named entities, such as persons and organizations. Here we will tackle the simpler task of recognizing **spans** of tokens that contain an entity mention, without the actual entity label.
#
# The English language model in spaCy features a full-fledged [named entity recognizer](https://spacy.io/usage/linguistic-features#named-entities) that identifies a variety of entities, and can be updated with new entity types by the user. Your task in this problem is to evaluate the performance of this component when predicting entity spans in the development data.
#
# Start by implementing a generator function that yields the gold-standard spans in a given data frame.
#
# **Hint:** The Pandas method [`itertuples()`](https://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.DataFrame.itertuples.html) is useful when iterating over the rows in a DataFrame.

# %%
def gold_spans(df):
    """Yield the gold-standard mention spans in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        triples consisting of the sentence id, start position, and end
        position of each span.
    """
    # input a df, return each span's sentence id, start position, end position
    # TODO: Replace the next line with your own code
    # because we use row.sentence_id directly, the Args index here doesn't matter
    for row in df.itertuples():
        yield row.sentence_id, row.beg, row.end

# %% [markdown]
# To test your code, you can count the spans yielded by your function. When called on the development data, you should get a total of 5,917 unique triples. The first triple and the last triple should be
#
#     ('0946-000', 2, 3)
#     ('1161-010', 1, 3)

# %%
spans_dev_gold = set(gold_spans(df_dev))
print(len(spans_dev_gold))
# Out:
# 5917

# %% [markdown]
# ----My Answer:
#
# ----set() function will deduplicate or remove the same data records and reorder the list.
#
# ----then, we use list() function to get the original order.

# %%
# the first triple
list(gold_spans(df_dev))[0]
# Out:
# ('0946-000', 2, 3)

# %%
# the last triple
list(gold_spans(df_dev))[-1]
# Out:
# ('1161-010', 1, 3)

# %% [markdown]
# Your next task is to write code that calls spaCy to predict the named entities in the development data, and to evaluate the accuracy of these predictions in terms of precision, recall, and F1. Print these scores using the function that you wrote for Problem&nbsp;1.

# %%
# TODO: Write code here to run and evaluate the spaCy named entity recognizer on the development data
# 1. use spaCy to predict named entities in df_dev
# 2. use evaluation_report() function get precission, recall, F1_score

def spaCy_predict(df):
    for row in df.itertuples():
        doc = nlp(row.sentence)
        for ent in doc.ents:
            yield row.sentence_id, ent.start, ent.end

# df_dev is the development data
# 1. use spaCy_predict() function to predict the df_dev
# 2. use evaluation_report() function to compare 'pred' and 'gold' sets

spaCy_predictions = set(spaCy_predict(df_dev))
evaluation_report(gold = spans_dev_gold, pred = spaCy_predictions)
# Out:
# precission:  0.5213954072029113 , recall:  0.702213959776914 , F1_score:  0.5984444764511019

# %% [markdown]
# ----My Answer:
#
# ----Here, we get above scores, which are not very good, the Precission and F1_score are too low.
#
# ----just more than a half of the predicted spans set are correct based on gold standard.

# %% [markdown]
# ## Problem 3: Error analysis

# %% [markdown]
# As you were able to see in Problem&nbsp;2, the span accuracy of the named entity recognizer is far from perfect. In particular, only slightly more than half of the predicted spans are correct according to the gold standard. Your next task is to analyse this result in more detail.
#
# Here is a function that prints the false positives as well

# %% [markdown]
#  as the false negatives spans for a data frame, given a reference set of gold-standard spans and a candidate set of predicted spans.

# %%
from collections import defaultdict

def error_report(df, spans_gold, spans_pred):
    false_pos = defaultdict(list)
    for s, b, e in spans_pred - spans_gold:
        false_pos[s].append((b, e))
    false_neg = defaultdict(list)
    for s, b, e in spans_gold - spans_pred:
        false_neg[s].append((b, e))
    for row in df.drop_duplicates('sentence_id').itertuples():
        if row.sentence_id in false_pos or row.sentence_id in false_neg:
            print('Sentence:', row.sentence)
            for b, e in false_pos[row.sentence_id]:
                print('  FP:', ' '.join(row.sentence.split()[b:e]))
            for b, e in false_neg[row.sentence_id]:
                print('  FN:', ' '.join(row.sentence.split()[b:e]))

# %% [markdown]
# Use this function to inspect and analyse the errors that the automated prediction makes. Can you see any patterns? Base your analysis on the first 500 rows of the training data. Summarize your observations in a short text.

# %%
# TODO: Write code here to do your analysis

# use first 500 rows 
# set of gold-standard spans
# set of predicted spans
error_report(df_dev.iloc[0:500,], set(gold_spans(df_dev)), set(spaCy_predict(df_dev)))
# Out:
# Sentence: CRICKET - LEICESTERSHIRE TAKE OVER AT TOP AFTER INNINGS VICTORY .
#   FN: LEICESTERSHIRE
# Sentence: LONDON 1996-08-30
#   FP: 1996-08-30
# Sentence: West Indian all-rounder Phil Simmons took four for 38 on Friday as Leicestershire beat Somerset by an innings and 39 runs in two days to take over at the head of the county championship .
#   FP: four
#   FP: two days
#   FP: 38
#   FP: Friday
#   FP: 39
# Sentence: After bowling Somerset out for 83 on the opening morning at Grace Road , Leicestershire extended their first innings by 94 runs before being bowled out for 296 with England discard Andy Caddick taking three for 83 .
#   FP: first
#   FP: 94
#   FP: 296
#   FP: 83
#   FP: 83
#   FP: three
#   FP: the opening morning
# Sentence: Trailing by 213 , Somerset got a solid start to their second innings before Simmons stepped in to bundle them out for 174 .
#   FP: second
#   FP: 174
#   FP: 213
# Sentence: Essex , however , look certain to regain their top spot after Nasser Hussain and Peter Such gave them a firm grip on their match against Yorkshire at Headingley .
#   FP: Yorkshire at
#   FN: Essex
#   FN: Yorkshire
# Sentence: Hussain , considered surplus to England 's one-day requirements , struck 158 , his first championship century of the season , as Essex reached 372 and took a first innings lead of 82 .
#   FP: one-day
#   FP: first
#   FP: 372
#   FP: 82
#   FP: first
#   FP: 158
# Sentence: By the close Yorkshire had turned that into a 37-run advantage but off-spinner Such had scuttled their hopes , taking four for 24 in 48 balls and leaving them hanging on 119 for five and praying for rain .
#   FP: five
#   FP: 119
#   FP: 48
#   FP: four
#   FP: 24
#   FN: Such
# Sentence: At the Oval , Surrey captain Chris Lewis , another man dumped by England , continued to silence his critics as he followed his four for 45 on Thursday with 80 not out on Friday in the match against Warwickshire .
#   FP: Friday
#   FP: 80
#   FP: four
#   FP: 45
#   FP: Thursday
# Sentence: He was well backed by England hopeful Mark Butcher who made 70 as Surrey closed on 429 for seven , a lead of 234 .
#   FP: 70
#   FP: seven
#   FP: 429
#   FP: 234
# Sentence: Derbyshire kept up the hunt for their first championship title since 1936 by reducing Worcestershire to 133 for five in their second innings , still 100 runs away from avoiding an innings defeat .
#   FP: 1936
#   FP: 133
#   FP: five
#   FP: second
#   FP: 100
#   FP: first
#   FN: Derbyshire
# Sentence: Australian Tom Moody took six for 82 but Chris Adams , 123 , and Tim O'Gorman , 109 , took Derbyshire to 471 and a first innings lead of 233 .
#   FP: 109
#   FP: six
#   FP: 82
#   FP: 123
#   FP: 471
#   FP: 233
#   FP: first
# Sentence: After the frustration of seeing the opening day of their match badly affected by the weather , Kent stepped up a gear to dismiss Nottinghamshire for 214 .
#   FP: 214
# Sentence: They were held up by a gritty 84 from Paul Johnson but ex-England fast bowler Martin McCague took four for 55 .
#   FP: 84
#   FP: four
#   FP: 55
#   FN: ex-England
# Sentence: By stumps Kent had reached 108 for three .
#   FP: three
#   FP: 108
# Sentence: CRICKET - ENGLISH COUNTY CHAMPIONSHIP SCORES .
#   FP: CRICKET - ENGLISH COUNTY CHAMPIONSHIP SCORES
#   FN: ENGLISH COUNTY CHAMPIONSHIP
# Sentence: LONDON 1996-08-30
#   FP: 1996-08-30
# Sentence: Result and close of play scores in English county championship matches on Friday :
#   FP: English county
#   FP: Friday
#   FN: English
# Sentence: Leicester : Leicestershire beat Somerset by an innings and 39 runs .
#   FP: 39
#   FN: Leicester
#   FN: Leicestershire
# Sentence: Somerset 83 and 174 ( P. Simmons 4-38 ) , Leicestershire 296 .
#   FP: 296
#   FP: 83
#   FP: 174
#   FN: Somerset
#   FN: Leicestershire
#   FN: P. Simmons
# Sentence: Leicestershire 22 points , Somerset 4 .
#   FP: 4
#   FP: 22
#   FN: Somerset
#   FN: Leicestershire
# Sentence: Chester-le-Street : Glamorgan 259 and 207 ( A. Dale 69 , H. Morris 69 ; D. Blenkiron 4-43 ) , Durham 114 ( S. Watkin 4-28 ) and 81-3 .
#   FP: H. Morris 69
#   FP: 259
#   FP: 4-28
#   FP: D.
#   FP: 81-3
#   FN: A. Dale
#   FN: H. Morris
#   FN: D. Blenkiron
#   FN: S. Watkin
#   FN: Chester-le-Street
# Sentence: Tunbridge Wells : Nottinghamshire 214 ( P. Johnson 84 ; M. McCague 4-55 ) , Kent 108-3 .
#   FP: M. McCague 4-55
#   FN: P. Johnson
#   FN: Kent
#   FN: M. McCague
#   FN: Nottinghamshire
# Sentence: London ( The Oval ) : Warwickshire 195 , Surrey 429-7 ( C. Lewis 80 not out , M. Butcher 70 , G. Kersey 63 , J. Ratcliffe 63 , D. Bicknell 55 ) .
#   FP: 195
#   FP: Surrey 429-7
#   FP: 55
#   FP: D.
#   FP: G. Kersey 63
#   FP: J. Ratcliffe 63
#   FN: Surrey
#   FN: Warwickshire
#   FN: C. Lewis
#   FN: D. Bicknell
#   FN: J. Ratcliffe
#   FN: The Oval
#   FN: G. Kersey
# Sentence: Hove : Sussex 363 ( W. Athey 111 , V. Drakes 52 ; I. Austin 4-37 ) , Lancashire 197-8 ( W. Hegg 54 )
#   FP: V. Drakes 52
#   FP: W. Athey 111
#   FP: Lancashire 197-8
#   FP: I. Austin 4-37
#   FP: W. Hegg 54
#   FN: Hove
#   FN: W. Athey
#   FN: Lancashire
#   FN: V. Drakes
#   FN: I. Austin
#   FN: W. Hegg
#   FN: Sussex
# Sentence: Portsmouth : Middlesex 199 and 426 ( J. Pooley 111 , M. Ramprakash 108 , M. Gatting 83 ) , Hampshire 232 and 109-5 .
#   FP: M. Ramprakash 108
#   FP: Hampshire 232
#   FP: 199
#   FP: 109-5
#   FP: 426
#   FP: J. Pooley 111
#   FP: M. Gatting 83
#   FN: Hampshire
#   FN: M. Gatting
#   FN: Portsmouth
#   FN: J. Pooley
#   FN: Middlesex
#   FN: M. Ramprakash
# Sentence: Chesterfield : Worcestershire 238 and 133-5 , Derbyshire 471 ( J. Adams 123 , T.O'Gorman 109 not out , K. Barnett 87 ; T. Moody 6-82 )
#   FP: Worcestershire 238 and 133-5
#   FP: T. Moody 6-82
#   FP: J. Adams 123
#   FP: 109
#   FN: T.O'Gorman
#   FN: J. Adams
#   FN: T. Moody
#   FN: Worcestershire
#   FN: Derbyshire
# Sentence: Bristol : Gloucestershire 183 and 185-6 ( J. Russell 56 not out ) , Northamptonshire 190 ( K. Curran 52 ; A. Smith 5-68 ) .
#   FP: A. Smith 5-68
#   FP: Northamptonshire 190 ( K. Curran 52
#   FP: 183
#   FP: J. Russell 56
#   FN: Gloucestershire
#   FN: J. Russell
#   FN: A. Smith
#   FN: Northamptonshire
#   FN: K. Curran
# Sentence: CRICKET - 1997 ASHES INTINERARY .
#   FP: CRICKET - 1997
#   FN: ASHES
# Sentence: LONDON 1996-08-30
#   FP: 1996-08-30
# Sentence: Australia will defend the Ashes in
#   FN: Ashes
# Sentence: a six-test series against England during a four-month tour
#   FP: four-month
# Sentence: starting on May 13 next year , the Test and County Cricket Board
#   FP: May 13 next year
#   FN: Test and County Cricket Board
# Sentence: Australia will also play three one-day internationals and
#   FP: three
# Sentence: as well as one-day matches against the Minor Counties and
#   FP: one-day
#   FN: Minor Counties
# Sentence: May 13 Arrive in London
#   FP: May 13 Arrive
# Sentence: May 14 Practice at Lord 's
#   FP: May 14 Practice
#   FN: Lord 's
# Sentence: May 15 v Duke of Norfolk 's XI ( at Arundel )
#   FP: May 15 v Duke of Norfolk 's
#   FP: XI
#   FN: Arundel
#   FN: Duke of Norfolk 's XI
# Sentence: May 17 v Northampton
#   FP: May 17
# Sentence: May 18 v Worcestershire
#   FP: May 18 v
#   FN: Worcestershire
# Sentence: May 20 v Durham
#   FP: May 20
#   FN: Durham
# Sentence: May 22 First one-day international ( at Headingley ,
#   FP: May 22 First one-day
# Sentence: May 24 Second one-day international ( at The Oval ,
#   FP: May 24 Second
# Sentence: May 25 Third one-day international ( at Lord 's , London )
#   FP: May 25 Third one-day
#   FN: Lord 's
# Sentence: May 27-29 v Gloucestershire or Sussex or Surrey ( three
#   FP: May 27-29 v Gloucestershire
#   FP: three
#   FN: Gloucestershire
# Sentence: May 31 - June 2 v Derbyshire ( three days )
#   FP: May 31 - June 2 v Derbyshire
#   FP: three days
#   FN: Derbyshire
# Sentence: June 5-9 First test match ( at Edgbaston , Birmingham )
#   FP: First
#   FP: June 5-9
# Sentence: June 14-16 v Leicestershire ( three days )
#   FP: three days
#   FP: June 14-16
#   FN: Leicestershire
# Sentence: June 19-23 Second test ( at Lord 's )
#   FP: June 19-23
#   FP: Second
#   FN: Lord 's
# Sentence: June 25-27 v British Universities ( at Oxford , three days )
#   FP: June 25-27
#   FP: British
#   FP: three days
#   FN: British Universities
# Sentence: June 28-30 v Hampshire ( three days )
#   FP: June 28-30 v Hampshire
#   FP: three days
#   FN: Hampshire
# Sentence: July 3-7 Third test ( at Old Trafford , Manchester )
#   FP: July 3-7 Third
# Sentence: July 9 v Minor Counties XI
#   FP: July 9
#   FN: Minor Counties XI
# Sentence: July 12 v Scotland
#   FP: July 12
# Sentence: July 16-18 v Glamorgan ( three days )
#   FP: July 16-18
#   FP: three days
#   FN: Glamorgan
# Sentence: July 19-21 v Middlesex ( three days )
#   FP: July 19-21
#   FP: three days
#   FN: Middlesex
# Sentence: July 24-28 Fourth test ( at Headingley )
#   FP: July 24-28
#   FP: Fourth
# Sentence: August 1-4 v Somerset ( four days )
#   FP: August 1-4
#   FP: four days
#   FN: Somerset
# Sentence: August 7-11 Fifth test ( at Trent Bridge , Nottingham )
#   FP: August 7-11 Fifth
# Sentence: August 16-18 v Kent ( three days )
#   FP: August 16-18
#   FP: three days
#   FN: Kent
# Sentence: August 21-25 Sixth test ( at The Oval , London ) .
#   FP: Sixth
#   FP: August 21-25
# Sentence: SOCCER - SHEARER NAMED AS ENGLAND CAPTAIN .
#   FN: ENGLAND
#   FN: SHEARER
# Sentence: LONDON 1996-08-30
#   FP: 1996-08-30
# Sentence: The world 's costliest footballer Alan Shearer was named as the new England captain on Friday .
#   FP: Friday
# Sentence: The 26-year-old , who joined Newcastle for 15 million pounds sterling ( $ 23.4 million ) , takes over from Tony Adams , who led the side during the European championship in June , and former captain David Platt .
#   FP: $ 23.4 million
#   FP: June
#   FP: 15 million pounds
# Sentence: Adams and Platt are both injured and will miss England 's opening World Cup qualifier against Moldova on Sunday .
#   FP: Sunday
#   FN: Adams
# Sentence: " There were three or four people who could have done it but when I spoke to Alan he was up for it and really wanted it .
#   FP: four
#   FP: three
# Sentence: Shearer 's Euro 96 striking partner Teddy Sheringham withdrew from the squad with an injury on Friday .
#   FP: Friday
# Sentence: BELGRADE 1996-08-30
#   FP: 1996-08-30
#   FN: BELGRADE
# Sentence: SOCCER - ROMANIA BEAT LITHUANIA IN UNDER-21 MATCH .
#   FN: ROMANIA
#   FN: LITHUANIA
# Sentence: BUCHAREST 1996-08-30
#   FP: 1996-08-30
#   FN: BUCHAREST
# Sentence: Romania beat Lithuania 2-1 ( halftime 1-1 ) in their European under-21 soccer match on Friday .
#   FP: Friday
#   FP: 1-1
# Sentence: Romania - Cosmin Contra ( 31st ) , Mihai Tararache ( 75th )
#   FP: 75th
#   FP: Romania - Cosmin Contra
#   FN: Cosmin Contra
#   FN: Romania
# Sentence: Lithuania - Danius Gleveckas ( 13rd )
#   FN: Danius Gleveckas
# Sentence: SOCCER - ROTOR FANS LOCKED OUT AFTER VOLGOGRAD VIOLENCE .
#   FN: ROTOR
#   FN: VOLGOGRAD
# Sentence: MOSCOW 1996-08-30
#   FP: 1996-08-30
# Sentence: Rotor Volgograd must play their next home game behind closed doors after fans hurled bottles and stones at Dynamo Moscow players during a 1-0 home defeat on Saturday that ended Rotor 's brief spell as league leaders .
#   FP: Volgograd
#   FP: Saturday
#   FN: Rotor
#   FN: Rotor Volgograd
# Sentence: The head of the Russian league 's disciplinary committee , Anatoly Gorokhovsky , said on Friday that Rotor would play Lada Togliatti to empty stands on September 3 .
#   FP: Friday
#   FP: September 3
#   FP: the Russian league 's
#   FN: Rotor
#   FN: Russian
# Sentence: The club , who put Manchester United out of last year 's UEFA Cup , were fined $ 1,000 .
#   FP: 1,000
#   FP: last year 's
# Sentence: Despite the defeat , Rotor are well placed with 11 games to play in the championship .
#   FP: 11
#   FN: Rotor
# Sentence: Lying three points behind Alania and two behind Dynamo Moscow , the Volgograd side have a game in hand over the leaders and two over the Moscow club .
#   FP: two
#   FP: two
#   FP: three
# Sentence: BOXING - PANAMA 'S ROBERTO DURAN FIGHTS THE SANDS OF TIME .
#   FN: ROBERTO DURAN
#   FN: PANAMA
# Sentence: PANAMA CITY 1996-08-30
#   FP: PANAMA
#   FN: PANAMA CITY
# Sentence: Panamanian boxing legend Roberto " Hands of Stone " Duran climbs into the ring on Saturday in another age-defying attempt to sustain his long career .
#   FP: Saturday
# Sentence: Duran , 45 , takes on little-known Mexican Ariel Cruz , 30 , in a super middleweight non-title bout in Panama City .
#   FP: 45
#   FP: 30
# Sentence: The fight , Duran 's first on home soil for 10 years , is being billed here as the " Return of the Legend " and Duran still talks as if he was in his prime .
#   FP: first
#   FP: 10 years
#   FN: Return of the Legend
# Sentence: If he loses Saturday , it could devalue his position as one of the world 's great boxers , " Panamanian Boxing Association President Ramon Manzanares said .
#   FP: Saturday
#   FN: Panamanian
#   FN: Boxing Association
# Sentence: Duran , whose 97-12 record spans three decades , hopes a win in the 10-round bout will earn him a rematch against Puerto Rico 's Hector " Macho " Camacho .
#   FP: 97-12
#   FP: three decades
#   FP: Puerto Rico 's
#   FN: Puerto Rico
# Sentence: Camacho took a controversial points decision against the Panamanian in Atlantic City in June in a title fight .
#   FP: June
# Sentence: SQUASH - HONG KONG OPEN QUARTER-FINAL RESULTS .
#   FP: SQUASH - HONG KONG OPEN
#   FN: HONG KONG OPEN
# Sentence: HONG KONG 1996-08-30
#   FP: 1996-08-30
# Sentence: Quarter-final results in the Hong Kong Open on Friday ( prefix number denotes seeding ) : 1 - Jansher Khan ( Pakistan ) beat Mark Cairns ( England ) 15-10 15-6 15-7
#   FP: Friday
#   FP: the Hong Kong Open
#   FP: 1
#   FP: 15-10 15-6
#   FN: Jansher Khan
#   FN: Hong Kong Open
# Sentence: Anthony Hill ( Australia ) beat Dan Jenson ( Australia ) 15-9 15-8 15-17 17-15
#   FP: 15-9
# Sentence: 4 - Peter Nicol ( Scotland ) beat 7 - Chris Walker ( England ) 15-8 15-13 13-15 15-9
#   FP: 4 - Peter Nicol
#   FP: 7
#   FP: 15-8 15-13
#   FN: Peter Nicol
#   FN: Chris Walker
#   FN: England
# Sentence: 2 - Rodney Eyles ( Australia ) beat Derek Ryan ( Ireland ) 15-6 15-9 11-15 15-10 .
#   FP: 2 - Rodney Eyles
#   FP: 15-6 15-9 11-15 15-10
#   FN: Rodney Eyles
#   FN: Ireland
# Sentence: SEOUL 1996-08-30
#   FP: SEOUL 1996-08-30
#   FN: SEOUL
# Sentence: Pohang 3 Ulsan 2 ( halftime 1-0 )
#   FP: Pohang 3 Ulsan 2
#   FN: Pohang
#   FN: Ulsan
# Sentence: Puchon 2 Chonbuk 1 ( halftime 1-1 )
#   FP: 1-1
#   FP: 2
#   FN: Puchon
#   FN: Chonbuk
# Sentence: Puchon 3 1 0 6 1 10
#   FP: 3 1 0 6 1 10
#   FN: Puchon
# Sentence: Chonan 3 0 1 13 10 9
#   FP: 9
#   FN: Chonan
# Sentence: Pohang 2 1 1 11 10 7
#   FP: Pohang 2 1 1 11
#   FN: Pohang
# Sentence: Suwan 1 3 0 7 3 6
#   FN: Suwan
# Sentence: Ulsan 1 0 2 8 9 3
#   FN: Ulsan
# Sentence: Anyang 0 3 1 6 9 3
#   FP: 0 3 1 6 9 3
#   FN: Anyang
# Sentence: Pusan 0 2 1 3 7 2
#   FP: Pusan 0 2 1 3
#   FN: Pusan
# Sentence: Chonbuk 0 0 3 3 7 0
#   FP: 0
#   FN: Chonbuk
# Sentence: SEOUL 1996-08-30
#   FP: SEOUL 1996-08-30
#   FN: SEOUL
# Sentence: LG 2 OB 0
#   FP: 2
#   FN: OB
#   FN: LG
# Sentence: Lotte 6 Hyundai 2
#   FP: 2
#   FN: Lotte
# Sentence: Hyundai 6 Lotte 5
#   FP: 6 Lotte 5
#   FN: Lotte
# Sentence: Haitai 2 Samsung 0
#   FP: Haitai 2 Samsung 0
#   FN: Haitai
#   FN: Samsung
# Sentence: Samsung 10 Haitai 3
#   FP: 3
#   FN: Haitai
# Sentence: Hanwha 6 Ssangbangwool 5
#   FP: 5
#   FP: 6
#   FN: Ssangbangwool
#   FN: Hanwha
# Sentence: Note - Lotte and Hyundai , Haitai and Samsung played two games .
#   FP: two
#   FN: Lotte
# Sentence: Haitai 64 2 43 .596 -
#   FP: 64 2 43
#   FN: Haitai
# Sentence: Ssangbangwool 59 2 49 .545 5 1/2
#   FP: .545 5 1/2
#   FN: Ssangbangwool
# Sentence: Hanwha 58 1 49 .542 6
#   FP: 58
#   FP: 49
#   FP: 6
# Sentence: Hyundai 57 5 49 .536 6 1/2
#   FP: 5 49 .536 6 1/2
#   FP: 57
# Sentence: Samsung 49 5 56 .468 14
#   FP: 14
# Sentence: Lotte 46 6 54 .462 14 1/2
#   FP: 14 1/2
#   FN: Lotte
# Sentence: LG 46 5 59 .441 17
#   FP: 46
#   FP: 17
#   FN: LG
# Sentence: OB 42 6 62 .409 20 1/2
#   FP: 42
#   FP: 20 1/2
#   FN: OB
# Sentence: TENNIS - FRIDAY 'S RESULTS FROM THE U.S. OPEN .
#   FP: U.S.
#   FN: U.S. OPEN
# Sentence: NEW YORK 1996-08-30
#   FP: 1996-08-30
# Sentence: Results from the U.S. Open Tennis Championships at the National Tennis Centre on Friday ( prefix number denotes seeding ) :
#   FP: the U.S. Open Tennis Championships
#   FP: Friday
#   FP: the National Tennis Centre
#   FN: National Tennis Centre
#   FN: U.S. Open Tennis Championships
# Sentence: Sandrine Testud ( France ) beat Ines Gorrochategui ( Argentina ) 4-6 6-2 6-1
#   FP: 6-1
#   FP: 4-6
# Sentence: 4 - Goran Ivanisevic ( Croatia ) beat Scott Draper ( Australia ) 6-7 ( 1-7 ) 6-3 6-4 6-4
#   FP: 4
#   FP: Scott Draper ( Australia
#   FP: 6-3
#   FP: 6-7
#   FP: 1-7
#   FN: Scott Draper
#   FN: Australia
#   FN: Goran Ivanisevic
#   FN: Croatia
# Sentence: Tim Henman ( Britain ) beat Doug Flach ( U.S. ) 6-3 6-4 6-2
#   FP: 6-3
# Sentence: Mark Philippoussis ( Australia ) beat Andrei Olhovskiy ( Russia ) 6 - 3 6-4 6-2
#   FP: 6 - 3 6-4 6-2
# Sentence: Sjeng Schalken ( Netherlands ) beat David Rikl ( Czech Republic ) 6 - 2 6-4 6-4
#   FP: 6 - 2 6-4 6-4
# Sentence: Guy Forget ( France ) beat 17 - Felix Mantilla ( Spain ) 6-4 7-5 6-3
#   FP: 17
#   FP: 6-3
#   FP: 6-4 7-5
#   FN: Felix Mantilla
# Sentence: Alexander Volkov ( Russia ) beat Mikael Tillstrom ( Sweden ) 1-6 6- 4 6-1 4-6 7-6 ( 10-8 )
#   FP: 1-6
#   FP: 10-8
# Sentence: Jonas Bjorkman ( Sweden ) beat David Nainkin ( South Africa ) ) 6-4 6-1 6-1
#   FP: 6-4
# Sentence: 8 - Lindsay Davenport ( U.S. ) beat Anne-Gaelle Sidot ( France ) 6-0 6-3
#   FP: 6-0 6-3
#   FP: Sidot
#   FP: 8
#   FN: Lindsay Davenport
#   FN: Anne-Gaelle Sidot
# Sentence: 4 - Conchita Martinez ( Spain ) beat Helena Sukova ( Czech Republic ) 6-4 6-3
#   FP: 6-4 6-3
#   FP: 4
#   FN: Conchita Martinez
# Sentence: Amanda Coetzer ( South Africa ) beat Irina Spirlea ( Romania ) 7-6 ( 7-5 ) 7-5
#   FP: 7-5
# Sentence: Add Men 's singles , second round 16 - Cedric Pioline ( France ) beat Roberto Carretero ( Spain ) 4-6 6 - 2 6-2 6-1 Alex Corretja ( Spain ) beat Filippo Veglio ( Switzerland ) 6-7 ( 4- 7 ) 6-4 6-4 6-0
#   FP: 4-6
#   FP: 16
#   FP: second
#   FP: 6-7
#   FP: 7
#   FN: Cedric Pioline
# Sentence: Add Women 's singles , third round Linda Wild ( U.S. ) beat Barbara Rittner ( Germany ) 6-4 4-6 7-5 Asa Carlsson ( Sweden ) beat 15 - Gabriela Sabatini ( Argentina ) 7-5 3-6 6-2
#   FP: 3-6
#   FP: 6-2
#   FP: third
#   FP: 15 - Gabriela Sabatini
#   FP: 6-4 4-6
#   FP: 7-5 Asa Carlsson
#   FN: Gabriela Sabatini
#   FN: Asa Carlsson
# Sentence: Add Men 's singles , second round 1 - Pete Sampras ( U.S. ) beat Jiri Novak ( Czech Republic ) 6-3 1-6 6-3 4-6 6-4 Paul Haarhuis ( Netherlands ) beat Michael Tebbutt ( Australia ) 1- 6 6-2 6-2 6-3
#   FP: 1 - Pete Sampras
#   FP: 1-6 6-3 4-6
#   FP: second
#   FP: 6 6-2
#   FP: 6-2 6-3
#   FP: 6-3
#   FN: Pete Sampras
# Sentence: Add Women 's singles , third round Lisa Raymond ( U.S. ) beat Kimberly Po ( U.S. ) 6-3 6-2
#   FP: third
#   FP: 6-3
# Sentence: Andrei Medvedev ( Ukraine ) beat Jan Kroslak ( Slovakia ) 6-4 6-3
#   FP: 6-4 6-3
# Sentence: Petr Korda ( Czech Republic ) bat Bohdan Ulihrach ( Czech Republic ) 6-0 7-6 ( 7-5 ) 6-2
#   FP: 6-2
#   FN: Petr Korda
# Sentence: 2 - Monica Seles ( U.S. ) beat Dally Randriantefy ( Madagascar )
#   FP: 2
#   FP: Dally Randriantefy ( Madagascar
#   FN: Monica Seles
#   FN: Dally Randriantefy
#   FN: Madagascar
# Sentence: Add men 's singles , second round 12 - Todd Martin ( U.S. ) beat Andrea Gaudenzi ( Italy ) 6-3 6-2 6-2 Stefan Edberg ( Sweden ) beat Bernd Karbacher ( Germany ) 3-6 6-3 6-3 1-0 retired ( leg injury )
#   FP: 6-3
#   FP: 6-3
#   FP: second
#   FP: 3-6
#   FP: 12
# Sentence: BASEBALL - MAJOR LEAGUE STANDINGS AFTER THURSDAY 'S GAMES .
#   FN: MAJOR LEAGUE
# Sentence: NEW YORK 1996-08-30
#   FP: 1996-08-30
# Sentence: AMERICAN LEAGUE EASTERN DIVISION
#   FP: AMERICAN LEAGUE EASTERN
#   FN: AMERICAN LEAGUE EASTERN DIVISION
# Sentence: NEW YORK 74 59 .556 -
#   FP: 74 59
# Sentence: BALTIMORE 70 63 .526 4
#   FP: 4
#   FP: BALTIMORE 70 63
#   FN: BALTIMORE
# Sentence: BOSTON 69 65 .515 5 1/2
#   FP: 5 1/2
#   FP: BOSTON 69 65
#   FN: BOSTON
# Sentence: TORONTO 63 71 .470 11 1/2
#   FP: 11 1/2
#   FP: 63 71
# Sentence: DETROIT 48 86 .358 26 1/2
#   FP: 26 1/2
#   FP: 48 86
# Sentence: CENTRAL DIVISION
#   FN: CENTRAL DIVISION
# Sentence: CLEVELAND 80 53 .602 -
#   FP: .602
#   FP: CLEVELAND 80 53
#   FN: CLEVELAND
# Sentence: CHICAGO 71 64 .526 10
#   FP: 10
#   FN: CHICAGO
# Sentence: MINNESOTA 67 67 .500 13 1/2
#   FP: 67 67
#   FP: 13 1/2
#   FN: MINNESOTA
# Sentence: MILWAUKEE 64 71 .474 17
#   FP: 17
#   FP: 64 71
#   FN: MILWAUKEE
# Sentence: KANSAS CITY 61 74 .452 20
#   FP: 20
# Sentence: WESTERN DIVISION
#   FN: WESTERN DIVISION
# Sentence: TEXAS 75 58 .564 -
#   FP: 75 58
# Sentence: SEATTLE 70 63 .526 5
#   FP: 5
#   FP: 70 63
# Sentence: OAKLAND 64 72 .471 12 1/2
#   FP: .471
#   FP: OAKLAND 64 72
#   FP: 12 1/2
#   FN: OAKLAND
# Sentence: CALIFORNIA 62 72 .463 13 1/2
#   FP: 13 1/2
#   FP: CALIFORNIA 62 72
#   FN: CALIFORNIA
# Sentence: CHICAGO AT TORONTO
#   FN: CHICAGO
# Sentence: MINNESOTA AT MILWAUKEE
#   FN: MINNESOTA
#   FN: MILWAUKEE
# Sentence: CLEVELAND AT TEXAS
#   FP: CLEVELAND AT
#   FN: TEXAS
#   FN: CLEVELAND
# Sentence: NATIONAL LEAGUE EASTERN DIVISION
#   FP: NATIONAL LEAGUE EASTERN
#   FN: NATIONAL LEAGUE EASTERN DIVISION
# Sentence: ATLANTA 83 49 .629 -
#   FP: 83
# Sentence: MONTREAL 71 61 .538 12
#   FP: 71 61
#   FP: 12
#   FN: MONTREAL
# Sentence: FLORIDA 64 70 .478 20
#   FP: 20
#   FP: 64 70
# Sentence: NEW YORK 59 75 .440 25
#   FP: 25
#   FP: 59 75
# Sentence: PHILADELPHIA 54 80 .403 30
#   FP: 30
# Sentence: CENTRAL DIVISION
#   FN: CENTRAL DIVISION
# Sentence: HOUSTON 72 63 .533 -
#   FP: HOUSTON 72 63
#   FP: .533 -
#   FN: HOUSTON
# Sentence: ST LOUIS 69 65 .515 2 1/2
#   FP: 2 1/2
# Sentence: CINCINNATI 66 67 .496 5
#   FP: 66 67
#   FP: 5
# Sentence: CHICAGO 65 66 .496 5
#   FP: 65 66 .496 5
#   FN: CHICAGO
# Sentence: PITTSBURGH 56 77 .421 15
#   FP: 56 77
#   FP: 15
# Sentence: WESTERN DIVISION
#   FN: WESTERN DIVISION
# Sentence: SAN DIEGO 75 60 .556 -
#   FP: 75 60
#   FP: SAN
#   FN: SAN DIEGO
# Sentence: LOS ANGELES 72 61 .541 2
#   FP: 2
# Sentence: COLORADO 70 65 .519 5
#   FP: 5
#   FP: 70 65
# Sentence: SAN FRANCISCO 57 74 .435 16
#   FP: 16
#   FP: 57 74
# Sentence: SAN DIEGO AT MONTREAL
#   FP: SAN
#   FN: MONTREAL
#   FN: SAN DIEGO
# Sentence: HOUSTON AT PITTSBURGH
#   FN: PITTSBURGH
# Sentence: SAN FRANCISCO AT NEW YORK
#   FN: NEW YORK
# Sentence: BASEBALL - MAJOR LEAGUE RESULTS THURSDAY .
#   FN: MAJOR LEAGUE
# Sentence: NEW YORK 1996-08-30
#   FP: 1996-08-30
# Sentence: DETROIT 4 Kansas City 1
#   FP: 4
#   FP: Kansas
#   FN: Kansas City
# Sentence: Minnesota 6 MILWAUKEE 1
#   FP: 6
#   FP: 1
#   FN: MILWAUKEE
# Sentence: CALIFORNIA 14 New York 3
#   FP: 3
#   FP: 14
# Sentence: SEATTLE 9 Baltimore 6
#   FP: 9
#   FP: 6
# Sentence: San Diego 3 NEW YORK 2
#   FP: 2
#   FP: 3
# Sentence: Chicago 4 HOUSTON 3
#   FP: 3
#   FP: 4
#   FN: HOUSTON
# Sentence: Cincinnati 18 COLORADO 7
#   FP: 7
#   FP: 18
#   FN: COLORADO
# Sentence: Atlanta 5 PITTSBURGH 1
#   FP: 5
#   FP: 1
#   FN: PITTSBURGH
# Sentence: Los Angeles 2 MONTREAL 1
#   FP: 1
#   FP: Los Angeles 2
#   FN: MONTREAL
#   FN: Los Angeles
# Sentence: Florida 10 ST LOUIS 9
#   FP: ST LOUIS 9
#   FP: 10
#   FN: ST LOUIS
# Sentence: TENNIS - TARANGO , O'BRIEN SPRING TWIN UPSETS UNDER THE LIGHTS .
#   FP: SPRING TWIN UPSETS
#   FN: O'BRIEN
#   FN: TARANGO
# Sentence: NEW YORK 1996-08-30
#   FP: 1996-08-30
# Sentence: Andre Agassi escaped disaster on Thursday but Wimbledon finalist MaliVai Washington and Marcelo Rios were not so fortunate on a night of upsets at the U.S. Open .
#   FP: the U.S. Open
#   FP: Thursday
#   FP: Washington
#   FP: MaliVai
#   FP: a night
#   FN: U.S. Open
#   FN: MaliVai Washington
# Sentence: The 11th-seeded Washington fell short of reprising his Wimbledon miracle comeback as he lost to red-hot wildcard Alex O'Brien 6-3 6-4 5-7 3-6 6-3 in a two hour 51 minute struggle on the Stadium court .
#   FP: 6-4 5-7 3-6
#   FP: 11th-seeded
#   FP: a two hour 51 minute

# %% [markdown]
# *TODO: Write a short text that summarises the errors that you observed*

# %% [markdown]
# ----My Answer:
#
# ----The main reason for the error of low precission is the influence of numbers, such as: date, time, percentage, ordinal number, number, etc.
#
# ----a FP(False Positives) is an error in binary classification in which a test result incorrectly indicates the presence of a condition, and in almost every sentence, there are FPs related to numbers or dates, so we think this is the main reason for the error.

# %% [markdown]
# Now, use the insights from your error analysis to improve the automated prediction that you implemented in Problem&nbsp;2. While the best way to do this would be to [update spaCy&rsquo;s NER model](https://spacy.io/usage/linguistic-features#updating) using domain-specific training data, for this lab it suffices to write code to post-process the output produced by spaCy. To filter out specific labels it is useful to know the named entity label scheme, which can be found in the [model's documentation](https://spacy.io/models/en#en_core_web_sm). You should be able to improve the F1 score from Problem&nbsp;2 by at last 15 percentage points.

# %% [markdown]
# ----My Answer:
#
# ----from models documentation: https://spacy.io/models/en#en_core_web_sm
#
# --> en_core_web_sm --> Label Scheme --> NER(named entity labels), we could find the:
#
# ----original types:
#
# ['CARDINAL', 'DATE', 'EVENT', 'FAC', 'GPE', 'LANGUAGE', 'LAW', 'LOC', 'MONEY', 'NORP', 'ORDINAL', 'ORG', 'PERCENT', 'PERSON', 'PRODUCT', 'QUANTITY', 'TIME', 'WORK_OF_ART']
#
# ----number related types:
#
# ['CARDINAL', 'DATE', 'MONEY', 'ORDINAL', 'PERCENT', 'QUANTITY', 'TIME'  ]
#
# ----so, we remove these number related types.

# %%
# TODO: Write code here to run and evaluate the spaCy named entity recognizer on the development data
def improved_spaCy_predict(df):
    for row in df.itertuples():
        doc = nlp(row.sentence)
        for ent in doc.ents:
            # here we remove these numbers or date related named entity labels.
            if ent.label_ not in ['CARDINAL', 'DATE', 'MONEY', 'ORDINAL', 'PERCENT', 'QUANTITY', 'TIME']:
                yield row.sentence_id, ent.start, ent.end

# after remove these named entity labels
# we got improved_spaCy_predictions, and compare it with gold standard

improved_spaCy_predictions = set(improved_spaCy_predict(df_dev))
evaluation_report(gold = spans_dev_gold, pred = improved_spaCy_predictions)
# Out:
# precission:  0.847284605961617 , recall:  0.701368936961298 , F1_score:  0.7674526121128065

# %%
#  improved_spaCy_predictions' F1_score minus F1_score from Problem 2

0.7674526121128065 - 0.5984444764511019
# Out:
# 0.16900813566170458

# %% [markdown]
# ----My Answer:
#
# ----As we can see, after removing these numbers or date related named entirty labels, we improved approximately 16.9% F1_score.

# %% [markdown]
# Show that you achieve the performance goal by reporting the evaluation measures that you implemented in Problem&nbsp;1.

# %% [markdown]
# Before going on, we ask you to store the outputs of the improved named entity recognizer on the development data in a new data frame. This new frame should have the same layout as the original data frame for the development data that you loaded above, but should contain the *predicted* start and end positions for each token span, rather than the gold positions. As the `label` of each span, you can use the special value `--NME--`.

# %%
# layout of old development data
df_dev.head()
# Out:
#   sentence_id                                           sentence  beg  end  \
# 0    0946-000  CRICKET - LEICESTERSHIRE TAKE OVER AT TOP AFTE...    2    3
# 1    0946-001                                  LONDON 1996-08-30    0    1
# 2    0946-002  West Indian all-rounder Phil Simmons took four...    0    2
# 3    0946-002  West Indian all-rounder Phil Simmons took four...    3    5
# 4    0946-002  West Indian all-rounder Phil Simmons took four...   12   13
#
#                                 label
# 0  Leicestershire_County_Cricket_Club
# 1                              London
# 2            West_Indies_cricket_team
# 3                        Phil_Simmons
# 4  Leicestershire_County_Cricket_Club

# %%
# we look at the improved_spaCy_predictions
improved_spaCy_predictions
# Out:
# {('0969-003', 5, 6),
#  ('0957-026', 0, 2),
#  ('0946-014', 9, 11),
#  ('1011-022', 15, 16),
#  ('0957-030', 5, 6),
#  ('0966-082', 1, 3),
#  ('1024-001', 0, 1),
#  ('1086-002', 0, 1),
#  ('1089-001', 2, 3),
#  ('1155-012', 15, 17),
#  ('0990-003', 1, 2),
#  ('1033-006', 3, 4),
#  ('0962-005', 4, 5),
#  ('1038-002', 4, 6),
#  ('1000-000', 3, 4),
#  ('1137-001', 0, 2),
#  ('0981-004', 0, 1),
#  ('0954-002', 21, 22),
#  ('1084-003', 2, 4),
#  ('1090-007', 28, 29),
#  ('1096-030', 0, 1),
#  ('1124-006', 0, 1),
#  ('0970-002', 1, 2),
#  ('1012-007', 5, 8),
#  ('1069-013', 9, 12),
#  ('0972-028', 4, 6),
#  ('0984-021', 6, 9),
#  ('1052-002', 15, 16),
#  ('1135-027', 6, 7),
#  ('0965-013', 23, 24),
#  ('0984-012', 5, 7),
#  ('1112-004', 21, 22),
#  ('1137-000', 0, 2),
#  ('1046-007', 25, 27),
#  ('1031-008', 15, 16),
#  ('0991-010', 9, 10),
#  ('1062-003', 2, 4),
#  ('1056-006', 4, 5),
#  ('1036-002', 2, 3),
#  ('1081-002', 4, 5),
#  ('1116-014', 10, 13),
#  ('0957-010', 3, 4),
#  ('1097-001', 0, 2),
#  ('1127-000', 0, 1),
#  ('0956-018', 0, 1),
#  ('1133-011', 6, 7),
#  ('1156-003', 33, 35),
#  ('0967-002', 18, 19),
#  ('1015-003', 42, 43),
#  ('1033-007', 15, 16),
#  ('1058-011', 23, 26),
#  ('1069-003', 1, 2),
#  ('1097-015', 0, 1),
#  ('1100-000', 0, 7),
#  ('1103-007', 1, 2),
#  ('1009-000', 5, 6),
#  ('1112-008', 16, 17),
#  ('1128-009', 0, 2),
#  ('1015-003', 24, 25),
#  ('1150-003', 3, 4),
#  ('0958-005', 0, 3),
#  ('1116-010', 2, 3),
#  ('1056-044', 0, 2),
#  ('1132-003', 0, 2),
#  ('1096-006', 1, 2),
#  ('1022-015', 1, 2),
#  ('1121-007', 32, 33),
#  ('1030-031', 0, 2),
#  ('0960-004', 17, 19),
#  ('1156-003', 25, 30),
#  ('1103-003', 0, 1),
#  ('0953-003', 7, 8),
#  ('1034-003', 34, 36),
#  ('0965-001', 0, 2),
#  ('0966-095', 4, 5),
#  ('1064-005', 5, 6),
#  ('1066-029', 0, 4),
#  ('1024-008', 2, 7),
#  ('1117-003', 24, 25),
#  ('1096-031', 25, 29),
#  ('1064-007', 47, 48),
#  ('1125-003', 0, 9),
#  ('1000-015', 36, 37),
#  ('1036-017', 9, 10),
#  ('1064-006', 3, 5),
#  ('1031-011', 10, 11),
#  ('1144-004', 25, 26),
#  ('1051-009', 18, 19),
#  ('1059-002', 2, 3),
#  ('1109-002', 1, 2),
#  ('1025-002', 0, 1),
#  ('0966-137', 1, 4),
#  ('1092-002', 15, 18),
#  ('0971-002', 0, 2),
#  ('1056-021', 4, 5),
#  ('1159-003', 19, 20),
#  ('1056-017', 11, 13),
#  ('1091-003', 17, 18),
#  ('1097-003', 18, 19),
#  ('1069-017', 1, 3),
#  ('1058-012', 0, 2),
#  ('1027-004', 1, 2),
#  ('1027-016', 12, 13),
#  ('1055-005', 0, 2),
#  ('1116-033', 8, 9),
#  ('1155-010', 31, 32),
#  ('1119-008', 14, 16),
#  ('0966-083', 1, 3),
#  ('0966-045', 1, 3),
#  ('1058-030', 0, 2),
#  ('0958-030', 2, 3),
#  ('0988-002', 2, 6),
#  ('0957-012', 9, 10),
#  ('0946-004', 14, 15),
#  ('1126-005', 16, 17),
#  ('1006-007', 1, 2),
#  ('0966-164', 4, 5),
#  ('1146-002', 5, 7),
#  ('1160-002', 2, 3),
#  ('0959-005', 0, 1),
#  ('1055-025', 3, 5),
#  ('1108-003', 0, 1),
#  ('1066-010', 0, 1),
#  ('1089-026', 9, 14),
#  ('1025-005', 2, 4),
#  ('0946-002', 14, 15),
#  ('0952-002', 1, 2),
#  ('1136-002', 0, 4),
#  ('1000-009', 20, 21),
#  ('1086-003', 2, 4),
#  ('0963-002', 26, 28),
#  ('1150-006', 12, 16),
#  ('0946-007', 5, 6),
#  ('1057-002', 0, 1),
#  ('1092-007', 0, 1),
#  ('0946-013', 24, 25),
#  ('1057-004', 0, 1),
#  ('1123-000', 2, 4),
#  ('0966-163', 4, 6),
#  ('0988-005', 17, 19),
#  ('0961-008', 24, 25),
#  ('0983-007', 18, 19),
#  ('1033-010', 6, 7),
#  ('1039-018', 21, 23),
#  ('0978-004', 0, 2),
#  ('1012-006', 22, 23),
#  ('1043-001', 0, 1),
#  ('1046-010', 11, 12),
#  ('1076-014', 0, 1),
#  ('1094-054', 0, 2),
#  ('1049-004', 5, 6),
#  ('1156-002', 9, 10),
#  ('1011-010', 10, 11),
#  ('0984-009', 9, 10),
#  ('1035-009', 31, 32),
#  ('1135-003', 4, 6),
#  ('1081-002', 10, 11),
#  ('1152-011', 18, 19),
#  ('1017-011', 2, 3),
#  ('0959-002', 2, 4),
#  ('0954-005', 5, 6),
#  ('1111-006', 1, 2),
#  ('1025-011', 2, 3),
#  ('1076-021', 0, 1),
#  ('0970-002', 9, 10),
#  ('1128-003', 17, 18),
#  ('0965-011', 31, 32),
#  ('1097-004', 21, 22),
#  ('1128-015', 1, 3),
#  ('0966-131', 4, 5),
#  ('0995-019', 20, 21),
#  ('1137-003', 36, 37),
#  ('0966-072', 1, 3),
#  ('1068-002', 2, 3),
#  ('0957-024', 6, 8),
#  ('1099-004', 4, 6),
#  ('1045-003', 29, 30),
#  ('0980-014', 3, 5),
#  ('0966-035', 1, 3),
#  ('1030-032', 15, 16),
#  ('1077-000', 5, 9),
#  ('0966-139', 1, 3),
#  ('0960-040', 7, 8),
#  ('1057-007', 14, 15),
#  ('0957-020', 7, 11),
#  ('0977-013', 1, 2),
#  ('1019-009', 0, 1),
#  ('1160-015', 3, 5),
#  ('1014-009', 21, 22),
#  ('1012-004', 17, 18),
#  ('1152-014', 46, 47),
#  ('1025-011', 36, 37),
#  ('1099-018', 34, 36),
#  ('1103-004', 0, 1),
#  ('1122-003', 5, 9),
#  ('1133-003', 13, 14),
#  ('1094-029', 2, 3),
#  ('1031-010', 10, 11),
#  ('0958-024', 3, 4),
#  ('0963-003', 18, 20),
#  ('1066-065', 0, 1),
#  ('1069-015', 11, 12),
#  ('1000-001', 0, 2),
#  ('1159-007', 28, 29),
#  ('1143-008', 12, 13),
#  ('1031-006', 7, 8),
#  ('1152-000', 0, 1),
#  ('1135-025', 11, 12),
#  ('1155-011', 15, 16),
#  ('1051-010', 35, 36),
#  ('1031-014', 28, 29),
#  ('1057-006', 11, 13),
#  ('1142-013', 12, 14),
#  ('0973-002', 0, 1),
#  ('0986-006', 2, 3),
#  ('1009-004', 20, 22),
#  ('0990-014', 0, 1),
#  ('1103-017', 0, 1),
#  ('1141-008', 0, 1),
#  ('1115-008', 30, 31),
#  ('1090-010', 4, 5),
#  ('1148-009', 12, 14),
#  ('0992-000', 1, 2),
#  ('1044-007', 22, 23),
#  ('0985-007', 6, 7),
#  ('1066-046', 0, 1),
#  ('1072-001', 0, 2),
#  ('1089-011', 0, 1),
#  ('1094-050', 0, 1),
#  ('0966-161', 7, 9),
#  ('1056-034', 11, 13),
#  ('0966-077', 4, 5),
#  ('0948-038', 3, 4),
#  ('0958-020', 0, 1),
#  ('1091-001', 0, 2),
#  ('1031-014', 32, 35),
#  ('0966-164', 10, 11),
#  ('1101-003', 16, 18),
#  ('1090-014', 0, 1),
#  ('1008-027', 0, 5),
#  ('1091-003', 45, 47),
#  ('1120-007', 7, 8),
#  ('1138-003', 17, 18),
#  ('1152-000', 5, 6),
#  ('1133-007', 4, 5),
#  ('1160-016', 9, 10),
#  ('1158-000', 5, 6),
#  ('0966-149', 1, 3),
#  ('1137-008', 32, 35),
#  ('1082-002', 2, 3),
#  ('1035-004', 14, 15),
#  ('1048-001', 2, 3),
#  ('1087-004', 17, 18),
#  ('1143-004', 25, 26),
#  ('1045-008', 28, 29),
#  ('1094-035', 0, 1),
#  ('1125-002', 15, 16),
#  ('1000-011', 13, 14),
#  ('1155-002', 24, 25),
#  ('1152-010', 1, 2),
#  ('1069-010', 11, 14),
#  ('0966-112', 1, 3),
#  ('1086-003', 9, 11),
#  ('1091-004', 11, 12),
#  ('0957-008', 3, 4),
#  ('0966-110', 1, 3),
#  ('0985-004', 10, 11),
#  ('1136-000', 3, 4),
#  ('0988-006', 1, 2),
#  ('0946-004', 11, 13),
#  ('1155-003', 18, 19),
#  ('1054-005', 4, 5),
#  ('1033-003', 28, 29),
#  ('1091-002', 2, 7),
#  ('0948-009', 6, 8),
#  ('0957-015', 5, 6),
#  ('0959-013', 0, 1),
#  ('0984-006', 33, 34),
#  ('1116-006', 16, 18),
#  ('1084-001', 0, 1),
#  ('1038-007', 8, 10),
#  ('0968-004', 33, 34),
#  ('1067-014', 0, 4),
#  ('1039-014', 19, 20),
#  ('1040-009', 0, 5),
#  ('1089-006', 16, 17),
#  ('1056-011', 1, 3),
#  ('1103-006', 14, 15),
#  ('1116-008', 10, 11),
#  ('1150-005', 24, 28),
#  ('1030-004', 3, 4),
#  ('0966-081', 4, 5),
#  ('1010-002', 0, 1),
#  ('1014-004', 31, 32),
#  ('0949-001', 0, 1),
#  ('1130-006', 3, 8),
#  ('0970-002', 4, 6),
#  ('1142-005', 24, 25),
#  ('1125-012', 9, 10),
#  ('0983-002', 5, 6),
#  ('0972-020', 5, 8),
#  ('0982-002', 21, 22),
#  ('1058-013', 3, 5),
#  ('1160-007', 6, 7),
#  ('1121-007', 1, 3),
#  ('1072-009', 11, 13),
#  ('1069-002', 6, 7),
#  ('1115-003', 33, 36),
#  ('1120-006', 17, 18),
#  ('1121-002', 1, 2),
#  ('1127-014', 29, 30),
#  ('1136-007', 13, 14),
#  ('1060-017', 4, 5),
#  ('1095-006', 0, 1),
#  ('0966-036', 1, 3),
#  ('1027-009', 25, 26),
#  ('1064-004', 0, 1),
#  ('1128-013', 7, 8),
#  ('1056-043', 11, 13),
#  ('1137-000', 3, 5),
#  ('1014-002', 8, 9),
#  ('1135-008', 26, 28),
#  ('0957-028', 10, 12),
#  ('1142-006', 20, 21),
#  ('1099-011', 0, 3),
#  ('1112-008', 18, 19),
#  ('1140-005', 9, 10),
#  ('0952-003', 10, 12),
#  ('0999-002', 29, 30),
#  ('1059-006', 24, 25),
#  ('1140-003', 15, 18),
#  ('1016-015', 8, 9),
#  ('1027-007', 32, 35),
#  ('0962-011', 0, 2),
#  ('1054-004', 3, 4),
#  ('1058-036', 26, 27),
#  ('1096-006', 3, 4),
#  ('0997-004', 27, 28),
#  ('0948-006', 0, 1),
#  ('1148-003', 0, 1),
#  ('1103-007', 36, 37),
#  ('1057-007', 11, 13),
#  ('1127-026', 3, 4),
#  ('1008-023', 14, 16),
#  ('1132-000', 0, 1),
#  ('0984-003', 16, 17),
#  ('1067-013', 0, 4),
#  ('0960-015', 29, 30),
#  ('1044-004', 11, 12),
#  ('0957-018', 15, 17),
#  ('1096-036', 1, 3),
#  ('1154-008', 33, 34),
#  ('1022-009', 4, 5),
#  ('0981-006', 8, 9),
#  ('1022-017', 10, 11),
#  ('0985-007', 1, 3),
#  ('1056-020', 4, 5),
#  ('1121-003', 36, 37),
#  ('0955-016', 0, 5),
#  ('1056-046', 7, 9),
#  ('0974-007', 20, 22),
#  ('0992-007', 29, 30),
#  ('1010-021', 21, 22),
#  ('1051-008', 14, 15),
#  ('1157-004', 6, 7),
#  ('1056-034', 24, 26),
#  ('1124-009', 30, 31),
#  ('1066-025', 0, 1),
#  ('0982-000', 5, 6),
#  ('0986-004', 0, 2),
#  ('1045-004', 32, 33),
#  ('1038-003', 40, 41),
#  ('1056-045', 1, 2),
#  ('1090-004', 12, 13),
#  ('1017-003', 10, 11),
#  ('1090-003', 11, 14),
#  ('0947-002', 7, 9),
#  ('1066-031', 0, 1),
#  ('1094-028', 0, 2),
#  ('1096-023', 7, 8),
#  ('1006-005', 21, 22),
#  ('1152-004', 12, 14),
#  ('1058-003', 6, 8),
#  ('1011-008', 14, 16),
#  ('0957-015', 11, 12),
#  ('1142-002', 16, 17),
#  ('0947-008', 9, 11),
#  ('0957-009', 0, 2),
#  ('0959-005', 2, 3),
#  ('1119-000', 5, 6),
#  ('1155-003', 13, 15),
#  ('0959-010', 0, 2),
#  ('0984-016', 0, 1),
#  ('1011-007', 4, 7),
#  ('1120-009', 1, 2),
#  ('1126-009', 7, 8),
#  ('1099-008', 9, 11),
#  ('1058-040', 28, 31),
#  ('1012-006', 24, 26),
#  ('0966-015', 4, 5),
#  ('1033-013', 12, 13),
#  ('1058-027', 19, 21),
#  ('1076-035', 0, 1),
#  ('1130-006', 17, 18),
#  ('0994-005', 18, 19),
#  ('1143-003', 16, 17),
#  ('1156-002', 11, 13),
#  ('1133-014', 2, 3),
#  ('1017-006', 5, 6),
#  ('1058-023', 2, 3),
#  ('0947-012', 21, 24),
#  ('0957-008', 0, 2),
#  ('0972-023', 0, 2),
#  ('0998-001', 2, 3),
#  ('1000-006', 18, 19),
#  ('0946-008', 3, 4),
#  ('1039-014', 15, 17),
#  ('0966-050', 4, 5),
#  ('1077-002', 20, 23),
#  ('1105-003', 0, 1),
#  ('1086-002', 10, 11),
#  ('0966-145', 4, 5),
#  ('1091-000', 7, 8),
#  ('1056-047', 12, 13),
#  ('0966-108', 1, 3),
#  ('1012-008', 0, 3),
#  ('0982-005', 4, 6),
#  ('1046-009', 34, 35),
#  ('1133-011', 0, 1),
#  ('1036-027', 10, 11),
#  ('1027-007', 2, 3),
#  ('1009-005', 18, 19),
#  ('1097-011', 0, 1),
#  ('1128-003', 37, 38),
#  ('1046-007', 2, 4),
#  ('0966-150', 4, 5),
#  ('1120-006', 12, 14),
#  ('1121-007', 7, 8),
#  ('1062-003', 11, 13),
#  ('1074-004', 10, 11),
#  ('0957-010', 0, 2),
#  ('0995-001', 0, 2),
#  ('1130-005', 45, 49),
#  ('0951-005', 0, 1),
#  ('0966-101', 1, 3),
#  ('0947-012', 14, 20),
#  ('1101-004', 31, 32),
#  ('1137-004', 2, 3),
#  ('0981-000', 0, 3),
#  ('1034-007', 1, 4),
#  ('1031-011', 3, 4),
#  ('1058-025', 12, 13),
#  ('1067-017', 0, 4),
#  ('1009-000', 0, 1),
#  ('1022-000', 0, 1),
#  ('0962-011', 6, 8),
#  ('0966-073', 1, 3),
#  ('0986-002', 3, 5),
#  ('1030-032', 17, 18),
#  ('1053-002', 2, 3),
#  ('1122-001', 0, 1),
#  ('1134-002', 7, 8),
#  ('1036-000', 3, 4),
#  ('0966-137', 5, 6),
#  ('0948-036', 6, 8),
#  ('1020-008', 1, 3),
#  ('1123-004', 2, 3),
#  ('0981-017', 5, 6),
#  ('1135-008', 22, 25),
#  ('1048-000', 6, 7),
#  ('1068-032', 0, 1),
#  ('1101-001', 0, 1),
#  ('0958-021', 0, 3),
#  ('1139-004', 4, 5),
#  ('1107-002', 2, 3),
#  ('1133-013', 0, 1),
#  ('0991-001', 0, 1),
#  ('1051-009', 1, 3),
#  ('1099-018', 37, 39),
#  ('1121-000', 3, 4),
#  ('1135-018', 0, 2),
#  ('1029-017', 3, 7),
#  ('1051-009', 45, 46),
#  ('1142-006', 16, 17),
#  ('1038-003', 46, 47),
#  ('0972-036', 9, 10),
#  ('1055-022', 3, 4),
#  ('1055-004', 3, 5),
#  ('1027-002', 2, 4),
#  ('1066-017', 0, 2),
#  ('1120-005', 17, 18),
#  ('1011-019', 1, 2),
#  ('1152-017', 3, 4),
#  ('1155-010', 7, 8),
#  ('0966-102', 4, 5),
#  ('0974-000', 0, 5),
#  ('1044-007', 24, 25),
#  ('1149-005', 46, 48),
#  ('1027-006', 12, 13),
#  ('1128-006', 34, 35),
#  ('0972-037', 3, 5),
#  ('1116-009', 6, 7),
#  ('1135-006', 18, 21),
#  ('1154-003', 29, 30),
#  ('0969-002', 3, 5),
#  ('1055-012', 0, 2),
#  ('1070-014', 1, 3),
#  ('1056-016', 20, 21),
#  ('1095-020', 3, 4),
#  ('1128-006', 23, 25),
#  ('1145-003', 7, 8),
#  ('1096-023', 2, 4),
#  ('1101-003', 37, 39),
#  ('0995-010', 21, 22),
#  ('1034-002', 1, 2),
#  ('1037-002', 25, 26),
#  ('1070-013', 8, 10),
#  ('0994-004', 4, 5),
#  ('1155-015', 12, 13),
#  ('1072-019', 59, 61),
#  ('1127-013', 0, 2),
#  ('1148-004', 0, 1),
#  ('1058-014', 9, 12),
#  ('1045-006', 29, 34),
#  ('1045-007', 21, 22),
#  ('1034-002', 34, 35),
#  ('1008-018', 4, 6),
#  ('1101-002', 0, 2),
#  ('1065-012', 0, 1),
#  ('1155-014', 5, 6),
#  ('0984-013', 6, 11),
#  ('1022-010', 10, 11),
#  ('1156-004', 14, 16),
#  ('0958-050', 2, 3),
#  ('0994-017', 13, 15),
#  ('1039-014', 21, 23),
#  ('1116-034', 0, 1),
#  ('0980-005', 21, 22),
#  ('1056-012', 4, 5),
#  ('1131-002', 20, 22),
#  ('1006-009', 20, 23),
#  ('1116-008', 0, 3),
#  ('1054-009', 4, 5),
#  ('1011-013', 7, 10),
#  ('1023-013', 1, 4),
#  ('1141-006', 0, 1),
#  ('0963-023', 0, 2),
#  ('1121-004', 4, 5),
#  ('1010-002', 2, 4),
#  ('1030-026', 3, 4),
#  ('1080-002', 2, 3),
#  ('1142-010', 12, 15),
#  ('0960-005', 8, 9),
#  ('1076-007', 0, 3),
#  ('1016-009', 17, 20),
#  ('1016-014', 5, 6),
#  ('1039-010', 2, 7),
#  ('1103-015', 0, 1),
#  ('1081-002', 7, 9),
#  ('1124-006', 36, 38),
#  ('1156-002', 18, 19),
#  ('1113-004', 0, 3),
#  ('1110-002', 0, 1),
#  ('1096-012', 28, 29),
#  ('1138-005', 20, 23),
#  ('0982-005', 0, 3),
#  ('1016-008', 44, 45),
#  ('1027-000', 2, 3),
#  ('1116-026', 13, 15),
#  ('1139-002', 13, 15),
#  ('1119-006', 15, 17),
#  ('1064-004', 2, 4),
#  ('1084-003', 7, 9),
#  ('1031-013', 37, 39),
#  ('1058-022', 1, 2),
#  ('1111-004', 8, 10),
#  ('1148-002', 7, 8),
#  ('1090-015', 0, 1),
#  ('0966-109', 1, 3),
#  ('1055-006', 0, 2),
#  ('1015-001', 0, 2),
#  ('1019-008', 10, 11),
#  ('1067-008', 7, 10),
#  ('1065-002', 0, 1),
#  ('0994-010', 23, 24),
#  ('1103-004', 8, 9),
#  ('0991-007', 29, 30),
#  ('0985-009', 22, 23),
#  ('1134-002', 2, 4),
#  ('1044-005', 3, 5),
#  ('1058-022', 23, 26),
#  ('0966-146', 4, 5),
#  ('0966-140', 1, 3),
#  ('1065-021', 0, 1),
#  ('1116-037', 17, 18),
#  ('1122-003', 10, 11),
#  ('1155-009', 19, 20),
#  ('0958-024', 0, 2),
#  ('0966-039', 4, 5),
#  ('0980-014', 12, 13),
#  ('1088-000', 0, 6),
#  ('1103-008', 26, 28),
#  ('0995-000', 0, 1),
#  ('1103-007', 38, 40),
#  ('1160-010', 5, 9),
#  ('1115-008', 24, 25),
#  ('1122-002', 13, 14),
#  ('1126-000', 0, 1),
#  ('1059-006', 26, 27),
#  ('1128-009', 23, 25),
#  ('0986-006', 10, 11),
#  ('0984-015', 0, 1),
#  ('0974-007', 0, 1),
#  ('1033-009', 24, 25),
#  ('1056-009', 4, 5),
#  ('1019-003', 15, 16),
#  ('0954-000', 0, 5),
#  ('0981-006', 10, 12),
#  ('1131-002', 1, 2),
#  ('1142-013', 6, 7),
#  ('0970-006', 26, 28),
#  ('1028-012', 8, 9),
#  ('1135-025', 20, 21),
#  ('1045-000', 0, 2),
#  ('0979-003', 17, 18),
#  ('1069-006', 5, 6),
#  ('1016-012', 9, 10),
#  ('1058-016', 13, 15),
#  ('1069-017', 23, 26),
#  ('0986-000', 7, 8),
#  ('0949-010', 6, 8),
#  ('0957-018', 29, 30),
#  ('1115-009', 0, 1),
#  ('1025-006', 0, 1),
#  ('0966-075', 4, 5),
#  ('1137-010', 15, 16),
#  ('0966-104', 4, 5),
#  ('1043-002', 6, 8),
#  ('1000-018', 26, 27),
#  ('0947-010', 11, 14),
#  ('1154-006', 26, 27),
#  ('0970-005', 28, 29),
#  ('0992-008', 9, 10),
#  ('1055-024', 0, 2),
#  ('1072-015', 26, 27),
#  ('1115-002', 1, 2),
#  ('0954-003', 9, 10),
#  ('1116-009', 13, 14),
#  ('0966-164', 19, 20),
#  ('1152-001', 0, 2),
#  ('1160-014', 0, 1),
#  ('0958-043', 0, 1),
#  ('0969-002', 9, 10),
#  ('1158-005', 14, 15),
#  ('0963-017', 23, 25),
#  ('0991-002', 0, 1),
#  ('1072-018', 0, 2),
#  ('0969-003', 0, 1),
#  ('1007-024', 18, 19),
#  ('1096-039', 11, 12),
#  ('1099-010', 17, 18),
#  ('1152-012', 15, 16),
#  ('1155-002', 0, 1),
#  ('0952-001', 0, 1),
#  ('0965-004', 6, 7),
#  ('0966-043', 1, 3),
#  ('0994-004', 11, 12),
#  ('1118-001', 2, 3),
#  ('0946-009', 2, 3),
#  ('1033-000', 0, 1),
#  ('1058-031', 12, 14),
#  ('1096-039', 0, 2),
#  ('1154-006', 16, 18),
#  ('1155-000', 0, 1),
#  ('1017-003', 34, 37),
#  ('1156-004', 6, 7),
#  ('1157-002', 19, 20),
#  ('1051-003', 15, 16),
#  ('0960-017', 15, 16),
#  ('1076-017', 0, 7),
#  ('1017-009', 12, 14),
#  ('0960-013', 20, 21),
#  ('1035-004', 24, 25),
#  ('1141-000', 0, 1),
#  ('0948-009', 0, 1),
#  ('1000-016', 15, 16),
#  ('1011-011', 0, 3),
#  ('1072-018', 55, 59),
#  ('1009-001', 0, 2),
#  ('1058-009', 29, 30),
#  ('0980-006', 1, 2),
#  ('1146-006', 49, 50),
#  ('1022-018', 1, 3),
#  ('1126-009', 9, 10),
#  ('1135-005', 0, 2),
#  ('1146-005', 0, 1),
#  ('1038-002', 26, 27),
#  ('1022-002', 12, 13),
#  ('1019-002', 22, 23),
#  ('1049-003', 1, 2),
#  ('0972-028', 0, 2),
#  ('0959-010', 3, 5),
#  ('1110-002', 6, 7),
#  ('1058-002', 0, 2),
#  ('0963-023', 17, 22),
#  ('1142-008', 0, 1),
#  ('1136-007', 7, 8),
#  ('1132-001', 0, 3),
#  ('1051-004', 4, 5),
#  ('0958-039', 0, 3),
#  ('0966-081', 1, 3),
#  ('0968-004', 43, 44),
#  ('1002-000', 4, 5),
#  ('1022-003', 23, 25),
#  ('0989-002', 18, 19),
#  ('1143-002', 29, 30),
#  ('1112-002', 13, 15),
#  ('1012-005', 15, 16),
#  ('0990-003', 13, 14),
#  ('1031-008', 25, 26),
#  ('1008-002', 0, 1),
#  ('1046-004', 30, 31),
#  ('1060-003', 8, 10),
#  ('1010-018', 0, 1),
#  ('1096-012', 35, 36),
#  ('1112-004', 18, 19),
#  ('1017-002', 5, 6),
#  ('1129-002', 1, 2),
#  ('1103-006', 27, 30),
#  ('1112-004', 0, 1),
#  ('1058-036', 1, 2),
#  ('0966-119', 1, 3),
#  ('1120-008', 12, 13),
#  ('1007-016', 12, 15),
#  ('1076-042', 0, 1),
#  ('1069-015', 15, 18),
#  ('1066-001', 0, 1),
#  ('1058-008', 1, 2),
#  ('1025-008', 28, 29),
#  ('1060-022', 1, 4),
#  ('1116-027', 15, 16),
#  ('0994-008', 27, 28),
#  ('0952-006', 4, 5),
#  ('1030-033', 0, 1),
#  ('1147-001', 0, 1),
#  ('0957-004', 3, 4),
#  ('1027-017', 27, 29),
#  ('1011-001', 0, 2),
#  ('1141-003', 2, 3),
#  ('1027-002', 0, 1),
#  ('1121-006', 11, 12),
#  ('1058-017', 0, 2),
#  ('1158-003', 10, 11),
#  ('1011-012', 10, 11),
#  ('0962-011', 9, 11),
#  ('1048-000', 8, 9),
#  ('0957-000', 7, 8),
#  ('1054-012', 4, 5),
#  ('1104-002', 6, 7),
#  ('1031-014', 0, 2),
#  ('1141-007', 3, 4),
#  ('1056-007', 4, 5),
#  ('0966-004', 1, 3),
#  ('0991-001', 2, 3),
#  ('1097-002', 0, 2),
#  ('1114-005', 0, 1),
#  ('0966-061', 4, 5),
#  ('1156-008', 0, 4),
#  ('0985-012', 20, 21),
#  ('1146-007', 0, 1),
#  ('0984-017', 25, 26),
#  ('1139-008', 20, 21),
#  ('0962-009', 1, 3),
#  ('0946-015', 2, 3),
#  ('1009-014', 16, 17),
#  ('1106-001', 0, 1),
#  ('0974-007', 29, 31),
#  ('0980-000', 0, 1),
#  ('0953-012', 25, 30),
#  ('0963-004', 12, 15),
#  ('0958-056', 2, 4),
#  ('1127-018', 0, 2),
#  ('1044-004', 43, 46),
#  ('0969-003', 7, 8),
#  ('1142-009', 1, 2),
#  ('1148-005', 5, 6),
#  ('1087-017', 6, 9),
#  ('1031-004', 39, 41),
#  ('1065-001', 0, 1),
#  ('1139-006', 13, 15),
#  ('1152-010', 16, 17),
#  ('1160-004', 28, 29),
#  ('1032-003', 4, 5),
#  ('1061-021', 0, 5),
#  ('1068-020', 0, 2),
#  ('1119-002', 4, 5),
#  ('1111-005', 5, 7),
#  ('1070-015', 7, 10),
#  ('0991-002', 10, 12),
#  ('1116-015', 2, 4),
#  ('1137-002', 18, 19),
#  ('1152-013', 9, 10),
#  ('0985-004', 14, 16),
#  ('1135-014', 6, 7),
#  ('0995-005', 5, 6),
#  ('1093-001', 0, 2),
#  ('1033-003', 0, 2),
#  ('0964-001', 0, 1),
#  ('0966-099', 4, 5),
#  ('1116-015', 20, 21),
#  ('1056-024', 4, 5),
#  ('1142-005', 6, 7),
#  ('0957-026', 3, 4),
#  ('0953-004', 26, 27),
#  ('0966-082', 4, 5),
#  ('1115-010', 1, 2),
#  ('1009-010', 0, 1),
#  ('0990-011', 18, 19),
#  ('1092-007', 11, 12),
#  ('0966-143', 4, 5),
#  ('1131-004', 10, 13),
#  ('1014-004', 34, 36),
#  ('1154-001', 0, 1),
#  ('1034-000', 0, 1),
#  ('1143-005', 6, 7),
#  ('1016-014', 7, 9),
#  ('0967-000', 8, 10),
#  ('1144-002', 38, 39),
#  ('0968-005', 17, 22),
#  ('1134-002', 0, 1),
#  ('0957-019', 36, 37),
#  ('0966-145', 1, 3),
#  ('1060-003', 3, 6),
#  ('1039-002', 0, 1),
#  ('1012-008', 38, 39),
#  ('1152-014', 9, 10),
#  ('1015-003', 26, 27),
#  ('1062-003', 19, 21),
#  ('1067-011', 2, 4),
#  ('0991-010', 1, 3),
#  ('1133-011', 9, 10),
#  ('0999-003', 3, 5),
#  ('1016-011', 8, 11),
#  ('1058-005', 0, 1),
#  ('1089-018', 12, 13),
#  ('1094-037', 0, 1),
#  ('0966-150', 1, 3),
#  ('0966-054', 4, 5),
#  ('1156-006', 15, 21),
#  ('1144-000', 0, 1),
#  ('1096-016', 0, 2),
#  ('1014-010', 8, 9),
#  ('1096-032', 9, 10),
#  ('1027-011', 3, 4),
#  ('1037-004', 27, 28),
#  ('0966-128', 1, 2),
#  ('0970-006', 24, 25),
#  ('1160-011', 22, 24),
#  ('0957-020', 15, 17),
#  ('0957-033', 23, 25),
#  ('0991-006', 4, 5),
#  ('0985-002', 14, 15),
#  ('1030-038', 12, 17),
#  ('1055-001', 0, 1),
#  ('1056-044', 3, 4),
#  ('0966-070', 4, 5),
#  ('1059-006', 28, 30),
#  ('1016-015', 12, 14),
#  ('1007-017', 0, 2),
#  ('1077-003', 8, 9),
#  ('0960-020', 7, 8),
#  ('1101-012', 36, 37),
#  ('0983-004', 13, 14),
#  ('0960-004', 2, 3),
#  ('1061-004', 0, 3),
#  ('1112-003', 33, 35),
#  ('1112-008', 23, 25),
#  ('0999-002', 1, 2),
#  ('0994-001', 0, 2),
#  ('1059-005', 33, 34),
#  ('0996-006', 15, 16),
#  ('1116-011', 6, 7),
#  ('1131-005', 5, 6),
#  ('0973-002', 11, 13),
#  ('1087-003', 5, 6),
#  ('0966-111', 1, 3),
#  ('1044-007', 0, 1),
#  ('1138-003', 13, 14),
#  ('1038-003', 11, 13),
#  ('0962-008', 1, 3),
#  ('1149-005', 25, 29),
#  ('1013-006', 1, 5),
#  ('0984-018', 12, 13),
#  ('1056-010', 4, 5),
#  ('1094-042', 0, 1),
#  ('1095-020', 0, 3),
#  ('0959-001', 0, 2),
#  ('1137-004', 0, 1),
#  ('0964-002', 21, 22),
#  ('1103-002', 0, 1),
#  ('1094-024', 0, 2),
#  ('0966-083', 4, 5),
#  ('0959-007', 0, 1),
#  ('0952-004', 5, 7),
#  ('1148-008', 4, 5),
#  ('1087-017', 13, 16),
#  ('1159-004', 4, 5),
#  ('1094-019', 0, 1),
#  ('0958-036', 0, 2),
#  ('1017-000', 0, 1),
#  ('1132-002', 12, 13),
#  ('1144-002', 0, 3),
#  ('1133-004', 23, 27),
#  ('1004-007', 6, 7),
#  ('1127-008', 18, 19),
#  ('1131-003', 23, 24),
#  ('1160-014', 3, 4),
#  ('0966-094', 1, 3),
#  ('0966-088', 1, 3),
#  ('0966-076', 1, 3),
#  ('1128-002', 1, 2),
#  ('1132-004', 10, 14),
#  ('1152-004', 49, 52),
#  ('1089-001', 0, 1),
#  ('0993-007', 4, 5),
#  ('1049-002', 24, 26),
#  ('0947-006', 11, 14),
#  ('1025-012', 0, 1),
#  ('1010-002', 10, 12),
#  ('1152-011', 21, 22),
#  ('1070-008', 4, 5),
#  ('1046-009', 5, 7),
#  ('1093-004', 14, 16),
#  ('1088-002', 3, 7),
#  ('1070-008', 7, 10),
#  ('1094-054', 3, 4),
#  ('1125-008', 5, 6),
#  ('1030-030', 13, 14),
#  ('1099-008', 14, 17),
#  ('0983-002', 1, 2),
#  ('1146-005', 35, 37),
#  ('1011-013', 2, 4),
#  ('1049-005', 27, 28),
#  ('0974-010', 6, 8),
#  ('1056-013', 1, 3),
#  ('1118-006', 10, 11),
#  ('1049-003', 22, 23),
#  ('1089-010', 1, 2),
#  ('1103-006', 25, 26),
#  ('0995-003', 26, 27),
#  ('1000-004', 14, 15),
#  ('1005-015', 7, 9),
#  ('1125-008', 38, 39),
#  ('0968-000', 0, 3),
#  ('1058-011', 0, 2),
#  ('0946-006', 15, 17),
#  ('1081-002', 2, 3),
#  ('1096-022', 7, 9),
#  ('1056-014', 6, 7),
#  ('0966-072', 4, 5),
#  ('0960-000', 5, 8),
#  ('1058-013', 0, 2),
#  ('1094-011', 0, 3),
#  ('0992-003', 11, 13),
#  ('1121-008', 17, 18),
#  ('1014-003', 14, 15),
#  ('1003-003', 10, 12),
#  ('1119-006', 24, 26),
#  ('1116-037', 25, 26),
#  ('1001-000', 0, 1),
#  ('0983-002', 35, 36),
#  ('1014-009', 6, 7),
#  ('0966-139', 4, 5),
#  ('1094-056', 0, 1),
#  ('1029-001', 0, 2),
#  ('0961-007', 10, 11),
#  ('1090-018', 22, 25),
#  ('1011-005', 15, 18),
#  ('1064-005', 2, 3),
#  ('1096-002', 4, 6),
#  ('0963-021', 15, 17),
#  ('1116-010', 0, 1),
#  ('1118-007', 21, 22),
#  ('1138-007', 14, 15),
#  ('0966-146', 1, 3),
#  ('1056-030', 1, 3),
#  ('1096-031', 1, 3),
#  ('0960-019', 22, 25),
#  ('1076-000', 0, 7),
#  ('1088-001', 0, 2),
#  ('1096-031', 13, 14),
#  ('1078-005', 2, 3),
#  ('0965-007', 16, 17),
#  ('1026-003', 15, 17),
#  ('1097-008', 12, 13),
#  ('1011-023', 45, 48),
#  ('1033-009', 0, 1),
#  ('1094-050', 2, 3),
#  ('1132-003', 24, 25),
#  ('1007-007', 15, 16),
#  ...}

# %% [markdown]
# ----My Answer:
#
# ----If we look at the predicted spans(improved_spaCy_predictions) we got based on the new entity recognizer(improved_spaCy_predict):
#
# ----it has 'sentence_id', 'predicted start position', 'end positions'
#
# ----As the label of each span, we use the special value '--NME--'.

# %%
# TODO: Write code here to store the predicted spans in a new data frame

#1. Create an empty DataFrame, just remove the old records, but keep the column names and layout.
new_df_dev = df_dev.drop(index=df_dev.index)

#2. add new row or data records at the end of this empty DataFrame.
# based on layout we add 'sentence_id', 'sentence', 'predicted start position', 'end positions' and 'label'
for id, start, end in improved_spaCy_predictions:
    new_df_dev.loc[len(new_df_dev.index)] = [id, df_dev[df_dev['sentence_id'] == id].iloc[0]['sentence'], start, end, '--NME--']

new_df_dev.head()
# Out:
#   sentence_id                                           sentence  beg  end  \
# 0    0969-003  Baratelli , who played for Nice and Paris St G...    5    6
# 1    0957-026  Andrei Medvedev ( Ukraine ) beat Jan Kroslak (...    0    2
# 2    0946-014  They were held up by a gritty 84 from Paul Joh...    9   11
# 3    1011-022  They also questioned whether NationsBank can r...   15   16
# 4    0957-030  2 - Monica Seles ( U.S. ) beat Dally Randriant...    5    6
#
#      label
# 0  --NME--
# 1  --NME--
# 2  --NME--
# 3  --NME--
# 4  --NME--

# %% [markdown]
# ----

# %% [markdown]
# ----My Answer:
#
# ----new_df_dev has the same layout as df_dev and 5 rows, all the labels are replaced by '--NME--'
#
# ----since the predicted spans length changed to, the new_df_dev has the different length

# %% [markdown]
# ## Problem 4: Entity linking

# %% [markdown]
# Now that we have a method for predicting mention spans, we turn to the task of **entity linking**, which amounts to predicting the knowledge base entity that is referenced by a given mention. In our case, for each span we want to predict the Wikipedia page that this mention references.
#
# Start by extending the generator function that you implemented in Problem&nbsp;2 to labelled spans.

# %%
def gold_mentions(df):
    """Yield the gold-standard mentions in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        quadruples consisting of the sentence id, start position, end
        position and entity label of each span.
    """
    # TODO: Replace the next line with your own code
    # 'sentence_id', 'start position', 'end position', 'entity label'
    for row in df.itertuples():
        yield row.sentence_id, row.beg, row.end, row.label

# %% [markdown]
# A naive baseline for entity linking on our data set is to link each mention span to the Wikipedia page name that we get when we join the tokens in the span by underscores, as is standard in Wikipedia page names. Suppose, for example, that a span contains the two tokens
#
#     Jimi Hendrix
#
# The baseline Wikipedia page name for this span would be
#
#     Jimi_Hendrix
#
# Implement this naive baseline and evaluate its performance. Print the evaluation measures that you implemented in Problem&nbsp;1.

# %% [markdown]
# **Here and in the remainder of this lab, you should base your entity predictions on the predicted spans that you computed in Problem&nbsp;3.**

# %%
# TODO: Write code here to implement the baseline
def naive_baseline_predict(df):
    for row in df.itertuples():
        label = "_".join(row.sentence.split(' ')[row.beg : row.end])
        yield row.sentence_id, row.beg, row.end, label

# %%
# use gold_mentions() function on df_dev to get gold standard
gold_standard_mentions = set(gold_mentions(df_dev)) # old df dev

# predict on new_df_dev get from problem 3
naive_baseline_prediction = set(naive_baseline_predict(new_df_dev)) # new df dev

evaluation_report(gold = gold_standard_mentions, pred = naive_baseline_prediction)
# Out:
# precission:  0.31400571661902815 , recall:  0.25992901808348823 , F1_score:  0.2844197873324087

# %%
naive_baseline_prediction
# Out:
# {('1026-007', 19, 21, 'Hosni_Mubarak'),
#  ('1128-006', 5, 6, 'Hachette'),
#  ('1120-000', 1, 2, 'Iraqis'),
#  ('0986-006', 14, 15, 'Houghton'),
#  ('1006-012', 12, 13, 'Benghazi'),
#  ('1090-011', 10, 12, 'Monica_Seles'),
#  ('1036-020', 8, 9, 'Norwegian'),
#  ('0948-025', 7, 8, 'Surrey'),
#  ('0959-004', 0, 2, 'American_League'),
#  ('1089-003', 0, 1, 'Parnevik'),
#  ('1018-003', 2, 5, "Nicole_Nichterwitz_'s"),
#  ('1121-007', 27, 28, 'Iraqi'),
#  ('0963-003', 0, 1, 'Henke'),
#  ('1037-004', 10, 12, 'Intelligent_Network'),
#  ('1044-002', 14, 15, 'Ramallah'),
#  ('1000-019', 1, 2, 'Budapest'),
#  ('1051-008', 11, 13, 'Antoine_Lebouc'),
#  ('1118-007', 19, 20, 'Scotland'),
#  ('1152-010', 16, 17, 'Iraq'),
#  ('1138-006', 0, 1, 'Wang'),
#  ('0966-082', 1, 3, 'Samuel_Matete'),
#  ('1095-015', 0, 1, 'Florida'),
#  ('1008-008', 6, 7, 'Midwest'),
#  ('1101-011', 0, 1, 'France'),
#  ('1099-018', 11, 13, 'Colin_Calderwood'),
#  ('1000-004', 14, 15, 'BSE'),
#  ('1047-001', 2, 3, 'England'),
#  ('1070-012', 4, 5, 'Canada'),
#  ('1089-002', 3, 4, 'Sweden'),
#  ('1121-000', 3, 4, 'Iraqis'),
#  ('0953-002', 0, 1, 'Panamanian'),
#  ('1139-000', 4, 6, 'Wang_Donghai'),
#  ('1014-003', 1, 2, 'Dole'),
#  ('1138-010', 0, 1, 'Wang'),
#  ('0966-153', 4, 5, 'Norway'),
#  ('1008-010', 28, 30, 'Lynn_Reaser'),
#  ('1036-009', 19, 20, 'Longyear'),
#  ('1073-004', 0, 4, 'South_Africa_-_Tries'),
#  ('0992-007', 0, 5, 'The_Party_of_Democratic_Action'),
#  ('1116-031', 3, 5, 'Desmond_Tutu'),
#  ('1131-005', 5, 6, 'Uruguay'),
#  ('0957-033', 15, 17, 'Andrea_Gaudenzi'),
#  ('0957-013', 3, 4, 'Sweden'),
#  ('0999-002', 29, 30, 'Interfax'),
#  ('0966-054', 4, 5, 'Germany'),
#  ('0957-017', 3, 5, 'South_Africa'),
#  ('1152-014', 34, 35, 'F-16'),
#  ('0995-003', 11, 12, 'Tavildara'),
#  ('1016-005', 1, 2, 'Palestinian'),
#  ('0965-005', 21, 22, 'American'),
#  ('0990-014', 8, 9, 'Lebed'),
#  ('1068-019', 2, 5, 'Bristol_City_0'),
#  ('1085-003', 2, 4, 'Vladimir_Makovsky'),
#  ('0966-100', 1, 3, 'Michael_Green'),
#  ('1103-003', 0, 1, 'Belgium'),
#  ('1089-026', 30, 31, 'Kraft'),
#  ('1049-004', 19, 20, 'Irish'),
#  ('1042-002', 24, 27, 'Xinhua_news_agency'),
#  ('0948-009', 6, 8, 'British_Universities'),
#  ('1133-006', 15, 16, 'Xiao'),
#  ('1121-002', 14, 15, 'Iraqi'),
#  ('1058-003', 6, 8, 'Chad_Ogea'),
#  ('1076-030', 0, 1, 'Sutjeska'),
#  ('1058-025', 12, 13, 'Seattle'),
#  ('1076-020', 0, 1, 'Zemun'),
#  ('1099-018', 20, 22, 'Duncan_Ferguson'),
#  ('1148-008', 6, 9, 'the_Palestinian_Authority'),
#  ('1058-027', 31, 35, 'the_Chicago_White_Sox'),
#  ('0966-090', 1, 3, 'Falilat_Ogunkoya'),
#  ('0972-012', 3, 4, 'Ranatunga'),
#  ('1140-005', 8, 9, 'Chinese'),
#  ('1109-007', 0, 1, 'Brazil'),
#  ('1010-000', 0, 1, 'U.S.'),
#  ('1096-030', 0, 1, 'Montreal'),
#  ('0992-003', 23, 24, 'Bosnian'),
#  ('1039-019', 9, 10, 'congress'),
#  ('0965-013', 23, 24, 'Jamaican'),
#  ('1006-006', 9, 11, 'Green_Square'),
#  ('1056-034', 16, 17, 'France'),
#  ('0947-010', 20, 22, 'Hampshire_232'),
#  ('1116-001', 0, 1, 'LONDON'),
#  ('1099-005', 10, 12, 'Stephan_Marasek'),
#  ('0970-002', 9, 10, 'Milan'),
#  ('1094-036', 0, 2, 'NEW_YORK'),
#  ('1103-013', 0, 1, 'Belgium'),
#  ('1144-002', 26, 27, 'Kurds'),
#  ('0962-010', 7, 9, 'Billy_Mayfair'),
#  ('1116-005', 11, 12, 'English'),
#  ('1161-010', 1, 3, 'Dhaka_Newsroom'),
#  ('1090-005', 17, 18, 'Japan'),
#  ('1109-007', 2, 3, 'Giovanni'),
#  ('1099-017', 40, 42, 'Andreas_Herzog'),
#  ('1095-011', 2, 3, 'SEATTLE'),
#  ('1108-005', 0, 1, 'Miller'),
#  ('0984-018', 12, 13, 'Japanese'),
#  ('1056-021', 1, 3, 'Annett_Neumann'),
#  ('1044-007', 0, 1, 'Arafat'),
#  ('1052-005', 0, 3, 'Slovakia_-_Lubomir'),
#  ('0966-131', 1, 3, 'Yelena_Gulyayeva'),
#  ('1001-006', 0, 4, '--_Bucharest_Newsroom_40-1'),
#  ('1043-000', 2, 3, 'Thai'),
#  ('1011-013', 2, 4, 'First_Bank'),
#  ('1028-012', 4, 7, 'Longely_&_Dahling'),
#  ('1092-004', 3, 7, 'Netherlands_Czech_Republic_at'),
#  ('1014-009', 0, 2, 'Carroll_Campbell'),
#  ('1148-004', 0, 1, 'LA'),
#  ('1137-010', 6, 8, 'Li_In-mo'),
#  ('0966-125', 2, 3, 'Kostadinova'),
#  ('0960-039', 7, 8, 'Tarango'),
#  ('1101-006', 18, 20, 'Zinedine_Zidane'),
#  ('1048-003', 17, 19, 'Nir_Sivilia'),
#  ('0982-001', 0, 1, 'LONDON'),
#  ('1058-002', 16, 19, 'the_Cleveland_Indians'),
#  ('1094-042', 0, 1, 'CINCINNATI'),
#  ('1078-005', 0, 1, 'Benetton'),
#  ('1011-009', 0, 4, 'Roosevelt_Financial_Group_Inc'),
#  ('1044-003', 13, 14, 'Authority'),
#  ('1146-005', 20, 21, 'Iraqi'),
#  ('0993-003', 30, 32, 'Ljubomir_Acimovic'),
#  ('1117-004', 7, 8, 'Holland'),
#  ('1016-008', 44, 45, 'Jerusalem'),
#  ('0957-004', 3, 4, 'France'),
#  ('0991-010', 9, 10, 'Chechnya'),
#  ('1143-002', 7, 8, 'Israel'),
#  ('0997-004', 14, 15, 'Russian'),
#  ('1071-004', 16, 18, 'Carlo_Corrazin'),
#  ('0974-007', 32, 34, 'Mark_Waugh'),
#  ('0984-013', 2, 3, 'Treasury'),
#  ('1042-003', 5, 7, 'Huize_county'),
#  ('1072-018', 95, 97, 'James_Dalton'),
#  ('1066-015', 0, 1, 'Portsmouth'),
#  ('1119-002', 4, 5, 'Iraqi'),
#  ('1074-002', 0, 1, 'Mauritania'),
#  ('1051-007', 4, 5, 'Argentina'),
#  ('0964-002', 18, 20, 'Real_Madrid'),
#  ('1142-013', 6, 7, 'Kurdish'),
#  ('1120-007', 14, 15, 'Iraq'),
#  ('1018-002', 0, 1, 'German'),
#  ('1107-002', 0, 1, 'Austria'),
#  ('1017-006', 13, 15, 'Air_France'),
#  ('1076-031', 0, 1, 'Radnicki'),
#  ('0957-020', 35, 36, 'Australia'),
#  ('1087-015', 3, 7, 'the_Professional_Squash_Association'),
#  ('1070-006', 7, 9, 'Reynard_Honda'),
#  ('1010-017', 2, 3, 'Bernardin'),
#  ('1106-002', 0, 1, 'Belgium'),
#  ('1022-013', 19, 21, 'Labour_Day'),
#  ('1087-008', 4, 5, 'Jansher'),
#  ('1075-003', 0, 1, 'Benin'),
#  ('0958-029', 0, 1, 'BOSTON'),
#  ('1102-002', 2, 3, 'Mexico'),
#  ('0975-012', 1, 3, 'Luli_Popescu'),
#  ('1058-036', 26, 27, 'Tigers'),
#  ('1150-001', 0, 1, 'ROCHESTER'),
#  ('1137-008', 2, 3, 'Yonhap'),
#  ('1008-027', 0, 5, "The_University_of_Michigan_'s"),
#  ('1160-015', 0, 2, 'Aidan_Quinn'),
#  ('0965-003', 0, 3, 'American_Dennis_Mitchell'),
#  ('1123-009', 0, 1, 'Hanwha'),
#  ('1056-022', 4, 5, 'Australia'),
#  ('1056-010', 1, 3, 'Natalia_Karimova'),
#  ('1067-014', 0, 4, 'Livingston_1_Hamilton_0'),
#  ('0972-004', 0, 1, 'Australia'),
#  ('0964-003', 5, 6, 'Brazil'),
#  ('1156-003', 32, 33, 'Italian'),
#  ('1084-002', 0, 1, 'Sweden'),
#  ('1017-002', 14, 15, 'Paris'),
#  ('1032-006', 21, 22, 'EOE'),
#  ('0966-128', 2, 3, 'Motkova'),
#  ('1096-015', 0, 2, 'Darren_Dreifort'),
#  ('1123-001', 0, 2, 'SEOUL_1996-08-31'),
#  ('1061-001', 0, 1, 'LONDON'),
#  ('0994-005', 37, 38, 'Sharetsky'),
#  ('1150-003', 6, 9, 'Lilac_Falls_Motel'),
#  ('1064-002', 9, 10, 'English'),
#  ('1141-003', 10, 11, 'Hubei'),
#  ('0994-010', 0, 1, 'Lukashenko'),
#  ('1067-005', 0, 3, 'Greenock_Morton_1'),
#  ('1090-004', 12, 13, 'Netherlands'),
#  ('1095-014', 0, 1, 'Atlanta'),
#  ('1039-011', 23, 28, 'the_Moro_National_Liberation_Front'),
#  ('0946-007', 22, 23, 'Essex'),
#  ('1016-002', 22, 25, 'the_Middle_East'),
#  ('1129-005', 12, 13, 'Russia'),
#  ('1011-008', 10, 11, 'Roosevelt'),
#  ('1143-005', 6, 7, 'Israeli'),
#  ('1130-005', 56, 59, '"_The_Knot'),
#  ('1031-007', 29, 30, 'Italian'),
#  ('1120-008', 12, 13, 'Britain'),
#  ('0990-002', 17, 18, 'Moscow'),
#  ('1056-039', 6, 8, 'Frederic_Magne'),
#  ('1031-007', 38, 39, 'Indosuez'),
#  ('0967-005', 7, 8, 'Euro'),
#  ('1097-020', 24, 25, 'Krajicek'),
#  ('1057-002', 0, 1, 'Pakistan'),
#  ('1009-004', 27, 28, 'Agriculture'),
#  ('0972-013', 5, 6, 'Chandana'),
#  ('1098-002', 6, 7, 'WBO'),
#  ('1158-001', 0, 1, 'BRUSSELS'),
#  ('1097-008', 17, 18, 'Karbacher'),
#  ('1101-004', 31, 32, 'Chelsea'),
#  ('1125-008', 21, 22, 'Rwandan'),
#  ('0996-007', 35, 37, 'Bosnian_Serbs'),
#  ('0978-000', 0, 2, 'Jones_Medical'),
#  ('0991-009', 10, 11, 'Chechnya'),
#  ('1066-066', 0, 1, 'Lincoln'),
#  ('1128-002', 29, 31, 'Zycie_Warszawy'),
#  ('0961-007', 17, 19, 'Jeffrey_Lurie'),
#  ('0957-008', 6, 8, 'Andrei_Olhovskiy'),
#  ('1099-015', 2, 4, 'Herbert_Prohaska'),
#  ('1124-010', 20, 22, 'Northern_Cape'),
#  ('0969-001', 2, 3, 'France'),
#  ('1033-013', 17, 18, 'Cotti'),
#  ('1115-004', 2, 3, 'Thatcher'),
#  ('1133-007', 4, 5, 'Wang'),
#  ('0985-007', 6, 7, 'Bruno'),
#  ('1152-010', 1, 2, 'U.S.'),
#  ('0997-002', 0, 1, 'Russian'),
#  ('1118-006', 10, 11, 'Scottish'),
#  ('1116-036', 20, 21, 'Europe'),
#  ('1054-019', 1, 3, 'Marco_Lietti'),
#  ('1038-003', 40, 41, 'Tsang'),
#  ('1094-035', 0, 1, 'FLORIDA'),
#  ('0974-007', 26, 28, 'Michael_Slater'),
#  ('1143-000', 6, 7, 'Lebanon'),
#  ('0960-000', 5, 8, 'SPRING_TWIN_UPSETS'),
#  ('0972-024', 5, 7, 'Fleming_44'),
#  ('1030-032', 17, 18, 'Clinton'),
#  ('1005-009', 5, 6, 'Indonesian'),
#  ('0966-037', 4, 5, 'Cuba'),
#  ('1016-014', 12, 14, 'Ezer_Weizman'),
#  ('1031-004', 37, 38, 'Wuxi'),
#  ('0966-031', 1, 3, 'Michael_Johnson'),
#  ('1070-010', 7, 9, 'Reynard_Mercedes-Benz'),
#  ('1036-024', 4, 5, 'Ukrainian'),
#  ('1083-002', 6, 7, 'Russia'),
#  ('1027-011', 12, 13, 'Palestinian'),
#  ('1010-020', 17, 18, 'U.S.'),
#  ('0966-010', 1, 3, 'Gillian_Russell'),
#  ('0972-040', 6, 7, 'Zimbabwe'),
#  ('1094-005', 0, 3, 'AMERICAN_LEAGUE_EASTERN'),
#  ('1059-005', 29, 30, 'Leicestershire'),
#  ('1146-001', 0, 1, 'BAGHDAD'),
#  ('0957-019', 36, 37, '6-2'),
#  ('1011-020', 3, 4, 'Boatmen'),
#  ('1019-000', 6, 7, 'Dutch'),
#  ('1096-032', 9, 10, 'Mets'),
#  ('1128-006', 34, 35, 'Poland'),
#  ('1120-005', 17, 18, 'Amman'),
#  ('1058-007', 8, 9, 'RBI'),
#  ('1013-003', 8, 9, 'Gulf'),
#  ('1035-008', 0, 1, 'Azerbaijan'),
#  ('0980-006', 26, 27, 'French'),
#  ('1149-011', 2, 8, 'the_National_Highway_Traffic_Safety_Administration'),
#  ('0966-072', 4, 5, 'Romania'),
#  ('0981-006', 28, 30, 'Lear_Corp'),
#  ('1135-025', 20, 21, 'Danish'),
#  ('1135-023', 34, 36, 'Suu_Kyi'),
#  ('0959-011', 0, 1, 'Chicago'),
#  ('1116-027', 20, 21, 'London'),
#  ('1031-012', 6, 7, 'Unicom'),
#  ('1096-034', 6, 8, 'Alvaro_Espinoza'),
#  ('1094-002', 0, 3, 'Major_League_Baseball'),
#  ('1096-022', 1, 2, 'Braves'),
#  ('0947-006', 2, 3, 'Glamorgan'),
#  ('1103-007', 1, 2, 'Yalcin'),
#  ('0960-023', 10, 11, 'American'),
#  ('1116-015', 11, 12, 'Naples'),
#  ('1056-047', 12, 13, 'Lithuania'),
#  ('1152-018', 22, 23, 'Gulf'),
#  ('0966-069', 4, 5, 'Russia'),
#  ('1045-003', 8, 9, 'U.N.'),
#  ('1043-005', 10, 11, 'Singapore'),
#  ('1135-003', 4, 6, 'Aung_San'),
#  ('0948-038', 3, 4, 'Scotland'),
#  ('0966-118', 4, 5, 'Russia'),
#  ('1094-011', 0, 3, 'DETROIT_49_86'),
#  ('1090-014', 10, 12, 'Fed_Cup'),
#  ('1027-006', 12, 13, 'Jamil'),
#  ('1068-010', 0, 3, 'Port_Vale_2'),
#  ('0980-014', 12, 13, 'CNBC'),
#  ('1056-001', 0, 1, 'MANCHESTER'),
#  ('1058-031', 12, 14, 'Mark_McGwire'),
#  ('1023-001', 0, 2, 'NEW_YORK'),
#  ('0979-002', 0, 1, 'NYMEX'),
#  ('1026-001', 0, 1, 'CAIRO'),
#  ('0960-010', 0, 1, "O'Brien"),
#  ('1095-004', 0, 2, 'American_League'),
#  ('0966-047', 4, 5, 'Kenya'),
#  ('1057-006', 20, 22, 'Adam_Hollioake'),
#  ('0965-011', 25, 28, 'the_1936_Olympics'),
#  ('1066-042', 0, 3, 'Bristol_Rovers_3'),
#  ('0965-011', 31, 32, 'Berlin'),
#  ('1044-004', 43, 46, 'the_West_Bank'),
#  ('1008-023', 8, 9, 'CNBC'),
#  ('1022-012', 18, 19, 'Canadian'),
#  ('0965-013', 7, 9, 'Gail_Devers'),
#  ('1008-002', 0, 1, 'WASHINGTON'),
#  ('1012-004', 9, 10, 'Farrakhan'),
#  ('1013-002', 7, 10, 'the_U.S._Gulf'),
#  ('1096-042', 8, 9, 'RBI'),
#  ('0948-002', 0, 1, 'Australia'),
#  ('1116-025', 2, 3, 'Belgian'),
#  ('1036-013', 6, 7, 'Ukrainians'),
#  ('1141-003', 2, 3, 'Wuhan'),
#  ('0993-007', 2, 3, 'Kevic'),
#  ('1119-002', 14, 15, 'Arbil'),
#  ('0955-001', 0, 2, 'SEOUL_1996-08-30'),
#  ('0962-011', 9, 11, 'Steve_Jurgenson'),
#  ('1142-006', 16, 17, 'Iraq'),
#  ('1056-039', 3, 4, 'Italy'),
#  ('0966-061', 1, 3, 'Michael_Moellenbeck'),
#  ('1057-007', 14, 15, 'Inzamam-ul-Haq'),
#  ('1008-010', 35, 36, 'Jacksonville'),
#  ('1046-010', 5, 7, 'John_Toshack'),
#  ('1156-007', 2, 3, 'Rome'),
#  ('1060-015', 4, 5, 'Trinidad'),
#  ('0947-011', 23, 26, 'T._Moody_6-82'),
#  ('1070-008', 7, 10, 'Lola_Ford_Cosworth'),
#  ('1004-003', 1, 2, 'Vipheak'),
#  ('1109-001', 0, 1, 'AMSTERDAM'),
#  ('1099-017', 14, 16, 'Wolfgang_Feiersinger'),
#  ('1143-003', 43, 44, 'Lebanon'),
#  ('1056-007', 1, 3, 'Marion_Clignet'),
#  ('1013-004', 8, 9, 'Mediterranean'),
#  ('1016-007', 26, 28, 'Martin_Erdmann'),
#  ('1054-013', 1, 3, 'Michael_Andersson'),
#  ('0994-007', 5, 6, 'Sharetsky'),
#  ('1017-007', 13, 15, 'Christian_Blanc'),
#  ('1096-002', 10, 13, "Devon_White_'s"),
#  ('1103-009', 44, 46, 'De_Wilde'),
#  ('1121-003', 4, 8, 'the_Iraqi_National_Congress'),
#  ('1111-008', 5, 7, 'Beryll_Remblance'),
#  ('1000-014', 10, 13, 'the_Czech_Republic'),
#  ('1031-007', 7, 8, 'Pirelli'),
#  ('1012-009', 10, 11, 'Libya'),
#  ('1103-016', 76, 77, '76th'),
#  ('1094-025', 2, 3, 'SEATTLE'),
#  ('1135-029', 6, 7, 'Burma'),
#  ('1009-013', 16, 17, 'Mexico'),
#  ('1120-006', 12, 14, 'Stansted_airport'),
#  ('0994-017', 13, 15, 'Zenon_Poznyak'),
#  ('0974-009', 6, 9, 'Aravinda_de_Silva'),
#  ('1018-004', 12, 13, 'Velten'),
#  ('0978-002', 25, 26, 'Jones'),
#  ('0966-087', 4, 5, 'Australia'),
#  ('1101-007', 2, 3, 'Djorkaeff'),
#  ('1136-007', 7, 8, 'Caltex'),
#  ('1072-014', 18, 19, 'Springboks'),
#  ('1070-006', 4, 5, 'Italy'),
#  ('1087-003', 5, 6, 'Hill'),
#  ('1134-003', 22, 23, 'Suharto'),
#  ('0993-003', 26, 27, 'Belgrade'),
#  ('1109-007', 7, 9, 'Marcello_Goncalves'),
#  ('1051-010', 15, 17, "Peter_O'Malley"),
#  ('1006-007', 5, 6, 'Niger'),
#  ('1000-016', 0, 1, 'Cofinec'),
#  ('1016-009', 3, 4, 'Bonn'),
#  ('0966-081', 1, 3, 'Torrance_Zellner'),
#  ('1000-008', 0, 1, 'Frater'),
#  ('1126-010', 5, 6, 'Mahala'),
#  ('1019-000', 1, 2, 'German'),
#  ('1135-000', 0, 1, 'Burma'),
#  ('1053-003', 19, 22, 'A._Hollioake_4-23'),
#  ('1067-018', 2, 5, 'East_Stirling_0'),
#  ('1066-017', 0, 2, 'Crystal_Palace'),
#  ('1096-034', 19, 21, 'Brent_Mayne'),
#  ('1154-002', 16, 17, 'Algerian'),
#  ('1017-000', 4, 6, 'Air_France'),
#  ('1020-002', 19, 22, 'Hindustan_Copper_Ltd'),
#  ('1124-003', 15, 16, 'Pretoria'),
#  ('1059-003', 18, 20, 'Richard_Kettleborough'),
#  ('1096-036', 23, 24, 'Cardinals'),
#  ('0991-006', 4, 5, 'Maskhadov'),
#  ('1096-013', 14, 16, 'Jeff_Parrett'),
#  ('0987-002', 6, 7, 'Nigeria'),
#  ('0977-002', 16, 20, 'the_Bank_of_Canada'),
#  ('1160-015', 17, 19, 'Kitty_Kiernan'),
#  ('0990-000', 2, 4, 'Lebed_Chechnya'),
#  ('0983-007', 18, 19, 'London'),
#  ('1058-036', 15, 17, 'Tony_Clark'),
#  ('0992-002', 0, 1, 'Bosnia'),
#  ('1096-013', 3, 6, "Delino_DeShields_'s"),
#  ('0995-006', 15, 16, 'Tavildara'),
#  ('1008-010', 31, 34, 'Barnett_Banks_Inc.'),
#  ('1159-007', 28, 29, 'Belgium'),
#  ('1056-024', 1, 3, 'Olga_Slioussareva'),
#  ('1127-012', 12, 14, 'Mubatik_Dagayeva'),
#  ('1081-002', 4, 5, '0-0'),
#  ('0972-014', 3, 4, 'Chandana'),
#  ('0995-010', 4, 5, 'Afghanistan'),
#  ('1152-013', 17, 18, 'U.S.'),
#  ('1058-040', 28, 31, 'the_Minnesota_Twins'),
#  ('1043-002', 0, 1, 'Singapore'),
#  ('0946-013', 17, 18, 'Kent'),
#  ('1036-024', 2, 3, 'Russian'),
#  ('1103-003', 22, 23, 'Turkish'),
#  ('1150-000', 3, 5, 'New_Hampshire'),
#  ('1084-000', 8, 9, 'QUALIFIER'),
#  ('0948-044', 9, 10, 'Nottingham'),
#  ('1041-000', 0, 4, 'Apic_Yamada_-_6mth'),
#  ('1148-009', 14, 16, 'Ben_Ali'),
#  ('0991-000', 2, 3, 'Chechens'),
#  ('1142-011', 25, 26, 'Iran'),
#  ('0986-006', 2, 3, 'Breen'),
#  ('1147-002', 10, 11, 'Arbil'),
#  ('1016-013', 7, 8, 'German'),
#  ('1121-008', 3, 4, 'Iraq'),
#  ('1130-006', 3, 8, 'Sleeping_Bread_"_Puig_\'s'),
#  ('1116-020', 3, 5, 'Anthony_Quayle'),
#  ('1020-004', 19, 21, 'Hindustan_Copper'),
#  ('0947-009', 13, 16, 'I._Austin_4-37'),
#  ('0954-003', 0, 2, 'Anthony_Hill'),
#  ('0957-017', 0, 2, 'Amanda_Coetzer'),
#  ('1116-035', 4, 7, 'Alan_John_Percivale'),
#  ('1056-016', 22, 24, 'Anton_Chantyr'),
#  ('0971-000', 0, 4, 'CRICKET_-_SRI_LANKA'),
#  ('1130-003', 23, 25, 'Fidel_Castro'),
#  ('1061-002', 2, 3, 'English'),
#  ('0966-024', 4, 5, 'Cuba'),
#  ('1115-003', 33, 36, 'the_Conservative_Party'),
#  ('1005-011', 10, 14, 'the_International_Monetary_Fund'),
#  ('1094-017', 0, 2, 'KANSAS_CITY'),
#  ('1099-017', 8, 10, 'Peter_Schoettel'),
#  ('1007-004', 1, 2, 'Clinton'),
#  ('0960-009', 22, 23, 'Wimbledon'),
#  ('1143-004', 25, 26, 'Sikhin'),
#  ('0946-003', 17, 18, 'Surrey'),
#  ('1084-000', 6, 7, 'EUROPEAN'),
#  ('1116-027', 15, 16, 'Blitz'),
#  ('1142-002', 7, 8, 'Iraq'),
#  ('1099-004', 4, 6, 'Belarus_5-1'),
#  ('1012-002', 16, 18, 'Louis_Farrakhan'),
#  ('1146-005', 32, 33, 'Barzani'),
#  ('1101-002', 18, 19, 'Mexico'),
#  ('1119-006', 0, 1, 'Arbil'),
#  ('1127-006', 10, 12, 'Dzhokhar_Dudayev'),
#  ('1017-001', 0, 1, 'PARIS'),
#  ('1117-003', 1, 2, 'Holland'),
#  ('1058-040', 3, 5, 'Marc_Newfield'),
#  ('1060-006', 1, 3, 'Colin_Montgomerie'),
#  ('1031-000', 5, 6, 'Chinese'),
#  ('0974-008', 3, 5, 'Arjuna_Ranatunga'),
#  ('1155-002', 0, 1, 'Iranian'),
#  ('1059-006', 6, 7, 'Surrey'),
#  ('1033-003', 0, 2, 'Flavio_Cotti'),
#  ('1072-004', 10, 12, 'New_Zealand'),
#  ('0966-018', 4, 5, 'Russia'),
#  ('0966-086', 1, 3, 'Eric_Thomas'),
#  ('0946-005', 14, 15, 'Simmons'),
#  ('1052-004', 0, 6, 'Faroe_Islands_-_Jan_Allan_Mueller'),
#  ('1056-038', 3, 4, 'Australia'),
#  ('1066-057', 0, 1, 'Fulham'),
#  ('0966-109', 1, 3, 'Sammy_Langat'),
#  ('0957-008', 3, 4, 'Australia'),
#  ('1016-012', 0, 1, 'Levy'),
#  ('0972-028', 0, 2, 'A._Ranatunga'),
#  ('1016-005', 3, 5, 'Yasser_Arafat'),
#  ('1035-004', 6, 7, 'Nagorno-Karabakh'),
#  ('0952-003', 10, 12, 'Anatoly_Gorokhovsky'),
#  ('1119-002', 11, 12, 'Kurdish'),
#  ('1154-002', 8, 9, 'Algiers'),
#  ('1009-015', 0, 4, 'The_California_Avocado_Commission'),
#  ('1036-011', 22, 23, 'Reuters'),
#  ('1076-024', 0, 4, 'Borac_4_0_0'),
#  ('1031-003', 0, 1, 'Italian'),
#  ('1130-005', 28, 30, 'Sleeping_Bread'),
#  ('1131-003', 30, 31, 'U.S.'),
#  ('1096-022', 21, 23, 'Andruw_Jones'),
#  ('1064-007', 37, 38, 'Orrell'),
#  ('0958-024', 3, 4, 'DETROIT'),
#  ('1099-007', 15, 16, 'Austrian'),
#  ('1156-000', 0, 1, 'Italy'),
#  ('1081-000', 4, 5, 'PORTUGAL'),
#  ('0992-003', 10, 11, 'State'),
#  ('0966-004', 4, 5, 'Jamaica'),
#  ('1009-020', 14, 15, 'Drazek'),
#  ('0957-019', 13, 15, 'Barbara_Rittner'),
#  ('1097-011', 11, 12, 'Swede'),
#  ('0951-002', 0, 1, 'Romania'),
#  ('0990-002', 31, 32, 'Interfax'),
#  ('1099-018', 8, 10, 'Thomas_Boyd'),
#  ('1066-047', 0, 2, 'Notts_County'),
#  ('0998-003', 0, 1, 'Lebed'),
#  ('1046-006', 19, 21, 'Armando_Alvarez'),
#  ('1073-009', 2, 3, 'Mehrtens'),
#  ('0966-155', 4, 5, 'Finland'),
#  ('1025-002', 12, 14, 'Benjamin_Netanyahu'),
#  ('1042-007', 10, 11, 'Xinhua'),
#  ('1090-015', 0, 1, 'Fernandez'),
#  ('0966-101', 1, 3, 'Donovan_Bailey'),
#  ('1058-023', 2, 3, 'Incaviglia'),
#  ('1132-004', 10, 14, 'Radio_Red_the_group'),
#  ('1103-015', 71, 73, 'Luis_Oliveira'),
#  ('1125-008', 38, 39, 'Rwandan'),
#  ('0955-015', 0, 1, 'Chonnam'),
#  ('1044-004', 15, 16, 'Arafat'),
#  ('0960-007', 31, 33, 'Leander_Paes'),
#  ('1051-001', 2, 3, 'England'),
#  ('1114-005', 0, 1, 'Lithuania'),
#  ('1101-006', 16, 17, 'Juventus'),
#  ('0966-014', 1, 3, 'Carla_Sacramento'),
#  ('0983-004', 1, 2, 'Iraqis'),
#  ('0993-002', 4, 6, 'Aerodrom_Beograd'),
#  ('1027-016', 8, 9, 'Israeli'),
#  ('1000-018', 26, 27, 'Petofi'),
#  ('0966-126', 4, 5, 'Ukraine'),
#  ('0961-007', 15, 16, 'Eagles'),
#  ('1031-006', 28, 29, 'India'),
#  ('0972-002', 4, 7, 'Singer_World_Series'),
#  ('1146-004', 1, 6, '(_Patriotic_Union_of_Kurdistan'),
#  ('0947-009', 9, 12, 'V._Drakes_52'),
#  ('1091-003', 34, 35, '6-2'),
#  ('1094-048', 0, 2, 'SAN_FRANCISCO'),
#  ('1056-017', 8, 10, 'Jean-Michel_Monin'),
#  ('0966-048', 4, 5, 'Kenya'),
#  ('0966-079', 4, 5, 'Kenya'),
#  ('0968-004', 0, 2, 'Atlanta_Games'),
#  ('1058-022', 23, 26, 'the_Seattle_Mariners'),
#  ('0983-004', 15, 16, 'Hussein'),
#  ('1053-002', 0, 1, 'England'),
#  ('1096-019', 4, 5, 'Braves'),
#  ('1133-004', 38, 39, 'Xiao'),
#  ('1122-002', 13, 14, 'Algiers'),
#  ('0985-009', 13, 14, 'American'),
#  ('1140-002', 11, 13, 'Hong_Kong'),
#  ('1054-020', 4, 5, 'Netherlands'),
#  ('1096-035', 4, 5, 'Mets'),
#  ('1082-002', 2, 3, 'Switzerland'),
#  ('1103-003', 5, 7, 'World_Cup'),
#  ('0968-004', 17, 18, 'Sarajevo'),
#  ('1031-002', 0, 1, 'MILAN'),
#  ('1136-007', 13, 14, 'Tianjin'),
#  ('1146-004', 8, 10, 'Jalal_Talabani'),
#  ('1048-003', 0, 1, 'Israel'),
#  ('1096-042', 5, 6, 'Berry'),
#  ('1094-020', 0, 1, 'SEATTLE'),
#  ('1058-043', 8, 10, 'Mike_Fetters'),
#  ('1036-017', 9, 10, 'Barentsburg'),
#  ('0972-023', 0, 2, 'Sri_Lanka'),
#  ('1070-015', 7, 10, 'Reynard_Ford_Cosworth'),
#  ('1025-008', 7, 8, 'Arab'),
#  ('1026-003', 15, 17, 'Rami_al-Saadani'),
#  ('1057-006', 14, 16, 'Graham_Thorpe'),
#  ('0972-035', 8, 9, 'Muralitharan'),
#  ('0966-111', 4, 5, 'Kenya'),
#  ('1056-034', 8, 10, 'Andrea_Collinelli'),
#  ('1012-008', 0, 3, 'The_Treasury_Department'),
#  ('1096-041', 11, 12, 'RBI'),
#  ('1121-008', 35, 36, 'Iraqi'),
#  ('1035-010', 0, 1, 'Interfax'),
#  ('1054-012', 4, 5, 'Spain'),
#  ('1116-000', 0, 1, 'Reuters'),
#  ('1058-028', 5, 7, 'Robin_Ventura'),
#  ('1011-018', 3, 4, 'Missouri'),
#  ('1061-017', 0, 1, 'Scottish'),
#  ('1142-006', 12, 13, 'Iranian'),
#  ('0952-003', 3, 7, "the_Russian_league_'s"),
#  ('0972-024', 3, 4, 'Healy'),
#  ('1031-013', 39, 40, 'Provera'),
#  ('1152-000', 0, 1, 'U.S.'),
#  ('0984-002', 11, 12, 'European'),
#  ('1073-002', 20, 22, 'Ellis_Park'),
#  ('1002-001', 0, 1, 'BOGOTA'),
#  ('0966-082', 4, 5, 'Zambia'),
#  ('0957-021', 10, 11, 'U.S.'),
#  ('0951-004', 8, 10, 'Mihai_Tararache'),
#  ('1016-002', 6, 7, 'Palestinians'),
#  ('1058-031', 29, 33, 'the_Boston_Red_Sox'),
#  ('1092-007', 0, 1, 'Austria'),
#  ('1022-009', 4, 5, 'Canada'),
#  ('1022-007', 0, 2, 'Statistics_Canada'),
#  ('1157-003', 2, 3, 'NATO'),
#  ('1038-003', 51, 53, 'New_Zealand'),
#  ('1152-016', 2, 3, 'U.S.'),
#  ('0966-019', 1, 3, 'Sara_Thorsett'),
#  ('1007-033', 0, 5, "The_Standard_&_Poor_'s"),
#  ('1011-022', 15, 16, 'Boatmen'),
#  ('0994-010', 23, 24, 'Russia'),
#  ('1146-004', 21, 24, 'Iraqi_News_Agency'),
#  ('1088-000', 0, 6, 'SQUASH_-_HONG_KONG_OPEN_SEMIFINAL'),
#  ('1096-024', 0, 2, 'Mike_Mordecai'),
#  ('1125-004', 2, 3, 'RDR'),
#  ('1033-003', 15, 16, 'OSCE'),
#  ('0974-003', 4, 6, 'Sri_Lanka'),
#  ('1142-000', 1, 2, 'Kurds'),
#  ('1087-002', 5, 7, 'Jansher_Khan'),
#  ('0972-002', 12, 14, 'Sri_Lanka'),
#  ('1103-004', 0, 1, 'Turkish'),
#  ('1037-003', 16, 17, 'GPTA'),
#  ('0954-002', 3, 7, 'the_Hong_Kong_Open'),
#  ('1002-003', 32, 35, 'Casa_de_Narino'),
#  ('1056-011', 4, 5, 'Russia'),
#  ('1049-002', 24, 26, 'World_Cup'),
#  ('0966-145', 4, 5, 'U.S.'),
#  ('1030-004', 3, 4, 'London'),
#  ('1039-007', 0, 1, 'Indonesian'),
#  ('1056-037', 9, 10, 'Latvia'),
#  ('1157-002', 19, 20, 'Iraq'),
#  ('0990-005', 4, 6, 'Boris_Nikolayevich'),
#  ('0946-012', 20, 21, 'Derbyshire'),
#  ('0961-008', 7, 8, 'Randall'),
#  ('0972-037', 3, 5, 'Gillespie_6-0-27-0'),
#  ('1155-010', 17, 18, 'Iranian'),
#  ('1101-008', 16, 18, 'Internazionale_Milan'),
#  ('1063-002', 0, 1, 'Ukraine'),
#  ('1152-011', 21, 22, 'Baghdad'),
#  ('0966-130', 1, 3, 'Nele_Zilinskiene'),
#  ('1006-014', 17, 18, 'Sudanese'),
#  ('0993-005', 24, 25, 'Belgrade'),
#  ('1016-005', 11, 13, 'Benjamin_Netanyahu'),
#  ('1096-019', 1, 2, 'Chicago'),
#  ('1045-008', 28, 29, 'Israeli'),
#  ('1033-010', 27, 28, 'Russia'),
#  ('0958-041', 0, 1, 'CINCINNATI'),
#  ('0958-001', 0, 2, 'NEW_YORK'),
#  ('1149-005', 44, 45, 'Midwest'),
#  ('1096-036', 1, 3, 'St_Louis'),
#  ('1147-000', 8, 9, 'Arbil'),
#  ('0975-002', 4, 5, 'Comelf'),
#  ('1058-007', 0, 1, 'Gonzalez'),
#  ('1019-002', 9, 10, 'German'),
#  ('1037-004', 27, 28, 'Ericsson'),
#  ('1046-009', 12, 13, 'FIFA'),
#  ('0966-036', 4, 5, 'Denmark'),
#  ('0966-039', 4, 5, 'Germany'),
#  ('1032-003', 14, 15, 'EOE'),
#  ('0985-002', 16, 17, 'Sun'),
#  ('1055-012', 0, 2, 'R._Croft'),
#  ('1056-017', 2, 4, 'Cyril_Bos'),
#  ('1099-011', 0, 3, "SK_Rapid_'s"),
#  ('1096-002', 24, 28, 'the_Cincinnati_Reds_3-1'),
#  ('1009-009', 9, 10, 'U.S.'),
#  ('0959-014', 0, 3, 'Los_Angeles_2'),
#  ('1064-007', 20, 24, 'the_Rugby_Football_Union'),
#  ('0946-008', 3, 4, 'Yorkshire'),
#  ('1000-011', 13, 14, 'Frater'),
#  ('1101-001', 0, 1, 'PARIS'),
#  ('1072-001', 0, 2, 'Andy_Colquhoun'),
#  ('0970-006', 24, 25, 'Torino'),
#  ('1027-025', 27, 28, 'Qalandia'),
#  ('0998-000', 2, 3, 'Chechens'),
#  ('1101-004', 14, 15, 'Mexican'),
#  ('1142-009', 4, 5, 'Baghdad'),
#  ('1097-004', 2, 3, 'Edberg'),
#  ('0949-004', 12, 14, 'World_Cup'),
#  ('1103-008', 0, 2, 'Marc_Degryse'),
#  ('1012-008', 19, 20, 'Tripoli'),
#  ('1137-000', 3, 5, 'S._Korea'),
#  ('1126-005', 0, 1, 'Marriner'),
#  ('1128-012', 10, 11, 'SPC'),
#  ('0984-004',
#   5,
#   13,
#   'the_London_International_Financial_Futures_and_Options_Exchange'),
#  ('1036-011', 17, 18, 'Onarheim'),
#  ('0980-002', 0, 1, 'U.S.'),
#  ('1142-010', 19, 20, 'Iraqi'),
#  ('1087-008', 1, 2, 'Australian'),
#  ('1116-023', 2, 6, 'James_Alfred_Van_Allen'),
#  ('1072-018', 0, 2, 'South_Africa'),
#  ('1139-006', 3, 4, 'Wang'),
#  ('1137-005', 9, 11, 'South_Korean'),
#  ('0947-008', 30, 31, 'D.'),
#  ('1039-011', 20, 21, 'Philippine'),
#  ('1139-006', 13, 15, 'Democracy_Wall'),
#  ('0994-004', 11, 12, 'Reuters'),
#  ('1024-000', 0, 2, 'IPO_FILING'),
#  ('1007-017', 8, 9, 'no-new-tax'),
#  ('0984-003', 0, 3, 'GERMANY_-_Bunds'),
#  ('1031-001', 0, 2, 'David_Jones'),
#  ('1138-002', 14, 16, 'Human_Rights'),
#  ('0946-010', 5, 6, 'England'),
#  ('1033-007', 3, 4, 'Chechnya'),
#  ('1011-022', 4, 5, 'NationsBank'),
#  ('1135-018', 0, 2, 'Suu_Kyi'),
#  ('1073-007', 0, 5, 'New_Zealand_-_Tries_:'),
#  ('0968-002', 24, 25, 'Sarajevo'),
#  ('0985-002', 14, 15, 'Britain'),
#  ('1125-006', 32, 33, 'Goma'),
#  ('0958-008', 0, 3, 'BALTIMORE_70_63'),
#  ('1096-005', 16, 17, 'Reds'),
#  ('1068-034', 0, 5, 'Leyton_Orient_2_Hartlepool_0'),
#  ('0966-028', 4, 5, 'U.S.'),
#  ('1096-003', 0, 1, 'Brown'),
#  ('1102-003', 2, 4, 'Nicolas_Ouedec'),
#  ('0972-005', 0, 2, 'M._Waugh'),
#  ('1030-032', 15, 16, 'Democratic'),
#  ('0997-000', 0, 1, 'Yeltsin'),
#  ('1033-010', 30, 31, 'OSCE'),
#  ('1006-009', 20, 23, 'Samer_Ammar_Soliman'),
#  ('0958-033', 0, 1, 'ATLANTA'),
#  ('0995-006', 20, 21, 'Layron'),
#  ('1152-013', 5, 6, 'U.S.'),
#  ('1155-009', 19, 20, 'Iranian'),
#  ('0966-097', 1, 3, 'Karin_Janke'),
#  ('1055-003', 0, 1, 'England'),
#  ('0963-017', 23, 25, 'PGA_Tour'),
#  ('1101-006', 6, 7, 'France'),
#  ('1059-006', 20, 22, 'Dave_Gilbert'),
#  ('1007-019', 0, 1, 'Johnson'),
#  ('0999-002', 1, 2, 'Moscow'),
#  ('1160-018', 4, 5, 'Collins'),
#  ('1028-011', 7, 8, 'Detroit'),
#  ('0997-003', 0, 2, 'Naina_Yeltsin'),
#  ('1058-040', 7, 9, 'Jose_Parra'),
#  ('1016-012', 13, 14, 'Netanyahu'),
#  ('1009-009', 18, 19, 'California'),
#  ('0946-003', 13, 14, 'Essex'),
#  ('0984-017', 17, 18, 'U.S.'),
#  ('1157-004', 5, 6, 'Iraqi'),
#  ('1091-003', 43, 44, 'Langrova'),
#  ('1096-016', 0, 2, 'Todd_Worrell'),
#  ('1058-042', 18, 19, 'Brewers'),
#  ('1055-011', 0, 2, 'D._Gough'),
#  ('1078-007', 2, 3, 'Germany'),
#  ('1001-002', 6, 7, 'BNR'),
#  ('1044-005', 3, 5, 'East_Jerusalem'),
#  ('0962-010', 5, 6, 'Stewart'),
#  ('1012-004', 5, 6, 'U.S.'),
#  ('1103-017', 0, 1, 'Belgian'),
#  ('1019-003', 4, 5, 'Nicole'),
#  ('1058-040', 1, 2, 'Milwaukee'),
#  ('1011-004', 1, 2, 'NationsBank'),
#  ('0953-003', 20, 22, 'Panama_City'),
#  ('1160-014', 3, 4, 'Northern'),
#  ('1037-002', 25, 26, 'Guangdong'),
#  ('1027-007', 5, 6, 'Israel'),
#  ('1085-002', 13, 14, 'European'),
#  ('1088-002', 38, 39, 'Australia'),
#  ('1057-006', 17, 19, 'Matthew_Maynard'),
#  ('1035-009', 2, 3, 'Interfax'),
#  ('1007-010', 6, 7, 'Dole'),
#  ('1043-003', 0, 2, 'Jeerasak_Densakul'),
#  ('1045-000', 4, 5, 'Israeli'),
#  ('1090-010', 0, 3, 'The_United_States'),
#  ('1056-025', 1, 3, 'Oksana_Grichina'),
#  ('1108-002', 21, 22, 'American'),
#  ('1135-026', 0, 2, 'Suu_Kyi'),
#  ('1127-001', 1, 2, 'Stremaitis'),
#  ('1121-004', 4, 5, 'Iraq'),
#  ('1072-009', 11, 13, 'Andrew_Mehrtens'),
#  ('1066-046', 0, 1, 'Gillingham'),
#  ('1065-009', 0, 2, 'St_Mirren'),
#  ('0963-017', 0, 1, 'Henke'),
#  ('1143-003', 18, 21, 'the_United_States'),
#  ('1097-004', 40, 44, 'the_National_Tennis_Centre'),
#  ('1118-002', 33, 34, 'Scotland'),
#  ('1097-015', 0, 1, 'Edberg'),
#  ('0995-003', 26, 27, 'Pamir'),
#  ('1031-015', 5, 7, 'Hong_Kong-listed'),
#  ('1066-029', 0, 4, 'Charlton_2_0_1'),
#  ('1131-003', 23, 24, 'Chile'),
#  ('1016-010', 5, 6, 'Israeli'),
#  ('1119-006', 29, 30, 'Kurds'),
#  ('1152-018', 18, 19, 'U.S.'),
#  ('1142-013', 12, 14, 'Gulf_War'),
#  ('0962-001', 2, 3, 'Wisconsin'),
#  ('1097-020', 26, 27, 'Dutch'),
#  ('0981-003', 2, 6, 'Douglas_&_Lomason_Co'),
#  ('1035-002', 11, 12, 'Germany'),
#  ('1142-000', 3, 4, 'Iranian'),
#  ('1101-007', 20, 23, 'Espanyol_of_Barcelona'),
#  ('1044-004', 11, 12, 'Palestinians'),
#  ('1096-010', 9, 10, 'Reds'),
#  ('0949-003', 29, 30, 'European'),
#  ('1025-008', 1, 2, 'Israel'),
#  ('1004-008', 0, 4, 'Co-Premiers_Prince_Norodom_Ranariddh'),
#  ('1121-005', 19, 20, 'Arbil'),
#  ('1070-009', 7, 9, 'Reynard_Mercedes-Benz'),
#  ('0999-001', 0, 1, 'MOSCOW'),
#  ('1065-036', 0, 2, 'East_Stirling'),
#  ('1016-011', 13, 14, 'German-Israeli'),
#  ('1014-004', 41, 43, 'Peter_Knight'),
#  ('1067-011', 2, 4, 'Berwick_0'),
#  ('1055-001', 2, 3, 'England'),
#  ('1090-003', 9, 10, 'Spain'),
#  ('0954-003', 6, 8, 'Dan_Jenson'),
#  ('1005-010', 12, 14, 'Hong_Kong'),
#  ('1014-009', 21, 22, 'Dole'),
#  ('1152-004', 19, 20, 'Gulf'),
#  ('1016-002', 1, 2, 'German'),
#  ('1056-034', 27, 29, 'Francis_Moreau'),
#  ('0966-164', 22, 23, 'Germany'),
#  ('1014-009', 16, 18, 'Jack_Kemp'),
#  ('0966-018', 1, 3, 'Margarita_Maruseva'),
#  ('1056-020', 4, 5, 'France'),
#  ('1140-003', 15, 18, 'the_High_Court'),
#  ('1152-014', 49, 52, 'the_United_States'),
#  ('1058-015', 7, 8, 'West'),
#  ('0973-002', 11, 13, 'Sri_Lanka'),
#  ('0948-029', 9, 10, 'Birmingham'),
#  ('1087-020', 19, 20, 'Eyles'),
#  ('1121-002', 22, 23, 'Kurdish'),
#  ('1031-004', 0, 1, 'Pirelli'),
#  ('1097-006', 6, 7, 'Edberg'),
#  ('1045-005', 8, 9, 'Israeli'),
#  ('1101-003', 37, 39, 'Franck_Leboeuf'),
#  ('1016-012', 9, 10, 'Israeli'),
#  ('1096-031', 1, 3, 'New_York'),
#  ('0990-011', 18, 19, 'Chechnya'),
#  ('0958-030', 2, 3, 'SEATTLE'),
#  ('1160-007', 9, 10, 'British'),
#  ('1100-002', 1, 3, 'Tom_Johnson'),
#  ('1152-003', 31, 32, 'U.S.'),
#  ('1121-003', 29, 30, 'Arbil'),
#  ('1103-012', 15, 17, 'Arif_Erdem'),
#  ('1135-006', 18, 21, "Suu_Kyi_'s"),
#  ('0966-160', 4, 6, 'Jesse_Owens'),
#  ('1062-003', 2, 4, 'Dean_Saunders'),
#  ('1060-010', 1, 3, 'Mark_McNulty'),
#  ('0947-007', 0, 2, 'Tunbridge_Wells'),
#  ('1070-013', 8, 10, 'Penske_Mercedes-Benz'),
#  ('1101-007', 15, 16, 'Ouedec'),
#  ('1012-002', 20, 21, 'U.S.'),
#  ('1094-045', 0, 1, 'SAN'),
#  ('0986-006', 18, 19, 'Quinn'),
#  ('0966-025', 1, 3, 'Falk_Balzer'),
#  ('1116-008', 0, 3, 'Charles_ceded_Alsace'),
#  ('1072-015', 26, 27, 'Joubert'),
#  ('0957-000', 7, 8, 'U.S.'),
#  ('1072-019', 16, 18, 'Jeff_Wilson'),
#  ('0966-034', 4, 5, 'Belgium'),
#  ('1015-003', 24, 25, 'Newfoundland'),
#  ('1125-008', 5, 6, 'Dondo'),
#  ('1064-005', 15, 17, 'Laurent_Benezech'),
#  ('0974-008', 9, 11, 'Sanath_Jayasuriya'),
#  ('1009-007', 16, 17, 'Mexican'),
#  ('1056-017', 0, 1, 'France'),
#  ('0957-018', 32, 34, 'Filippo_Veglio'),
#  ('1060-017', 4, 5, 'Ireland'),
#  ('1067-006', 0, 2, 'Partick_1'),
#  ('0980-014', 16, 17, 'U.S.'),
#  ('1010-003', 0, 1, 'Bernardin'),
#  ('0986-006', 4, 5, 'Staunton'),
#  ('1055-019', 3, 5, 'Saqlain_Mushtaq'),
#  ('0963-004', 12, 15, 'U.S._Amateur_Championship'),
#  ('1094-024', 3, 4, 'DETROIT'),
#  ('1116-036', 15, 16, 'Europe'),
#  ('1004-007', 6, 7, 'Vipheak'),
#  ('1155-009', 15, 16, 'Berlin'),
#  ('1009-014', 14, 15, 'Mexican'),
#  ('1066-023', 0, 2, 'Manchester_City'),
#  ('1100-002', 17, 18, 'Venezuela'),
#  ('1136-007', 3, 4, 'Mobil'),
#  ('1058-041', 0, 1, 'Milwaukee'),
#  ('1152-004', 49, 52, 'the_United_States'),
#  ('1146-002', 10, 11, 'Iraqi'),
#  ('1115-002', 1, 2, 'British'),
#  ('0992-009', 1, 2, 'SDA'),
#  ('1116-006', 14, 15, 'Austrians'),
#  ('1160-003', 2, 4, 'Neil_Jordan'),
#  ('1054-000', 0, 4, 'CYCLING_-_TOUR_OF'),
#  ('1094-013', 0, 2, 'CLEVELAND_80'),
#  ('1056-047', 9, 11, 'Rasa_Mazeikyte'),
#  ('0946-010', 13, 14, 'Surrey'),
#  ('1161-002', 37, 38, 'Moslem'),
#  ('0966-164', 7, 9, 'Falk_Balzer'),
#  ('1030-031', 8, 9, 'Clinton'),
#  ('1160-011', 20, 21, 'China'),
#  ('1069-001', 0, 1, 'LONDON'),
#  ('0991-003', 24, 25, 'Lebed'),
#  ('1054-023', 5, 6, 'Netherlands'),
#  ('0966-152', 4, 5, 'Germany'),
#  ('0984-009', 9, 10, 'Paris'),
#  ('0974-007', 0, 1, 'Australia'),
#  ('1056-044', 3, 4, 'Russia'),
#  ('1056-014', 6, 7, '3:52.204'),
#  ('1011-003', 22, 23, 'Missouri'),
#  ('0966-005', 4, 5, 'Sweden'),
#  ('1053-001', 2, 3, 'England'),
#  ('1060-020', 1, 4, 'Miguel_Angel_Jimenez'),
#  ('1030-013', 6, 7, 'German'),
#  ('1160-004', 14, 16, 'Michael_Collins'),
#  ('1004-007', 11, 12, 'KNP'),
#  ('0957-019', 20, 23, '7-5_Asa_Carlsson'),
#  ('1143-003', 32, 33, 'Naqoura'),
#  ('0957-012', 6, 8, 'Mikael_Tillstrom'),
#  ('0966-116', 4, 5, 'Germany'),
#  ('1009-011', 23, 27, 'the_World_Trade_Organisation'),
#  ('0962-005', 4, 5, 'U.S.'),
#  ('1124-003', 18, 19, 'Afrikaners'),
#  ('1099-008', 9, 11, 'Gary_McAllister'),
#  ('1012-008', 40, 41, 'Scotland'),
#  ('1116-005', 14, 15, 'Europe'),
#  ('0957-019', 7, 9, 'Linda_Wild'),
#  ('1161-007', 7, 9, 'Bangladesh_Lamps'),
#  ('0960-015', 1, 2, 'Texan'),
#  ('0948-024', 10, 11, 'London'),
#  ('0966-161', 16, 17, 'Namibia'),
#  ('1096-002', 0, 3, 'Major_league_ERA'),
#  ('1035-002', 4, 5, 'Azerbaijan'),
#  ('1046-002', 28, 29, 'Spanish'),
#  ('1125-012', 37, 38, 'Hutus'),
#  ('0966-110', 1, 3, 'Nico_Motchebon'),
#  ('1116-032', 10, 11, 'Anglicans'),
#  ('0966-164', 13, 15, 'George_Panayiotopoulos'),
#  ('1068-006', 0, 3, 'Grimsby_0_Portsmouth'),
#  ('1037-004', 3, 4, 'AXE'),
#  ('0957-024', 0, 2, 'Hendrik_Dreekmann'),
#  ('1045-006', 41, 45, 'the_Palestinian_Liberation_Organisation'),
#  ('1035-008', 10, 11, 'Nagorno-Karabakh'),
#  ('0996-004', 14, 15, 'Poles'),
#  ('1143-001', 0, 1, 'JERUSALEM'),
#  ('0968-004', 5, 6, 'Edwards'),
#  ('1016-014', 7, 9, 'Yitzhak_Mordechai'),
#  ('1009-018', 27, 29, 'Tom_Bellamore'),
#  ('1031-003', 13, 14, 'China'),
#  ('1070-015', 1, 3, 'Mauricio_Gugelmin'),
#  ('1089-024', 0, 1, 'Bob'),
#  ('0991-002', 10, 12, 'Aslan_Maskhadov'),
#  ('1051-002', 8, 9, 'British'),
#  ('1111-008', 3, 4, 'John'),
#  ('1155-011', 6, 7, 'Banisadr'),
#  ('1076-014', 0, 1, 'Partizan'),
#  ('1135-021', 6, 7, 'Rangoon'),
#  ('1132-000', 4, 5, 'Michoacan'),
#  ('1027-020', 12, 13, 'Israeli'),
#  ('0975-012', 4, 6, 'Bucharest_Newsroom'),
#  ('0963-023', 0, 2, 'Phil_Mickelson'),
#  ('1133-006', 22, 24, 'Amnesty_International'),
#  ('0966-162', 4, 5, 'Jamaica'),
#  ('1121-002', 1, 2, 'Iraqi'),
#  ('1137-002', 24, 25, 'Seoul'),
#  ('1072-008', 12, 14, 'Walter_Little'),
#  ('1000-000', 3, 4, 'H1'),
#  ('0946-012', 1, 3, 'Tom_Moody'),
#  ('0966-164', 19, 20, 'Florian'),
#  ('0948-044', 6, 8, 'Trent_Bridge'),
#  ('1049-003', 22, 23, 'Norwich'),
#  ('1127-019', 11, 13, 'Nurbika_Mamatuyeva'),
#  ('1034-000', 0, 1, 'Dutch'),
#  ('1155-012', 7, 8, 'France'),
#  ('1103-006', 27, 30, 'Filip_De_Wilde'),
#  ('1011-012', 10, 11, 'Missouri'),
#  ('1103-020', 7, 9, 'Van_Moer'),
#  ('0981-006', 24, 27, 'Johnson_Controls_Inc'),
#  ('1134-002', 11, 18, 'the_Organisation_of_Islamic_Conference_(_OIC'),
#  ('1058-028', 0, 1, 'Thomas'),
#  ('1049-004', 0, 1, 'Quinn'),
#  ('0987-005', 5, 6, 'Uyo'),
#  ('0966-000', 0, 6, 'ATHLETICS_-_BERLIN_GRAND_PRIX_RESULTS'),
#  ('1044-000', 0, 1, 'Arafat'),
#  ('1101-003', 6, 7, 'France'),
#  ('1025-005', 2, 4, 'Yasser_Arafat'),
#  ('1071-002', 0, 1, 'Canada'),
#  ('0974-009', 1, 2, 'Kaluwitharana'),
#  ('1052-002', 15, 16, 'European'),
#  ('1139-002', 5, 7, 'Wang_Donghai'),
#  ('0968-004', 33, 34, 'Balkans'),
#  ('1089-006', 16, 17, 'Classic'),
#  ('1004-007', 15, 17, 'Chan_Rattana'),
#  ('1096-006', 1, 2, 'Bolesy'),
#  ('1003-002', 2, 3, 'Surinamese'),
#  ('0947-006', 20, 21, 'Durham'),
#  ('0988-002', 21, 23, 'Gold_Fields'),
#  ('1112-008', 18, 19, 'Germany'),
#  ('1000-009', 10, 11, 'Budapest'),
#  ('1069-006', 5, 6, 'Durham'),
#  ('0946-009', 2, 3, 'Oval'),
#  ('1039-019', 0, 1, 'Megawati'),
#  ('0958-025', 2, 3, 'TORONTO'),
#  ('0966-135', 1, 3, 'Bob_Kennedy'),
#  ('1117-001', 0, 1, 'LONDON'),
#  ('1035-010',
#   14,
#   23,
#   'the_Organisation_for_Security_and_Cooperation_in_Europe_('),
#  ('0985-011', 12, 13, 'American'),
#  ('1131-002', 4, 7, 'the_United_Nations'),
#  ('1039-014', 6, 7, 'Timor'),
#  ('0954-003', 3, 4, 'Australia'),
#  ('1010-002', 2, 4, 'Joseph_Bernardin'),
#  ('0991-002', 22, 23, 'Chechnya'),
#  ('1117-003', 29, 30, 'England'),
#  ('0958-021', 0, 3, 'OAKLAND_64_72'),
#  ('1016-014', 5, 6, 'Israeli'),
#  ('0960-014', 12, 13, 'Washington'),
#  ('0949-005', 12, 14, 'Glenn_Hoddle'),
#  ('1076-016', 0, 1, 'Vojvodina'),
#  ('1110-002', 14, 16, 'James_Heath'),
#  ('1057-007', 5, 7, 'Saeed_Anwar'),
#  ('0974-007', 23, 25, 'Ricky_Ponting'),
#  ('0957-020', 7, 11, '1_-_Pete_Sampras'),
#  ('1094-047', 0, 1, 'COLORADO'),
#  ('1141-000', 0, 1, 'China'),
#  ('1007-026', 38, 39, 'Geraghty'),
#  ('1005-005', 22, 24, 'South_Korean'),
#  ('1006-011', 17, 19, 'Jebel_al-Akhdar'),
#  ('1091-003', 45, 47, 'Czech_Republic'),
#  ('1116-011', 8, 9, 'Pedro'),
#  ('0955-004', 0, 4, 'Pohang_3_Ulsan_2'),
#  ('1033-008', 5, 6, 'Chechen'),
#  ('1032-002', 7, 8, 'Dutch'),
#  ('0997-005', 1, 3, 'Naina_Yeltsin'),
#  ('1152-007', 24, 25, 'Iraqi'),
#  ('0960-013', 20, 21, 'Washington'),
#  ('1073-002', 3, 5, 'New_Zealand'),
#  ('1002-003', 14, 15, 'Reuters'),
#  ('0995-006', 0, 1, 'Sherbatov'),
#  ('1027-004', 6, 7, 'Palestinian'),
#  ('0983-002', 35, 36, 'Britain'),
#  ('1034-002', 1, 2, 'Dutch'),
#  ('1160-010', 5, 9, '"_The_Crying_Game'),
#  ('0995-001', 0, 2, 'Yuri_Kushko'),
#  ('0997-004', 1, 2, 'Russian'),
#  ...}

# %% [markdown]
# ## Problem 5: Extending the training data using the knowledge base

# %% [markdown]
# State-of-the-art approaches to entity linking exploit information in knowledge bases. In our case, where Wikipedia is the knowledge base, one particularly useful type of information are links to other Wikipedia pages. In particular, we can interpret the anchor texts (the highlighted texts that you click on) as mentions of the entities (pages) that they link to. This allows us to harvest long lists of mention–entity pairings.
#
# The following cell loads a data frame summarizing anchor texts and page references harvested from the first paragraphs of the English Wikipedia. The data frame also contains all entity mentions in the training data (but not the development or the test data).

# %%
with bz2.open('kb.tsv.bz2', 'rt') as source:
    df_kb = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# To understand what information is availabel in this data, the following cell shows the entry for the anchor text `Sweden`.

# %%
df_kb.loc[df_kb.mention == 'Sweden']
# Out:
#       mention                                 entity      prob
# 17436  Sweden                                 Sweden  0.985768
# 17437  Sweden          Sweden_national_football_team  0.014173
# 17438  Sweden  Sweden_men's_national_ice_hockey_team  0.000059

# %% [markdown]
# As you can see, each row of the data frame contains a pair $(m, e)$ of a mention $m$ and an entity $e$, as well as the conditional probability $P(e|m)$ for mention $m$ referring to entity $e$. These probabilities were estimated based on the frequencies of mention–entity pairs in the knowledge base. The example shows that the anchor text &lsquo;Sweden&rsquo; is most often used to refer to the entity [Sweden](http://en.wikipedia.org/wiki/Sweden), but in a few cases also to refer to Sweden&rsquo;s national football and ice hockey teams. Note that references are sorted in decreasing order of probability, so that the most probable pairing come first.
#
# Implement an entity linking method that resolves each mention to the most probable entity in the data frame. If the mention is not included in the data frame, you can predict the generic label `--NME--`. Print the precision, recall, and F1 of your method using the function that you implemented for Problem&nbsp;1.

# %%
new_df_dev.head()
# Out:
#   sentence_id                                           sentence  beg  end  \
# 0    0969-003  Baratelli , who played for Nice and Paris St G...    5    6
# 1    0957-026  Andrei Medvedev ( Ukraine ) beat Jan Kroslak (...    0    2
# 2    0946-014  They were held up by a gritty 84 from Paul Joh...    9   11
# 3    1011-022  They also questioned whether NationsBank can r...   15   16
# 4    0957-030  2 - Monica Seles ( U.S. ) beat Dally Randriant...    5    6
#
#      label
# 0  --NME--
# 1  --NME--
# 2  --NME--
# 3  --NME--
# 4  --NME--

# %%
df_kb.head()
# Out:
#            mention                   entity  prob
# 0      000 Guineas      2000_Guineas_Stakes   1.0
# 1            10 00     United_States_dollar   1.0
# 2      126 million     United_States_dollar   1.0
# 3     13th dynasty  Middle_Kingdom_of_Egypt   1.0
# 4  14th Dalai Lama          14th_Dalai_Lama   1.0

# %%
# # TODO: Write code here to implement the "most probable entity" method.
# # df: new_df_dev
# # since we conclude df_kb in function, we only need df Args
# Yao's code
# def entity_link(df):
#     return_list = []
#     for row in df.itertuples():
#         entity = df_kb.loc[df_kb.mention == nlp(row[2])[row[3]:row[4]].text][0:1]['entity'].values # remove _
#         if len(entity) == 0:
#             return_list += [(row[1],row[3],row[4],'--NME--')] # row[1] is sentence_id, row[3]: beg; row[4]: end
#         else:
#             return_list += [(row[1],row[3],row[4],entity[0])]
#     return set(return_list)

# %%
# TODO: Write code here to implement the "most probable entity" method.    
def entity_link(new_df_dev):
    return_list = []
    for row in new_df_dev.itertuples():
        df_label = '_'.join(row[2].split(' ')[row[3] : row[4]]) # add '_'
        mentions = df_kb.loc[df_kb['mention'] == df_label]
        if len(mentions) > 0:
            # the prob goes from highest to lowest, hte first one is what we need 
            label = mentions.iloc[0].entity
            return_list += [(row[1],row[3],row[4],label)]
        else:
            label = '--NME--'
            return_list += [(row[1],row[3],row[4],label)] # row[1] is sentence_id, row[3]: beg; row[4]: end

        # yield row.sentence_id, row.beg, row.end, label
    return set(return_list)

# %%
pred = set(entity_link(new_df_dev))
evaluation_report(gold_standard_mentions, pred = pred)
# Out:
# precission:  0.4889750918742344 , recall:  0.4047659286800744 , F1_score:  0.4429033749422099

# %% [markdown]
# ## Problem 6: Context-sensitive disambiguation

# %% [markdown]
# Consider the entity mention &lsquo;Lincoln&rsquo;. The most probable entity for this mention turns out to be [Lincoln, Nebraska](http://en.wikipedia.org/Lincoln,_Nebraska); but in pages about American history, we would be better off to predict [Abraham Lincoln](http://en.wikipedia.org/Abraham_Lincoln). This suggests that we should try to disambiguate between different entity references based on the textual context on the page from which the mention was taken. Your task in this last problem is to implement this idea.
#
# Set up a dictionary that contains, for each mention $m$ that can refer to more than one entity $e$, a separate Naive Bayes classifier that is trained to predict the correct entity $e$, given the textual context of the mention. As the prior probabilities of the classifier, choose the probabilities $P(e|m)$ that you used in Problem&nbsp;5. To let you estimate the context-specific probabilities, we have compiled a data set with mention contexts:

# %%
with bz2.open('contexts.tsv.bz2') as source:
    df_contexts = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# This data frame contains, for each ambiguous mention $m$ and each knowledge base entity $e$ to which this mention can refer, up to 100 randomly selected contexts in which $m$ is used to refer to $e$. For this data, a **context** is defined as the 5 tokens to the left and the 5 tokens to the right of the mention. Here are a few examples:

# %%
df_contexts.head()
# Out:
#           mention                 entity  \
# 0            1970  UEFA_Champions_League
# 1            1970         FIFA_World_Cup
# 2  1990 World Cup    1990_FIFA_World_Cup
# 3  1990 World Cup    1990_FIFA_World_Cup
# 4  1990 World Cup    1990_FIFA_World_Cup
#
#                                              context
# 0    Cup twice the first in @ and the second in 1983
# 1  America 1975 and during the @ and 1978 World C...
# 2                 Manolo represented Spain at the @
# 3  Hašek represented Czechoslovakia at the @ and ...
# 4  renovations in 1989 for the @ The present capa...

# %% [markdown]
# Note that, in each context, the position of the mention is indicated by the `@` symbol.
#
# From this data frame, it is easy to select the data that you need to train the classifiers – the contexts and corresponding entities for all mentions. To illustrate this, the following cell shows how to select all contexts that belong to the mention &lsquo;Lincoln&rsquo;:

# %%
df_contexts.context[df_contexts.mention == 'Lincoln']
# Out:
# 41465    Nebraska Concealed Handgun Permit In @ municip...
# 41466    Lazlo restaurants are located in @ and Omaha C...
# 41467    California Washington Overland Park Kansas @ N...
# 41468    City Missouri Omaha Nebraska and @ Nebraska It...
# 41469    by Sandhills Publishing Company in @ Nebraska USA
#                                ...
# 41609                                      @ Leyton Orient
# 41610                    English division three Swansea @
# 41611    league membership narrowly edging out @ on goa...
# 41612                                          @ Cambridge
# 41613                                                   @
# Name: context, Length: 149, dtype: object

# %% [markdown]
# Implement the context-sensitive disambiguation method and evaluate its performance. Here are some more hints that may help you along the way:
#
# **Hint 1:** The prior probabilities for a Naive Bayes classifier can be specified using the `class_prior` option. You will have to provide the probabilities in the same order as the alphabetically sorted class (entity) names.
#
# **Hint 2:** Not all mentions in the knowledge base are ambiguous, and therefore not all mentions have context data. If a mention has only one possible entity, pick that one. If a mention has no entity at all, predict the `--NME--` label.

# %%
# TODO: Write code here to implement the context-sensitive disambiguation method
import math
import numpy as np
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer

vectorizer1 = CountVectorizer()
vectorizer1.fit(np.append(df_contexts.context.values,df_contexts.mention.values))

dict_mention = dict()

for m in set(df_contexts.mention):
    contexts = df_contexts[df_contexts.mention == m]['context'].values
    entity = df_contexts[df_contexts.mention == m]['entity'].values
    #complete contexts by replacing the '@'
    contexts_replace = [x[0].replace('@', x[1]) for x in zip(contexts, entity)]
    #compute prior probabilities
    prior_prob_list = [df_kb.prob[(df_kb.mention == m)&(df_kb.entity == x)].values[0] for x in sorted(set(entity))]
    #vectorize context as input data
    X = vectorizer1.transform(contexts_replace)
    model = MultinomialNB(class_prior = prior_prob_list)
    dict_mention[m] = model.fit(X,entity)

# %%
# prediction
def predict_cs(df):
    return_list = []
    for row in df.itertuples():
        # extract mentions from sentences
        mention = nlp(row[2])[row[3]:row[4]].text
        if mention in dict_mention.keys():
            context = [nlp(row[2])[row[3]-5:row[4]-5].text]
            #predict using the model stored in dictionary
            entity_pre = dict_mention[mention].predict(vectorizer1.transform(context))[0]
            return_list += [(row[1],row[3],row[4],entity_pre)]
        
        else:
            # for the mentions which don't have contexts, use entity_link instead
            return_list += [x for x in entity_link(pd.DataFrame([row[1:]]))]

    return set(return_list)

# %%
evaluation_report(set(gold_mentions(df_dev)), predict_cs(new_df_dev))
# Out:
# precission:  0.5134748877092691 , recall:  0.42504647625485886 , F1_score:  0.46509477577438746

# %% [markdown]
# You should expect to see a small (around 1&nbsp;unit) increase in both precision, recall, and F1.

# %% [markdown]
# ----My Answer:
#
# ----In problem 5:
# precission:  0.6496529195590037 , recall:  0.5377725198580362 , F1_score:  0.588441978733241
#
# ----In problem 6:
# precission:  0.6518987341772152 , recall:  0.5396315700523914 , F1_score:  0.5904761904761905
#
# ----As we expected, these values have improved slightly, the function in Problem 6 works

# %% [markdown]
# ## Reflection questions

# %% [markdown]
# The following reflection questions will help you prepare for the diagnostic test. Answer each of them in the form of a short text and put your answers in the cell below. You will get feedback on your answers from your lab assistant.

# %% [markdown]
# **RQ 5.1:** In Problem&nbsp;3, you did an error analysis on the task of recognizing text spans mentioning named entities. Summarize your results. Pick one type of error that you observed. How could you improve the model&rsquo;s performance on this type of error? What resources (such as domain knowledge, data, compute) would you need to implement this improvement?
#
# **RQ 5.2:** Thinking back about Problem&nbsp;6, explain what the word *context* refers to in the task addressed there, and how context can help to disambiguate between different entities. Suggest other types of context that you could use for disambiguation.
#
# **RQ 5.3:** One type of entity mentions that we did not cover explicitly in this lab are pronouns. As an example, consider the sentence pair *Ruth Bader Ginsburg was an American jurist*. *She served as an associate justice of the Supreme Court from 1993 until her death in 2020*. What facts would you want to extract from this sentence pair? How do pronouns make fact extraction hard?

# %% [markdown]
# *TODO: Enter your answers here*
#
# ----5.1
#
# We improve accuracy by removing number-related types. For example, one of the FPs is 'FP: 1996-08-30', This is a type that represents the date. There are various formats of the date. We need to improve the accuracy of the predicted date through calculation and some discriminants.
#
# ----5.2
#
# context similarity.
#
# for example: The meaning of "apple" in the sentences "my mobile phone is Apple" and "I like to eat apples" is different.
#
# We can calculate similarity by context. For example, we know that "Apple: is a kind of fruit.", "Apple: a high-tech company in the United States, and its classic products include iPhone", we can express these two meanings with vectors; Next, for a sentence that needs to be recognized, such as "I want to eat an apple", the context of "apple" in this sentence is taken out and converted into a vector, and compared with the above two meanings, which one has the highest similarity, it can be considered what meaning the word represents.
#
# Other types can be word class. We use the above apple's example, "eat" is a verb, it will be associated with apples(fruit). Adjectives such as: "systematic", "latest", they will be used to describe Apple mobile phones.
#
#
# ---5.3
#
# Ruth Bader Ginsburg served as associate justice of the Supreme Court from 1993 until her death in 2020.
#
# Because we need to associate the pronoun with the preceding object or context, which increases the difficulty of extracting information.

# %% [markdown]
# **This was the last lab in the Text Mining course. Congratulations! 🥳**
