# %% [markdown]
# # L5: Information extraction

# %% [markdown]
# Information extraction (IE) is the task of identifying named entities and semantic relations between these entities in text data. In this lab we will focus on two sub-tasks in IE, **named entity recognition** (identifying mentions of entities) and **entity linking** (matching these mentions to entities in a knowledge base).

# %% [markdown]
# **Reminder about our [Rules for hand-in assignments](https://www.ida.liu.se/~TDDE16/exam.en.shtml#handins) and the [Policy on cheating and plagiarism](https://www.ida.liu.se/~TDDE16/exam.en.shtml#cheating)**

# %% [markdown]
# We start by loading spaCy:

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# The data that we will be using has been tokenized following the conventions of the [Penn Treebank](ftp://ftp.cis.upenn.edu/pub/treebank/public_html/tokenization.html), and we need to prevent spaCy from using its own tokenizer on top of this. We therefore override spaCy&rsquo;s tokenizer with one that simply splits on space.

# %%
from spacy.tokens import Doc

class WhitespaceTokenizer(object):
    def __init__(self, vocab):
        self.vocab = vocab

    def __call__(self, text):
        return Doc(self.vocab, words=text.split(' '))

nlp.tokenizer = WhitespaceTokenizer(nlp.vocab)

# %% [markdown]
# ## Data set

# %% [markdown]
# The main data set for this lab is a collection of news wire articles in which mentions of named entities have been annotated with page names from the [English Wikipedia](https://en.wikipedia.org/wiki/). The next code cell loads the training and the development parts of the data into Pandas data frames.

# %%
import bz2
import csv
import pandas as pd

with bz2.open('ner-train.tsv.bz2', 'rt') as source:
    df_train = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

with bz2.open('ner-dev.tsv.bz2', 'rt') as source:
    df_dev = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# Each row in these two data frames corresponds to one mention of a named entity and has five columns:
#
# 1. a unique identifier for the sentence containing the entity mention
# 2. the pre-tokenized sentence, with tokens separated by spaces
# 3. the start position of the token span containing the entity mention
# 4. the end position of the token span (exclusive, as in Python list indexing)
# 5. the entity label; either a Wikipedia page name or the generic label `--NME--`
#
# The following cell prints the first five samples from the training data:

# %%
df_train.head()
type(df_train)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# In this sample, we see that the first sentence is annotated with three entity mentions:
#
# * the span 0–1 &lsquo;EU&rsquo; is annotated as a mention but only labelled with the generic `--NME--`
# * the span 2–3 &lsquo;German&rsquo; is annotated with the page [Germany](http://en.wikipedia.org/wiki/Germany)
# * the span 6–7 &lsquo;British&rsquo; is annotated with the page [United_Kingdom](http://en.wikipedia.org/wiki/United_Kingdom)

# %% [markdown]
# ## Problem 1: Evaluation measures

# %% [markdown]
# To warm up, we ask you to write code to print the three measures that you will be using for evaluation:

# %%
def evaluation_report(gold, pred):
    """Print precision, recall, and F1 score.
    
    Args:
        gold: The set with the gold-standard values.
        pred: The set with the predicted values.
    
    Returns:
        Nothing, but prints the precision, recall, and F1 values computed
        based on the specified sets.
    """
    # TODO: Replace the next line with your own code
    TP = len(gold & pred) # intersection
    TN = 0
    FP = len(pred - gold)
    FN = len(gold - pred)

    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    F1_score = (2 * precision * recall) / (precision + recall)
    
    print("precission: ",precision, ", recall: ", recall, ", F1_score: ", F1_score )

# %% [markdown]
# To test your code, you can run the following cell:

# %%
evaluation_report(set(range(3)), set(range(5)))
# Out:
# precission:  0.6 , recall:  1.0 , F1_score:  0.7499999999999999

# %% [markdown]
# This should give you a precision of 60%, a recall of 100%, and an F1-value of 75%.

# %% [markdown]
# ## Problem 2: Span recognition

# %% [markdown]
# One of the first tasks that an information extraction system has to solve is to locate and classify (mentions of) named entities, such as persons and organizations. Here we will tackle the simpler task of recognizing **spans** of tokens that contain an entity mention, without the actual entity label.
#
# The English language model in spaCy features a full-fledged [named entity recognizer](https://spacy.io/usage/linguistic-features#named-entities) that identifies a variety of entities, and can be updated with new entity types by the user. Your task in this problem is to evaluate the performance of this component when predicting entity spans in the development data.
#
# Start by implementing a generator function that yields the gold-standard spans in a given data frame.
#
# **Hint:** The Pandas method [`itertuples()`](https://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.DataFrame.itertuples.html) is useful when iterating over the rows in a DataFrame.

# %%
def gold_spans(df):
    """Yield the gold-standard mention spans in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        triples consisting of the sentence id, start position, and end
        position of each span.
    """
    # TODO: Replace the next line with your own code
    for row in df.itertuples():
        yield row.sentence_id, row.beg, row.end

# %% [markdown]
# To test your code, you can count the spans yielded by your function. When called on the development data, you should get a total of 5,917 unique triples. The first triple and the last triple should be
#
#     ('0946-000', 2, 3)
#     ('1161-010', 1, 3)

# %%
spans_dev_gold = set(gold_spans(df_dev))
print(len(spans_dev_gold))
# Out:
# 5917

# %% [markdown]
# Your next task is to write code that calls spaCy to predict the named entities in the development data, and to evaluate the accuracy of these predictions in terms of precision, recall, and F1. Print these scores using the function that you wrote for Problem&nbsp;1.

# %%
# TODO: Write code here to run and evaluate the spaCy named entity recognizer on the development data
def spacy_pred(df):
    for row in df.itertuples():
        doc = nlp(row.sentence)
        for ent in doc.ents:
            yield row.sentence_id, ent.start, ent.end
pred = set(spacy_pred(df_dev))
evaluation_report(spans_dev_gold, pred= pred)
# Out:
# precission:  0.5213954072029113 , recall:  0.702213959776914 , F1_score:  0.5984444764511019

# %% [markdown]
# ## Problem 3: Error analysis

# %% [markdown]
# As you were able to see in Problem&nbsp;2, the span accuracy of the named entity recognizer is far from perfect. In particular, only slightly more than half of the predicted spans are correct according to the gold standard. Your next task is to analyse this result in more detail.
#
# Here is a function that prints the false positives as well as the false negatives spans for a data frame, given a reference set of gold-standard spans and a candidate set of predicted spans.

# %%
from collections import defaultdict

def error_report(df, spans_gold, spans_pred):
    false_pos = defaultdict(list)
    for s, b, e in spans_pred - spans_gold:
        false_pos[s].append((b, e))
    false_neg = defaultdict(list)
    for s, b, e in spans_gold - spans_pred:
        false_neg[s].append((b, e))
    for row in df.drop_duplicates('sentence_id').itertuples():
        if row.sentence_id in false_pos or row.sentence_id in false_neg:
            print('Sentence:', row.sentence)
            for b, e in false_pos[row.sentence_id]:
                print('  FP:', ' '.join(row.sentence.split()[b:e]))
            for b, e in false_neg[row.sentence_id]:
                print('  FN:', ' '.join(row.sentence.split()[b:e]))

# %% [markdown]
# Use this function to inspect and analyse the errors that the automated prediction makes. Can you see any patterns? Base your analysis on the first 500 rows of the training data. Summarize your observations in a short text.

# %%
# TODO: Write code here to do your analysis

# %% [markdown]
# *TODO: Write a short text that summarises the errors that you observed*

# %% [markdown]
# Now, use the insights from your error analysis to improve the automated prediction that you implemented in Problem&nbsp;2. While the best way to do this would be to [update spaCy&rsquo;s NER model](https://spacy.io/usage/linguistic-features#updating) using domain-specific training data, for this lab it suffices to write code to post-process the output produced by spaCy. To filter out specific labels it is useful to know the named entity label scheme, which can be found in the [model's documentation](https://spacy.io/models/en#en_core_web_sm). You should be able to improve the F1 score from Problem&nbsp;2 by at last 15 percentage points.

# %%
# TODO: Write code here to run and evaluate the spaCy named entity recognizer on the development data
def spacy_pred(df):
    for row in df.itertuples():
        doc = nlp(row.sentence)
        for ent in doc.ents:
            # if ent.label_ in ['CARDINAL', 'DATE', 'EVENT', 'FAC', 'GPE', 'LANGUAGE', 'LAW', 'LOC', 'MONEY', 'NORP', 'ORDINAL',
            #  'ORG', 'PERCENT', 'PERSON', 'PRODUCT', 'QUANTITY', 'TIME', 'WORK_OF_ART']:
            # here we removed time, date, cardinal, money, fac, ORDINAL
            if ent.label_ in ['EVENT', 'GPE', 'LANGUAGE', 'LAW', 'LOC', 'NORP','ORG', 'PERCENT', 'PERSON', 'PRODUCT', 'QUANTITY', 'WORK_OF_ART']:
                yield row.sentence_id, ent.start, ent.end
pred = set(spacy_pred(df_dev))
evaluation_report(spans_dev_gold, pred= pred)
# Out:
# precission:  0.8194831013916501 , recall:  0.6966368091938482 , F1_score:  0.7530830364483421

# %% [markdown]
# Show that you achieve the performance goal by reporting the evaluation measures that you implemented in Problem&nbsp;1.

# %% [markdown]
# Before going on, we ask you to store the outputs of the improved named entity recognizer on the development data in a new data frame. This new frame should have the same layout as the original data frame for the development data that you loaded above, but should contain the *predicted* start and end positions for each token span, rather than the gold positions. As the `label` of each span, you can use the special value `--NME--`.

# %%
# TODO: Write code here to store the predicted spans in a new data frame

# remove data, keep titles
new_df_dev = df_dev.drop(index=df_dev.index)

#add new row to the end of DataFrame
for id, start, end in pred:
    new_df_dev.loc[len(new_df_dev.index)] = [id, df_dev[df_dev['sentence_id'] == id].iloc[0]['sentence'], start, end, '--NME--']

print(type(new_df_dev))
new_df_dev
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      sentence_id                                           sentence  beg  end  \
# 0       1038-004  Hong Kong also had the necessary " constitutio...   28   29
# 1       1125-008  Zairean Prime Minister Kengo wa Dondo said at ...   21   22
# 2       1103-015  Belgium - 1 - Filip De Wilde , 2 - Bertrand Cr...   33   38
# 3       1152-010  The U.S. defense officials said military fligh...    1    2
# 4       0966-137        4. El Hassane Lahssini ( Morocco ) 13:06.57    5    6
# ...          ...                                                ...  ...  ...
# 5025    0981-007  Family-controlled Douglas & Lomason , which ha...    1    4
# 5026    1159-003  " There is no trace so far , the enquiry is co...   15   16
# 5027    0980-006  One U.S. firm bought 35,000 September 97 mid-c...    1    2
# 5028    1090-005  The other two first-round ties will pit hosts ...   17   18
# 5029    1046-006  But Deportivo were unable to capitalise on the...   19   21
#
#         label
# 0     --NME--
# 1     --NME--
# 2     --NME--
# 3     --NME--
# 4     --NME--
# ...       ...
# 5025  --NME--
# 5026  --NME--
# 5027  --NME--
# 5028  --NME--
# 5029  --NME--
#
# [5030 rows x 5 columns]

# %% [markdown]
# ## Problem 4: Entity linking

# %% [markdown]
# Now that we have a method for predicting mention spans, we turn to the task of **entity linking**, which amounts to predicting the knowledge base entity that is referenced by a given mention. In our case, for each span we want to predict the Wikipedia page that this mention references.
#
# Start by extending the generator function that you implemented in Problem&nbsp;2 to labelled spans.

# %%
def gold_mentions(df):
    """Yield the gold-standard mentions in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        quadruples consisting of the sentence id, start position, end
        position and entity label of each span.
    """
    # TODO: Replace the next line with your own code
    # --just add one more label column
    for row in df.itertuples():
        yield row.sentence_id, row.beg, row.end, row.label

gold_standard_mentions = set(gold_mentions(df_dev))
gold_standard_mentions
# Out:
# {('1016-003', 22, 24, 'East_Jerusalem'),
#  ('0986-006', 8, 9, 'Jason_McAteer'),
#  ('1060-019', 4, 6, 'South_Africa'),
#  ('0986-000', 7, 8, 'Liechtenstein_national_football_team'),
#  ('0972-025', 0, 2, '--NME--'),
#  ('1030-007', 6, 7, '--NME--'),
#  ('1067-008', 7, 9, 'St_Johnstone_F.C.'),
#  ('1072-019', 5, 7, 'Christian_Cullen'),
#  ('0946-006', 0, 1, 'Essex_County_Cricket_Club'),
#  ('1054-006', 4, 5, 'Italy'),
#  ('1051-003', 22, 23, 'Robert_Allenby'),
#  ('1057-002', 18, 19, 'Edgbaston'),
#  ('1103-017', 2, 5, 'Wilfried_Van_Moer'),
#  ('0972-013', 0, 2, '--NME--'),
#  ('1070-008', 7, 10, '--NME--'),
#  ('1035-007', 18, 19, 'Germany'),
#  ('0956-010', 2, 3, '--NME--'),
#  ('0972-002', 4, 7, '1996_Singer_World_Series'),
#  ('1143-007', 26, 27, 'Lebanon'),
#  ('1069-011', 0, 1, 'Derbyshire_County_Cricket_Club'),
#  ('0972-005', 0, 2, '--NME--'),
#  ('0990-006', 0, 1, 'Alexander_Lebed'),
#  ('1050-000', 2, 3, 'Republic_of_Ireland_national_football_team'),
#  ('1061-016', 2, 3, 'Cardiff_RFC'),
#  ('1031-004', 37, 38, 'Wuxi'),
#  ('1045-001', 0, 2, 'United_Nations'),
#  ('0955-010', 0, 1, '--NME--'),
#  ('1010-001', 0, 1, 'Chicago'),
#  ('1044-003', 3, 4, 'Yasser_Arafat'),
#  ('1019-001', 0, 1, 'Groningen'),
#  ('1042-001', 0, 1, 'Beijing'),
#  ('1009-001', 0, 2, '--NME--'),
#  ('0996-008', 0, 1, 'Poland'),
#  ('0957-019', 29, 31, 'Gabriela_Sabatini'),
#  ('1072-015', 20, 21, '--NME--'),
#  ('0960-014', 12, 13, 'MaliVai_Washington'),
#  ('1008-010', 37, 38, '--NME--'),
#  ('1139-008', 0, 1, '--NME--'),
#  ('1058-030', 10, 11, 'Chicago_White_Sox'),
#  ('0966-145', 1, 3, 'Kenny_Harrison'),
#  ('1060-016', 1, 3, 'Frank_Nobilo'),
#  ('1101-011', 26, 28, 'Marcel_Desailly'),
#  ('1056-017', 16, 17, 'Germany'),
#  ('1129-002', 17, 18, 'Moscow'),
#  ('1058-027', 42, 44, 'Toronto_Blue_Jays'),
#  ('1131-002', 20, 22, 'United_Nations_Security_Council'),
#  ('0966-068', 1, 3, 'Chandra_Sturrup'),
#  ('1033-004', 2, 3, '--NME--'),
#  ('0956-002', 2, 4, 'South_Korea'),
#  ('0981-004', 0, 1, 'Magna_International'),
#  ('1131-002', 5, 7, 'United_Nations'),
#  ('1007-004', 3, 5, 'Bob_Dole'),
#  ('1030-031', 0, 2, 'Dick_Morris'),
#  ('1061-017', 0, 1, 'Scotland'),
#  ('1016-012', 9, 10, 'Israel'),
#  ('1080-002', 0, 1, 'Romania_national_football_team'),
#  ('1116-019', 18, 21, 'On_the_Waterfront'),
#  ('0999-004', 4, 5, '--NME--'),
#  ('0957-028', 3, 5, 'Czech_Republic'),
#  ('1116-004', 2, 4, 'Henry_VIII_of_England'),
#  ('1056-016', 28, 30, '--NME--'),
#  ('1126-010', 5, 6, 'Mahala'),
#  ('1003-000', 4, 5, 'Suriname'),
#  ('0974-003', 4, 6, 'Sri_Lanka_national_cricket_team'),
#  ('1007-014', 29, 33, '--NME--'),
#  ('1027-000', 2, 3, 'State_of_Palestine'),
#  ('1012-008', 1, 3, 'United_States_Department_of_the_Treasury'),
#  ('1005-015', 7, 9, 'New_York_City'),
#  ('1056-034', 2, 4, '--NME--'),
#  ('1098-002', 12, 13, 'Mexico'),
#  ('1058-011', 0, 2, 'Roger_Pavlik'),
#  ('1062-002', 14, 15, 'Europe'),
#  ('0966-148', 1, 3, 'Sigurd_Njerve'),
#  ('1096-042', 8, 9, '--NME--'),
#  ('1137-008', 7, 9, 'South_Korea'),
#  ('0957-015', 2, 4, 'Lindsay_Davenport'),
#  ('1025-011', 30, 31, 'Jerusalem'),
#  ('1030-039', 2, 3, 'London'),
#  ('1116-027', 3, 6, 'World_War_II'),
#  ('0958-055', 0, 2, 'San_Francisco_Giants'),
#  ('1137-003', 19, 23, '--NME--'),
#  ('0985-007', 10, 11, 'The_Sun_(United_Kingdom)'),
#  ('0958-055', 3, 5, 'New_York_Yankees'),
#  ('1049-003', 6, 8, 'Mick_McCarthy'),
#  ('0959-013', 2, 3, 'Pittsburgh_Pirates'),
#  ('0999-003', 3, 5, '--NME--'),
#  ('0972-009', 0, 2, 'Steve_Waugh'),
#  ('1011-017', 7, 8, 'Missouri'),
#  ('0959-007', 2, 4, 'New_York_Yankees'),
#  ('1114-004', 0, 1, 'Romania_national_football_team'),
#  ('1038-005', 37, 38, 'Donald_Tsang'),
#  ('1156-006', 9, 12, '--NME--'),
#  ('0969-003', 27, 28, 'En_Avant_de_Guingamp'),
#  ('0994-014', 0, 1, 'Alexander_Lukashenko'),
#  ('1159-005', 26, 27, 'Nandrin'),
#  ('0990-012', 0, 1, 'Alexander_Lebed'),
#  ('0961-002', 0, 2, 'Randall_Cunningham'),
#  ('0981-006', 10, 12, 'North_America'),
#  ('1056-025', 4, 5, 'Russia'),
#  ('1116-033', 8, 9, 'Kuwait'),
#  ('1071-004', 10, 12, 'Paul_Peschisolido'),
#  ('1030-017', 24, 26, 'Raymond_James_Financial'),
#  ('1055-038', 2, 3, 'Ronnie_Irani'),
#  ('1144-004', 25, 26, 'Reuters'),
#  ('1073-000', 6, 8, 'New_Zealand_national_rugby_union_team'),
#  ('1154-008', 9, 10, '--NME--'),
#  ('0990-002', 17, 18, 'Moscow'),
#  ('1027-020', 12, 13, 'Israel'),
#  ('0962-004', 1, 6, 'Brown_Deer_Park_Golf_Course'),
#  ('1091-004', 11, 12, 'Sweden'),
#  ('0981-001', 3, 4, '--NME--'),
#  ('1004-008', 2, 4, 'Norodom_Ranariddh'),
#  ('1035-010', 23, 24, '--NME--'),
#  ('1152-011', 26, 27, 'Iran'),
#  ('0966-134', 1, 3, 'Daniel_Komen'),
#  ('0956-005', 2, 3, '--NME--'),
#  ('0996-003', 30, 32, 'Ministry_of_Foreign_Affairs_(Poland)'),
#  ('1143-008', 12, 13, 'Lebanon'),
#  ('0958-005', 0, 4, 'American_League_East'),
#  ('0960-009', 22, 23, 'The_Championships,_Wimbledon'),
#  ('0994-004', 7, 9, '--NME--'),
#  ('0984-019', 5, 6, 'Norway'),
#  ('1089-002', 0, 2, 'Jesper_Parnevik'),
#  ('1027-024', 4, 5, 'Yasser_Arafat'),
#  ('0992-007', 29, 30, 'Serbia'),
#  ('1142-011', 6, 10, 'Patriotic_Union_of_Kurdistan'),
#  ('0991-011', 14, 15, 'Alexander_Lebed'),
#  ('0990-005', 7, 8, 'Boris_Yeltsin'),
#  ('1056-006', 1, 3, 'Antonella_Bellutti'),
#  ('1044-004', 32, 33, 'Jews'),
#  ('0960-005', 20, 22, 'Jeff_Tarango'),
#  ('0965-009', 2, 3, 'Brussels'),
#  ('0997-004', 14, 15, 'Russia'),
#  ('1101-004', 31, 32, 'Chelsea_F.C.'),
#  ('0954-002', 4, 7, '--NME--'),
#  ('1072-019', 41, 43, 'Justin_Marshall'),
#  ('1061-000', 7, 8, 'Wales'),
#  ('1033-009', 2, 3, 'Chechnya'),
#  ('1137-003', 36, 38, '--NME--'),
#  ('1089-017', 0, 1, 'Nolan_Henke'),
#  ('0966-005', 1, 3, 'Ludmila_Engquist'),
#  ('1067-011', 0, 1, 'Ayr_United_F.C.'),
#  ('1030-032', 2, 4, 'Wall_Street'),
#  ('1056-034', 11, 13, '--NME--'),
#  ('1058-035', 3, 4, 'Boston_Red_Sox'),
#  ('1009-010', 21, 22, 'United_States'),
#  ('1068-010', 0, 2, 'Port_Vale_F.C.'),
#  ('1150-003', 6, 8, '--NME--'),
#  ('1097-011', 11, 12, '--NME--'),
#  ('0997-002', 2, 4, 'Boris_Yeltsin'),
#  ('0966-107', 1, 3, 'Wilson_Kipketer'),
#  ('1016-010', 19, 21, 'Klaus_Kinkel'),
#  ('0972-012', 5, 6, 'Muttiah_Muralitharan'),
#  ('1077-001', 0, 1, 'Chișinău'),
#  ('1155-000', 8, 9, 'Bonn'),
#  ('1074-001', 0, 1, 'Nouakchott'),
#  ('1014-004', 31, 32, 'Bob_Dole'),
#  ('1061-006', 3, 4, 'Bristol_Bears'),
#  ('0972-035', 6, 7, 'Chaminda_Vaas'),
#  ('1116-035', 2, 3, 'United_Kingdom'),
#  ('0991-006', 0, 1, 'Alexander_Lebed'),
#  ('0999-004', 11, 12, '--NME--'),
#  ('1148-005', 18, 19, 'Tunisia'),
#  ('0984-017', 18, 20, 'Labor_Day'),
#  ('1006-014', 17, 18, 'Sudan'),
#  ('1025-006', 6, 7, 'Gaza'),
#  ('1067-014', 0, 1, 'Livingston_F.C.'),
#  ('1089-001', 2, 3, 'Wisconsin'),
#  ('1069-017', 27, 29, '--NME--'),
#  ('1066-023', 0, 2, 'Manchester_City_F.C.'),
#  ('1056-037', 9, 10, 'Latvia'),
#  ('0975-007', 4, 5, '--NME--'),
#  ('1143-009', 2, 5, 'Hezbollah'),
#  ('1160-018', 4, 5, 'Michael_Collins_(Irish_leader)'),
#  ('1099-003', 0, 1, 'Austria_national_football_team'),
#  ('0958-053', 3, 4, 'Philadelphia_Phillies'),
#  ('1066-024', 0, 2, 'West_Bromwich_Albion_F.C.'),
#  ('1095-007', 2, 3, 'Minnesota_Twins'),
#  ('1101-012', 76, 78, 'Jesús_Arellano'),
#  ('1160-012', 1, 2, 'Michael_Collins_(Irish_leader)'),
#  ('0966-064', 1, 3, 'Merlene_Ottey'),
#  ('0966-134', 4, 5, 'Kenya'),
#  ('1071-000', 2, 3, '--NME--'),
#  ('1072-018', 100, 102, '--NME--'),
#  ('1094-054', 0, 2, 'Los_Angeles_Angels'),
#  ('1130-006', 3, 5, '--NME--'),
#  ('0991-003', 30, 31, 'Aslan_Maskhadov'),
#  ('0958-056', 2, 4, '--NME--'),
#  ('1114-004', 2, 4, 'Cosmin_Contra'),
#  ('0947-007', 6, 8, '--NME--'),
#  ('0972-012', 3, 4, 'Arjuna_Ranatunga'),
#  ('1046-009', 34, 35, 'Europe'),
#  ('1054-016', 6, 7, 'Team_Jumbo–Visma'),
#  ('1111-001', 0, 1, 'Dublin'),
#  ('0957-021', 10, 11, 'United_States'),
#  ('1134-001', 0, 1, '--NME--'),
#  ('1103-016', 51, 53, 'Arif_Erdem'),
#  ('0965-005', 21, 22, 'United_States'),
#  ('1076-031', 0, 4, '--NME--'),
#  ('0966-067', 1, 3, 'Chryste_Gaines'),
#  ('1115-009', 5, 7, '--NME--'),
#  ('1138-002', 10, 12, 'New_York'),
#  ('1004-007', 0, 1, 'Norodom_Sihanouk'),
#  ('1022-013', 1, 2, 'Canada'),
#  ('1135-006', 21, 25, 'National_League_for_Democracy'),
#  ('1152-003', 15, 17, 'Bill_Clinton'),
#  ('0948-025', 5, 6, 'Sussex_County_Cricket_Club'),
#  ('1076-017', 0, 1, '--NME--'),
#  ('1068-000', 2, 3, 'England'),
#  ('1157-003', 2, 3, 'NATO'),
#  ('1011-006', 26, 27, 'Missouri'),
#  ('1160-011', 25, 26, 'Israel'),
#  ('1058-025', 12, 13, 'Seattle_Mariners'),
#  ('1046-000', 2, 3, 'Real_Madrid_CF'),
#  ('1018-006', 20, 21, 'Reuters'),
#  ('1005-003', 0, 2, '--NME--'),
#  ('1103-003', 0, 1, 'Belgium_national_football_team'),
#  ('1045-005', 8, 9, 'Israel'),
#  ('1111-003', 3, 5, 'Curragh_Racecourse'),
#  ('1035-003', 20, 22, '--NME--'),
#  ('0954-002', 27, 28, 'England'),
#  ('1099-005', 22, 23, 'Scotland_national_football_team'),
#  ('1077-006', 5, 7, '1998_FIFA_World_Cup'),
#  ('1067-018', 2, 4, 'East_Stirlingshire_F.C.'),
#  ('1065-024', 0, 1, 'Clyde_F.C.'),
#  ('0985-004', 10, 11, '--NME--'),
#  ('1154-003', 0, 1, 'Algeria'),
#  ('0980-015', 13, 16, '--NME--'),
#  ('0975-000', 0, 1, 'Romania'),
#  ('0948-041', 6, 7, 'Headingley'),
#  ('1069-015', 1, 2, 'Headingley'),
#  ('1124-005', 5, 6, 'Afrikaners'),
#  ('1142-006', 16, 17, 'Iraq'),
#  ('0966-119', 1, 3, 'Tim_Lobinger'),
#  ('1036-017', 23, 25, '--NME--'),
#  ('0966-099', 1, 3, 'Dennis_Mitchell'),
#  ('0951-005', 0, 1, 'Lithuania_national_under-21_football_team'),
#  ('1082-002', 10, 12, '1998_FIFA_World_Cup'),
#  ('1098-001', 0, 1, 'Dublin'),
#  ('1036-020', 8, 9, 'Norway'),
#  ('1066-051', 0, 1, 'Wrexham_A.F.C.'),
#  ('1143-003', 29, 30, 'Greenwich_Mean_Time'),
#  ('0984-019', 0, 1, '--NME--'),
#  ('1124-000', 0, 2, '--NME--'),
#  ('1081-001', 0, 1, 'Yerevan'),
#  ('1125-012', 14, 15, 'Tanzania'),
#  ('1126-002', 11, 12, 'Islam'),
#  ('1049-002', 15, 16, 'Liechtenstein'),
#  ('1005-000', 0, 2, '--NME--'),
#  ('1138-004', 6, 7, '--NME--'),
#  ('0966-018', 4, 5, 'Russia'),
#  ('1068-021', 0, 1, 'Gillingham_F.C.'),
#  ('1160-003', 34, 37, 'Venice_Film_Festival'),
#  ('1011-023', 40, 42, '--NME--'),
#  ('0947-008', 12, 14, '--NME--'),
#  ('1023-001', 0, 2, 'New_York_City'),
#  ('1152-016', 8, 9, 'Persian_Gulf'),
#  ('1054-018', 1, 2, 'Viatcheslav_Ekimov'),
#  ('1096-013', 14, 16, 'Jeff_Parrett'),
#  ('1127-002', 2, 3, 'Russia'),
#  ('0980-002', 0, 1, 'United_States'),
#  ('1092-007', 0, 1, 'Austria_Fed_Cup_team'),
#  ('0953-011', 20, 21, 'Panama'),
#  ('0961-000', 0, 1, 'National_Football_League'),
#  ('1079-007', 2, 3, 'Germany'),
#  ('1128-002', 1, 2, 'Poland'),
#  ('0993-003', 15, 16, 'Batajnica'),
#  ('0953-002', 0, 1, 'Panama'),
#  ('1116-008', 2, 3, 'Alsace'),
#  ('1036-013', 4, 5, 'Russia'),
#  ('1041-000', 0, 2, '--NME--'),
#  ('0966-081', 1, 3, 'Torrance_Zellner'),
#  ('1056-017', 0, 1, 'France'),
#  ('1075-002', 0, 1, 'Mauritania_national_football_team'),
#  ('1115-003', 4, 6, '--NME--'),
#  ('1160-003', 25, 26, 'Irish_Republican_Army'),
#  ('0972-039', 5, 8, 'Aravinda_de_Silva'),
#  ('1139-006', 13, 15, 'Democracy_Wall'),
#  ('0980-003', 3, 4, '--NME--'),
#  ('1011-020', 33, 34, '--NME--'),
#  ('1116-009', 13, 14, 'Napoleon'),
#  ('1147-000', 4, 5, 'Iraq'),
#  ('1050-002', 1, 4, 'Republic_of_Ireland_national_football_team'),
#  ('1059-002', 2, 3, 'Kent_County_Cricket_Club'),
#  ('1133-004', 33, 35, 'Deng_Xiaoping'),
#  ('0991-003', 20, 22, 'Chechnya'),
#  ('1070-003', 2, 3, 'Vancouver'),
#  ('1134-000', 0, 1, '--NME--'),
#  ('1104-000', 5, 6, 'Spain'),
#  ('1126-010', 24, 25, 'NATO'),
#  ('1142-006', 0, 1, '--NME--'),
#  ('1035-003', 14, 16, '--NME--'),
#  ('1008-004', 1, 3, 'United_States_Department_of_Commerce'),
#  ('1069-013', 29, 31, '--NME--'),
#  ('0955-005', 0, 1, '--NME--'),
#  ('0947-012', 2, 3, 'Gloucestershire_County_Cricket_Club'),
#  ('1057-006', 23, 25, 'Ronnie_Irani'),
#  ('1068-016', 0, 1, 'Blackpool_F.C.'),
#  ('1092-000', 4, 7, '1997_Fed_Cup'),
#  ('1071-005', 2, 6, '--NME--'),
#  ('0957-020', 12, 13, 'United_States'),
#  ('1131-006', 19, 21, 'Latin_America'),
#  ('0986-006', 12, 13, 'Alan_McLoughlin'),
#  ('1113-002', 2, 4, 'DFB-Pokal'),
#  ('1018-003', 2, 4, '--NME--'),
#  ('1160-005', 26, 28, 'Northern_Ireland'),
#  ('0991-011', 2, 4, 'Viktor_Chernomyrdin'),
#  ('1017-003', 10, 11, '--NME--'),
#  ('1118-007', 21, 22, 'Labour_Party_(UK)'),
#  ('1123-001', 0, 1, 'Seoul'),
#  ('1072-013', 8, 10, 'New_Zealand_national_rugby_union_team'),
#  ('0947-005', 0, 1, 'Leicestershire_County_Cricket_Club'),
#  ('1031-013', 8, 9, 'China'),
#  ('1077-004', 18, 20, 'Inter_Milan'),
#  ('1019-002', 22, 23, 'Groningen'),
#  ('0949-004', 0, 1, 'Tony_Adams'),
#  ('0966-162', 4, 5, 'Jamaica'),
#  ('1152-011', 0, 1, 'Bill_Clinton'),
#  ('1045-000', 0, 2, '--NME--'),
#  ('1057-003', 11, 12, 'Lancashire_County_Cricket_Club'),
#  ('1065-008', 0, 2, 'St_Johnstone_F.C.'),
#  ('0966-049', 4, 5, 'Netherlands'),
#  ('1156-001', 0, 1, 'Rome'),
#  ('1155-002', 9, 10, 'Germany'),
#  ('1048-000', 2, 3, 'Israel_national_football_team'),
#  ('0986-006', 2, 3, 'Gary_Breen'),
#  ('1103-017', 0, 1, 'Belgium'),
#  ('1099-017', 5, 7, 'Markus_Schopp'),
#  ('1138-010', 21, 23, 'Tiananmen_Square'),
#  ('1072-005', 12, 14, 'New_Zealand_national_rugby_union_team'),
#  ('0985-004', 1, 2, 'United_Kingdom'),
#  ('1068-030', 0, 1, 'Colchester_United_F.C.'),
#  ('1027-010', 5, 6, 'Jerusalem'),
#  ('1046-004', 14, 15, 'AJ_Auxerre'),
#  ('1072-012', 34, 37, '--NME--'),
#  ('1037-003', 16, 17, '--NME--'),
#  ('1125-003', 16, 17, 'United_Nations'),
#  ('1099-007', 0, 1, 'Everton_F.C.'),
#  ('1082-001', 0, 1, 'Baku'),
#  ('1127-003', 3, 4, '--NME--'),
#  ('1095-019', 3, 5, 'New_York_Yankees'),
#  ('0966-010', 1, 3, 'Gillian_Russell'),
#  ('1055-012', 0, 2, '--NME--'),
#  ('1033-005', 7, 8, '--NME--'),
#  ('0961-001', 0, 1, 'Philadelphia'),
#  ('0964-003', 0, 1, 'Mauro_Silva'),
#  ('1132-005', 0, 1, '--NME--'),
#  ('0961-007', 17, 19, 'Jeffrey_Lurie'),
#  ('1055-037', 8, 9, 'Dean_Headley'),
#  ('1005-008', 12, 13, 'South_Korea'),
#  ('0960-003', 7, 8, '1996_Wimbledon_Championships'),
#  ('1132-003', 11, 12, 'Michoacán'),
#  ('1127-008', 18, 19, 'Russia'),
#  ('1161-001', 0, 1, 'Dhaka'),
#  ('1161-002', 37, 38, 'Islam'),
#  ('0957-002', 9, 12, '--NME--'),
#  ('0996-006', 0, 1, 'Dariusz_Rosati'),
#  ('1154-004', 1, 3, 'Le_Matin_(France)'),
#  ('1011-007', 4, 7, 'Commerce_Bancshares'),
#  ('1137-003', 24, 26, '--NME--'),
#  ('1002-000', 4, 5, 'Colombia'),
#  ('1096-032', 33, 34, 'San_Francisco_Giants'),
#  ('1090-011', 3, 4, 'Japan_Fed_Cup_team'),
#  ('0947-006', 15, 17, '--NME--'),
#  ('0952-004', 5, 7, 'Manchester_United_F.C.'),
#  ('1115-005', 22, 23, '--NME--'),
#  ('0971-001', 0, 1, 'Colombo'),
#  ('1083-002', 0, 1, 'Pallacanestro_Treviso'),
#  ('0972-011', 0, 2, '--NME--'),
#  ('1011-006', 2, 5, '--NME--'),
#  ('1003-003', 10, 12, '--NME--'),
#  ('1094-017', 0, 2, 'Kansas_City_Royals'),
#  ('0966-135', 1, 3, 'Bob_Kennedy_(runner)'),
#  ('0947-011', 10, 12, '--NME--'),
#  ('1006-012', 3, 4, 'Egypt'),
#  ('1076-043', 0, 1, 'FK_Rudar_Ugljevik'),
#  ('1115-008', 30, 31, 'Margaret_Thatcher'),
#  ('1126-010', 16, 17, 'United_Nations'),
#  ('1000-016', 15, 16, '--NME--'),
#  ('1094-011', 0, 1, 'Detroit_Tigers'),
#  ('0994-014', 5, 6, 'Moscow'),
#  ('1038-002', 26, 27, 'China'),
#  ('1059-005', 5, 6, 'Worcestershire_County_Cricket_Club'),
#  ('1152-003', 24, 25, 'Iraq'),
#  ('1127-022', 0, 1, '--NME--'),
#  ('1160-011', 28, 29, 'Neil_Jordan'),
#  ('1006-004', 14, 16, 'United_Nations'),
#  ('1032-003', 14, 15, '--NME--'),
#  ('0972-008', 0, 2, '--NME--'),
#  ('1101-003', 16, 18, 'UEFA_Euro_1996'),
#  ('1024-010', 23, 25, 'United_States'),
#  ('0949-001', 0, 1, 'London'),
#  ('1136-002', 1, 4, '--NME--'),
#  ('1058-036', 1, 2, 'Detroit'),
#  ('1069-017', 9, 11, '--NME--'),
#  ('1117-003', 0, 2, '--NME--'),
#  ('1152-003', 3, 4, 'United_States'),
#  ('1094-031', 0, 4, 'National_League_East'),
#  ('0995-003', 15, 16, 'Islam'),
#  ('1011-003', 22, 23, 'Missouri'),
#  ('1017-006', 17, 20, 'Charles_de_Gaulle_Airport'),
#  ('0966-055', 1, 3, 'Anthony_Washington'),
#  ('1055-018', 6, 8, 'Waqar_Younis'),
#  ('0994-003', 2, 3, 'Belarus'),
#  ('0947-004', 0, 1, 'Somerset_County_Cricket_Club'),
#  ('0997-000', 7, 8, 'Interfax'),
#  ('1058-011', 24, 26, 'American_League'),
#  ('0953-013', 8, 9, 'Panama'),
#  ('1120-000', 1, 2, 'Iraq'),
#  ('1111-009', 2, 4, 'Richard_Hannon'),
#  ('0980-003', 2, 3, 'Chicago'),
#  ('0976-001', 0, 1, 'Warsaw'),
#  ('1126-002', 33, 34, 'Serbs'),
#  ('1058-022', 3, 5, 'Pete_Incaviglia'),
#  ('0994-004', 11, 12, 'Reuters'),
#  ('0960-013', 20, 21, 'MaliVai_Washington'),
#  ('1090-018', 8, 9, 'Billie_Jean_King'),
#  ('1161-000', 0, 1, 'Dhaka_Stock_Exchange'),
#  ('1154-000', 0, 1, 'Algeria'),
#  ('0957-018', 26, 28, 'Àlex_Corretja'),
#  ('1116-036', 15, 16, 'Europe'),
#  ('0990-000', 2, 3, 'Alexander_Lebed'),
#  ('1144-000', 2, 3, 'Iraq'),
#  ('0965-000', 4, 5, 'Donovan_Bailey'),
#  ('1056-038', 0, 2, 'Darryn_Hill'),
#  ('1096-020', 16, 18, 'Kevin_Foster_(baseball)'),
#  ('0990-002', 31, 32, 'Interfax'),
#  ('0972-014', 0, 2, '--NME--'),
#  ('1096-006', 5, 7, 'John_Boles_(baseball)'),
#  ('0984-020', 0, 1, '--NME--'),
#  ('1012-006', 31, 34, 'Nation_of_Islam'),
#  ('1031-004', 0, 1, 'Pirelli'),
#  ('1159-000', 7, 8, 'Belgium'),
#  ('0957-015', 5, 6, 'United_States'),
#  ('0966-158', 4, 5, 'Belarus'),
#  ('1103-006', 10, 12, '--NME--'),
#  ('1067-011', 2, 3, 'Berwick_Rangers_F.C.'),
#  ('1131-002', 1, 2, 'United_States'),
#  ('1115-004', 2, 3, 'Margaret_Thatcher'),
#  ('1009-003', 7, 8, 'Mexico'),
#  ('0974-010', 3, 5, 'Roshan_Mahanama'),
#  ('1031-001', 0, 2, '--NME--'),
#  ('1014-004', 41, 43, '--NME--'),
#  ('1059-006', 6, 7, 'Surrey_County_Cricket_Club'),
#  ('0949-011', 8, 9, 'Newcastle_United_F.C.'),
#  ('1001-002', 1, 5, '--NME--'),
#  ('0954-002', 18, 20, 'Jansher_Khan'),
#  ('0980-014', 3, 5, 'Lawrence_B._Lindsey'),
#  ('0974-004', 5, 6, '--NME--'),
#  ('0946-004', 11, 13, 'Grace_Road'),
#  ('1011-003', 7, 11, '--NME--'),
#  ('1053-001', 2, 3, 'England'),
#  ('1027-009', 25, 26, 'Jews'),
#  ('1090-012', 0, 1, 'Monica_Seles'),
#  ('0993-005', 24, 25, 'Belgrade'),
#  ('1027-016', 19, 20, 'Jerusalem'),
#  ('0960-015', 21, 22, 'MaliVai_Washington'),
#  ('0948-031', 3, 4, 'Leicestershire_County_Cricket_Club'),
#  ('1068-024', 3, 4, 'York_City_F.C.'),
#  ('1119-006', 24, 26, 'John_Major'),
#  ('1034-004', 1, 2, 'Netherlands'),
#  ('1048-003', 3, 4, 'Bulgaria_national_under-21_football_team'),
#  ('1099-018', 20, 22, 'Duncan_Ferguson'),
#  ('1136-002', 23, 24, 'China'),
#  ('0947-009', 18, 19, 'Lancashire_County_Cricket_Club'),
#  ('0957-024', 9, 10, 'Sweden'),
#  ('1007-027', 3, 5, 'New_York_Stock_Exchange'),
#  ('1116-003', 3, 5, 'Elizabeth_I_of_England'),
#  ('1058-013', 3, 5, 'Jim_Thome'),
#  ('1073-010', 0, 2, 'New_Zealand_national_rugby_union_team'),
#  ('1160-015', 0, 2, 'Aidan_Quinn'),
#  ('1092-004', 3, 6, '--NME--'),
#  ('1061-000', 3, 4, 'England'),
#  ('1043-000', 2, 3, 'Thailand'),
#  ('1058-040', 21, 22, 'Milwaukee_Brewers'),
#  ('0959-015', 2, 4, '--NME--'),
#  ('0966-163', 4, 6, 'Davidson_Ezinwa'),
#  ('1057-007', 2, 4, '--NME--'),
#  ('1061-012', 2, 3, 'Llanelli_RFC'),
#  ('0957-004', 0, 2, 'Sandrine_Testud'),
#  ('1082-000', 4, 5, 'Switzerland_national_football_team'),
#  ('1150-006', 13, 16, '--NME--'),
#  ('1044-004', 28, 29, 'Islam'),
#  ('0963-004', 12, 15, 'United_States_Amateur_Championship_(golf)'),
#  ('1087-020', 19, 20, 'Rodney_Eyles'),
#  ('0981-006', 7, 8, '--NME--'),
#  ('1045-006', 11, 12, 'Jerusalem'),
#  ('0962-009', 4, 6, 'Dave_Barr_(golfer)'),
#  ('1031-000', 5, 6, 'China'),
#  ('0965-005', 0, 1, 'Donovan_Bailey'),
#  ('1127-008', 0, 1, 'Russia'),
#  ('1045-006', 39, 40, 'Israel'),
#  ('1101-002', 3, 5, 'Nicolas_Ouédec'),
#  ('1152-012', 15, 16, 'Iraq'),
#  ('1039-007', 0, 1, 'Indonesia'),
#  ('1007-013', 34, 35, 'Washington,_D.C.'),
#  ('1064-000', 7, 8, 'Bob_Dwyer'),
#  ('1088-002', 43, 45, 'Peter_Nicol'),
#  ('1039-011', 24, 28, 'Moro_National_Liberation_Front'),
#  ('0974-007', 2, 4, 'Ian_Healy'),
#  ('0996-002', 0, 1, 'Poland'),
#  ('1052-001', 2, 4, 'Faroe_Islands'),
#  ('0992-001', 0, 1, 'Sarajevo'),
#  ('1090-017', 5, 6, 'Monica_Seles'),
#  ('1128-010', 17, 18, '--NME--'),
#  ('0957-016', 5, 6, 'Spain'),
#  ('1049-004', 0, 1, 'Niall_Quinn'),
#  ('1133-008', 0, 1, 'Xiao_Qiang'),
#  ('0974-007', 11, 13, '--NME--'),
#  ('1152-017', 3, 4, 'United_States_Marine_Corps'),
#  ('0957-009', 6, 8, 'David_Rikl'),
#  ('1011-012', 34, 35, 'Illinois'),
#  ('0947-007', 3, 4, 'Nottinghamshire_County_Cricket_Club'),
#  ('0958-030', 0, 1, 'Baltimore_Orioles'),
#  ('1012-009', 10, 11, 'Libya'),
#  ('1006-006', 9, 11, '--NME--'),
#  ('1056-027', 1, 3, '--NME--'),
#  ('1066-052', 0, 1, 'Stockport_County_F.C.'),
#  ('1090-010', 21, 22, 'Nagoya'),
#  ('0953-012', 25, 30, '--NME--'),
#  ('1011-005', 17, 18, '--NME--'),
#  ('1056-037', 6, 8, '--NME--'),
#  ('1140-000', 0, 2, 'Hong_Kong'),
#  ('1016-013', 1, 2, '--NME--'),
#  ('1137-000', 3, 5, 'South_Korea'),
#  ('1025-011', 2, 3, '--NME--'),
#  ('1087-008', 4, 5, 'Jansher_Khan'),
#  ('1155-000', 3, 4, 'Germany'),
#  ('0956-004', 2, 3, '--NME--'),
#  ('1046-007', 2, 4, 'Roberto_Carlos'),
#  ('0966-161', 13, 15, 'Frankie_Fredericks'),
#  ('1094-022', 0, 1, 'Los_Angeles_Angels'),
#  ('1054-020', 1, 3, 'Erik_Dekker'),
#  ('1012-006', 1, 4, 'United_States_Department_of_the_Treasury'),
#  ('1123-010', 0, 1, '--NME--'),
#  ('0948-003', 4, 5, 'England_cricket_team'),
#  ('1004-002', 3, 5, 'Norodom_Sihanouk'),
#  ('1156-003', 0, 1, 'Julius_Nyerere'),
#  ('0963-017', 13, 15, 'Andrew_Magee'),
#  ('1045-003', 29, 30, 'Israel'),
#  ('1063-002', 0, 1, 'Ukraine_national_football_team'),
#  ('1122-004', 11, 12, 'Algeria'),
#  ('1069-012', 7, 8, 'Surrey_County_Cricket_Club'),
#  ('1103-016', 69, 71, 'Saffet_Sancaklı'),
#  ('0966-145', 4, 5, 'United_States'),
#  ('1067-017', 2, 3, 'Cowdenbeath_F.C.'),
#  ('1133-004', 38, 39, 'Xiao_Qiang'),
#  ('0950-001', 0, 1, 'Belgrade'),
#  ('1022-010', 10, 11, 'Canada'),
#  ('1128-004', 26, 27, 'Warsaw'),
#  ('1051-010', 32, 34, '--NME--'),
#  ('1146-005', 32, 33, 'Masoud_Barzani'),
#  ('1036-009', 9, 10, 'Arctic'),
#  ('1087-017', 6, 9, '--NME--'),
#  ('1036-031', 0, 1, '--NME--'),
#  ('1090-013', 3, 4, 'Monica_Seles'),
#  ('1066-074', 0, 1, 'Brighton_&_Hove_Albion_F.C.'),
#  ('1056-011', 1, 3, '--NME--'),
#  ('1116-027', 10, 12, 'Hermann_Göring'),
#  ('1068-013', 6, 8, 'Manchester_City_F.C.'),
#  ('1160-016', 11, 12, 'Neil_Jordan'),
#  ('0966-006', 1, 3, 'Aliuska_López'),
#  ('1058-014', 9, 12, 'American_League_Central'),
#  ('1016-015', 12, 14, 'Shimon_Peres'),
#  ('1099-017', 20, 22, 'Dieter_Ramusch'),
#  ('1127-015', 11, 13, 'Doku_Zavgayev'),
#  ('1046-003', 9, 10, 'Real_Madrid_CF'),
#  ('1096-021', 0, 1, '--NME--'),
#  ('1068-008', 0, 1, 'Norwich_City_F.C.'),
#  ('1144-004', 8, 9, 'Kurdistan_Democratic_Party'),
#  ('1096-024', 0, 2, 'Mike_Mordecai'),
#  ('1127-014', 29, 30, 'Urus-Martan'),
#  ('1049-003', 33, 35, 'Ian_Harte'),
#  ('1035-009', 31, 32, 'Amsterdam'),
#  ('1152-015', 7, 9, 'United_States_Air_Force'),
#  ('1010-016', 12, 13, 'Chicago'),
#  ('1055-006', 0, 2, '--NME--'),
#  ('0979-002', 23, 25, 'Labor_Day'),
#  ('1128-004', 6, 7, '--NME--'),
#  ('1059-005', 12, 13, 'Warwickshire_County_Cricket_Club'),
#  ('1087-004', 4, 5, 'Jansher_Khan'),
#  ('0977-001', 0, 1, 'Ottawa'),
#  ('1056-030', 1, 3, 'Wendy_Everson'),
#  ('1076-030', 2, 3, '--NME--'),
#  ('1054-011', 1, 3, '--NME--'),
#  ('1087-000', 2, 3, '--NME--'),
#  ('1072-014', 1, 2, '--NME--'),
#  ('1072-012', 5, 6, '--NME--'),
#  ('1146-000', 0, 1, 'Iraq'),
#  ('1016-009', 5, 7, 'European_Union'),
#  ('1138-007', 19, 21, '--NME--'),
#  ('1017-001', 0, 1, 'Paris'),
#  ('1115-003', 14, 15, 'Margaret_Thatcher'),
#  ('0957-008', 6, 8, 'Andrei_Olhovskiy'),
#  ('1083-002', 2, 3, 'Italy'),
#  ('1064-007', 32, 33, 'Bath_Rugby'),
#  ('1033-007', 6, 8, '--NME--'),
#  ('1019-012', 7, 8, 'Germany'),
#  ('0984-016', 0, 3, '--NME--'),
#  ('1155-015', 8, 9, 'Germany'),
#  ('0983-005', 37, 38, 'Iraq'),
#  ('1091-003', 42, 44, 'Petra_Langrová'),
#  ('1034-003', 34, 36, 'Tel_Aviv'),
#  ('1114-002', 0, 1, 'Romania_national_football_team'),
#  ('0965-004', 11, 12, 'Berlin'),
#  ('1051-002', 8, 10, 'British_Masters'),
#  ('1116-004', 15, 16, 'Kingdom_of_England'),
#  ('1101-011', 31, 33, 'Frank_Leboeuf'),
#  ('0947-008', 22, 24, '--NME--'),
#  ('1097-019', 0, 1, 'Stefan_Edberg'),
#  ('1094-033', 0, 1, 'Atlanta_Braves'),
#  ('1151-006', 20, 21, 'Dallas'),
#  ('1142-001', 0, 1, 'Istanbul'),
#  ('1010-000', 0, 1, 'United_States'),
#  ('1031-006', 28, 29, 'India'),
#  ('1125-007', 10, 11, 'Rwanda'),
#  ('1040-001', 0, 1, 'Tokyo'),
#  ('0979-013', 4, 8, '--NME--'),
#  ('1156-006', 0, 1, 'Julius_Nyerere'),
#  ('1012-003', 19, 21, 'United_States_Department_of_State'),
#  ('1101-011', 82, 84, 'Patrice_Loko'),
#  ('0994-005', 18, 19, 'Europe'),
#  ('1144-004', 5, 6, 'Kurdistan_Democratic_Party'),
#  ('1058-044', 1, 2, 'Milwaukee_Brewers'),
#  ('1105-003', 0, 1, 'Spain'),
#  ('1124-002', 20, 22, 'Northern_Cape'),
#  ('0966-076', 4, 5, 'Kenya'),
#  ('1156-004', 14, 16, 'Great_Lakes'),
#  ('1131-006', 15, 16, 'Bolivia'),
#  ('0947-007', 15, 16, 'Kent_County_Cricket_Club'),
#  ('0966-148', 4, 5, 'Norway'),
#  ('0958-013', 0, 1, 'Cleveland_Indians'),
#  ('1116-029', 6, 8, 'Jackie_Stewart'),
#  ('1099-009', 9, 11, 'Craig_Brown'),
#  ('1039-007', 2, 3, 'Suharto'),
#  ('1072-019', 59, 61, '--NME--'),
#  ('1112-002', 13, 15, 'FIFA_World_Cup'),
#  ('0963-000', 2, 3, 'Nolan_Henke'),
#  ('1109-007', 2, 3, 'Giovanni_Silva_de_Oliveira'),
#  ('1026-004', 0, 1, 'Akhbar'),
#  ('1155-010', 27, 28, 'Kurdistan'),
#  ('1154-009', 7, 8, 'Algeria'),
#  ('1056-007', 4, 5, 'France'),
#  ('1069-017', 19, 21, '--NME--'),
#  ('1043-001', 0, 1, 'Singapore'),
#  ('1125-006', 28, 29, 'Democratic_Republic_of_the_Congo'),
#  ('0966-007', 4, 5, 'Slovenia'),
#  ('1135-015', 1, 2, 'National_League_for_Democracy'),
#  ('0948-002', 4, 5, 'The_Ashes'),
#  ('1101-002', 16, 17, 'France_national_football_team'),
#  ('1068-006', 0, 1, 'Grimsby_Town_F.C.'),
#  ('1121-002', 28, 29, 'Iraq'),
#  ('0972-012', 0, 2, '--NME--'),
#  ('1054-025', 1, 2, 'Jesper_Skibby'),
#  ('0966-031', 4, 5, 'United_States'),
#  ('0966-065', 4, 5, 'United_States'),
#  ('0985-003', 6, 7, 'Frank_Bruno'),
#  ('0966-122', 4, 5, 'Russia'),
#  ('1136-006', 0, 3, '--NME--'),
#  ('0947-010', 15, 17, '--NME--'),
#  ('1029-017', 4, 6, '--NME--'),
#  ('1061-007', 2, 4, 'West_Hartlepool_R.F.C.'),
#  ('1006-004', 42, 43, 'Lockerbie'),
#  ('1138-002', 6, 8, '--NME--'),
#  ('0946-011', 14, 15, 'Worcestershire_County_Cricket_Club'),
#  ('0952-000', 2, 3, 'FC_Rotor_Volgograd'),
#  ('1046-010', 11, 12, '--NME--'),
#  ('1144-000', 4, 5, '--NME--'),
#  ('1054-012', 6, 8, '--NME--'),
#  ('0991-003', 16, 18, 'Russia'),
#  ('0967-006', 0, 1, 'Karlsruher_SC'),
#  ('0996-006', 5, 7, 'Slobodan_Milošević'),
#  ('1066-054', 0, 1, 'Walsall_F.C.'),
#  ('0966-147', 4, 5, 'Armenia'),
#  ('1112-002', 3, 5, 'Jürgen_Klinsmann'),
#  ('1011-017', 1, 3, '--NME--'),
#  ('1056-008', 4, 5, 'Australia'),
#  ('1133-000', 0, 1, 'China'),
#  ('1058-029', 0, 1, 'Harold_Baines'),
#  ('0990-009', 6, 7, 'Chechnya'),
#  ('1073-002', 0, 2, 'South_Africa_national_rugby_union_team'),
#  ('1131-005', 5, 6, 'Uruguay'),
#  ('0993-003', 30, 32, '--NME--'),
#  ('1064-004', 2, 4, 'Philippe_Sella'),
#  ('1038-002', 0, 2, 'Hong_Kong'),
#  ('0958-015', 0, 1, 'Minnesota_Twins'),
#  ('1055-006', 4, 6, 'Mushtaq_Ahmad'),
#  ('0994-003', 6, 8, 'Alexander_Lukashenko'),
#  ('1045-003', 12, 14, 'United_Nations_Security_Council'),
#  ('1059-000', 4, 5, 'Kent_County_Cricket_Club'),
#  ('0977-000', 0, 1, 'Canada'),
#  ('0947-009', 13, 15, '--NME--'),
#  ('1051-005', 5, 6, 'Spain'),
#  ('1055-038', 5, 6, 'Robert_Croft'),
#  ('1142-012', 8, 9, 'Iraq'),
#  ('1160-000', 5, 6, 'Venice'),
#  ('0957-033', 9, 11, 'Todd_Martin'),
#  ('1119-001', 0, 1, 'London'),
#  ('0960-004', 8, 9, 'The_Championships,_Wimbledon'),
#  ('1146-005', 35, 37, 'Saddam_Hussein'),
#  ('1121-000', 3, 4, 'Iraq'),
#  ('1070-009', 1, 3, 'Bobby_Rahal'),
#  ('1157-004', 10, 11, 'Iraq'),
#  ('1011-022', 15, 17, '--NME--'),
#  ('0967-002', 0, 1, 'UEFA'),
#  ('1024-001', 0, 1, 'Washington,_D.C.'),
#  ('0968-004', 0, 2, '1996_Summer_Olympics'),
#  ('1030-032', 15, 16, 'Democratic_Party_(United_States)'),
#  ('0997-000', 3, 4, 'Naina_Yeltsina'),
#  ('0949-004', 2, 3, 'David_Platt_(footballer)'),
#  ('0966-033', 4, 5, 'Norway'),
#  ('0966-156', 4, 5, 'Australia'),
#  ('0959-005', 2, 4, 'Kansas_City_Royals'),
#  ('1149-005', 41, 42, '--NME--'),
#  ('1055-032', 4, 5, 'Adam_Hollioake'),
#  ('0958-048', 0, 2, 'San_Francisco_Giants'),
#  ('1056-022', 4, 5, 'Australia'),
#  ('1069-015', 6, 7, 'Yorkshire_County_Cricket_Club'),
#  ('0990-014', 15, 16, 'Alexander_Lebed'),
#  ('1091-004', 17, 18, 'Ecuador'),
#  ('1146-005', 23, 24, 'Baghdad'),
#  ('1056-010', 4, 5, 'Russia'),
#  ('1017-007', 9, 11, 'Air_France'),
#  ('1054-017', 6, 7, '7-Eleven_(cycling_team)'),
#  ('1073-007', 5, 7, 'Sean_Fitzpatrick'),
#  ('0947-011', 7, 8, 'Derbyshire_County_Cricket_Club'),
#  ('1099-007', 2, 4, 'Duncan_Ferguson'),
#  ('1027-007', 30, 31, '--NME--'),
#  ('1121-007', 1, 3, 'Bill_Clinton'),
#  ('1099-005', 0, 1, 'Austria_national_football_team'),
#  ('1039-006', 0, 1, 'Kompas'),
#  ('1116-027', 20, 21, 'London'),
#  ('1055-009', 0, 2, '--NME--'),
#  ('1069-011', 4, 5, 'Worcestershire_County_Cricket_Club'),
#  ('1149-005', 35, 37, '--NME--'),
#  ('1103-016', 36, 38, 'Abdullah_Ercan'),
#  ('1116-032', 7, 9, 'South_Africa'),
#  ('0985-006', 6, 7, 'United_Kingdom'),
#  ('1053-000', 4, 5, 'Pakistan_national_cricket_team'),
#  ('1058-032', 0, 1, 'Dave_Telgheder'),
#  ('1009-013', 14, 15, 'Michoacán'),
#  ('1032-007', 15, 16, '--NME--'),
#  ('1046-009', 5, 7, '--NME--'),
#  ('0986-002', 16, 18, '1998_FIFA_World_Cup'),
#  ('1034-002', 34, 35, 'Amsterdam'),
#  ('1128-000', 0, 1, 'Poland'),
#  ('1030-040', 1, 2, 'Tokyo'),
#  ('0995-002', 2, 3, 'Tajikistan'),
#  ('1073-000', 0, 2, 'Rugby_union'),
#  ('1068-025', 0, 1, 'Shrewsbury_Town_F.C.'),
#  ('1152-008', 19, 20, 'Tennessee'),
#  ('1085-000', 2, 3, 'Belarus_national_football_team'),
#  ('1066-058', 0, 1, 'Hull_City_A.F.C.'),
#  ('1158-003', 5, 6, 'Belgium'),
#  ('1056-047', 12, 13, 'Lithuania'),
#  ('1022-007', 13, 14, '--NME--'),
#  ('1056-028', 4, 6, 'New_Zealand'),
#  ('1065-010', 0, 1, 'Airdrieonians_F.C.'),
#  ('1027-021', 2, 3, 'Israel'),
#  ('1105-003', 2, 3, '--NME--'),
#  ('0957-001', 0, 2, 'New_York_City'),
#  ('0961-002', 4, 7, 'National_Football_League'),
#  ('0966-021', 4, 5, 'United_States'),
#  ('0946-008', 13, 14, 'Peter_Such'),
#  ('1039-015', 32, 33, 'Indonesia'),
#  ('1138-010', 19, 20, 'Beijing'),
#  ('1026-000', 0, 1, 'Egypt'),
#  ('0958-038', 0, 2, 'National_League_Central'),
#  ('1056-017', 8, 10, '--NME--'),
#  ('0999-006', 0, 1, 'Interfax'),
#  ('1047-003', 2, 4, 'Bradford_Bulls'),
#  ('1066-063', 0, 1, 'Carlisle_United_F.C.'),
#  ('1116-007', 19, 23, 'War_of_the_Spanish_Succession'),
#  ('1143-004', 16, 17, 'Lebanon'),
#  ('1056-001', 2, 3, 'England'),
#  ('1099-003', 9, 10, 'Scotland_national_football_team'),
#  ('1066-040', 0, 1, 'A.F.C._Bournemouth'),
#  ('1104-002', 22, 24, 'Real_Madrid_CF'),
#  ('1055-037', 2, 3, 'Darren_Gough'),
#  ('1089-000', 7, 10, 'Greater_Milwaukee_Open'),
#  ('1022-007', 5, 6, 'Canada'),
#  ('0967-002', 7, 9, 'Standard_Liège'),
#  ('0994-008', 27, 28, 'Reuters'),
#  ('0983-002', 17, 18, 'London'),
#  ('1068-010', 3, 4, 'Oxford_United_F.C.'),
#  ('1058-017', 19, 21, 'Jim_Leyritz'),
#  ('1076-042', 0, 4, '--NME--'),
#  ('1147-002', 13, 14, 'Iraq'),
#  ('1072-019', 67, 69, 'Robin_Brooke'),
#  ('1146-005', 50, 51, 'Jalal_Talabani'),
#  ('0947-010', 20, 21, 'Hampshire_County_Cricket_Club'),
#  ('0966-004', 1, 3, 'Michelle_Freeman'),
#  ('0961-003', 8, 10, 'Philadelphia_Eagles'),
#  ('0956-016', 0, 1, 'Hanwha_Eagles'),
#  ('1016-014', 0, 1, '--NME--'),
#  ('1094-024', 0, 2, 'Kansas_City_Royals'),
#  ('1101-011', 4, 6, 'Bernard_Lama'),
#  ('0966-112', 1, 3, '--NME--'),
#  ('1032-000', 6, 7, '--NME--'),
#  ('1000-004', 14, 15, 'Budapest_Stock_Exchange'),
#  ('0972-013', 3, 4, 'Romesh_Kaluwitharana'),
#  ('1090-001', 0, 2, '--NME--'),
#  ('0957-019', 24, 25, 'Sweden'),
#  ('0964-000', 11, 12, 'FIFA'),
#  ('1141-006', 0, 1, 'Wuhan'),
#  ('1133-007', 4, 5, '--NME--'),
#  ('1048-000', 4, 5, 'Bulgaria_national_football_team'),
#  ('1005-006', 19, 21, 'South_Korea'),
#  ('1022-012', 28, 29, 'Greenwich_Mean_Time'),
#  ('1120-008', 12, 13, 'United_Kingdom'),
#  ('1160-011', 20, 21, 'China'),
#  ('1063-002', 14, 15, 'Europe'),
#  ('0946-012', 8, 10, 'Chris_Adams_(cricketer)'),
#  ('1005-006', 0, 1, 'Singapore'),
#  ('1026-000', 5, 6, 'Islam'),
#  ('0990-003', 1, 2, 'Alexander_Lebed'),
#  ('1025-003', 26, 27, '--NME--'),
#  ('1069-015', 3, 4, 'Leeds'),
#  ('1145-000', 4, 5, 'Bahrain'),
#  ('1028-000', 2, 6, '--NME--'),
#  ('1012-007', 5, 8, 'Million_Man_March'),
#  ('1095-008', 0, 1, 'Texas_Rangers_(baseball)'),
#  ('0966-092', 4, 5, 'Nigeria'),
#  ('1010-016', 7, 8, 'Italy'),
#  ('1066-026', 0, 2, 'Sheffield_United_F.C.'),
#  ('1056-016', 20, 21, 'Russia'),
#  ('1118-007', 25, 28, 'Scottish_National_Party'),
#  ('1059-006', 24, 25, 'Derbyshire_County_Cricket_Club'),
#  ('1068-014', 7, 8, 'Bolton_Wanderers_F.C.'),
#  ('1019-013', 8, 9, 'Netherlands'),
#  ('1117-003', 29, 30, 'England'),
#  ('1156-003', 40, 41, 'Burundi'),
#  ('1055-000', 2, 3, 'England_cricket_team'),
#  ('1058-003', 16, 17, 'Texas_Rangers_(baseball)'),
#  ('1144-002', 26, 27, 'Kurdistan'),
#  ('1101-006', 16, 17, 'Juventus_F.C.'),
#  ('0949-010', 2, 4, 'UEFA_Euro_1996'),
#  ('1101-003', 34, 35, 'Chelsea_F.C.'),
#  ('1071-004', 16, 18, '--NME--'),
#  ('1143-003', 12, 13, 'Lebanon'),
#  ('1121-008', 35, 37, 'Iraqi_Kurdistan'),
#  ('1124-001', 0, 2, 'Cape_Town'),
#  ('1054-007', 6, 7, 'TVM_(cycling_team)'),
#  ('1121-004', 4, 5, 'Iraq'),
#  ('0947-010', 0, 1, 'Portsmouth'),
#  ('1058-023', 2, 3, 'Pete_Incaviglia'),
#  ('1056-009', 4, 5, 'United_Kingdom'),
#  ('1160-014', 0, 1, '--NME--'),
#  ('1074-004', 10, 11, 'Benin_national_football_team'),
#  ('0966-095', 1, 3, 'Phylis_Smith'),
#  ('1127-014', 22, 23, 'Alla_Dudayeva'),
#  ('0954-002', 21, 22, 'Pakistan'),
#  ('0967-003', 17, 19, 'Guy_Hellers'),
#  ('1116-006', 7, 8, 'House_of_Orléans'),
#  ('1152-014', 32, 33, '--NME--'),
#  ('1124-009', 30, 31, 'France'),
#  ('1109-001', 0, 1, 'Amsterdam'),
#  ('0992-003', 25, 27, 'Alija_Izetbegović'),
#  ('1014-010', 10, 12, 'Ross_Perot'),
#  ('1031-006', 26, 27, 'Indonesia'),
#  ('0953-004', 3, 4, '--NME--'),
#  ('1025-011', 7, 8, 'Benjamin_Netanyahu'),
#  ('0974-008', 9, 11, 'Sanath_Jayasuriya'),
#  ('1099-017', 35, 37, 'Herfried_Sabitzer'),
#  ('1130-005', 9, 14, '--NME--'),
#  ('1150-005', 21, 23, '--NME--'),
#  ('1051-011', 18, 19, 'Sweden'),
#  ('1094-050', 0, 1, 'Atlanta_Braves'),
#  ('1025-008', 15, 16, '--NME--'),
#  ('1013-004', 6, 7, 'Europe'),
#  ('1099-018', 0, 1, 'Scotland_national_football_team'),
#  ('1025-009', 6, 7, 'Israel'),
#  ('1095-007', 0, 1, 'Milwaukee_Brewers'),
#  ('1059-004', 29, 31, 'Royal_Tunbridge_Wells'),
#  ('0954-003', 6, 8, 'Dan_Jenson'),
#  ('1066-065', 0, 1, 'Northampton_Town_F.C.'),
#  ('0991-002', 22, 23, 'Chechnya'),
#  ('1090-015', 7, 9, 'US_Open_(tennis)'),
#  ('0948-009', 6, 8, 'British_Universities_cricket_team'),
#  ('1057-006', 26, 28, 'Robert_Croft'),
#  ('1051-010', 35, 36, 'Australia'),
#  ('1087-015', 4, 7, 'Professional_Squash_Association'),
#  ('0995-002', 0, 1, 'Tavildara'),
#  ('1065-037', 0, 2, 'Ross_County_F.C.'),
#  ('1131-004', 11, 13, 'United_States'),
#  ('1070-012', 7, 9, '--NME--'),
#  ('1101-012', 52, 55, '--NME--'),
#  ('0966-096', 1, 3, 'Linda_Kisabaka'),
#  ('1094-000', 2, 4, 'Major_League_Baseball'),
#  ('1043-003', 27, 28, '--NME--'),
#  ('1012-008', 4, 5, 'Libya'),
#  ('1054-022', 1, 2, 'Erik_Breukink'),
#  ('1059-006', 28, 30, 'Dean_Jones_(cricketer)'),
#  ('1015-003', 24, 25, 'Newfoundland_(island)'),
#  ('1153-006', 36, 37, 'Liège'),
#  ('1087-019', 4, 5, 'Jansher_Khan'),
#  ('0994-016', 0, 1, 'Alexander_Lukashenko'),
#  ('1008-028', 0, 1, '--NME--'),
#  ('1056-021', 1, 3, 'Annett_Neumann'),
#  ('1049-002', 24, 26, '1998_FIFA_World_Cup'),
#  ('1152-016', 17, 18, 'United_States'),
#  ('0966-034', 4, 5, 'Belgium'),
#  ('1126-010', 1, 2, 'Reuters'),
#  ('1088-002', 21, 22, 'Pakistan'),
#  ('0981-013', 0, 1, 'Ford_Motor_Company'),
#  ('1058-016', 13, 15, 'Andy_Pettitte'),
#  ('1043-002', 3, 4, 'Thailand'),
#  ('1094-046', 0, 2, 'Los_Angeles_Angels'),
#  ('0958-027', 2, 3, 'Texas_Rangers_(baseball)'),
#  ('0966-082', 4, 5, 'Zambia'),
#  ('1066-034', 0, 1, 'Chesterfield_F.C.'),
#  ('0957-013', 6, 8, '--NME--'),
#  ('0973-000', 8, 10, 'Sri_Lanka_national_cricket_team'),
#  ('1049-004', 5, 6, 'Republic_of_Ireland_national_football_team'),
#  ('0966-032', 4, 5, 'Trinidad'),
#  ('1141-002', 1, 2, 'China'),
#  ('0992-002', 0, 1, 'Bosnia_and_Herzegovina'),
#  ('1004-003', 0, 2, '--NME--'),
#  ('0957-021', 13, 15, 'Kimberly_Po'),
#  ('1054-007', 4, 5, 'Netherlands'),
#  ('1103-020', 17, 18, 'Italy_national_football_team'),
#  ('1156-000', 6, 7, 'Julius_Nyerere'),
#  ('1085-002', 2, 3, 'Estonia_national_football_team'),
#  ('1115-005', 1, 3, 'Bernard_Ingham'),
#  ('1044-005', 0, 1, '--NME--'),
#  ('1115-010', 8, 9, 'Nancy_Reagan'),
#  ('1061-018', 0, 1, 'Boroughmuir_RFC'),
#  ('1099-018', 5, 7, 'Craig_Burley'),
#  ('0980-000', 8, 9, 'Chicago'),
#  ('1072-005', 28, 30, 'New_Zealand_national_rugby_union_team'),
#  ('1051-003', 15, 16, 'Spain'),
#  ('1042-003', 12, 13, 'Yunnan'),
#  ('0998-000', 2, 3, 'Chechens'),
#  ('1101-002', 0, 2, 'UEFA_Euro_1996'),
#  ('0980-016', 14, 15, 'Federal_Open_Market_Committee'),
#  ('1065-019', 0, 1, 'Ayr_United_F.C.'),
#  ('1066-029', 0, 1, 'Charlton_Athletic_F.C.'),
#  ('1069-001', 0, 1, 'London'),
#  ('1006-002', 0, 1, 'Tripoli,_Lebanon'),
#  ('0984-006', 4, 6, 'United_States_Treasury_security'),
#  ('1107-002', 2, 3, 'Scotland_national_football_team'),
#  ('1150-005', 25, 28, '--NME--'),
#  ('1142-005', 17, 18, 'Kurdistan_Democratic_Party'),
#  ('1008-019', 2, 3, 'Federal_Open_Market_Committee'),
#  ('1031-006', 7, 8, 'Pirelli'),
#  ('1160-018', 16, 17, 'Neil_Jordan'),
#  ('0957-024', 0, 2, 'Hendrik_Dreekmann'),
#  ('1056-046', 0, 2, 'Lucy_Tyler-Sharman'),
#  ('1154-001', 0, 1, 'Paris'),
#  ('1110-002', 0, 1, 'United_States'),
#  ('0980-005', 3, 4, 'Japan'),
#  ('0957-033', 15, 17, 'Andrea_Gaudenzi'),
#  ('0972-037', 10, 11, 'Darren_Lehmann'),
#  ('1027-007', 33, 35, '--NME--'),
#  ('1035-000', 7, 8, 'Germany'),
#  ('1056-020', 1, 3, 'Félicia_Ballanger'),
#  ('0958-052', 3, 4, 'Montreal_Expos'),
#  ('1067-007', 2, 3, 'Dundee_United_F.C.'),
#  ('1010-017', 2, 3, 'Joseph_Bernardin'),
#  ('1142-008', 0, 1, '--NME--'),
#  ('1066-016', 0, 1, 'Ipswich_Town_F.C.'),
#  ('1000-005', 0, 1, '--NME--'),
#  ('0979-001', 0, 2, 'New_York_City'),
#  ('0999-006', 2, 3, '--NME--'),
#  ('1135-006', 26, 27, 'National_League_for_Democracy'),
#  ('1033-007', 3, 4, 'Chechnya'),
#  ('0966-013', 1, 3, '--NME--'),
#  ('1010-000', 2, 3, 'Joseph_Bernardin'),
#  ('1128-010', 8, 9, '--NME--'),
#  ('1022-010', 20, 21, 'United_States'),
#  ('0956-006', 2, 3, '--NME--'),
#  ('1065-032', 0, 1, 'Alloa_Athletic_F.C.'),
#  ('1045-003', 34, 36, 'David_Peleg'),
#  ('1012-000', 0, 1, 'United_States'),
#  ('1055-004', 0, 2, '--NME--'),
#  ('1049-001', 2, 3, 'Liechtenstein'),
#  ('1069-013', 33, 35, '--NME--'),
#  ('0997-003', 0, 2, '--NME--'),
#  ('1108-002', 21, 22, 'United_States'),
#  ('1101-011', 70, 72, 'Nicolas_Ouédec'),
#  ('0947-004', 10, 11, 'Leicestershire_County_Cricket_Club'),
#  ('1095-014', 0, 1, 'Atlanta_Braves'),
#  ('0965-011', 18, 20, 'Jesse_Owens'),
#  ('1096-036', 13, 15, 'Alan_Benes'),
#  ('1035-001', 0, 1, 'Bonn'),
#  ('1096-010', 9, 10, 'Cincinnati_Reds'),
#  ('1016-013', 10, 12, 'Volker_Rühe'),
#  ('1154-008', 0, 1, 'Algeria'),
#  ('1094-030', 3, 4, 'Los_Angeles_Angels'),
#  ('1066-037', 0, 1, 'Blackpool_F.C.'),
#  ('1152-002', 0, 1, 'Washington,_D.C.'),
#  ('0966-076', 1, 3, 'Tegla_Loroupe'),
#  ('1050-003', 8, 10, '--NME--'),
#  ('1133-014', 21, 22, 'Xiao_Qiang'),
#  ('1101-012', 35, 37, 'Germán_Villa'),
#  ('1143-000', 6, 7, 'Lebanon'),
#  ('1054-008', 4, 5, 'Netherlands'),
#  ('1057-006', 11, 13, 'Alec_Stewart'),
#  ('1103-015', 71, 73, 'Luís_Oliveira'),
#  ('1031-003', 5, 6, 'Pirelli'),
#  ...}

# %% [markdown]
# A naive baseline for entity linking on our data set is to link each mention span to the Wikipedia page name that we get when we join the tokens in the span by underscores, as is standard in Wikipedia page names. Suppose, for example, that a span contains the two tokens
#
#     Jimi Hendrix
#
# The baseline Wikipedia page name for this span would be
#
#     Jimi_Hendrix
#
# Implement this naive baseline and evaluate its performance. Print the evaluation measures that you implemented in Problem&nbsp;1.

# %% [markdown]
# **Here and in the remainder of this lab, you should base your entity predictions on the predicted spans that you computed in Problem&nbsp;3.**

# %%
# TODO: Write code here to implement the baseline
def baseline_predict_mentions(df):
    for row in df.itertuples():
        label = row.sentence.split(" ")[int(row.beg):int(row.end)]
        label = "_".join(label)
        yield row.sentence_id, row.beg, row.end, label
                    
predicted_mentions = set(baseline_predict_mentions(new_df_dev))
evaluation_report(gold_standard_mentions, predicted_mentions)
# Out:
# precission:  0.3035785288270378 , recall:  0.258069967889133 , F1_score:  0.2789805426144149

# %% [markdown]
# ## Problem 5: Extending the training data using the knowledge base

# %% [markdown]
# State-of-the-art approaches to entity linking exploit information in knowledge bases. In our case, where Wikipedia is the knowledge base, one particularly useful type of information are links to other Wikipedia pages. In particular, we can interpret the anchor texts (the highlighted texts that you click on) as mentions of the entities (pages) that they link to. This allows us to harvest long lists of mention–entity pairings.
#
# The following cell loads a data frame summarizing anchor texts and page references harvested from the first paragraphs of the English Wikipedia. The data frame also contains all entity mentions in the training data (but not the development or the test data).

# %%
with bz2.open('kb.tsv.bz2', 'rt') as source:
    df_kb = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# To understand what information is available in this data, the following cell shows the entry for the anchor text `Sweden`.

# %%
df_kb.loc[df_kb.mention == 'Sweden']

# %% [markdown]
# As you can see, each row of the data frame contains a pair $(m, e)$ of a mention $m$ and an entity $e$, as well as the conditional probability $P(e|m)$ for mention $m$ referring to entity $e$. These probabilities were estimated based on the frequencies of mention–entity pairs in the knowledge base. The example shows that the anchor text &lsquo;Sweden&rsquo; is most often used to refer to the entity [Sweden](http://en.wikipedia.org/wiki/Sweden), but in a few cases also to refer to Sweden&rsquo;s national football and ice hockey teams. Note that references are sorted in decreasing order of probability, so that the most probable pairing come first.
#
# Implement an entity linking method that resolves each mention to the most probable entity in the data frame. If the mention is not included in the data frame, you can predict the generic label `--NME--`. Print the precision, recall, and F1 of your method using the function that you implemented for Problem&nbsp;1.

# %%
# TODO: Write code here to implement the "most probable entity" method.

# %% [markdown]
# ## Problem 6: Context-sensitive disambiguation

# %% [markdown]
# Consider the entity mention &lsquo;Lincoln&rsquo;. The most probable entity for this mention turns out to be [Lincoln, Nebraska](http://en.wikipedia.org/Lincoln,_Nebraska); but in pages about American history, we would be better off to predict [Abraham Lincoln](http://en.wikipedia.org/Abraham_Lincoln). This suggests that we should try to disambiguate between different entity references based on the textual context on the page from which the mention was taken. Your task in this last problem is to implement this idea.
#
# Set up a dictionary that contains, for each mention $m$ that can refer to more than one entity $e$, a separate Naive Bayes classifier that is trained to predict the correct entity $e$, given the textual context of the mention. As the prior probabilities of the classifier, choose the probabilities $P(e|m)$ that you used in Problem&nbsp;5. To let you estimate the context-specific probabilities, we have compiled a data set with mention contexts:

# %%
with bz2.open('contexts.tsv.bz2') as source:
    df_contexts = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# This data frame contains, for each ambiguous mention $m$ and each knowledge base entity $e$ to which this mention can refer, up to 100 randomly selected contexts in which $m$ is used to refer to $e$. For this data, a **context** is defined as the 5 tokens to the left and the 5 tokens to the right of the mention. Here are a few examples:

# %%
df_contexts.head()

# %% [markdown]
# Note that, in each context, the position of the mention is indicated by the `@` symbol.
#
# From this data frame, it is easy to select the data that you need to train the classifiers – the contexts and corresponding entities for all mentions. To illustrate this, the following cell shows how to select all contexts that belong to the mention &lsquo;Lincoln&rsquo;:

# %%
df_contexts.context[df_contexts.mention == 'Lincoln']

# %% [markdown]
# Implement the context-sensitive disambiguation method and evaluate its performance. Here are some more hints that may help you along the way:
#
# **Hint 1:** The prior probabilities for a Naive Bayes classifier can be specified using the `class_prior` option. You will have to provide the probabilities in the same order as the alphabetically sorted class (entity) names.
#
# **Hint 2:** Not all mentions in the knowledge base are ambiguous, and therefore not all mentions have context data. If a mention has only one possible entity, pick that one. If a mention has no entity at all, predict the `--NME--` label.

# %%
# TODO: Write code here to implement the context-sensitive disambiguation method

# %% [markdown]
# You should expect to see a small (around 1&nbsp;unit) increase in both precision, recall, and F1.

# %% [markdown]
# ## Reflection questions

# %% [markdown]
# The following reflection questions will help you prepare for the diagnostic test. Answer each of them in the form of a short text and put your answers in the cell below. You will get feedback on your answers from your lab assistant.

# %% [markdown]
# **RQ 5.1:** In Problem&nbsp;3, you did an error analysis on the task of recognizing text spans mentioning named entities. Summarize your results. Pick one type of error that you observed. How could you improve the model&rsquo;s performance on this type of error? What resources (such as domain knowledge, data, compute) would you need to implement this improvement?
#
# **RQ 5.2:** Thinking back about Problem&nbsp;6, explain what the word *context* refers to in the task addressed there, and how context can help to disambiguate between different entities. Suggest other types of context that you could use for disambiguation.
#
# **RQ 5.3:** One type of entity mentions that we did not cover explicitly in this lab are pronouns. As an example, consider the sentence pair *Ruth Bader Ginsburg was an American jurist*. *She served as an associate justice of the Supreme Court from 1993 until her death in 2020*. What facts would you want to extract from this sentence pair? How do pronouns make fact extraction hard?

# %% [markdown]
# *TODO: Enter your answers here*

# %% [markdown]
# **This was the last lab in the Text Mining course. Congratulations! 🥳**
