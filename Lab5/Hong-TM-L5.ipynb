# %% [markdown]
# # L5: Information extraction

# %% [markdown]
# Information extraction (IE) is the task of identifying named entities and semantic relations between these entities in text data. In this lab we will focus on two sub-tasks in IE, **named entity recognition** (identifying mentions of entities) and **entity linking** (matching these mentions to entities in a knowledge base).

# %% [markdown]
# **Reminder about our [Rules for hand-in assignments](https://www.ida.liu.se/~TDDE16/exam.en.shtml#handins) and the [Policy on cheating and plagiarism](https://www.ida.liu.se/~TDDE16/exam.en.shtml#cheating)**

# %% [markdown]
# We start by loading spaCy:

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# The data that we will be using has been tokenized following the conventions of the [Penn Treebank](ftp://ftp.cis.upenn.edu/pub/treebank/public_html/tokenization.html), and we need to prevent spaCy from using its own tokenizer on top of this. We therefore override spaCy&rsquo;s tokenizer with one that simply splits on space.

# %%
from spacy.tokens import Doc

class WhitespaceTokenizer(object):
    def __init__(self, vocab):
        self.vocab = vocab

    def __call__(self, text):
        return Doc(self.vocab, words=text.split(' '))

nlp.tokenizer = WhitespaceTokenizer(nlp.vocab)

# %% [markdown]
# ## Data set

# %% [markdown]
# The main data set for this lab is a collection of news wire articles in which mentions of named entities have been annotated with page names from the [English Wikipedia](https://en.wikipedia.org/wiki/). The next code cell loads the training and the development parts of the data into Pandas data frames.

# %%
import bz2
import csv
import pandas as pd

with bz2.open('ner-train.tsv.bz2', 'rt') as source:
    df_train = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

with bz2.open('ner-dev.tsv.bz2', 'rt') as source:
    df_dev = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# Each row in these two data frames corresponds to one mention of a named entity and has five columns:
#
# 1. a unique identifier for the sentence containing the entity mention
# 2. the pre-tokenized sentence, with tokens separated by spaces
# 3. the start position of the token span containing the entity mention
# 4. the end position of the token span (exclusive, as in Python list indexing)
# 5. the entity label; either a Wikipedia page name or the generic label `--NME--`
#
# The following cell prints the first five samples from the training data:

# %%
df_train.head()
# Out:
#   sentence_id                                          sentence  beg  end  \
# 0    0000-000  EU rejects German call to boycott British lamb .    0    1
# 1    0000-000  EU rejects German call to boycott British lamb .    2    3
# 2    0000-000  EU rejects German call to boycott British lamb .    6    7
# 3    0000-001                                   Peter Blackburn    0    2
# 4    0000-002                               BRUSSELS 1996-08-22    0    1
#
#             label
# 0         --NME--
# 1         Germany
# 2  United_Kingdom
# 3         --NME--
# 4        Brussels

# %% [markdown]
# In this sample, we see that the first sentence is annotated with three entity mentions:
#
# * the span 0–1 &lsquo;EU&rsquo; is annotated as a mention but only labelled with the generic `--NME--`
# * the span 2–3 &lsquo;German&rsquo; is annotated with the page [Germany](http://en.wikipedia.org/wiki/Germany)
# * the span 6–7 &lsquo;British&rsquo; is annotated with the page [United_Kingdom](http://en.wikipedia.org/wiki/United_Kingdom)

# %% [markdown]
# ## Problem 1: Evaluation measures

# %% [markdown]
# To warm up, we ask you to write code to print the three measures that you will be using for evaluation:

# %%
def evaluation_report(gold, pred):
    """Print precision, recall, and F1 score.
    
    Args:
        gold: The set with the gold-standard values.
        pred: The set with the predicted values.
    
    Returns:
        Nothing, but prints the precision, recall, and F1 values computed
        based on the specified sets.
    """
    # TODO: Replace the next line with your own code
    TP = len(gold & pred) # intersection
    TN = 0
    FP = len(pred - gold)
    FN = len(gold - pred)

    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    F1_score = (2 * precision * recall) / (precision + recall)
    
    print("precission: ",precision, ", recall: ", recall, ", F1_score: ", F1_score )

# %% [markdown]
# To test your code, you can run the following cell:

# %%
evaluation_report(set(range(3)), set(range(5)))
# Out:
# precission:  0.6 , recall:  1.0 , F1_score:  0.7499999999999999

# %% [markdown]
# This should give you a precision of 60%, a recall of 100%, and an F1-value of 75%.

# %% [markdown]
# ## Problem 2: Span recognition

# %% [markdown]
# One of the first tasks that an information extraction system has to solve is to locate and classify (mentions of) named entities, such as persons and organizations. Here we will tackle the simpler task of recognizing **spans** of tokens that contain an entity mention, without the actual entity label.
#
# The English language model in spaCy features a full-fledged [named entity recognizer](https://spacy.io/usage/linguistic-features#named-entities) that identifies a variety of entities, and can be updated with new entity types by the user. Your task in this problem is to evaluate the performance of this component when predicting entity spans in the development data.
#
# Start by implementing a generator function that yields the gold-standard spans in a given data frame.
#
# **Hint:** The Pandas method [`itertuples()`](https://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.DataFrame.itertuples.html) is useful when iterating over the rows in a DataFrame.

# %%
def gold_spans(df):
    """Yield the gold-standard mention spans in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        triples consisting of the sentence id, start position, and end
        position of each span.
    """
    # TODO: Replace the next line with your own code
    for row in df.itertuples(index = False):
        yield row.sentence_id, row.beg, row.end

# %% [markdown]
# To test your code, you can count the spans yielded by your function. When called on the development data, you should get a total of 5,917 unique triples. The first triple and the last triple should be
#
#     ('0946-000', 2, 3)
#     ('1161-010', 1, 3)

# %%
spans_dev_gold = set(gold_spans(df_dev))
print(len(spans_dev_gold))
# Out:
# 5917

# %% [markdown]
# ----set() function will deduplicate and reorder the list.
#
# ----use list() function to get the original order.

# %%
list(gold_spans(df_dev))[0]
# Out:
# ('0946-000', 2, 3)

# %%
list(gold_spans(df_dev))[-1]
# Out:
# ('1161-010', 1, 3)

# %% [markdown]
# Your next task is to write code that calls spaCy to predict the named entities in the development data, and to evaluate the accuracy of these predictions in terms of precision, recall, and F1. Print these scores using the function that you wrote for Problem&nbsp;1.

# %%
# TODO: Write code here to run and evaluate the spaCy named entity recognizer on the development data
def spaCy_predict(df):
    for row in df.itertuples():
        doc = nlp(row.sentence)
        for ent in doc.ents:
            yield row.sentence_id, ent.start, ent.end

spaCy_predictions = set(spaCy_predict(df_dev))
evaluation_report(gold = spans_dev_gold, pred = spaCy_predictions)
# Out:
# precission:  0.5213954072029113 , recall:  0.702213959776914 , F1_score:  0.5984444764511019

# %% [markdown]
# ## Problem 3: Error analysis

# %% [markdown]
# As you were able to see in Problem&nbsp;2, the span accuracy of the named entity recognizer is far from perfect. In particular, only slightly more than half of the predicted spans are correct according to the gold standard. Your next task is to analyse this result in more detail.
#
# Here is a function that prints the false positives as well as the false negatives spans for a data frame, given a reference set of gold-standard spans and a candidate set of predicted spans.

# %%
from collections import defaultdict

def error_report(df, spans_gold, spans_pred):
    false_pos = defaultdict(list)
    for s, b, e in spans_pred - spans_gold:
        false_pos[s].append((b, e))
    false_neg = defaultdict(list)
    for s, b, e in spans_gold - spans_pred:
        false_neg[s].append((b, e))
    for row in df.drop_duplicates('sentence_id').itertuples():
        if row.sentence_id in false_pos or row.sentence_id in false_neg:
            print('Sentence:', row.sentence)
            for b, e in false_pos[row.sentence_id]:
                print('  FP:', ' '.join(row.sentence.split()[b:e]))
            for b, e in false_neg[row.sentence_id]:
                print('  FN:', ' '.join(row.sentence.split()[b:e]))

# %% [markdown]
# Use this function to inspect and analyse the errors that the automated prediction makes. Can you see any patterns? Base your analysis on the first 500 rows of the training data. Summarize your observations in a short text.

# %%
# TODO: Write code here to do your analysis

error_report(df_dev.iloc[:500,], set(gold_spans(df_dev)),set(spaCy_predict(df_dev)))
# Out:
# Sentence: CRICKET - LEICESTERSHIRE TAKE OVER AT TOP AFTER INNINGS VICTORY .
#   FN: LEICESTERSHIRE
# Sentence: LONDON 1996-08-30
#   FP: 1996-08-30
# Sentence: West Indian all-rounder Phil Simmons took four for 38 on Friday as Leicestershire beat Somerset by an innings and 39 runs in two days to take over at the head of the county championship .
#   FP: Friday
#   FP: 39
#   FP: four
#   FP: 38
#   FP: two days
# Sentence: After bowling Somerset out for 83 on the opening morning at Grace Road , Leicestershire extended their first innings by 94 runs before being bowled out for 296 with England discard Andy Caddick taking three for 83 .
#   FP: the opening morning
#   FP: 296
#   FP: three
#   FP: 83
#   FP: 83
#   FP: first
#   FP: 94
# Sentence: Trailing by 213 , Somerset got a solid start to their second innings before Simmons stepped in to bundle them out for 174 .
#   FP: 213
#   FP: second
#   FP: 174
# Sentence: Essex , however , look certain to regain their top spot after Nasser Hussain and Peter Such gave them a firm grip on their match against Yorkshire at Headingley .
#   FP: Yorkshire at
#   FN: Yorkshire
#   FN: Essex
# Sentence: Hussain , considered surplus to England 's one-day requirements , struck 158 , his first championship century of the season , as Essex reached 372 and took a first innings lead of 82 .
#   FP: 158
#   FP: 372
#   FP: 82
#   FP: one-day
#   FP: first
#   FP: first
# Sentence: By the close Yorkshire had turned that into a 37-run advantage but off-spinner Such had scuttled their hopes , taking four for 24 in 48 balls and leaving them hanging on 119 for five and praying for rain .
#   FP: 24
#   FP: 48
#   FP: 119
#   FP: four
#   FP: five
#   FN: Such
# Sentence: At the Oval , Surrey captain Chris Lewis , another man dumped by England , continued to silence his critics as he followed his four for 45 on Thursday with 80 not out on Friday in the match against Warwickshire .
#   FP: 45
#   FP: Friday
#   FP: four
#   FP: 80
#   FP: Thursday
# Sentence: He was well backed by England hopeful Mark Butcher who made 70 as Surrey closed on 429 for seven , a lead of 234 .
#   FP: 429
#   FP: seven
#   FP: 234
#   FP: 70
# Sentence: Derbyshire kept up the hunt for their first championship title since 1936 by reducing Worcestershire to 133 for five in their second innings , still 100 runs away from avoiding an innings defeat .
#   FP: 1936
#   FP: first
#   FP: 133
#   FP: five
#   FP: 100
#   FP: second
#   FN: Derbyshire
# Sentence: Australian Tom Moody took six for 82 but Chris Adams , 123 , and Tim O'Gorman , 109 , took Derbyshire to 471 and a first innings lead of 233 .
#   FP: 471
#   FP: 233
#   FP: first
#   FP: six
#   FP: 82
#   FP: 123
#   FP: 109
# Sentence: After the frustration of seeing the opening day of their match badly affected by the weather , Kent stepped up a gear to dismiss Nottinghamshire for 214 .
#   FP: 214
# Sentence: They were held up by a gritty 84 from Paul Johnson but ex-England fast bowler Martin McCague took four for 55 .
#   FP: four
#   FP: 84
#   FP: 55
#   FN: ex-England
# Sentence: By stumps Kent had reached 108 for three .
#   FP: 108
#   FP: three
# Sentence: CRICKET - ENGLISH COUNTY CHAMPIONSHIP SCORES .
#   FP: CRICKET - ENGLISH COUNTY CHAMPIONSHIP SCORES
#   FN: ENGLISH COUNTY CHAMPIONSHIP
# Sentence: LONDON 1996-08-30
#   FP: 1996-08-30
# Sentence: Result and close of play scores in English county championship matches on Friday :
#   FP: English county
#   FP: Friday
#   FN: English
# Sentence: Leicester : Leicestershire beat Somerset by an innings and 39 runs .
#   FP: 39
#   FN: Leicester
#   FN: Leicestershire
# Sentence: Somerset 83 and 174 ( P. Simmons 4-38 ) , Leicestershire 296 .
#   FP: 174
#   FP: 83
#   FP: 296
#   FN: P. Simmons
#   FN: Somerset
#   FN: Leicestershire
# Sentence: Leicestershire 22 points , Somerset 4 .
#   FP: 22
#   FP: 4
#   FN: Leicestershire
#   FN: Somerset
# Sentence: Chester-le-Street : Glamorgan 259 and 207 ( A. Dale 69 , H. Morris 69 ; D. Blenkiron 4-43 ) , Durham 114 ( S. Watkin 4-28 ) and 81-3 .
#   FP: H. Morris 69
#   FP: 81-3
#   FP: 259
#   FP: 4-28
#   FP: D.
#   FN: D. Blenkiron
#   FN: Chester-le-Street
#   FN: S. Watkin
#   FN: A. Dale
#   FN: H. Morris
# Sentence: Tunbridge Wells : Nottinghamshire 214 ( P. Johnson 84 ; M. McCague 4-55 ) , Kent 108-3 .
#   FP: M. McCague 4-55
#   FN: Kent
#   FN: M. McCague
#   FN: Nottinghamshire
#   FN: P. Johnson
# Sentence: London ( The Oval ) : Warwickshire 195 , Surrey 429-7 ( C. Lewis 80 not out , M. Butcher 70 , G. Kersey 63 , J. Ratcliffe 63 , D. Bicknell 55 ) .
#   FP: Surrey 429-7
#   FP: J. Ratcliffe 63
#   FP: G. Kersey 63
#   FP: D.
#   FP: 55
#   FP: 195
#   FN: Surrey
#   FN: G. Kersey
#   FN: J. Ratcliffe
#   FN: D. Bicknell
#   FN: C. Lewis
#   FN: Warwickshire
#   FN: The Oval
# Sentence: Hove : Sussex 363 ( W. Athey 111 , V. Drakes 52 ; I. Austin 4-37 ) , Lancashire 197-8 ( W. Hegg 54 )
#   FP: W. Hegg 54
#   FP: W. Athey 111
#   FP: Lancashire 197-8
#   FP: I. Austin 4-37
#   FP: V. Drakes 52
#   FN: W. Hegg
#   FN: Hove
#   FN: Sussex
#   FN: V. Drakes
#   FN: W. Athey
#   FN: Lancashire
#   FN: I. Austin
# Sentence: Portsmouth : Middlesex 199 and 426 ( J. Pooley 111 , M. Ramprakash 108 , M. Gatting 83 ) , Hampshire 232 and 109-5 .
#   FP: 109-5
#   FP: 426
#   FP: 199
#   FP: J. Pooley 111
#   FP: M. Ramprakash 108
#   FP: Hampshire 232
#   FP: M. Gatting 83
#   FN: J. Pooley
#   FN: Middlesex
#   FN: Hampshire
#   FN: M. Gatting
#   FN: M. Ramprakash
#   FN: Portsmouth
# Sentence: Chesterfield : Worcestershire 238 and 133-5 , Derbyshire 471 ( J. Adams 123 , T.O'Gorman 109 not out , K. Barnett 87 ; T. Moody 6-82 )
#   FP: Worcestershire 238 and 133-5
#   FP: J. Adams 123
#   FP: 109
#   FP: T. Moody 6-82
#   FN: Derbyshire
#   FN: T. Moody
#   FN: T.O'Gorman
#   FN: J. Adams
#   FN: Worcestershire
# Sentence: Bristol : Gloucestershire 183 and 185-6 ( J. Russell 56 not out ) , Northamptonshire 190 ( K. Curran 52 ; A. Smith 5-68 ) .
#   FP: Northamptonshire 190 ( K. Curran 52
#   FP: A. Smith 5-68
#   FP: 183
#   FP: J. Russell 56
#   FN: K. Curran
#   FN: A. Smith
#   FN: Gloucestershire
#   FN: J. Russell
#   FN: Northamptonshire
# Sentence: CRICKET - 1997 ASHES INTINERARY .
#   FP: CRICKET - 1997
#   FN: ASHES
# Sentence: LONDON 1996-08-30
#   FP: 1996-08-30
# Sentence: Australia will defend the Ashes in
#   FN: Ashes
# Sentence: a six-test series against England during a four-month tour
#   FP: four-month
# Sentence: starting on May 13 next year , the Test and County Cricket Board
#   FP: May 13 next year
#   FN: Test and County Cricket Board
# Sentence: Australia will also play three one-day internationals and
#   FP: three
# Sentence: as well as one-day matches against the Minor Counties and
#   FP: one-day
#   FN: Minor Counties
# Sentence: May 13 Arrive in London
#   FP: May 13 Arrive
# Sentence: May 14 Practice at Lord 's
#   FP: May 14 Practice
#   FN: Lord 's
# Sentence: May 15 v Duke of Norfolk 's XI ( at Arundel )
#   FP: XI
#   FP: May 15 v Duke of Norfolk 's
#   FN: Arundel
#   FN: Duke of Norfolk 's XI
# Sentence: May 17 v Northampton
#   FP: May 17
# Sentence: May 18 v Worcestershire
#   FP: May 18 v
#   FN: Worcestershire
# Sentence: May 20 v Durham
#   FP: May 20
#   FN: Durham
# Sentence: May 22 First one-day international ( at Headingley ,
#   FP: May 22 First one-day
# Sentence: May 24 Second one-day international ( at The Oval ,
#   FP: May 24 Second
# Sentence: May 25 Third one-day international ( at Lord 's , London )
#   FP: May 25 Third one-day
#   FN: Lord 's
# Sentence: May 27-29 v Gloucestershire or Sussex or Surrey ( three
#   FP: May 27-29 v Gloucestershire
#   FP: three
#   FN: Gloucestershire
# Sentence: May 31 - June 2 v Derbyshire ( three days )
#   FP: May 31 - June 2 v Derbyshire
#   FP: three days
#   FN: Derbyshire
# Sentence: June 5-9 First test match ( at Edgbaston , Birmingham )
#   FP: First
#   FP: June 5-9
# Sentence: June 14-16 v Leicestershire ( three days )
#   FP: June 14-16
#   FP: three days
#   FN: Leicestershire
# Sentence: June 19-23 Second test ( at Lord 's )
#   FP: Second
#   FP: June 19-23
#   FN: Lord 's
# Sentence: June 25-27 v British Universities ( at Oxford , three days )
#   FP: June 25-27
#   FP: British
#   FP: three days
#   FN: British Universities
# Sentence: June 28-30 v Hampshire ( three days )
#   FP: June 28-30 v Hampshire
#   FP: three days
#   FN: Hampshire
# Sentence: July 3-7 Third test ( at Old Trafford , Manchester )
#   FP: July 3-7 Third
# Sentence: July 9 v Minor Counties XI
#   FP: July 9
#   FN: Minor Counties XI
# Sentence: July 12 v Scotland
#   FP: July 12
# Sentence: July 16-18 v Glamorgan ( three days )
#   FP: July 16-18
#   FP: three days
#   FN: Glamorgan
# Sentence: July 19-21 v Middlesex ( three days )
#   FP: July 19-21
#   FP: three days
#   FN: Middlesex
# Sentence: July 24-28 Fourth test ( at Headingley )
#   FP: Fourth
#   FP: July 24-28
# Sentence: August 1-4 v Somerset ( four days )
#   FP: four days
#   FP: August 1-4
#   FN: Somerset
# Sentence: August 7-11 Fifth test ( at Trent Bridge , Nottingham )
#   FP: August 7-11 Fifth
# Sentence: August 16-18 v Kent ( three days )
#   FP: August 16-18
#   FP: three days
#   FN: Kent
# Sentence: August 21-25 Sixth test ( at The Oval , London ) .
#   FP: August 21-25
#   FP: Sixth
# Sentence: SOCCER - SHEARER NAMED AS ENGLAND CAPTAIN .
#   FN: ENGLAND
#   FN: SHEARER
# Sentence: LONDON 1996-08-30
#   FP: 1996-08-30
# Sentence: The world 's costliest footballer Alan Shearer was named as the new England captain on Friday .
#   FP: Friday
# Sentence: The 26-year-old , who joined Newcastle for 15 million pounds sterling ( $ 23.4 million ) , takes over from Tony Adams , who led the side during the European championship in June , and former captain David Platt .
#   FP: June
#   FP: 15 million pounds
#   FP: $ 23.4 million
# Sentence: Adams and Platt are both injured and will miss England 's opening World Cup qualifier against Moldova on Sunday .
#   FP: Sunday
#   FN: Adams
# Sentence: " There were three or four people who could have done it but when I spoke to Alan he was up for it and really wanted it .
#   FP: four
#   FP: three
# Sentence: Shearer 's Euro 96 striking partner Teddy Sheringham withdrew from the squad with an injury on Friday .
#   FP: Friday
# Sentence: BELGRADE 1996-08-30
#   FP: 1996-08-30
#   FN: BELGRADE
# Sentence: SOCCER - ROMANIA BEAT LITHUANIA IN UNDER-21 MATCH .
#   FN: ROMANIA
#   FN: LITHUANIA
# Sentence: BUCHAREST 1996-08-30
#   FP: 1996-08-30
#   FN: BUCHAREST
# Sentence: Romania beat Lithuania 2-1 ( halftime 1-1 ) in their European under-21 soccer match on Friday .
#   FP: Friday
#   FP: 1-1
# Sentence: Romania - Cosmin Contra ( 31st ) , Mihai Tararache ( 75th )
#   FP: Romania - Cosmin Contra
#   FP: 75th
#   FN: Cosmin Contra
#   FN: Romania
# Sentence: Lithuania - Danius Gleveckas ( 13rd )
#   FN: Danius Gleveckas
# Sentence: SOCCER - ROTOR FANS LOCKED OUT AFTER VOLGOGRAD VIOLENCE .
#   FN: ROTOR
#   FN: VOLGOGRAD
# Sentence: MOSCOW 1996-08-30
#   FP: 1996-08-30
# Sentence: Rotor Volgograd must play their next home game behind closed doors after fans hurled bottles and stones at Dynamo Moscow players during a 1-0 home defeat on Saturday that ended Rotor 's brief spell as league leaders .
#   FP: Saturday
#   FP: Volgograd
#   FN: Rotor Volgograd
#   FN: Rotor
# Sentence: The head of the Russian league 's disciplinary committee , Anatoly Gorokhovsky , said on Friday that Rotor would play Lada Togliatti to empty stands on September 3 .
#   FP: September 3
#   FP: the Russian league 's
#   FP: Friday
#   FN: Rotor
#   FN: Russian
# Sentence: The club , who put Manchester United out of last year 's UEFA Cup , were fined $ 1,000 .
#   FP: 1,000
#   FP: last year 's
# Sentence: Despite the defeat , Rotor are well placed with 11 games to play in the championship .
#   FP: 11
#   FN: Rotor
# Sentence: Lying three points behind Alania and two behind Dynamo Moscow , the Volgograd side have a game in hand over the leaders and two over the Moscow club .
#   FP: three
#   FP: two
#   FP: two
# Sentence: BOXING - PANAMA 'S ROBERTO DURAN FIGHTS THE SANDS OF TIME .
#   FN: PANAMA
#   FN: ROBERTO DURAN
# Sentence: PANAMA CITY 1996-08-30
#   FP: PANAMA
#   FN: PANAMA CITY
# Sentence: Panamanian boxing legend Roberto " Hands of Stone " Duran climbs into the ring on Saturday in another age-defying attempt to sustain his long career .
#   FP: Saturday
# Sentence: Duran , 45 , takes on little-known Mexican Ariel Cruz , 30 , in a super middleweight non-title bout in Panama City .
#   FP: 45
#   FP: 30
# Sentence: The fight , Duran 's first on home soil for 10 years , is being billed here as the " Return of the Legend " and Duran still talks as if he was in his prime .
#   FP: 10 years
#   FP: first
#   FN: Return of the Legend
# Sentence: If he loses Saturday , it could devalue his position as one of the world 's great boxers , " Panamanian Boxing Association President Ramon Manzanares said .
#   FP: Saturday
#   FN: Boxing Association
#   FN: Panamanian
# Sentence: Duran , whose 97-12 record spans three decades , hopes a win in the 10-round bout will earn him a rematch against Puerto Rico 's Hector " Macho " Camacho .
#   FP: three decades
#   FP: Puerto Rico 's
#   FP: 97-12
#   FN: Puerto Rico
# Sentence: Camacho took a controversial points decision against the Panamanian in Atlantic City in June in a title fight .
#   FP: June
# Sentence: SQUASH - HONG KONG OPEN QUARTER-FINAL RESULTS .
#   FP: SQUASH - HONG KONG OPEN
#   FN: HONG KONG OPEN
# Sentence: HONG KONG 1996-08-30
#   FP: 1996-08-30
# Sentence: Quarter-final results in the Hong Kong Open on Friday ( prefix number denotes seeding ) : 1 - Jansher Khan ( Pakistan ) beat Mark Cairns ( England ) 15-10 15-6 15-7
#   FP: Friday
#   FP: 1
#   FP: the Hong Kong Open
#   FP: 15-10 15-6
#   FN: Jansher Khan
#   FN: Hong Kong Open
# Sentence: Anthony Hill ( Australia ) beat Dan Jenson ( Australia ) 15-9 15-8 15-17 17-15
#   FP: 15-9
# Sentence: 4 - Peter Nicol ( Scotland ) beat 7 - Chris Walker ( England ) 15-8 15-13 13-15 15-9
#   FP: 4 - Peter Nicol
#   FP: 15-8 15-13
#   FP: 7
#   FN: Chris Walker
#   FN: England
#   FN: Peter Nicol
# Sentence: 2 - Rodney Eyles ( Australia ) beat Derek Ryan ( Ireland ) 15-6 15-9 11-15 15-10 .
#   FP: 15-6 15-9 11-15 15-10
#   FP: 2 - Rodney Eyles
#   FN: Rodney Eyles
#   FN: Ireland
# Sentence: SEOUL 1996-08-30
#   FP: SEOUL 1996-08-30
#   FN: SEOUL
# Sentence: Pohang 3 Ulsan 2 ( halftime 1-0 )
#   FP: Pohang 3 Ulsan 2
#   FN: Pohang
#   FN: Ulsan
# Sentence: Puchon 2 Chonbuk 1 ( halftime 1-1 )
#   FP: 1-1
#   FP: 2
#   FN: Puchon
#   FN: Chonbuk
# Sentence: Puchon 3 1 0 6 1 10
#   FP: 3 1 0 6 1 10
#   FN: Puchon
# Sentence: Chonan 3 0 1 13 10 9
#   FP: 9
#   FN: Chonan
# Sentence: Pohang 2 1 1 11 10 7
#   FP: Pohang 2 1 1 11
#   FN: Pohang
# Sentence: Suwan 1 3 0 7 3 6
#   FN: Suwan
# Sentence: Ulsan 1 0 2 8 9 3
#   FN: Ulsan
# Sentence: Anyang 0 3 1 6 9 3
#   FP: 0 3 1 6 9 3
#   FN: Anyang
# Sentence: Pusan 0 2 1 3 7 2
#   FP: Pusan 0 2 1 3
#   FN: Pusan
# Sentence: Chonbuk 0 0 3 3 7 0
#   FP: 0
#   FN: Chonbuk
# Sentence: SEOUL 1996-08-30
#   FP: SEOUL 1996-08-30
#   FN: SEOUL
# Sentence: LG 2 OB 0
#   FP: 2
#   FN: LG
#   FN: OB
# Sentence: Lotte 6 Hyundai 2
#   FP: 2
#   FN: Lotte
# Sentence: Hyundai 6 Lotte 5
#   FP: 6 Lotte 5
#   FN: Lotte
# Sentence: Haitai 2 Samsung 0
#   FP: Haitai 2 Samsung 0
#   FN: Haitai
#   FN: Samsung
# Sentence: Samsung 10 Haitai 3
#   FP: 3
#   FN: Haitai
# Sentence: Hanwha 6 Ssangbangwool 5
#   FP: 6
#   FP: 5
#   FN: Hanwha
#   FN: Ssangbangwool
# Sentence: Note - Lotte and Hyundai , Haitai and Samsung played two games .
#   FP: two
#   FN: Lotte
# Sentence: Haitai 64 2 43 .596 -
#   FP: 64 2 43
#   FN: Haitai
# Sentence: Ssangbangwool 59 2 49 .545 5 1/2
#   FP: .545 5 1/2
#   FN: Ssangbangwool
# Sentence: Hanwha 58 1 49 .542 6
#   FP: 58
#   FP: 49
#   FP: 6
# Sentence: Hyundai 57 5 49 .536 6 1/2
#   FP: 57
#   FP: 5 49 .536 6 1/2
# Sentence: Samsung 49 5 56 .468 14
#   FP: 14
# Sentence: Lotte 46 6 54 .462 14 1/2
#   FP: 14 1/2
#   FN: Lotte
# Sentence: LG 46 5 59 .441 17
#   FP: 17
#   FP: 46
#   FN: LG
# Sentence: OB 42 6 62 .409 20 1/2
#   FP: 42
#   FP: 20 1/2
#   FN: OB
# Sentence: TENNIS - FRIDAY 'S RESULTS FROM THE U.S. OPEN .
#   FP: U.S.
#   FN: U.S. OPEN
# Sentence: NEW YORK 1996-08-30
#   FP: 1996-08-30
# Sentence: Results from the U.S. Open Tennis Championships at the National Tennis Centre on Friday ( prefix number denotes seeding ) :
#   FP: Friday
#   FP: the U.S. Open Tennis Championships
#   FP: the National Tennis Centre
#   FN: U.S. Open Tennis Championships
#   FN: National Tennis Centre
# Sentence: Sandrine Testud ( France ) beat Ines Gorrochategui ( Argentina ) 4-6 6-2 6-1
#   FP: 6-1
#   FP: 4-6
# Sentence: 4 - Goran Ivanisevic ( Croatia ) beat Scott Draper ( Australia ) 6-7 ( 1-7 ) 6-3 6-4 6-4
#   FP: Scott Draper ( Australia
#   FP: 6-7
#   FP: 6-3
#   FP: 4
#   FP: 1-7
#   FN: Croatia
#   FN: Australia
#   FN: Goran Ivanisevic
#   FN: Scott Draper
# Sentence: Tim Henman ( Britain ) beat Doug Flach ( U.S. ) 6-3 6-4 6-2
#   FP: 6-3
# Sentence: Mark Philippoussis ( Australia ) beat Andrei Olhovskiy ( Russia ) 6 - 3 6-4 6-2
#   FP: 6 - 3 6-4 6-2
# Sentence: Sjeng Schalken ( Netherlands ) beat David Rikl ( Czech Republic ) 6 - 2 6-4 6-4
#   FP: 6 - 2 6-4 6-4
# Sentence: Guy Forget ( France ) beat 17 - Felix Mantilla ( Spain ) 6-4 7-5 6-3
#   FP: 6-4 7-5
#   FP: 17
#   FP: 6-3
#   FN: Felix Mantilla
# Sentence: Alexander Volkov ( Russia ) beat Mikael Tillstrom ( Sweden ) 1-6 6- 4 6-1 4-6 7-6 ( 10-8 )
#   FP: 1-6
#   FP: 10-8
# Sentence: Jonas Bjorkman ( Sweden ) beat David Nainkin ( South Africa ) ) 6-4 6-1 6-1
#   FP: 6-4
# Sentence: 8 - Lindsay Davenport ( U.S. ) beat Anne-Gaelle Sidot ( France ) 6-0 6-3
#   FP: Sidot
#   FP: 6-0 6-3
#   FP: 8
#   FN: Lindsay Davenport
#   FN: Anne-Gaelle Sidot
# Sentence: 4 - Conchita Martinez ( Spain ) beat Helena Sukova ( Czech Republic ) 6-4 6-3
#   FP: 6-4 6-3
#   FP: 4
#   FN: Conchita Martinez
# Sentence: Amanda Coetzer ( South Africa ) beat Irina Spirlea ( Romania ) 7-6 ( 7-5 ) 7-5
#   FP: 7-5
# Sentence: Add Men 's singles , second round 16 - Cedric Pioline ( France ) beat Roberto Carretero ( Spain ) 4-6 6 - 2 6-2 6-1 Alex Corretja ( Spain ) beat Filippo Veglio ( Switzerland ) 6-7 ( 4- 7 ) 6-4 6-4 6-0
#   FP: 4-6
#   FP: second
#   FP: 16
#   FP: 6-7
#   FP: 7
#   FN: Cedric Pioline
# Sentence: Add Women 's singles , third round Linda Wild ( U.S. ) beat Barbara Rittner ( Germany ) 6-4 4-6 7-5 Asa Carlsson ( Sweden ) beat 15 - Gabriela Sabatini ( Argentina ) 7-5 3-6 6-2
#   FP: 6-4 4-6
#   FP: 15 - Gabriela Sabatini
#   FP: 6-2
#   FP: third
#   FP: 3-6
#   FP: 7-5 Asa Carlsson
#   FN: Gabriela Sabatini
#   FN: Asa Carlsson
# Sentence: Add Men 's singles , second round 1 - Pete Sampras ( U.S. ) beat Jiri Novak ( Czech Republic ) 6-3 1-6 6-3 4-6 6-4 Paul Haarhuis ( Netherlands ) beat Michael Tebbutt ( Australia ) 1- 6 6-2 6-2 6-3
#   FP: second
#   FP: 1 - Pete Sampras
#   FP: 6-3
#   FP: 6-2 6-3
#   FP: 1-6 6-3 4-6
#   FP: 6 6-2
#   FN: Pete Sampras
# Sentence: Add Women 's singles , third round Lisa Raymond ( U.S. ) beat Kimberly Po ( U.S. ) 6-3 6-2
#   FP: 6-3
#   FP: third
# Sentence: Andrei Medvedev ( Ukraine ) beat Jan Kroslak ( Slovakia ) 6-4 6-3
#   FP: 6-4 6-3
# Sentence: Petr Korda ( Czech Republic ) bat Bohdan Ulihrach ( Czech Republic ) 6-0 7-6 ( 7-5 ) 6-2
#   FP: 6-2
#   FN: Petr Korda
# Sentence: 2 - Monica Seles ( U.S. ) beat Dally Randriantefy ( Madagascar )
#   FP: Dally Randriantefy ( Madagascar
#   FP: 2
#   FN: Monica Seles
#   FN: Dally Randriantefy
#   FN: Madagascar
# Sentence: Add men 's singles , second round 12 - Todd Martin ( U.S. ) beat Andrea Gaudenzi ( Italy ) 6-3 6-2 6-2 Stefan Edberg ( Sweden ) beat Bernd Karbacher ( Germany ) 3-6 6-3 6-3 1-0 retired ( leg injury )
#   FP: 6-3
#   FP: 3-6
#   FP: 12
#   FP: 6-3
#   FP: second
# Sentence: BASEBALL - MAJOR LEAGUE STANDINGS AFTER THURSDAY 'S GAMES .
#   FN: MAJOR LEAGUE
# Sentence: NEW YORK 1996-08-30
#   FP: 1996-08-30
# Sentence: AMERICAN LEAGUE EASTERN DIVISION
#   FP: AMERICAN LEAGUE EASTERN
#   FN: AMERICAN LEAGUE EASTERN DIVISION
# Sentence: NEW YORK 74 59 .556 -
#   FP: 74 59
# Sentence: BALTIMORE 70 63 .526 4
#   FP: 4
#   FP: BALTIMORE 70 63
#   FN: BALTIMORE
# Sentence: BOSTON 69 65 .515 5 1/2
#   FP: 5 1/2
#   FP: BOSTON 69 65
#   FN: BOSTON
# Sentence: TORONTO 63 71 .470 11 1/2
#   FP: 63 71
#   FP: 11 1/2
# Sentence: DETROIT 48 86 .358 26 1/2
#   FP: 26 1/2
#   FP: 48 86
# Sentence: CENTRAL DIVISION
#   FN: CENTRAL DIVISION
# Sentence: CLEVELAND 80 53 .602 -
#   FP: CLEVELAND 80 53
#   FP: .602
#   FN: CLEVELAND
# Sentence: CHICAGO 71 64 .526 10
#   FP: 10
#   FN: CHICAGO
# Sentence: MINNESOTA 67 67 .500 13 1/2
#   FP: 67 67
#   FP: 13 1/2
#   FN: MINNESOTA
# Sentence: MILWAUKEE 64 71 .474 17
#   FP: 64 71
#   FP: 17
#   FN: MILWAUKEE
# Sentence: KANSAS CITY 61 74 .452 20
#   FP: 20
# Sentence: WESTERN DIVISION
#   FN: WESTERN DIVISION
# Sentence: TEXAS 75 58 .564 -
#   FP: 75 58
# Sentence: SEATTLE 70 63 .526 5
#   FP: 70 63
#   FP: 5
# Sentence: OAKLAND 64 72 .471 12 1/2
#   FP: 12 1/2
#   FP: OAKLAND 64 72
#   FP: .471
#   FN: OAKLAND
# Sentence: CALIFORNIA 62 72 .463 13 1/2
#   FP: 13 1/2
#   FP: CALIFORNIA 62 72
#   FN: CALIFORNIA
# Sentence: CHICAGO AT TORONTO
#   FN: CHICAGO
# Sentence: MINNESOTA AT MILWAUKEE
#   FN: MILWAUKEE
#   FN: MINNESOTA
# Sentence: CLEVELAND AT TEXAS
#   FP: CLEVELAND AT
#   FN: CLEVELAND
#   FN: TEXAS
# Sentence: NATIONAL LEAGUE EASTERN DIVISION
#   FP: NATIONAL LEAGUE EASTERN
#   FN: NATIONAL LEAGUE EASTERN DIVISION
# Sentence: ATLANTA 83 49 .629 -
#   FP: 83
# Sentence: MONTREAL 71 61 .538 12
#   FP: 71 61
#   FP: 12
#   FN: MONTREAL
# Sentence: FLORIDA 64 70 .478 20
#   FP: 64 70
#   FP: 20
# Sentence: NEW YORK 59 75 .440 25
#   FP: 25
#   FP: 59 75
# Sentence: PHILADELPHIA 54 80 .403 30
#   FP: 30
# Sentence: CENTRAL DIVISION
#   FN: CENTRAL DIVISION
# Sentence: HOUSTON 72 63 .533 -
#   FP: HOUSTON 72 63
#   FP: .533 -
#   FN: HOUSTON
# Sentence: ST LOUIS 69 65 .515 2 1/2
#   FP: 2 1/2
# Sentence: CINCINNATI 66 67 .496 5
#   FP: 5
#   FP: 66 67
# Sentence: CHICAGO 65 66 .496 5
#   FP: 65 66 .496 5
#   FN: CHICAGO
# Sentence: PITTSBURGH 56 77 .421 15
#   FP: 15
#   FP: 56 77
# Sentence: WESTERN DIVISION
#   FN: WESTERN DIVISION
# Sentence: SAN DIEGO 75 60 .556 -
#   FP: SAN
#   FP: 75 60
#   FN: SAN DIEGO
# Sentence: LOS ANGELES 72 61 .541 2
#   FP: 2
# Sentence: COLORADO 70 65 .519 5
#   FP: 70 65
#   FP: 5
# Sentence: SAN FRANCISCO 57 74 .435 16
#   FP: 16
#   FP: 57 74
# Sentence: SAN DIEGO AT MONTREAL
#   FP: SAN
#   FN: MONTREAL
#   FN: SAN DIEGO
# Sentence: HOUSTON AT PITTSBURGH
#   FN: PITTSBURGH
# Sentence: SAN FRANCISCO AT NEW YORK
#   FN: NEW YORK
# Sentence: BASEBALL - MAJOR LEAGUE RESULTS THURSDAY .
#   FN: MAJOR LEAGUE
# Sentence: NEW YORK 1996-08-30
#   FP: 1996-08-30
# Sentence: DETROIT 4 Kansas City 1
#   FP: Kansas
#   FP: 4
#   FN: Kansas City
# Sentence: Minnesota 6 MILWAUKEE 1
#   FP: 6
#   FP: 1
#   FN: MILWAUKEE
# Sentence: CALIFORNIA 14 New York 3
#   FP: 3
#   FP: 14
# Sentence: SEATTLE 9 Baltimore 6
#   FP: 6
#   FP: 9
# Sentence: San Diego 3 NEW YORK 2
#   FP: 3
#   FP: 2
# Sentence: Chicago 4 HOUSTON 3
#   FP: 4
#   FP: 3
#   FN: HOUSTON
# Sentence: Cincinnati 18 COLORADO 7
#   FP: 7
#   FP: 18
#   FN: COLORADO
# Sentence: Atlanta 5 PITTSBURGH 1
#   FP: 5
#   FP: 1
#   FN: PITTSBURGH
# Sentence: Los Angeles 2 MONTREAL 1
#   FP: Los Angeles 2
#   FP: 1
#   FN: MONTREAL
#   FN: Los Angeles
# Sentence: Florida 10 ST LOUIS 9
#   FP: ST LOUIS 9
#   FP: 10
#   FN: ST LOUIS
# Sentence: TENNIS - TARANGO , O'BRIEN SPRING TWIN UPSETS UNDER THE LIGHTS .
#   FP: SPRING TWIN UPSETS
#   FN: TARANGO
#   FN: O'BRIEN
# Sentence: NEW YORK 1996-08-30
#   FP: 1996-08-30
# Sentence: Andre Agassi escaped disaster on Thursday but Wimbledon finalist MaliVai Washington and Marcelo Rios were not so fortunate on a night of upsets at the U.S. Open .
#   FP: the U.S. Open
#   FP: MaliVai
#   FP: Thursday
#   FP: Washington
#   FP: a night
#   FN: U.S. Open
#   FN: MaliVai Washington
# Sentence: The 11th-seeded Washington fell short of reprising his Wimbledon miracle comeback as he lost to red-hot wildcard Alex O'Brien 6-3 6-4 5-7 3-6 6-3 in a two hour 51 minute struggle on the Stadium court .
#   FP: 6-4 5-7 3-6
#   FP: 11th-seeded
#   FP: a two hour 51 minute

# %% [markdown]
# *TODO: Write a short text that summarises the errors that you observed*

# %% [markdown]
# ----The main reason for the error is the influence of numbers, such as: date, time, percentage, ordinal number, number, etc.

# %% [markdown]
# Now, use the insights from your error analysis to improve the automated prediction that you implemented in Problem&nbsp;2. While the best way to do this would be to [update spaCy&rsquo;s NER model](https://spacy.io/usage/linguistic-features#updating) using domain-specific training data, for this lab it suffices to write code to post-process the output produced by spaCy. To filter out specific labels it is useful to know the named entity label scheme, which can be found in the [model's documentation](https://spacy.io/models/en#en_core_web_sm). You should be able to improve the F1 score from Problem&nbsp;2 by at last 15 percentage points.

# %% [markdown]
# --original types:
#
# ---['CARDINAL', 'DATE', 'EVENT', 'FAC', 'GPE', 'LANGUAGE', 'LAW', 'LOC', 'MONEY', 'NORP', 'ORDINAL', 'ORG', 'PERCENT', 'PERSON', 'PRODUCT', 'QUANTITY', 'TIME', 'WORK_OF_ART']
#
# --number related types:
#
# ---['TIME', 'DATE', 'MONEY', 'CARDINAL', 'QUANTITY', 'ORDINAL']
#
# --we remove these number related types.

# %%
# TODO: Write code here to run and evaluate the spaCy named entity recognizer on the development data
def improved_spaCy_predict(df):
    for row in df.itertuples():
        doc = nlp(row.sentence)
        for ent in doc.ents:
            # here we remove these number related types.
            # ['TIME', 'DATE', 'MONEY', 'CARDINAL', 'QUANTITY', 'ORDINAL', 'PERCENT']
            if ent.label_ not in ['TIME', 'DATE', 'MONEY', 'CARDINAL', 'QUANTITY', 'ORDINAL', 'PERCENT']:
                yield row.sentence_id, ent.start, ent.end

improved_spaCy_predictions = set(improved_spaCy_predict(df_dev))
evaluation_report(gold = spans_dev_gold, pred = improved_spaCy_predictions)
# Out:
# precission:  0.847284605961617 , recall:  0.701368936961298 , F1_score:  0.7674526121128065

# %%
0.7674526121128065 - 0.5984444764511019
# Out:
# 0.16900813566170458

# %% [markdown]
# ----As we can see, after removing these number related types, we improved approximately 16.9% F1_score.

# %% [markdown]
# Show that you achieve the performance goal by reporting the evaluation measures that you implemented in Problem&nbsp;1.

# %% [markdown]
# Before going on, we ask you to store the outputs of the improved named entity recognizer on the development data in a new data frame. This new frame should have the same layout as the original data frame for the development data that you loaded above, but should contain the *predicted* start and end positions for each token span, rather than the gold positions. As the `label` of each span, you can use the special value `--NME--`.

# %%
df_dev.head()
# Out:
#   sentence_id                                           sentence  beg  end  \
# 0    0946-000  CRICKET - LEICESTERSHIRE TAKE OVER AT TOP AFTE...    2    3
# 1    0946-001                                  LONDON 1996-08-30    0    1
# 2    0946-002  West Indian all-rounder Phil Simmons took four...    0    2
# 3    0946-002  West Indian all-rounder Phil Simmons took four...    3    5
# 4    0946-002  West Indian all-rounder Phil Simmons took four...   12   13
#
#                                 label
# 0  Leicestershire_County_Cricket_Club
# 1                              London
# 2            West_Indies_cricket_team
# 3                        Phil_Simmons
# 4  Leicestershire_County_Cricket_Club

# %%
# TODO: Write code here to store the predicted spans in a new data frame

# Create an empty DataFrame.
# Just remove the old records, but keep the column names.
new_df_dev = df_dev.drop(index=df_dev.index)

#add new row to the end of the empty DataFrame.
for id, beg, end in improved_spaCy_predictions:
    new_df_dev.loc[len(new_df_dev.index)] = [id, df_dev[df_dev['sentence_id'] == id].iloc[0]['sentence'], beg, end, '--NME--']

new_df_dev
# Out:
#      sentence_id                                           sentence  beg  end  \
# 0       0966-092                  3. Fatima Yusuf ( Nigeria ) 51.43    1    3
# 1       1094-030                             NEW YORK AT CALIFORNIA    0    2
# 2       1157-000        Nato declines comment on fighting in Iraq .    6    7
# 3       0966-130             6= Nele Zilinskiene ( Lithuania ) 1.91    4    5
# 4       1076-029                          Obilic 2 Zeleznik ( B ) 0    0    3
# ...          ...                                                ...  ...  ...
# 4893    1064-007  With the first day of the league season briefl...   45   46
# 4894    0973-002  Australia scored 228 for nine wickets in their...   11   13
# 4895    0946-012  Australian Tom Moody took six for 82 but Chris...   20   21
# 4896    1042-002  Police in southwest China have arrested 30 peo...    3    4
# 4897    0972-013         J. Gillespie st Kaluwitharana b Chandana 6    0    4
#
#         label
# 0     --NME--
# 1     --NME--
# 2     --NME--
# 3     --NME--
# 4     --NME--
# ...       ...
# 4893  --NME--
# 4894  --NME--
# 4895  --NME--
# 4896  --NME--
# 4897  --NME--
#
# [4898 rows x 5 columns]

# %% [markdown]
# ## Problem 4: Entity linking

# %% [markdown]
# Now that we have a method for predicting mention spans, we turn to the task of **entity linking**, which amounts to predicting the knowledge base entity that is referenced by a given mention. In our case, for each span we want to predict the Wikipedia page that this mention references.
#
# Start by extending the generator function that you implemented in Problem&nbsp;2 to labelled spans.

# %%
def gold_mentions(df):
    """Yield the gold-standard mentions in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        quadruples consisting of the sentence id, start position, end
        position and entity label of each span.
    """
    # TODO: Replace the next line with your own code
    # --just add one more label column
    for row in df.itertuples():
        yield row.sentence_id, row.beg, row.end, row.label

# %% [markdown]
# A naive baseline for entity linking on our data set is to link each mention span to the Wikipedia page name that we get when we join the tokens in the span by underscores, as is standard in Wikipedia page names. Suppose, for example, that a span contains the two tokens
#
#     Jimi Hendrix
#
# The baseline Wikipedia page name for this span would be
#
#     Jimi_Hendrix
#
# Implement this naive baseline and evaluate its performance. Print the evaluation measures that you implemented in Problem&nbsp;1.

# %% [markdown]
# **Here and in the remainder of this lab, you should base your entity predictions on the predicted spans that you computed in Problem&nbsp;3.**

# %%
# TODO: Write code here to implement the baseline
def naive_baseline_predict(df):
    for row in df.itertuples():
        label = "_".join(row.sentence.split(' ')[row.beg : row.end])
        yield row.sentence_id, row.beg, row.end, label

# %%
gold_standard_mentions = set(gold_mentions(df_dev))
naive_baseline_prediction = set(naive_baseline_predict(new_df_dev))

evaluation_report(gold = gold_standard_mentions, pred = naive_baseline_prediction)
# Out:
# precission:  0.31400571661902815 , recall:  0.25992901808348823 , F1_score:  0.2844197873324087

# %% [markdown]
# ## Problem 5: Extending the training data using the knowledge base

# %% [markdown]
# State-of-the-art approaches to entity linking exploit information in knowledge bases. In our case, where Wikipedia is the knowledge base, one particularly useful type of information are links to other Wikipedia pages. In particular, we can interpret the anchor texts (the highlighted texts that you click on) as mentions of the entities (pages) that they link to. This allows us to harvest long lists of mention–entity pairings.
#
# The following cell loads a data frame summarizing anchor texts and page references harvested from the first paragraphs of the English Wikipedia. The data frame also contains all entity mentions in the training data (but not the development or the test data).

# %%
with bz2.open('kb.tsv.bz2', 'rt') as source:
    df_kb = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# To understand what information is available in this data, the following cell shows the entry for the anchor text `Sweden`.

# %%
df_kb.loc[df_kb.mention == 'Sweden'].iloc[0]
# Out:
# mention      Sweden
# entity       Sweden
# prob       0.985768
# Name: 17436, dtype: object

# %%
df_kb.head()
# Out:
#            mention                   entity  prob
# 0      000 Guineas      2000_Guineas_Stakes   1.0
# 1            10 00     United_States_dollar   1.0
# 2      126 million     United_States_dollar   1.0
# 3     13th dynasty  Middle_Kingdom_of_Egypt   1.0
# 4  14th Dalai Lama          14th_Dalai_Lama   1.0

# %% [markdown]
# As you can see, each row of the data frame contains a pair $(m, e)$ of a mention $m$ and an entity $e$, as well as the conditional probability $P(e|m)$ for mention $m$ referring to entity $e$. These probabilities were estimated based on the frequencies of mention–entity pairs in the knowledge base. The example shows that the anchor text &lsquo;Sweden&rsquo; is most often used to refer to the entity [Sweden](http://en.wikipedia.org/wiki/Sweden), but in a few cases also to refer to Sweden&rsquo;s national football and ice hockey teams. Note that references are sorted in decreasing order of probability, so that the most probable pairing come first.
#
# Implement an entity linking method that resolves each mention to the most probable entity in the data frame. If the mention is not included in the data frame, you can predict the generic label `--NME--`. Print the precision, recall, and F1 of your method using the function that you implemented for Problem&nbsp;1.

# %%
def gold_mentions(df):
    for row in df.itertuples():
        yield row.mention, row.entity
gold_standard_mentions = set(gold_mentions(df_kb))
print(len(gold_standard_mentions))
gold_standard_mentions
# Out:
# 23359
# {('Spanish Chavacano', 'Spanish_language'),
#  ('Soviet regime', 'Soviet_Union'),
#  ('WSC World XI', 'World_Series_Cricket_World_XI'),
#  ('Vörös Lobogó', 'MTK_Budapest_FC'),
#  ('Sale Victoria', 'Victoria_(Australia)'),
#  ('Unita', 'UNITA'),
#  ('John Newcombe', 'John_Newcombe'),
#  ('Republic of France', 'France'),
#  ('Todd Woodbridge', 'Todd_Woodbridge'),
#  ('Oaxaca region', 'Oaxaca'),
#  ('Firenze', 'Florence'),
#  ('Spanish', 'Spaniards'),
#  ('Venezuela', 'Venezuela'),
#  ('Berlin 1936', '1936_Summer_Olympics'),
#  ('Marseillais', 'Marseille'),
#  ('Genoa', 'Genoa_C.F.C.'),
#  ('modern country', 'France'),
#  ('Margaret Crowley', 'Margaret_Crowley_(athlete)'),
#  ('Tauziat', 'Nathalie_Tauziat'),
#  ('CNN Travel', 'CNN'),
#  ('Rugby League', 'Rugby_league'),
#  ('Brenden', 'Brenden_Pappas'),
#  ('Naziism', 'Nazi_Party'),
#  ('Soviet side', 'Soviet_Union'),
#  ('major league level', 'Major_League_Baseball'),
#  ('Ericsson AB', 'Ericsson'),
#  ('Bordèu', 'Bordeaux'),
#  ('1992 Barcelona Games', '1992_Summer_Olympics'),
#  ('GOP', 'Republican_Party_(United_States)'),
#  ('Lokomotiv Moskva', 'FC_Lokomotiv_Moscow'),
#  ('São Paulo de Luanda', 'Luanda'),
#  ('Western Caribbean', 'Caribbean'),
#  ('Pan American World Airways', 'Pan_American_World_Airways'),
#  ('Glaswegian', 'Glasgow'),
#  ('French national football team', 'France_national_football_team'),
#  ('coast guard', 'Coast_guard'),
#  ('same city', 'Sheffield'),
#  ('Chevron Research Company', 'Chevron_Corporation'),
#  ('Virginia Minnesota', 'Virginia'),
#  ('Spaniards', 'Spain'),
#  ('North Kivu Province', 'North_Kivu'),
#  ('Belga', 'Belga_(news_agency)'),
#  ('Brooke', 'Zinzan_Brooke'),
#  ('Buena Vista Home Entertainment', 'The_Walt_Disney_Company'),
#  ('Charles de Gaulle Airport', 'Charles_de_Gaulle_Airport'),
#  ('Svetlana Masterkova', 'Svetlana_Masterkova'),
#  ('Edvard Griegs', 'Edvard_Grieg'),
#  ('indonesian', 'Indonesia'),
#  ('Dept of the Treasury', 'United_States_Department_of_the_Treasury'),
#  ('Englishman', 'Kingdom_of_England'),
#  ('European', 'Europe'),
#  ('campus', 'Huntington,_West_Virginia'),
#  ('Norman Conquest', 'England'),
#  ('City', 'Manchester_City_F.C.'),
#  ('Gianni Versace', 'Gianni_Versace'),
#  ('San Francisco', 'San_Francisco_Giants'),
#  ('Zenith Corp', 'Zenith_Electronics'),
#  ('Madhumalla', 'Madhumalla'),
#  ('Pedro Martinez', 'Pedro_Martínez'),
#  ('Richmond', 'Richmond_Football_Club'),
#  ('Virginia Ruano Pascual', 'Virginia_Ruano_Pascual'),
#  ('SCOTUS', 'Supreme_Court_of_the_United_States'),
#  ('Army National Guard', 'United_States_National_Guard'),
#  ('Tunis', 'Tunisia'),
#  ('Pittsburgh Pirate', 'Pittsburgh_Pirates'),
#  ('American', 'Vogue_(magazine)'),
#  ('NEUCHATEL', 'Neuchâtel'),
#  ('Martin Max', 'Martin_Max'),
#  ('Kanton', 'Guangzhou'),
#  ('France', 'Switzerland'),
#  ('Fabrizio Mori', 'Fabrizio_Mori'),
#  ('Euro', 'European_Union'),
#  ('Kevin Tapani', 'Kevin_Tapani'),
#  ('previous franchise of the same name', 'Minnesota_Twins'),
#  ('Chevron Corporation', 'Chevron_Corporation'),
#  ('IMI UZI', 'Uzi'),
#  ('Montgomery Alabama', 'Montgomery,_Alabama'),
#  ('Bharatratna', 'Bharat_Ratna'),
#  ('Geronimo', 'Geronimo'),
#  ('POSCO Atoms', 'Pohang_Steelers'),
#  ('Dubai', 'Dubai'),
#  ('indigenous American', 'Indigenous_peoples_of_the_Americas'),
#  ('Steffen Freund', 'Steffen_Freund'),
#  ('Garibaldi', 'Giuseppe_Garibaldi'),
#  ('Nelson', 'Nelson,_New_Zealand'),
#  ('Kent County Cricket Club', 'Kent_County_Cricket_Club'),
#  ('Duluth Minn', 'Duluth,_Minnesota'),
#  ('Angolan national team', 'Angola_national_football_team'),
#  ('national side', 'South_Africa_national_rugby_union_team'),
#  ('OL', 'Olympique_Lyonnais'),
#  ('Belgique', 'Belgium'),
#  ('Canadian National tennis', 'Canadian_Open_(tennis)'),
#  ('Calgary Alberta', 'Calgary'),
#  ('Chilean international', 'Chile_national_football_team'),
#  ('Victorian rules', 'Australian_rules_football'),
#  ('Hellenic', 'Greece'),
#  ('Ramon Vega', 'Ramon_Vega'),
#  ('Asiatic', 'Asia'),
#  ('Vasas Budapest', 'Vasas_SC'),
#  ('IMOLA', 'Imola'),
#  ('Leicestershire Second XI', 'Leicestershire_County_Cricket_Club'),
#  ('SIDHU', 'Navjot_Singh_Sidhu'),
#  ('Republic of Armenia', 'Armenia'),
#  ('Hangzhou China', 'Hangzhou'),
#  ('Cardinal Joseph Bernardin', 'Joseph_Bernardin'),
#  ('Japan Fed Cup team', 'Japan_Fed_Cup_team'),
#  ('Irish', 'United_Kingdom'),
#  ('Jiang', 'Jiang_Zemin'),
#  ('Northern Ireland under 16s', 'Northern_Ireland_national_football_team'),
#  ('West Ham United Football Club', 'West_Ham_United_F.C.'),
#  ('Sir John Major', 'John_Major'),
#  ('Pakistani Punjab', 'Punjab,_Pakistan'),
#  ('Supreme Federal Tribunal', 'Supreme_Federal_Court'),
#  ('Ford Motor Company Fund', 'Ford_Motor_Company'),
#  ('Most Valuable Player', 'Major_League_Baseball_Most_Valuable_Player_Award'),
#  ('Paul Van Himst', 'Paul_Van_Himst'),
#  ('Gil Vicente FC', 'Gil_Vicente_F.C.'),
#  ('Oakland California', 'Oakland,_California'),
#  ('Baseball', 'Major_League_Baseball'),
#  ('national football team', 'Zimbabwe_national_football_team'),
#  ('Australia', 'Australia_national_rugby_union_team'),
#  ('Krzysztof Piskula', 'Krzysztof_Piskuła'),
#  ('circuit court of appeals', 'United_States_courts_of_appeals'),
#  ('Spanish words', 'Spanish_language'),
#  ('Belarusians', 'Belarus'),
#  ('defense', 'United_States_Department_of_Defense'),
#  ('Sport Club Freiburg', 'SC_Freiburg'),
#  ('predominant language', 'Chinese_language'),
#  ('Austria Vienna', 'FK_Austria_Wien'),
#  ('Congolese international', 'Congo_national_football_team'),
#  ('SFR of Yugoslavia', 'Socialist_Federal_Republic_of_Yugoslavia'),
#  ('FREETOWN', 'Freetown'),
#  ('Kurdish region', 'Iraqi_Kurdistan'),
#  ('Liberal Democratic Party', 'Liberal_Democratic_Party_(Japan)'),
#  ('State of Arkansas', 'Arkansas'),
#  ('ATLANTIC CITY', 'Atlantic_City,_New_Jersey'),
#  ('UNAM Pumas', 'Club_Universidad_Nacional'),
#  ('Austrian', 'Austria'),
#  ('Pat Hentgen', 'Pat_Hentgen'),
#  ('Mandarin', 'Chinese_language'),
#  ('Gyogone', 'Insein_Township'),
#  ('Holy Land', 'Israel'),
#  ('Walt Disney', 'The_Walt_Disney_Company'),
#  ('Hispalis Seville', 'Seville'),
#  ('Independent Liberals', 'Liberal_Party_(UK)'),
#  ('NL Most Valuable Player Award',
#   'Major_League_Baseball_Most_Valuable_Player_Award'),
#  ('IOC', 'Indian_Oil_Corporation'),
#  ('Minnesota', 'Minnesota_Twins'),
#  ('Jonathan Lomas', 'Jonathan_Lomas'),
#  ('Oklahoma US', 'Oklahoma'),
#  ('Pierre Fulke', 'Pierre_Fulke'),
#  ('Uruguayan football team', 'Uruguay'),
#  ('Osaka City', 'Osaka'),
#  ('Volkswagen Motorsport', 'Volkswagen'),
#  ('Montenegro', 'Montenegro'),
#  ('Labour Party', 'Labour_Party_(UK)'),
#  ('Spa Circuit', 'Circuit_de_Spa-Francorchamps'),
#  ('Aston Villa', 'Aston_Villa_F.C.'),
#  ('Leiecester City', 'Leicester_City_F.C.'),
#  ('Media Indonesia', 'Media_Indonesia'),
#  ('Romanian international', 'Romania_national_football_team'),
#  ('DKBA', 'Democratic_Karen_Buddhist_Army'),
#  ('Elizabeth City', 'Elizabeth,_New_Jersey'),
#  ('Kingdom of France', 'France'),
#  ('Nation magazine', 'The_Nation'),
#  ('1990 World Cup Finals', '1990_FIFA_World_Cup'),
#  ('Himalaya Mountains', 'Himalayas'),
#  ('SPA FRANCORCHAMPS', 'Circuit_de_Spa-Francorchamps'),
#  ('Collins Books', 'HarperCollins'),
#  ('namesake autonomous community', 'Community_of_Madrid'),
#  ('Van city', 'Van,_Turkey'),
#  ('DF Yugoslavia', 'Socialist_Federal_Republic_of_Yugoslavia'),
#  ('Oppenheimer Co', 'Oppenheimer_Holdings'),
#  ('Nazis', 'Nazi_Party'),
#  ('korea', 'Korea'),
#  ('Davidic', 'David'),
#  ('Highlands', 'Scottish_Highlands'),
#  ('Napoleon III', 'Napoleon_III'),
#  ('YMCAs', 'YMCA'),
#  ('Heerenveen', 'SC_Heerenveen'),
#  ('The Philippines', 'Philippines'),
#  ('former regions', 'Etruria'),
#  ('Bessemer', 'Bessemer_Venture_Partners'),
#  ('Canberra', 'Canberra_Raiders'),
#  ('federal government agency', 'Government_of_Russia'),
#  ('Real Madrid', 'Real_Madrid_CF'),
#  ('Sri Lankan Government', 'Sri_Lanka'),
#  ('Geir Moen', 'Geir_Moen'),
#  ('beduin', 'Bedouin'),
#  ('Liechtensteinerin', 'Liechtenstein'),
#  ('registered company', 'Limited_company'),
#  ('Bristol Rovers Football Club', 'Bristol_Rovers_F.C.'),
#  ('Regina', 'Saskatchewan'),
#  ('Titanic', 'RMS_Titanic'),
#  ('Brooklyn Supurbas', 'Los_Angeles_Dodgers'),
#  ('Choudhury', 'Humayun_Rashid_Choudhury'),
#  ('Early Roman Empire', 'Roman_Empire'),
#  ('national socialist organisations', 'Nazi_Party'),
#  ('South China Morning Post', 'South_China_Morning_Post'),
#  ('Soviet occupation zone of Germany', 'East_Germany'),
#  ('War', 'World_War_II'),
#  ('Khartum', 'Khartoum'),
#  ('Liberal candidate', 'Liberal_Party_of_Australia'),
#  ('ASEC', 'ASEC_Mimosas'),
#  ('National Human Rights Commission of Mexico',
#   'National_Human_Rights_Commission_(Mexico)'),
#  ('national team', 'Mozambique_national_football_team'),
#  ('Chicago Board of Trade', 'Chicago_Board_of_Trade'),
#  ('DAVEY JOHNSON', 'Davey_Johnson'),
#  ('Islamabadl', 'Islamabad'),
#  ('most populous city', 'New_York_City'),
#  ('Commerce', 'United_States_Department_of_Commerce'),
#  ('1991 Gulf War', 'Gulf_War'),
#  ('Deutsche Bahn', 'Deutsche_Bahn'),
#  ('northern Peru', 'Peru'),
#  ('Faroe Islands', 'Faroe_Islands'),
#  ('Parisians', 'Paris'),
#  ('Tamil Nadu India', 'Tamil_Nadu'),
#  ('emperors', 'Roman_Empire'),
#  ('Hastings Banda', 'Hastings_Banda'),
#  ('Grand Slam tennis tournaments', 'Grand_Slam_(tennis)'),
#  ('Boxer Protocol', 'Boxer_Protocol'),
#  ('Teresa', 'Teresa'),
#  ('Mette Bergmann', 'Mette_Bergmann'),
#  ('Mhow', 'Dr._Ambedkar_Nagar'),
#  ('Steffi Graf', 'Steffi_Graf'),
#  ('Masoud Barzani', 'Masoud_Barzani'),
#  ('Margaret Thatcher', 'Margaret_Thatcher'),
#  ('Native people of the Americas', 'Indigenous_peoples_of_the_Americas'),
#  ('Slavia', 'SK_Slavia_Prague'),
#  ('Israel Ministry of Foreign Affairs',
#   'Ministry_of_Foreign_Affairs_(Israel)'),
#  ('New Jersey', 'New_Jersey'),
#  ('Russia', 'Russia'),
#  ('Wigan', 'Wigan_Warriors'),
#  ('austrian', 'Austria'),
#  ('Indo Pak partition', 'Partition_of_India'),
#  ('bahrain', 'Bahrain'),
#  ('Indigenous Americans', 'Indigenous_peoples_of_the_Americas'),
#  ('Sydney 2000', '2000_Summer_Olympics'),
#  ('Juventus FC', 'Juventus_F.C.'),
#  ('oman', 'Oman'),
#  ('City of Chesapeake', 'Chesapeake,_Virginia'),
#  ('Ramle', 'Ramla'),
#  ('KBC Lease', 'KBC_Bank'),
#  ('Duma', 'Duma'),
#  ('Sourav', 'Sourav_Ganguly'),
#  ('Vasco da Gama', 'Associação_Desportiva_Vasco_da_Gama'),
#  ('Mexican army', 'Mexican_Army'),
#  ('Netherlands', 'Netherlands'),
#  ('the city', 'Amsterdam'),
#  ('Wimbledon tennis', 'The_Championships,_Wimbledon'),
#  ('county club', 'Sussex_County_Cricket_Club'),
#  ('Kyran Bracken', 'Kyran_Bracken'),
#  ('Lithuanians', 'Lithuania'),
#  ('US Nationals', 'US_Open_(tennis)'),
#  ('indios', 'Indigenous_peoples_of_the_Americas'),
#  ('Zimbabwean national team', 'Zimbabwe_national_football_team'),
#  ('Northampton', 'Northampton'),
#  ('HypoVereinsbank', 'HypoVereinsbank'),
#  ('Court of Appeals for the Fourth Circuit',
#   'United_States_Court_of_Appeals_for_the_Fourth_Circuit'),
#  ('Jonathan Stark', 'Jonathan_Stark'),
#  ('Philippine', 'Philippines'),
#  ('Kosovars', 'Kosovo'),
#  ('prewar', 'World_War_II'),
#  ('country', 'Bangladesh'),
#  ('British Jewish family', 'British_Jews'),
#  ('Native American tribe', 'Native_Americans_in_the_United_States'),
#  ('AUSTRALIA', 'Australia_national_cricket_team'),
#  ('Puebla', 'Club_Puebla'),
#  ('Jews', 'Israelis'),
#  ('West German', 'Germans'),
#  ('Inland Northwest', 'Washington_(state)'),
#  ('Airport', 'Munich_Airport'),
#  ('holding', 'Holding_company'),
#  ('central Asiatic', 'Central_Asia'),
#  ('human immunodeficiency virus HIV infection', 'HIV/AIDS'),
#  ('Kijów', 'Kiev'),
#  ('Eastern Suburbs', 'Sydney_Roosters'),
#  ('fascist Croatian puppet state', 'Independent_State_of_Croatia'),
#  ('Houston Astros', 'Houston_Astros'),
#  ('Stoltenberg', 'Jason_Stoltenberg'),
#  ('Bosnia and Herzegovinian', 'Bosnia_and_Herzegovina'),
#  ('Walsall', 'Walsall_F.C.'),
#  ('Aryan Japhetic', 'Aryan_race'),
#  ('neighboring country', 'Hungary'),
#  ('Leicester United Kingdom', 'Leicester'),
#  ('Barry Bonds', 'Barry_Bonds'),
#  ('Drnovice', 'FK_Drnovice'),
#  ('National Basketball Association NBA', 'National_Basketball_Association'),
#  ('national guard', 'United_States_National_Guard'),
#  ('Hartlepool United Reserves', 'Hartlepool_United_F.C.'),
#  ('Nicolas Pereira', 'Nicolás_Pereira'),
#  ('Lega Calcio Serie', 'Serie_A'),
#  ('India Kashmir', 'Kashmir'),
#  ('Swiss internationalist', 'Switzerland_national_football_team'),
#  ('Ericsson Company', 'Ericsson'),
#  ('Interstate Highway', 'Interstate_5'),
#  ('Himalayan', 'Himalaya_Kingdom'),
#  ('Sierra Leonian', 'Sierra_Leone'),
#  ('State of New York', 'New_York'),
#  ('American', 'United_States_Navy'),
#  ('Port Natal Durban', 'Durban'),
#  ('Warner Brothers Studios', 'Warner_Bros.'),
#  ('Saxony', 'Saxony'),
#  ('Hakkari', 'Hakkâri'),
#  ('Buenos Aires Province', 'Buenos_Aires_Province'),
#  ('Vienna Austria', 'Vienna'),
#  ('Korea Republic', 'South_Korea'),
#  ('Lixion Avila', 'Lixion_Avila'),
#  ('Southern Europe', 'Europe'),
#  ('continent', 'North_America'),
#  ('the area', 'Winnipeg'),
#  ('Bolton', 'Bolton_Wanderers_F.C.'),
#  ('Boston Milwaukee and Atlanta Braves', 'Atlanta_Braves'),
#  ('Chesapeake', 'Chesapeake,_Virginia'),
#  ('Yugoslav communism', 'Socialist_Federal_Republic_of_Yugoslavia'),
#  ('Legislative Council', 'Palestinian_Legislative_Council'),
#  ('Dunfermline Athletic', 'Dunfermline_Athletic_F.C.'),
#  ('Republic of Congo', 'Republic_of_the_Congo'),
#  ('counterpart', 'San_Francisco_Giants'),
#  ('city of Houston', 'Houston'),
#  ('Old Trafford ground', 'Old_Trafford_Cricket_Ground'),
#  ('Barvikha', 'Barvikha'),
#  ('Indo European ethnicities', 'Aryan_race'),
#  ('SOUTH CHINA MORNING POST', 'South_China_Morning_Post'),
#  ('British army officer', 'British_people'),
#  ('Nation Capital', 'Washington,_D.C.'),
#  ('Dutch football team', 'Netherlands_national_football_team'),
#  ('navy', 'United_States_Navy'),
#  ('Chandrika Kumaratunga', 'Chandrika_Kumaratunga'),
#  ('MONTREAL', 'Montreal'),
#  ('Kuwaiti women', 'Kuwait'),
#  ('JS Massira', 'JS_Massira'),
#  ('UNP', 'United_National_Party'),
#  ('Cruz Azulqualified', 'Cruz_Azul'),
#  ('national side', 'Romania_national_football_team'),
#  ('Republic of Croatia', 'Croatia'),
#  ('Jonathan Edwards', 'Jonathan_Edwards'),
#  ('member states', 'Council_of_Europe'),
#  ('Cal Ripken', 'Cal_Ripken_Jr.'),
#  ('Brewers', 'Milwaukee_Brewers'),
#  ('indigenous American people', 'Indigenous_peoples_of_the_Americas'),
#  ('Afghanin', 'Afghanistan'),
#  ('Islamdom', 'Islam'),
#  ('Slovene', 'Slovenia'),
#  ('Ministry of Finance', 'Ministry_of_Finance_(Japan)'),
#  ('Montenegrin born', 'Montenegro'),
#  ('Liberals', 'Liberal_Party_(UK)'),
#  ('Vorskla', 'FC_Vorskla_Poltava'),
#  ('Tom Cruise', 'Tom_Cruise'),
#  ('national team', 'Russia_national_football_team'),
#  ('theological study', 'Christian_theology'),
#  ('Jakarta Indonesia', 'Jakarta'),
#  ('Canterbury', 'Canterbury-Bankstown_Bulldogs'),
#  ('Scotland', 'Scotland_national_rugby_union_team'),
#  ('Champions Cup', 'UEFA_Champions_League'),
#  ('Partition', 'Partition_of_India'),
#  ('scored 337 runs', 'Run_(baseball)'),
#  ('World Cup 1970 in Mexico', 'FIFA_World_Cup'),
#  ('Australian representative', 'Australia_national_rugby_union_team'),
#  ('Germantown Pennsylvania', 'Philadelphia'),
#  ('Amerindian settlement', 'Indigenous_peoples_of_the_Americas'),
#  ('Norifumi Abe', 'Norifumi_Abe'),
#  ('Tami Whitlinger', 'Tami_Whitlinger'),
#  ('Uzbekistan', 'Uzbekistan'),
#  ('Europeans', 'Europe'),
#  ('Philippines', 'Mindanao'),
#  ('father', 'Hafez_al-Assad'),
#  ('Ahmad Shah Masood', 'Ahmad_Shah_Massoud'),
#  ('Imperial Era', 'Roman_Empire'),
#  ('Italian', 'Serie_A'),
#  ('Oldham Athletic', 'Oldham_Athletic_A.F.C.'),
#  ('Wingdows', 'Microsoft_Windows'),
#  ('English language', 'English_language'),
#  ('central Asian republics', 'Central_Asia'),
#  ('Andy Benes', 'Andy_Benes'),
#  ('Orlando Miller', 'Orlando_Miller'),
#  ('Marc Newfield', 'Marc_Newfield'),
#  ('Christian theologies', 'Christian_theology'),
#  ('Himalayan regime', 'Himalayas'),
#  ('Athesis Adige', 'Adige'),
#  ('Angolan footballer', 'Angola'),
#  ('Plymouth Argyle reserves', 'Plymouth_Argyle_F.C.'),
#  ('Milwaukee Wisconsin', 'Milwaukee'),
#  ('York City', 'York_City_F.C.'),
#  ('automaker', 'Toyota'),
#  ('Camelot', 'Camelot,_Chesapeake,_Virginia'),
#  ('NSW Liberal Party', 'Liberal_Party_of_Australia'),
#  ('country', 'Lithuania'),
#  ('Oakland CA US', 'Oakland,_California'),
#  ('Rudar Ugljevik', 'FK_Rudar_Ugljevik'),
#  ('football', 'National_Football_League'),
#  ('regional', 'Middle_East'),
#  ('Apple iTunes Store', 'Apple_Inc.'),
#  ('Europe', 'Europe'),
#  ('capital', 'Riga'),
#  ('the partition', 'Partition_of_India'),
#  ('Port of Venice', 'Venice'),
#  ('Partizan Belgrade', 'FK_Partizan'),
#  ('Zimbabwean national side', 'Zimbabwe_national_cricket_team'),
#  ('Aldi Süd', 'Aldi'),
#  ('Metropolitan London', 'London'),
#  ('Corinthians', 'Sport_Club_Corinthians_Paulista'),
#  ('City of Milan', 'Milan'),
#  ('Yugoslavia', 'Serbia'),
#  ('AS Nancy Lorraine', 'AS_Nancy'),
#  ('Japie Mulder', 'Japie_Mulder'),
#  ('Calcutta', 'Kolkata'),
#  ('Kayin races', 'Karen_people'),
#  ('international', 'Wales_national_football_team'),
#  ('UEFA Cup and Europa League', 'UEFA_Europa_League'),
#  ('King Baudouin', 'Baudouin_of_Belgium'),
#  ('Communist party', 'Communist_Party_of_China'),
#  ('WAL', 'Wales'),
#  ('Spanish Basque Country', 'Basque_Country_(autonomous_community)'),
#  ('provisional wing', 'Provisional_Irish_Republican_Army'),
#  ('Northern Pakistan', 'Pakistan'),
#  ('continental', 'Europe'),
#  ('American Democratic', 'Democratic_Party_(United_States)'),
#  ('Malta', 'Malta'),
#  ('Nice', 'OGC_Nice'),
#  ('Nazi ideology', 'Nazism'),
#  ('Native North American', 'Native_Americans_in_the_United_States'),
#  ('ING Clarion Real Estate Investment', 'ING_Group'),
#  ('Kenny Cunningham', 'Kenny_Cunningham'),
#  ('national team of Romania', 'Romania_national_football_team'),
#  ('Ronald Dutch Reagan', 'Ronald_Reagan'),
#  ('western Texas', 'Texas'),
#  ('Republic of Serbian Krajina', 'Republic_of_Serbian_Krajina'),
#  ('Roman emperor', 'Roman_Empire'),
#  ('Marine Corps officer', 'United_States_Marine_Corps'),
#  ('Caribbean Islands', 'Caribbean'),
#  ('brazilian', 'Brazil'),
#  ('New media', 'New_media'),
#  ('Eddie Irvine', 'Eddie_Irvine'),
#  ('state sponsored health programs', 'Medicare_(United_States)'),
#  ('Italian Cup', 'Coppa_Italia'),
#  ('Amerindians', 'Indigenous_peoples_of_the_Americas'),
#  ('Young Liberals', 'Liberal_Party_of_Australia'),
#  ('Commission on Human Rights', 'United_Nations_Commission_on_Human_Rights'),
#  ('CONCACAF', 'CONCACAF_Champions_League'),
#  ('Loyola de Palacio', 'Loyola_de_Palacio'),
#  ('Operation Telic', 'Iraq'),
#  ('Canadian politician', 'Canada'),
#  ('Ecuadoran', 'Ecuador'),
#  ('Mark Brooks', 'Mark_Brooks_(golfer)'),
#  ('Vince Spadea', 'Vince_Spadea'),
#  ('full international', 'Scotland_national_football_team'),
#  ('Rigan', 'Riga'),
#  ('Raja', 'Raja_Casablanca'),
#  ('Army officer', 'United_States_Army'),
#  ('British author', 'British_people'),
#  ('United States district judge', 'United_States_district_court'),
#  ('UEFA Cup Final', 'UEFA_Europa_League'),
#  ('Himalayans', 'Himalayas'),
#  ('Michael Tebbutt', 'Michael_Tebbutt'),
#  ('Leeds Missouri Kansas City', 'Kansas_City,_Missouri'),
#  ('Austrians', 'Austrian_Empire'),
#  ('Jesper Parnevik', 'Jesper_Parnevik'),
#  ('native people', 'Native_Americans_in_the_United_States'),
#  ('partitioning', 'Partition_of_India'),
#  ('Juergen Klinsmann', 'Jürgen_Klinsmann'),
#  ('Grazer AK', 'Grazer_AK'),
#  ('Dewas', 'Dewas'),
#  ('ethno cultural Tibet', 'Tibet'),
#  ('Conservative Party of the United Kingdom', 'Conservative_Party_(UK)'),
#  ('French Interior Minister', 'Minister_of_the_Interior_(France)'),
#  ('Kawasaki', 'Kawasaki_Heavy_Industries'),
#  ('President Robert Mugabe', 'Robert_Mugabe'),
#  ('Turkish National Team', 'Turkey_national_football_team'),
#  ('Van Gastel', 'Jean-Paul_van_Gastel'),
#  ('Defense', 'United_States_Department_of_Defense'),
#  ('Indy', 'IndyCar_Series'),
#  ('Wimbledon', 'The_Championships,_Wimbledon'),
#  ('Team Hungary', 'Hungary'),
#  ('Graham Thorpe', 'Graham_Thorpe'),
#  ('Security Council', 'United_Nations_Security_Council'),
#  ('Cannes', 'AS_Cannes'),
#  ('Mercury Insurance Open', 'Southern_California_Open'),
#  ('Husqvarna', 'Husqvarna_Motorcycles'),
#  ('Naziism', 'Nazi_Germany'),
#  ('national football team', 'El_Salvador_national_football_team'),
#  ('CART', 'IndyCar_Series'),
#  ('Jaap Stam', 'Jaap_Stam'),
#  ('Communist government', 'Communist_Party_of_China'),
#  ('Dow Jones', 'Dow_Jones_Industrial_Average'),
#  ('Grace Road Leicester', 'Grace_Road'),
#  ('Leeds United', 'Leeds_United_F.C.'),
#  ('Italian', 'Italy'),
#  ('Asa Carlsson', 'Åsa_Svensson'),
#  ('Brigita Bukovec', 'Brigita_Bukovec'),
#  ('Government orders', 'Government_of_Russia'),
#  ('the Confederacy', 'Confederate_States_of_America'),
#  ('Peronistas', 'Peronism'),
#  ('DIARIO 16', 'Diario_16'),
#  ('Julia Carling', 'Julia_Carling'),
#  ('Hereford', 'Hereford_United_F.C.'),
#  ('Arabia', 'Saudi_Arabia'),
#  ('Simitis', 'Costas_Simitis'),
#  ('Bulldogs', 'Canterbury-Bankstown_Bulldogs'),
#  ('Vitali Smirnov', 'Vitali_Smirnov'),
#  ('tricolor', 'France_national_football_team'),
#  ('capital of Wales', 'Cardiff'),
#  ('people from New Zealand', 'New_Zealanders'),
#  ('Windows 98 2000 XP', 'Microsoft_Windows'),
#  ('Old City walls', 'Old_City_(Jerusalem)'),
#  ('communist forces', 'Communist_Party_of_China'),
#  ('Stallone', 'Sylvester_Stallone'),
#  ('AJACCIO', 'Ajaccio'),
#  ('Costain Group', 'Costain_Group'),
#  ('Brazilian national football team', 'Brazil_national_football_team'),
#  ('Foreign Organization of the NSDAP NSDAP AO', 'NSDAP/AO'),
#  ('Serbian majority', 'Serbs'),
#  ('State of Pennsylvania', 'Pennsylvania'),
#  ('Shigeki Maruyama', 'Shigeki_Maruyama'),
#  ('Trincomalee', 'Trincomalee'),
#  ('Club Pachuca', 'C.F._Pachuca'),
#  ('French tennis championships', 'French_Open'),
#  ('Yue', 'Zhejiang'),
#  ('Βulgarian', 'Bulgaria'),
#  ('MLBers', 'Major_League_Baseball'),
#  ('Jearl Miles Clark', 'Jearl_Miles_Clark'),
#  ('Sirnak', 'Şırnak_Province'),
#  ('central Asia', 'Central_Asia'),
#  ('Van', 'Van,_Turkey'),
#  ('Damascus City', 'Damascus'),
#  ('Mario Covas', 'Mário_Covas'),
#  ('former Soviet Republics', 'Post-Soviet_states'),
#  ('county match', 'County_Championship'),
#  ('Brian Currin', 'Brian_Currin'),
#  ('Euro 1992', 'UEFA_Euro_1992'),
#  ('Prince Charles', 'Charles,_Prince_of_Wales'),
#  ('nazism', 'Nazism'),
#  ('The elder Ross Perot', 'Ross_Perot'),
#  ('New Haven Connecticut', 'New_Haven,_Connecticut'),
#  ('Kia Motors', 'Kia_Motors'),
#  ('French Guyanese', 'French_Guiana'),
#  ('Norwest', 'Norwest'),
#  ('BSE', 'Budapest_Stock_Exchange'),
#  ('El Al Israel Airlines', 'El_Al'),
#  ('Panama', 'Panama'),
#  ('Tasmanians', 'Tasmania'),
#  ('Republic of Nicaragua', 'Nicaragua'),
#  ('Calvin Davis', 'Calvin_Davis'),
#  ('the club', 'Newcastle_Knights'),
#  ('Papua', 'Papua_New_Guinea'),
#  ('Venetian school', 'Venice'),
#  ('Gujarat peninsula', 'Gujarat'),
#  ('Southeastern Europe', 'Balkans'),
#  ('Royal Enclosure', 'Ascot_Racecourse'),
#  ('socialist Yugoslavia', 'Socialist_Federal_Republic_of_Yugoslavia'),
#  ('Boavista Futebol Clube', 'Boavista_F.C.'),
#  ('Commandments', 'Ten_Commandments'),
#  ('HU', 'Hungary'),
#  ('belarusian', 'Belarus'),
#  ('Basque Country greater region', 'Basque_Country_(greater_region)'),
#  ('Tel Aviv Jaffa', 'Tel_Aviv'),
#  ('Venezuelan born', 'Venezuela'),
#  ('Newfoundland Island', 'Newfoundland_(island)'),
#  ('the fourth state', 'Georgia_(U.S._state)'),
#  ('Serdica', 'Sofia'),
#  ('British', 'English_language'),
#  ('Bill and Hillary Clinton', 'Bill_Clinton'),
#  ('FC Nyva Svitanok Vinnytsia', 'FC_Nyva_Vinnytsia'),
#  ('Nomadic Arab', 'Bedouin'),
#  ('Kurds', 'Kurdistan'),
#  ('Ensemble Monte Carlo', 'Monte_Carlo'),
#  ('Kosovans', 'Kosovo'),
#  ('ISO 9002', 'ISO_9000'),
#  ('Dmitri Markov', 'Dmitri_Markov'),
#  ('Ljubljana 80', 'Ljubljana'),
#  ('Ethnic German', 'Germans'),
#  ('Pakistani', 'Pakistan'),
#  ('Basque Country', 'Basque_Country_(greater_region)'),
#  ('Most Valuable Player Awards',
#   'Major_League_Baseball_Most_Valuable_Player_Award'),
#  ('Swedish Empire', 'Sweden'),
#  ('Philippines Theater', 'Philippines'),
#  ('NCR', 'Metro_Manila'),
#  ('Andhra Pradesh India', 'Andhra_Pradesh'),
#  ('international', 'Cameroon_national_football_team'),
#  ('Kashmir Province', 'Kashmir'),
#  ('common enemy', 'United_States'),
#  ('Metro Manila', 'Metro_Manila'),
#  ('Elizabeth New Jersey', 'Elizabeth,_New_Jersey'),
#  ('Rupert Murdoch', 'Rupert_Murdoch'),
#  ('Manchester', 'Old_Trafford_Cricket_Ground'),
#  ('Chilean men national team', 'Chile_national_football_team'),
#  ('Solun', 'Thessaloniki'),
#  ('canadian', 'Canada'),
#  ('Britishlawyer', 'United_Kingdom'),
#  ('Maltese records', 'Malta'),
#  ('the New York Stock Exchange', 'New_York_Stock_Exchange'),
#  ('Neil Williams', 'Neil_Williams_(cricketer)'),
#  ('Catholic Christianity', 'Catholic_Church'),
#  ('Scotland under 21s', 'Scotland_national_under-21_football_team'),
#  ('imperial crown of Brazil', 'Empire_of_Brazil'),
#  ('Coast Guard', 'Coast_guard'),
#  ('Hekmatyar', 'Gulbuddin_Hekmatyar'),
#  ('City of Portland Oregon', 'Portland,_Oregon'),
#  ('Alomar', 'Roberto_Alomar'),
#  ('King Birendra Bir Bikram Shah', 'Birendra_of_Nepal'),
#  ('the Provisional Irish Republican Army',
#   'Provisional_Irish_Republican_Army'),
#  ('Malaysia government', 'Malaysia'),
#  ('EA Guingamp', 'En_Avant_de_Guingamp'),
#  ('Mark Calcavecchia', 'Mark_Calcavecchia'),
#  ('Bayern München', 'FC_Bayern_Munich'),
#  ('Bayern Munich', 'FC_Bayern_Munich'),
#  ('National Socialist', 'Neo-Nazism'),
#  ('Scotland', 'Scotland'),
#  ('MONTPELIER', 'Montpelier,_Vermont'),
#  ('Ryga', 'Riga'),
#  ('Communist', 'Communist_party'),
#  ('Sri Lankan national team', 'Sri_Lanka_national_cricket_team'),
#  ('United States Assistant Secretary of Agriculture',
#   'United_States_Department_of_Agriculture'),
#  ('International Monetary Funds', 'International_Monetary_Fund'),
#  ('Indonesian', 'Indonesia'),
#  ('city of Eau Claire', 'Eau_Claire,_Wisconsin'),
#  ('Wimbledon championships', 'The_Championships,_Wimbledon'),
#  ('zionist movement', 'Zionism'),
#  ('Doncaster Cup', 'Doncaster_Cup'),
#  ('Central African Republic national football team',
#   'Central_African_Republic_national_football_team'),
#  ('Venice Florida', 'Venice'),
#  ('de Klerk', 'F._W._de_Klerk'),
#  ('City of Geneva', 'Geneva'),
#  ('Skopje Macedonia', 'Skopje'),
#  ('Soviet style', 'Soviet_Union'),
#  ('David Byas', 'David_Byas'),
#  ('Chesterfield Town', 'Chesterfield_F.C.'),
#  ('Paris', 'Paris_Saint-Germain_Rugby_League'),
#  ('US Open', 'U.S._Open_(golf)'),
#  ('Orange', 'Orange_S.A.'),
#  ('Nazis', 'Nazi_Germany'),
#  ('Cypriot', 'Cyprus'),
#  ('Russian national team', 'Russia_national_football_team'),
#  ('Canterbury Bulldogs', 'Canterbury-Bankstown_Bulldogs'),
#  ('Nelson Appleton Miles', 'Nelson_A._Miles'),
#  ('Scarborough Football Club', 'Scarborough_F.C.'),
#  ('SD', 'South_Dakota'),
#  ('Adam Opel KG', 'Opel'),
#  ('city of Split', 'Split,_Croatia'),
#  ('MAARIV', 'Maariv_(newspaper)'),
#  ('Shinichi Itoh', 'Shinichi_Ito'),
#  ('English', 'England_national_rugby_union_team'),
#  ('Washington State USA', 'Washington_(state)'),
#  ('HIV infection', 'HIV/AIDS'),
#  ('South Islands', 'South_Island'),
#  ('Spanish language Castilian', 'Spanish_language'),
#  ('Wally Whitehurst', 'Wally_Whitehurst'),
#  ('Brazilian', 'Brazil_national_football_team'),
#  ('McLaren M18 M22', 'McLaren'),
#  ('Hanyang 한성 漢城', 'Seoul'),
#  ('Hebr', 'Hebrew_language'),
#  ('Anatolia Turkey', 'Anatolia'),
#  ('Tegla Loroupe', 'Tegla_Loroupe'),
#  ('county Antrim', 'County_Antrim'),
#  ('Irish', 'Northern_Ireland_national_football_team'),
#  ('Stalin era', 'Joseph_Stalin'),
#  ('Valero Energy Corp', 'Valero_Energy'),
#  ('the German', 'Germans'),
#  ('ATP Tour', 'Association_of_Tennis_Professionals'),
#  ('Honuran', 'Honduras'),
#  ('Massitusits', 'Massachusetts'),
#  ('Winnipeg', 'Winnipeg'),
#  ('senior national team of his country', 'Austria_national_football_team'),
#  ('Pumas', 'Club_Universidad_Nacional'),
#  ('European club competitions', 'UEFA'),
#  ('the Arab world', 'Arab_world'),
#  ('post Soviet', 'Post-Soviet_states'),
#  ('midwestern', 'Midwestern_United_States'),
#  ('marxist', 'Marxism'),
#  ('westerner', 'Western_world'),
#  ('Walt Disney Studios', 'The_Walt_Disney_Company'),
#  ('UBS AG', 'UBS'),
#  ('2000 Sydney Olympic Games', '2000_Summer_Olympics'),
#  ('Australia national team', 'Australia_national_rugby_union_team'),
#  ('Ajax Reserves', 'AFC_Ajax'),
#  ('Portuguese seaborne empire', 'Portuguese_Empire'),
#  ('Para', 'Paralympic_Games'),
#  ('England Rugby', 'England_national_rugby_union_team'),
#  ('Durham', 'Durham_County_Cricket_Club'),
#  ('Oksana Grichina', 'Oksana_Grishina'),
#  ('Irvine California', 'Irvine,_California'),
#  ('Korea', 'North_Korea'),
#  ('Khartoum', 'Khartoum'),
#  ('Pakistani supplied', 'Pakistan'),
#  ('Republican Committee', 'Republican_Party_(United_States)'),
#  ('County of Wiltshire', 'Wiltshire'),
#  ('namesake', 'Jimi_Hendrix'),
#  ('Dunvant RFC', 'Dunvant_RFC'),
#  ('New York', 'New_York_Yankees'),
#  ('Erekat', 'Saeb_Erekat'),
#  ('after', 'Roman_Empire'),
#  ('Canadafor', 'Canada'),
#  ('Crystal Palace', 'Crystal_Palace_F.C.'),
#  ('Chinese affairs', 'China'),
#  ('Super Cup', 'Supercoppa_Italiana'),
#  ('Independiente', 'Club_Atlético_Independiente'),
#  ('Jill Craybas', 'Jill_Craybas'),
#  ('British Jews', 'British_Jews'),
#  ('Little Rock AR', 'Little_Rock,_Arkansas'),
#  ('Dekker', 'Erik_Dekker'),
#  ('Major League runs', 'Run_(baseball)'),
#  ('Teemu Selanne', 'Teemu_Selänne'),
#  ('public safety', 'Coast_guard'),
#  ('Wimbledon Tennis', 'The_Championships,_Wimbledon'),
#  ('country', 'Zimbabwe'),
#  ('National Transportation Safety Board NTSB',
#   'National_Transportation_Safety_Board'),
#  ('Caribbean islands', 'Caribbean'),
#  ('Arlington Texas', 'Arlington,_Texas'),
#  ('NIR', 'Northern_Ireland'),
#  ('Tongans', 'Tonga'),
#  ('Communist Yugoslavia', 'Socialist_Federal_Republic_of_Yugoslavia'),
#  ('New Zealand rugby union side', 'New_Zealand_national_rugby_union_team'),
#  ('County of Southampton', 'Hampshire'),
#  ('Oslo centre', 'Oslo'),
#  ('Letitia Vriesde', 'Letitia_Vriesde'),
#  ('Apple Macintosh', 'Apple_Inc.'),
#  ('Cypriot national football team', 'Cyprus_national_football_team'),
#  ('Disney Studio', 'The_Walt_Disney_Company'),
#  ('HONDURAS', 'Honduras'),
#  ('Lancashire Lightning', 'Lancashire_County_Cricket_Club'),
#  ('Sir Ian McGeechan', 'Ian_McGeechan'),
#  ('World Cup cricket', 'Cricket_World_Cup'),
#  ('Paul Adams', 'Paul_Adams_(cricketer)'),
#  ('Houstonians', 'Houston'),
#  ('Swansea Rugby Club', 'Swansea_RFC'),
#  ('Canadian island', 'Newfoundland_(island)'),
#  ('archaic German text', 'German_language'),
#  ('Amnesty international', 'Amnesty_International'),
#  ('Emirate of Dubai', 'Dubai'),
#  ('Christophe Ohrel', 'Christophe_Ohrel'),
#  ('Australian Davis Cup team', 'Australia_Davis_Cup_team'),
#  ('Missourian', 'Missouri'),
#  ('San Franciscan', 'San_Francisco'),
#  ('Société nationale des chemins de fer français', 'SNCF'),
#  ('Namibia', 'Namibia'),
#  ('Albanian ethnicity', 'Albanians'),
#  ('Sven Pieters', 'Sven_Pieters'),
#  ('Volkswagen UK', 'Volkswagen'),
#  ('WWll', 'World_War_II'),
#  ('Kenya national football team', 'Kenya_national_football_team'),
#  ('Confederacy of the South', 'Confederate_States_of_America'),
#  ('Vinko Marinovic', 'Vinko_Marinović'),
#  ('American Army', 'United_States_Army'),
#  ('West Division', 'American_League_West'),
#  ('Derbyshire CCC', 'Derbyshire_County_Cricket_Club'),
#  ('Togo 17', 'Togo_national_football_team'),
#  ('Black Muslims', 'Nation_of_Islam'),
#  ('Leah Pells', 'Leah_Pells'),
#  ('Indian cricket board', 'Board_of_Control_for_Cricket_in_India'),
#  ('French Vogue', 'Vogue_(magazine)'),
#  ('Zevenaar', 'Zevenaar'),
#  ('Sweden based', 'Sweden'),
#  ('League', 'Australian_Football_League'),
#  ('national team', 'Cyprus_national_football_team'),
#  ('Fitzpatrick', 'Sean_Fitzpatrick'),
#  ('Tulio', 'Túlio_Maravilha'),
#  ('Graham Lloyd', 'Graham_Lloyd'),
#  ('Kansai International Airport', 'Kansai_International_Airport'),
#  ('Atlanta Olympics', '1996_Summer_Olympics'),
#  ('Olympic Committee', 'National_Olympic_Committee'),
#  ('1983', 'UEFA_Champions_League'),
#  ('English', 'Spanish_language'),
#  ('SFRY', 'Socialist_Federal_Republic_of_Yugoslavia'),
#  ('original team', 'Montreal_Expos'),
#  ('CERA', 'KBC_Bank'),
#  ('Croatia National Team', 'Croatia_national_football_team'),
#  ('Norths', 'North_Sydney_Bears'),
#  ('BRUSSELS', 'Brussels'),
#  ('Jerusalemites', 'Jerusalem'),
#  ('Collins Press', 'HarperCollins'),
#  ('city of Panama', 'Panama_City'),
#  ('Metro Richmond', 'Richmond,_Virginia'),
#  ('National Socialist Revolution', 'Nazism'),
#  ('Phil Simmons', 'Phil_Simmons'),
#  ('American based', 'United_States'),
#  ('Hindi', 'India'),
#  ('Italian', 'English_language'),
#  ('Seoul South Korea', 'Seoul'),
#  ('en', 'English_language'),
#  ('the Conservatives', 'Conservative_Party_(UK)'),
#  ('72M', 'T-72'),
#  ('league titles', 'Serie_A'),
#  ('Ukrainian national team', 'Ukraine_national_football_team'),
#  ('Southampton', 'Southampton_F.C.'),
#  ('Finns', 'Finland'),
#  ('Charles Taylor', 'Charles_Taylor_(Liberian_politician)'),
#  ('Canadian', 'North_America'),
#  ('Manhattan Island', 'Manhattan'),
#  ('Michael Andretti', 'Michael_Andretti'),
#  ('Hebraic', 'Hebrew_language'),
#  ('Peruvians', 'Peru'),
#  ('Leicestershire Foxes', 'Leicestershire_County_Cricket_Club'),
#  ('Polish national football team', 'Poland_national_football_team'),
#  ('Hull', 'Hull_City_A.F.C.'),
#  ('Secretary', 'United_States_Department_of_State'),
#  ('Italian League', 'Serie_A'),
#  ('Sierra Mountains', 'Sierra_Nevada_(U.S.)'),
#  ('Christian theologians and theologies', 'Christian_theology'),
#  ('Roosevelts', 'Roosevelt_family'),
#  ('Philadelphia Kansas City Athletics', 'Oakland_Athletics'),
#  ('Patriotic Salvation Movement', 'Patriotic_Salvation_Movement'),
#  ('Queenslander', 'Queensland'),
#  ('Ukraianian', 'Ukraine'),
#  ('John Talen', 'John_Talen'),
#  ('Stade Rennais', 'Stade_Rennais_F.C.'),
#  ('LN', 'Lega_Nord'),
#  ('Newark City', 'Newark,_New_Jersey'),
#  ('south Korea', 'South_Korea'),
#  ('Manhattanite', 'Manhattan'),
#  ('Malta national team', 'Malta_national_football_team'),
#  ('Jay Buhner', 'Jay_Buhner'),
#  ('1992 UEFA European Championship', 'UEFA_Euro_1992'),
#  ('English', 'FA_Cup'),
#  ('National Football League NFL', 'National_Football_League'),
#  ('Tunceli', 'Tunceli_Province'),
#  ('St George Dragons', 'St._George_Dragons'),
#  ('BP plc', 'BP'),
#  ('Philadelphia Blue Jays', 'Philadelphia_Phillies'),
#  ('native peoples', 'Indigenous_peoples_of_the_Americas'),
#  ('Washington', 'Texas_Rangers_(baseball)'),
#  ('Bethlehem', 'Bethlehem'),
#  ('French men international', 'France_national_football_team'),
#  ('Boston Massachusetts USA', 'Boston'),
#  ('Richard', 'Richard_Witschge'),
#  ('Barcelona Olympics in 1992', '1992_Summer_Olympics'),
#  ('Minister of State for Foreign Affairs and Regional Cooperation',
#   'Foreign_minister'),
#  ('union', 'Rugby_union'),
#  ('USS Enterprise', 'USS_Enterprise_(CVN-65)'),
#  ('Norways', 'Norway'),
#  ('Samsung Heavy Industries', 'Samsung_Heavy_Industries'),
#  ('Costa Rica', 'Costa_Rica_national_football_team'),
#  ('Chihuahua', 'Chihuahua_City'),
#  ('Boston Braves previously the Boston Bees', 'Atlanta_Braves'),
#  ('PONTIAC', 'Pontiac,_Michigan'),
#  ('Colombians', 'Colombia'),
#  ('Phnom Penh', 'Phnom_Penh'),
#  ('BRISBANE', 'Brisbane'),
#  ('Anatolia', 'Anatolia'),
#  ('Gerhard Berger', 'Gerhard_Berger'),
#  ('Atalanta Bergamo Calcio', 'Atalanta_B.C.'),
#  ('Spa', '1996_Belgian_Grand_Prix'),
#  ('Republic of Colombia', 'Colombia'),
#  ('Sumitomo', 'The_Sumitomo_Bank'),
#  ('Brazilian Portuguese Empire', 'Portuguese_Empire'),
#  ('Baltimore City', 'Baltimore'),
#  ('Turkish', 'Turkey_national_football_team'),
#  ('Canopic jars', 'Canopic_jar'),
#  ('Ravi', 'Ravi_River'),
#  ('senior national team', 'England_national_football_team'),
#  ('the American University', 'American_University'),
#  ('Vogue Magazine', 'Vogue_(magazine)'),
#  ('Kurdistan province of Iran', 'Kurdistan'),
#  ('Pescara', 'Delfino_Pescara_1936'),
#  ('Peace Rivers', 'Peace_River'),
#  ('governmental', 'Government_of_Russia'),
#  ('Second World War', 'World_War_II'),
#  ('Mozambique IX', 'Mozambique_national_football_team'),
#  ('Dundee Football Club', 'Dundee_F.C.'),
#  ('Indian', 'Native_Americans_in_the_United_States'),
#  ('war of succession', 'War_of_the_Spanish_Succession'),
#  ('division', 'Partition_of_India'),
#  ('Italian Riviera', 'Italy'),
#  ('Russian international association football',
#   'Russia_national_football_team'),
#  ('Hong Kong', 'Hong_Kong_dollar'),
#  ('the Republic of Mozambique', 'Mozambique'),
#  ('New Jersey State', 'New_Jersey'),
#  ('Association of Tennis Professionals ATP',
#   'Association_of_Tennis_Professionals'),
#  ('The People Republic of China', 'China'),
#  ('Desmond Tutu', 'Desmond_Tutu'),
#  ('East Havana', 'Havana'),
#  ('Bhavnagarl', 'Bhavnagar'),
#  ('Great Patriotic War', 'World_War_II'),
#  ('Western culture', 'Western_world'),
#  ('Malawians', 'Malawi'),
#  ('Anton Bruckner', 'Anton_Bruckner'),
#  ('federal Courts of Appeals', 'United_States_courts_of_appeals'),
#  ('Romania', 'Romania_national_football_team'),
#  ('Western Hemispheres', 'Western_Hemisphere'),
#  ('Navaz Sharif', 'Nawaz_Sharif'),
#  ('Overseas territories of Portugal', 'Portuguese_Empire'),
#  ('Daily News', 'New_York_Daily_News'),
#  ('courts of appeals', 'United_States_courts_of_appeals'),
#  ('Andhra coast', 'Andhra_Pradesh'),
#  ('Botham', 'Liam_Botham'),
#  ('independent Azerbaijan', 'Azerbaijan'),
#  ('Prince Louis Napoleon', 'Napoleon_III'),
#  ('Chile 2010 World Cup team', 'Chile_national_football_team'),
#  ('MILAN', 'Milan'),
#  ('Stenhousemuir', 'Stenhousemuir_F.C.'),
#  ('Liberal leader', 'Colombian_Liberal_Party'),
#  ('Labour', 'Labour_Party_(Malta)'),
#  ('Alaska Aces', 'Alaska_Aces_(PBA)'),
#  ('Colombiaian', 'Colombia'),
#  ('Pires', 'Robert_Pires'),
#  ('Los Angeles', 'Los_Angeles_Angels'),
#  ('National League East Division', 'National_League_East'),
#  ('Sun Microsystems Inc', 'Sun_Microsystems'),
#  ('Federal party of the same name', 'Liberal_Party_of_Australia'),
#  ('Dayton peace accords', 'Dayton_Agreement'),
#  ('EU Commissioner', 'European_Commission'),
#  ('Apple Computer', 'Apple_Inc.'),
#  ('The American University', 'American_University'),
#  ('Pope', 'Pope_John_Paul_II'),
#  ('its Civil War', 'Vietnam_War'),
#  ('the country', 'Madagascar'),
#  ('Football', 'Rugby_league'),
#  ('Chicago USA', 'Chicago'),
#  ('automobile manufacturer', 'Ford_Motor_Company'),
#  ('national team', 'Turkey_national_football_team'),
#  ('POLLOCK', 'Shaun_Pollock'),
#  ('Parisian', 'Paris'),
#  ('Thessaloniki Greece', 'Thessaloniki'),
#  ('English', 'United_States'),
#  ('Carlisle', 'Carlisle_United_F.C.'),
#  ('Saudi criminal justice system', 'Saudi_Arabia'),
#  ('CALCUTTA', 'Kolkata'),
#  ('californian', 'California'),
#  ('German born', 'Germans'),
#  ('National Democratic Alliance', 'National_Democratic_Alliance_(Sudan)'),
#  ('Dresden', 'Dresden_Airport'),
#  ('Cabinet ministers', 'Cabinet_(government)'),
#  ('Nice', 'Nice'),
#  ('Gloucester rugby', 'Gloucester_Rugby'),
#  ('St Croix', 'Saint_Croix'),
#  ('New England Area', 'New_England'),
#  ('Denny Neagle', 'Denny_Neagle'),
#  ('UN Coalition', 'United_Nations'),
#  ('David Skoch', 'David_Škoch'),
#  ('Paralympic participations', 'Paralympic_Games'),
#  ('Mexican', 'Mexico'),
#  ('Indian Union', 'India'),
#  ('FTSE', 'FTSE_100_Index'),
#  ('Nolan Ryan', 'Nolan_Ryan'),
#  ('Estonia', 'Estonia'),
#  ('Catane', 'Catania'),
#  ('HRH The Prince of Wales', 'Charles,_Prince_of_Wales'),
#  ('Beaconsfield', 'Kimberley,_Northern_Cape'),
#  ('red', 'Native_Americans_in_the_United_States'),
#  ('islamists', 'Islamism'),
#  ('Revolutionary Armed Forces of Colombia FARC EP',
#   'Revolutionary_Armed_Forces_of_Colombia'),
#  ('Rosset', 'Marc_Rosset'),
#  ('Goldman Sachs JBWere', 'Goldman_Sachs'),
#  ('Insein', 'Insein_Prison'),
#  ('Moldovan national team', 'Moldova_national_football_team'),
#  ('Las Vegas Nevada', 'Las_Vegas'),
#  ('Liberal politician', 'Liberal_Party_(UK)'),
#  ('Steve Waugh', 'Steve_Waugh'),
#  ('Pest', 'Budapest'),
#  ('one federal district', 'Washington,_D.C.'),
#  ('Suns', 'Sun_Microsystems'),
#  ('Portugal expanding empire', 'Portuguese_Empire'),
#  ('Mitsui Group', 'Mitsui'),
#  ('Kremlin', 'Moscow_Kremlin'),
#  ('Bonn Germany', 'Bonn'),
#  ('Portuguese internationals', 'Portugal_national_football_team'),
#  ('European Tour', 'PGA_European_Tour'),
#  ('California United States', 'California'),
#  ('Beylik of Tunis', 'Tunisia'),
#  ('Middlesex 1946', 'Middlesex_County_Cricket_Club'),
#  ('Western', 'Western_Australia'),
#  ('Maccabi Haifa', 'Maccabi_Haifa_F.C.'),
#  ('National League MVP', 'Major_League_Baseball_Most_Valuable_Player_Award'),
#  ('Austrian national team', 'Austria_national_football_team'),
#  ('Basque Homeland and Freedom', 'Eta_(disambiguation)'),
#  ('Berti Vogts', 'Berti_Vogts'),
#  ('Serbian parts', 'Republika_Srpska'),
#  ('Eastern Republic of Uruguay', 'Uruguay'),
#  ('FLNC', 'National_Liberation_Front_of_Corsica'),
#  ('Portuguese poet', 'Portugal'),
#  ('Sydney 2000 Olympics', '2000_Summer_Olympics'),
#  ('the Italian national side', 'Italy_national_football_team'),
#  ('Montenegron', 'Montenegro'),
#  ('French Guiana Overseas region of France', 'French_Guiana'),
#  ('McLaren Peugeot', 'McLaren'),
#  ('Premier League', 'Scottish_Premier_League'),
#  ('the town of the same name', 'Kimberley,_Northern_Cape'),
#  ('Olympiakos', 'Olympiacos_F.C.'),
#  ('Gold Cup', 'Doncaster_Cup'),
#  ('Zemun', 'FK_Zemun'),
#  ('Vietnam War', 'Vietnam_War'),
#  ('Nebraska', 'Nebraska'),
#  ('State', 'New_York'),
#  ('Hillary', 'Hillary_Clinton'),
#  ('new brass key', 'Nebraska'),
#  ('northern', 'Italy'),
#  ('Democratic', 'Democratic_Party_(United_States)'),
#  ('duman clerk', 'Duma'),
#  ('Ivan Rodriguez', 'Iván_Rodríguez'),
#  ('council', 'Nice'),
#  ('Mexico capital', 'Mexico_City'),
#  ('UEFA Cup or Europa League', 'UEFA_Europa_League'),
#  ('George Herbert Walker Bush', 'George_H._W._Bush'),
#  ('CBD', 'Brazilian_Football_Confederation'),
#  ('province of British Columbia', 'British_Columbia'),
#  ('Chinese medium', 'Chinese_language'),
#  ('German government', 'Germany'),
#  ('ATP World Tour', 'Association_of_Tennis_Professionals'),
#  ('Chargers club', 'Gold_Coast_Chargers'),
#  ('Varteks Varazdin', 'NK_Varaždin_(1931–2015)'),
#  ('Biblical texts', 'Bible'),
#  ...}

# %%
# TODO: Write code here to implement the "most probable entity" method.
def most_probable_entity(df):
    for row in df.itertuples():
        df[df.mention == 'Sweden'].iloc[0]

        
most_probable_entity(df_kb)
# Out:
#   Cell In [200], line 2
#     def most_probable_entity(df):
#                                  ^
# SyntaxError: incomplete input

# %% [markdown]
# ## Problem 6: Context-sensitive disambiguation

# %% [markdown]
# Consider the entity mention &lsquo;Lincoln&rsquo;. The most probable entity for this mention turns out to be [Lincoln, Nebraska](http://en.wikipedia.org/Lincoln,_Nebraska); but in pages about American history, we would be better off to predict [Abraham Lincoln](http://en.wikipedia.org/Abraham_Lincoln). This suggests that we should try to disambiguate between different entity references based on the textual context on the page from which the mention was taken. Your task in this last problem is to implement this idea.
#
# Set up a dictionary that contains, for each mention $m$ that can refer to more than one entity $e$, a separate Naive Bayes classifier that is trained to predict the correct entity $e$, given the textual context of the mention. As the prior probabilities of the classifier, choose the probabilities $P(e|m)$ that you used in Problem&nbsp;5. To let you estimate the context-specific probabilities, we have compiled a data set with mention contexts:

# %%
with bz2.open('contexts.tsv.bz2') as source:
    df_contexts = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# This data frame contains, for each ambiguous mention $m$ and each knowledge base entity $e$ to which this mention can refer, up to 100 randomly selected contexts in which $m$ is used to refer to $e$. For this data, a **context** is defined as the 5 tokens to the left and the 5 tokens to the right of the mention. Here are a few examples:

# %%
df_contexts.head()

# %% [markdown]
# Note that, in each context, the position of the mention is indicated by the `@` symbol.
#
# From this data frame, it is easy to select the data that you need to train the classifiers – the contexts and corresponding entities for all mentions. To illustrate this, the following cell shows how to select all contexts that belong to the mention &lsquo;Lincoln&rsquo;:

# %%
df_contexts.context[df_contexts.mention == 'Lincoln']

# %% [markdown]
# Implement the context-sensitive disambiguation method and evaluate its performance. Here are some more hints that may help you along the way:
#
# **Hint 1:** The prior probabilities for a Naive Bayes classifier can be specified using the `class_prior` option. You will have to provide the probabilities in the same order as the alphabetically sorted class (entity) names.
#
# **Hint 2:** Not all mentions in the knowledge base are ambiguous, and therefore not all mentions have context data. If a mention has only one possible entity, pick that one. If a mention has no entity at all, predict the `--NME--` label.

# %%
# TODO: Write code here to implement the context-sensitive disambiguation method

# %% [markdown]
# You should expect to see a small (around 1&nbsp;unit) increase in both precision, recall, and F1.

# %% [markdown]
# ## Reflection questions

# %% [markdown]
# The following reflection questions will help you prepare for the diagnostic test. Answer each of them in the form of a short text and put your answers in the cell below. You will get feedback on your answers from your lab assistant.

# %% [markdown]
# **RQ 5.1:** In Problem&nbsp;3, you did an error analysis on the task of recognizing text spans mentioning named entities. Summarize your results. Pick one type of error that you observed. How could you improve the model&rsquo;s performance on this type of error? What resources (such as domain knowledge, data, compute) would you need to implement this improvement?
#
# **RQ 5.2:** Thinking back about Problem&nbsp;6, explain what the word *context* refers to in the task addressed there, and how context can help to disambiguate between different entities. Suggest other types of context that you could use for disambiguation.
#
# **RQ 5.3:** One type of entity mentions that we did not cover explicitly in this lab are pronouns. As an example, consider the sentence pair *Ruth Bader Ginsburg was an American jurist*. *She served as an associate justice of the Supreme Court from 1993 until her death in 2020*. What facts would you want to extract from this sentence pair? How do pronouns make fact extraction hard?

# %% [markdown]
# *TODO: Enter your answers here*

# %% [markdown]
# **This was the last lab in the Text Mining course. Congratulations! 🥳**
