# %% [markdown]
# # L5: Information extraction

# %% [markdown]
# Information extraction (IE) is the task of identifying named entities and semantic relations between these entities in text data. In this lab we will focus on two sub-tasks in IE, **named entity recognition** (identifying mentions of entities) and **entity linking** (matching these mentions to entities in a knowledge base).

# %% [markdown]
# **Reminder about our [Rules for hand-in assignments](https://www.ida.liu.se/~TDDE16/exam.en.shtml#handins) and the [Policy on cheating and plagiarism](https://www.ida.liu.se/~TDDE16/exam.en.shtml#cheating)**

# %% [markdown]
# We start by loading spaCy:

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# The data that we will be using has been tokenized following the conventions of the [Penn Treebank](ftp://ftp.cis.upenn.edu/pub/treebank/public_html/tokenization.html), and we need to prevent spaCy from using its own tokenizer on top of this. We therefore override spaCy&rsquo;s tokenizer with one that simply splits on space.

# %%
from spacy.tokens import Doc

class WhitespaceTokenizer(object):
    def __init__(self, vocab):
        self.vocab = vocab

    def __call__(self, text):
        return Doc(self.vocab, words=text.split(' '))

nlp.tokenizer = WhitespaceTokenizer(nlp.vocab)

# %% [markdown]
# ## Data set

# %% [markdown]
# The main data set for this lab is a collection of news wire articles in which mentions of named entities have been annotated with page names from the [English Wikipedia](https://en.wikipedia.org/wiki/). The next code cell loads the training and the development parts of the data into Pandas data frames.

# %%
import bz2
import csv
import pandas as pd

with bz2.open('ner-train.tsv.bz2', 'rt') as source:
    df_train = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

with bz2.open('ner-dev.tsv.bz2', 'rt') as source:
    df_dev = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# Each row in these two data frames corresponds to one mention of a named entity and has five columns:
#
# 1. a unique identifier for the sentence containing the entity mention
# 2. the pre-tokenized sentence, with tokens separated by spaces
# 3. the start position of the token span containing the entity mention
# 4. the end position of the token span (exclusive, as in Python list indexing)
# 5. the entity label; either a Wikipedia page name or the generic label `--NME--`
#
# The following cell prints the first five samples from the training data:

# %%
df_train.head()
type(df_train)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# In this sample, we see that the first sentence is annotated with three entity mentions:
#
# * the span 0–1 &lsquo;EU&rsquo; is annotated as a mention but only labelled with the generic `--NME--`
# * the span 2–3 &lsquo;German&rsquo; is annotated with the page [Germany](http://en.wikipedia.org/wiki/Germany)
# * the span 6–7 &lsquo;British&rsquo; is annotated with the page [United_Kingdom](http://en.wikipedia.org/wiki/United_Kingdom)

# %% [markdown]
# ## Problem 1: Evaluation measures

# %% [markdown]
# To warm up, we ask you to write code to print the three measures that you will be using for evaluation:

# %%
def evaluation_report(gold, pred):
    """Print precision, recall, and F1 score.
    
    Args:
        gold: The set with the gold-standard values.
        pred: The set with the predicted values.
    
    Returns:
        Nothing, but prints the precision, recall, and F1 values computed
        based on the specified sets.
    """
    # TODO: Replace the next line with your own code
    TP = len(gold & pred) # intersection
    TN = 0
    FP = len(pred - gold)
    FN = len(gold - pred)

    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    F1_score = (2 * precision * recall) / (precision + recall)
    
    print("precission: ",precision, ", recall: ", recall, ", F1_score: ", F1_score )

# %% [markdown]
# To test your code, you can run the following cell:

# %%
evaluation_report(set(range(3)), set(range(5)))
# Out:
# precission:  0.6 , recall:  1.0 , F1_score:  0.7499999999999999

# %% [markdown]
# This should give you a precision of 60%, a recall of 100%, and an F1-value of 75%.

# %% [markdown]
# ## Problem 2: Span recognition

# %% [markdown]
# One of the first tasks that an information extraction system has to solve is to locate and classify (mentions of) named entities, such as persons and organizations. Here we will tackle the simpler task of recognizing **spans** of tokens that contain an entity mention, without the actual entity label.
#
# The English language model in spaCy features a full-fledged [named entity recognizer](https://spacy.io/usage/linguistic-features#named-entities) that identifies a variety of entities, and can be updated with new entity types by the user. Your task in this problem is to evaluate the performance of this component when predicting entity spans in the development data.
#
# Start by implementing a generator function that yields the gold-standard spans in a given data frame.
#
# **Hint:** The Pandas method [`itertuples()`](https://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.DataFrame.itertuples.html) is useful when iterating over the rows in a DataFrame.

# %%
def gold_spans(df):
    """Yield the gold-standard mention spans in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        triples consisting of the sentence id, start position, and end
        position of each span.
    """
    # TODO: Replace the next line with your own code
    for row in df.itertuples():
        yield row.sentence_id, row.beg, row.end

# %% [markdown]
# To test your code, you can count the spans yielded by your function. When called on the development data, you should get a total of 5,917 unique triples. The first triple and the last triple should be
#
#     ('0946-000', 2, 3)
#     ('1161-010', 1, 3)

# %%
spans_dev_gold = set(gold_spans(df_dev))
print(len(spans_dev_gold))
# Out:
# 5917

# %% [markdown]
# Your next task is to write code that calls spaCy to predict the named entities in the development data, and to evaluate the accuracy of these predictions in terms of precision, recall, and F1. Print these scores using the function that you wrote for Problem&nbsp;1.

# %%
# TODO: Write code here to run and evaluate the spaCy named entity recognizer on the development data
def spacy_pred(df):
    for row in df.itertuples():
        doc = nlp(row.sentence)
        for ent in doc.ents:
            yield row.sentence_id, ent.start, ent.end
pred = set(spacy_pred(df_dev))
evaluation_report(spans_dev_gold, pred= pred)
# Out:
# precission:  0.5213954072029113 , recall:  0.702213959776914 , F1_score:  0.5984444764511019

# %% [markdown]
# ## Problem 3: Error analysis

# %% [markdown]
# As you were able to see in Problem&nbsp;2, the span accuracy of the named entity recognizer is far from perfect. In particular, only slightly more than half of the predicted spans are correct according to the gold standard. Your next task is to analyse this result in more detail.
#
# Here is a function that prints the false positives as well as the false negatives spans for a data frame, given a reference set of gold-standard spans and a candidate set of predicted spans.

# %%
from collections import defaultdict

def error_report(df, spans_gold, spans_pred):
    false_pos = defaultdict(list)
    for s, b, e in spans_pred - spans_gold:
        false_pos[s].append((b, e))
    false_neg = defaultdict(list)
    for s, b, e in spans_gold - spans_pred:
        false_neg[s].append((b, e))
    for row in df.drop_duplicates('sentence_id').itertuples():
        if row.sentence_id in false_pos or row.sentence_id in false_neg:
            print('Sentence:', row.sentence)
            for b, e in false_pos[row.sentence_id]:
                print('  FP:', ' '.join(row.sentence.split()[b:e]))
            for b, e in false_neg[row.sentence_id]:
                print('  FN:', ' '.join(row.sentence.split()[b:e]))

# %% [markdown]
# Use this function to inspect and analyse the errors that the automated prediction makes. Can you see any patterns? Base your analysis on the first 500 rows of the training data. Summarize your observations in a short text.

# %%
# TODO: Write code here to do your analysis

# %% [markdown]
# *TODO: Write a short text that summarises the errors that you observed*

# %% [markdown]
# Now, use the insights from your error analysis to improve the automated prediction that you implemented in Problem&nbsp;2. While the best way to do this would be to [update spaCy&rsquo;s NER model](https://spacy.io/usage/linguistic-features#updating) using domain-specific training data, for this lab it suffices to write code to post-process the output produced by spaCy. To filter out specific labels it is useful to know the named entity label scheme, which can be found in the [model's documentation](https://spacy.io/models/en#en_core_web_sm). You should be able to improve the F1 score from Problem&nbsp;2 by at last 15 percentage points.

# %%
# TODO: Write code here to run and evaluate the spaCy named entity recognizer on the development data
def spacy_pred(df):
    for row in df.itertuples():
        doc = nlp(row.sentence)
        for ent in doc.ents:
            # if ent.label_ in ['CARDINAL', 'DATE', 'EVENT', 'FAC', 'GPE', 'LANGUAGE', 'LAW', 'LOC', 'MONEY', 'NORP', 'ORDINAL',
            #  'ORG', 'PERCENT', 'PERSON', 'PRODUCT', 'QUANTITY', 'TIME', 'WORK_OF_ART']:
            # here we removed time, date, cardinal, money, fac, ORDINAL
            if ent.label_ in ['EVENT', 'GPE', 'LANGUAGE', 'LAW', 'LOC', 'NORP','ORG', 'PERCENT', 'PERSON', 'PRODUCT', 'QUANTITY', 'WORK_OF_ART']:
                yield row.sentence_id, ent.start, ent.end
pred = set(spacy_pred(df_dev))
evaluation_report(spans_dev_gold, pred= pred)
# Out:
# precission:  0.8194831013916501 , recall:  0.6966368091938482 , F1_score:  0.7530830364483421

# %% [markdown]
# Show that you achieve the performance goal by reporting the evaluation measures that you implemented in Problem&nbsp;1.

# %% [markdown]
# Before going on, we ask you to store the outputs of the improved named entity recognizer on the development data in a new data frame. This new frame should have the same layout as the original data frame for the development data that you loaded above, but should contain the *predicted* start and end positions for each token span, rather than the gold positions. As the `label` of each span, you can use the special value `--NME--`.

# %%
# TODO: Write code here to store the predicted spans in a new data frame

# remove data, keep titles
new_df_dev = df_dev.drop(index=df_dev.index)

#add new row to the end of DataFrame
for id, start, end in pred:
    new_df_dev.loc[len(new_df_dev.index)] = [id, df_dev[df_dev['sentence_id'] == id].iloc[0]['sentence'], start, end, '--NME--']

print(type(new_df_dev))
new_df_dev
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      sentence_id                                           sentence  beg  end  \
# 0       0968-005  Edwards was quoted as saying : " What type of ...   23   24
# 1       1096-019  In Chicago , the Braves and Cubs split a doubl...    1    2
# 2       0954-002  Quarter-final results in the Hong Kong Open on...   21   22
# 3       0962-005       on Thursday ( players U.S. unless stated ) :    4    5
# 4       0966-149                7. Carlos Calado ( Portugal ) 16.31    4    5
# ...          ...                                                ...  ...  ...
# 5025    1120-007  The men have claimed political asylum in Brita...    7    8
# 5026    1055-022                   Saeed Anwar c Stewart b Gough 33    3    4
# 5027    1007-007  " The worst thing that could happen for financ...   31   33
# 5028    0994-005  " The world community should not be indifferen...   18   19
# 5029    1137-002  North Korea demanded on Saturday that South Ko...    6    8
#
#         label
# 0     --NME--
# 1     --NME--
# 2     --NME--
# 3     --NME--
# 4     --NME--
# ...       ...
# 5025  --NME--
# 5026  --NME--
# 5027  --NME--
# 5028  --NME--
# 5029  --NME--
#
# [5030 rows x 5 columns]

# %% [markdown]
# ## Problem 4: Entity linking

# %% [markdown]
# Now that we have a method for predicting mention spans, we turn to the task of **entity linking**, which amounts to predicting the knowledge base entity that is referenced by a given mention. In our case, for each span we want to predict the Wikipedia page that this mention references.
#
# Start by extending the generator function that you implemented in Problem&nbsp;2 to labelled spans.

# %%
def gold_mentions(df):
    """Yield the gold-standard mentions in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        quadruples consisting of the sentence id, start position, end
        position and entity label of each span.
    """
    # TODO: Replace the next line with your own code
    # --just add one more label column
    for row in df.itertuples():
        yield row.sentence_id, row.beg, row.end, row.label

gold_standard_mentions = set(gold_mentions(df_dev))
gold_standard_mentions
# Out:
# {('1128-014', 0, 1, '--NME--'),
#  ('1065-008', 0, 2, 'St_Johnstone_F.C.'),
#  ('1054-007', 1, 3, 'Tristan_Hoffman'),
#  ('1067-017', 2, 3, 'Cowdenbeath_F.C.'),
#  ('1090-008', 30, 31, 'United_States'),
#  ('1142-012', 4, 5, 'Kurdistan_Democratic_Party'),
#  ('0972-023', 0, 2, 'Sri_Lanka_national_cricket_team'),
#  ('0966-114', 1, 3, '--NME--'),
#  ('1031-014', 28, 29, 'United_States'),
#  ('1007-016', 19, 20, 'Democratic_Party_(United_States)'),
#  ('1089-011', 0, 1, 'Jesper_Parnevik'),
#  ('1103-015', 30, 32, 'Gunther_Schepens'),
#  ('1103-002', 0, 1, 'Brussels'),
#  ('1073-005', 2, 4, 'Henry_Honiball'),
#  ('1059-006', 28, 30, 'Dean_Jones_(cricketer)'),
#  ('1056-024', 4, 5, 'Russia'),
#  ('1072-012', 5, 6, '--NME--'),
#  ('1103-006', 14, 15, '--NME--'),
#  ('1066-062', 0, 1, 'Scunthorpe_United_F.C.'),
#  ('1152-013', 17, 18, 'United_States'),
#  ('1003-003', 36, 37, 'Moengo'),
#  ('1025-002', 19, 20, '--NME--'),
#  ('1117-001', 0, 1, 'London'),
#  ('1133-013', 0, 1, 'Xiao_Qiang'),
#  ('1089-007', 0, 2, 'Tiger_Woods'),
#  ('1067-013', 0, 1, 'Dumbarton_F.C.'),
#  ('1011-017', 7, 8, 'Missouri'),
#  ('0966-028', 1, 3, 'Jack_Pierce_(hurdler)'),
#  ('1076-030', 2, 3, '--NME--'),
#  ('1051-010', 1, 3, 'Phillip_Price'),
#  ('0990-010', 7, 8, 'Russia'),
#  ('1099-003', 0, 1, 'Austria_national_football_team'),
#  ('1096-040', 10, 11, 'Colorado_Rockies'),
#  ('1016-014', 10, 11, 'Israel'),
#  ('0954-003', 9, 10, 'Australia'),
#  ('1011-007', 4, 7, 'Commerce_Bancshares'),
#  ('1090-005', 8, 9, 'Germany_Fed_Cup_team'),
#  ('0966-087', 4, 5, 'Australia'),
#  ('0984-017', 17, 18, 'United_States'),
#  ('1116-009', 13, 14, 'Napoleon'),
#  ('1142-010', 9, 10, 'United_States'),
#  ('1072-012', 24, 25, '--NME--'),
#  ('1094-005', 0, 4, 'American_League_East'),
#  ('1110-002', 6, 7, '--NME--'),
#  ('1046-004', 16, 18, '--NME--'),
#  ('0994-001', 0, 2, '--NME--'),
#  ('0966-158', 1, 3, '--NME--'),
#  ('1031-007', 38, 39, '--NME--'),
#  ('1085-001', 0, 1, 'Minsk'),
#  ('1045-008', 22, 23, 'United_Nations'),
#  ('1058-040', 29, 31, 'Minnesota_Twins'),
#  ('1009-013', 16, 17, 'Mexico'),
#  ('0973-001', 0, 1, 'Colombo'),
#  ('1049-002', 24, 26, '1998_FIFA_World_Cup'),
#  ('1126-009', 7, 8, 'Islam'),
#  ('1090-018', 8, 9, 'Billie_Jean_King'),
#  ('0957-013', 6, 8, '--NME--'),
#  ('1146-006', 7, 8, 'Saddam_Hussein'),
#  ('1120-007', 14, 15, 'Iraq'),
#  ('1148-005', 18, 19, 'Tunisia'),
#  ('1058-040', 7, 9, 'José_Parra_(baseball)'),
#  ('1056-032', 4, 5, 'Lithuania'),
#  ('0949-003', 37, 39, 'David_Platt_(footballer)'),
#  ('1121-006', 11, 12, 'Kurdistan'),
#  ('0957-018', 12, 13, 'France'),
#  ('1082-002', 10, 12, '1998_FIFA_World_Cup'),
#  ('1016-009', 14, 15, 'Jews'),
#  ('1132-003', 0, 2, '--NME--'),
#  ('0998-002', 5, 6, 'Chechnya'),
#  ('1101-012', 88, 90, 'Francisco_Palencia'),
#  ('1057-007', 11, 13, 'Saleem_Malik'),
#  ('1096-005', 0, 1, '--NME--'),
#  ('1142-000', 7, 8, 'Iraq'),
#  ('1133-001', 0, 1, '--NME--'),
#  ('1132-000', 0, 1, 'Mexico'),
#  ('1103-016', 64, 66, 'Hakan_Şükür'),
#  ('0994-010', 23, 24, 'Russia'),
#  ('1030-033', 0, 1, 'Dick_Morris'),
#  ('1031-015', 5, 7, '--NME--'),
#  ('1072-019', 26, 28, 'Frank_Bunce'),
#  ('1101-012', 71, 73, 'Ramón_Ramírez'),
#  ('0966-056', 1, 3, '--NME--'),
#  ('0964-002', 31, 32, 'Brazil'),
#  ('0963-023', 9, 11, 'PGA_Tour'),
#  ('0966-046', 1, 3, 'Vénuste_Niyongabo'),
#  ('1011-007', 3, 4, '--NME--'),
#  ('0967-005', 25, 27, '--NME--'),
#  ('1011-006', 0, 2, '--NME--'),
#  ('1068-008', 2, 3, 'Wolverhampton_Wanderers_F.C.'),
#  ('1128-007', 10, 11, 'Poland'),
#  ('1054-006', 6, 7, 'Team_Polti'),
#  ('1154-004', 1, 3, 'Le_Matin_(France)'),
#  ('1113-000', 2, 4, 'DFB-Pokal'),
#  ('0965-008', 8, 9, 'Donovan_Bailey'),
#  ('0960-009', 18, 20, 'Todd_Martin'),
#  ('1095-019', 3, 5, 'New_York_Yankees'),
#  ('0960-005', 20, 22, 'Jeff_Tarango'),
#  ('1005-011', 11, 14, 'International_Monetary_Fund'),
#  ('1154-002', 8, 9, 'Algiers'),
#  ('1016-007', 26, 28, '--NME--'),
#  ('1048-000', 2, 3, 'Israel_national_football_team'),
#  ('1138-003', 10, 11, 'Zhejiang'),
#  ('1069-013', 17, 19, '--NME--'),
#  ('0962-005', 4, 5, 'United_States'),
#  ('1135-015', 20, 21, '--NME--'),
#  ('1096-012', 27, 31, '--NME--'),
#  ('1056-017', 8, 10, '--NME--'),
#  ('1055-002', 10, 11, 'Pakistan_national_cricket_team'),
#  ('1126-006', 3, 4, 'Islam'),
#  ('1051-009', 42, 44, 'Pedro_Linhart'),
#  ('0966-005', 4, 5, 'Sweden'),
#  ('1090-010', 21, 22, 'Nagoya'),
#  ('1058-007', 8, 9, '--NME--'),
#  ('1160-016', 11, 12, 'Neil_Jordan'),
#  ('0948-019', 3, 4, 'Durham_County_Cricket_Club'),
#  ('0966-161', 7, 9, 'Michael_Johnson_(sprinter)'),
#  ('1089-026', 0, 2, 'Duffy_Waldorf'),
#  ('1018-000', 0, 1, 'Germany'),
#  ('0984-012', 0, 2, 'United_States'),
#  ('0971-002', 3, 4, 'Australia_national_cricket_team'),
#  ('1134-002', 9, 10, 'Suharto'),
#  ('0958-020', 0, 1, 'Seattle_Mariners'),
#  ('1067-015', 2, 3, 'Stranraer'),
#  ('0947-009', 18, 19, 'Lancashire_County_Cricket_Club'),
#  ('0997-004', 1, 2, 'Russia'),
#  ('1065-025', 0, 1, 'Dumbarton_F.C.'),
#  ('0985-012', 0, 1, 'Frank_Bruno'),
#  ('1148-009', 8, 9, '--NME--'),
#  ('1046-001', 0, 2, 'A_Coruña'),
#  ('0966-158', 4, 5, 'Belarus'),
#  ('1045-002', 13, 14, 'State_of_Palestine'),
#  ('1026-002', 12, 14, '--NME--'),
#  ('0990-006', 3, 4, 'Boris_Yeltsin'),
#  ('1096-032', 9, 10, 'New_York_Mets'),
#  ('1109-000', 6, 7, 'Brazil_national_football_team'),
#  ('1069-006', 1, 2, 'Riverside_Ground'),
#  ('0992-003', 11, 13, 'John_C._Kornblum'),
#  ('1160-010', 6, 9, 'The_Crying_Game'),
#  ('1027-020', 1, 2, 'State_of_Palestine'),
#  ('0989-002', 20, 22, 'Nagoum_Yamassoum'),
#  ('1157-002', 1, 5, 'NATO'),
#  ('1094-038', 0, 2, 'National_League_Central'),
#  ('1072-008', 1, 3, 'New_Zealand_national_rugby_union_team'),
#  ('1016-013', 10, 12, 'Volker_Rühe'),
#  ('1097-019', 0, 1, 'Stefan_Edberg'),
#  ('1121-008', 35, 37, 'Iraqi_Kurdistan'),
#  ('0953-003', 8, 10, '--NME--'),
#  ('1007-033', 1, 4, 'S&P_500_Index'),
#  ('1024-000', 3, 6, '--NME--'),
#  ('1063-000', 4, 6, 'Northern_Ireland_national_football_team'),
#  ('0999-003', 0, 1, 'Interfax'),
#  ('1128-005', 17, 18, '--NME--'),
#  ('0987-001', 0, 1, 'Lagos'),
#  ('0980-013', 20, 22, 'Federal_Reserve'),
#  ('1072-019', 56, 58, 'Michael_Jones_(rugby_union)'),
#  ('1130-004', 33, 35, 'Fulgencio_Batista'),
#  ('1032-002', 31, 32, '--NME--'),
#  ('1050-002', 16, 17, 'Europe'),
#  ('0957-020', 35, 36, 'Australia'),
#  ('1111-008', 5, 7, '--NME--'),
#  ('1090-016', 19, 20, 'Billie_Jean_King'),
#  ('0946-007', 5, 6, 'England_cricket_team'),
#  ('1058-031', 12, 14, 'Mark_McGwire'),
#  ('0958-028', 3, 4, 'Los_Angeles_Angels'),
#  ('1068-013', 9, 10, 'Charlton_Athletic_F.C.'),
#  ('1006-012', 3, 4, 'Egypt'),
#  ('1158-003', 10, 11, 'Reuters'),
#  ('1045-009', 12, 13, 'Jerusalem'),
#  ('1103-012', 15, 17, 'Arif_Erdem'),
#  ('1054-012', 1, 3, '--NME--'),
#  ('1148-008', 4, 5, 'Tunisia'),
#  ('1106-006', 2, 4, 'Marc_Degryse'),
#  ('1058-004', 4, 5, '--NME--'),
#  ('0947-003', 4, 5, 'Somerset_County_Cricket_Club'),
#  ('1090-010', 1, 3, 'United_States_Fed_Cup_team'),
#  ('1126-005', 14, 15, 'Tuzla'),
#  ('1149-005', 26, 28, 'Labor_Day'),
#  ('1068-036', 2, 3, 'Northampton_Town_F.C.'),
#  ('1116-036', 15, 16, 'Europe'),
#  ('1046-003', 9, 10, 'Real_Madrid_CF'),
#  ('1115-008', 24, 25, '--NME--'),
#  ('1142-001', 0, 1, 'Istanbul'),
#  ('0994-005', 13, 14, 'Alexander_Lukashenko'),
#  ('1135-003', 0, 1, 'Myanmar'),
#  ('1070-012', 1, 3, 'Paul_Tracy'),
#  ('0994-015', 10, 11, 'Moscow'),
#  ('1156-007', 2, 3, 'Rome'),
#  ('0979-012', 7, 9, 'Labor_Day'),
#  ('1057-007', 16, 18, 'Wasim_Akram'),
#  ('0963-011', 0, 1, 'Nolan_Henke'),
#  ('0966-070', 1, 3, 'Inger_Miller'),
#  ('1096-017', 1, 2, 'Philadelphia_Phillies'),
#  ('1097-012', 27, 28, 'Stefan_Edberg'),
#  ('1156-003', 15, 16, 'United_States'),
#  ('1129-005', 12, 13, 'Russia'),
#  ('1027-002', 2, 4, '--NME--'),
#  ('0986-006', 18, 19, 'Niall_Quinn'),
#  ('1060-020', 1, 4, 'Miguel_Ángel_Jiménez'),
#  ('0966-027', 1, 3, 'Frank_Busemann'),
#  ('1030-032', 15, 16, 'Democratic_Party_(United_States)'),
#  ('0962-009', 19, 21, 'Steve_Stricker'),
#  ('1106-007', 0, 1, 'Turkey_national_football_team'),
#  ('1046-000', 2, 3, 'Real_Madrid_CF'),
#  ('1061-005', 0, 1, 'London_Broncos'),
#  ('1065-015', 0, 2, 'East_Fife_F.C.'),
#  ('1099-008', 9, 11, 'Gary_McAllister'),
#  ('1027-015', 12, 13, '--NME--'),
#  ('1007-005', 23, 25, 'Federal_Reserve'),
#  ('1096-012', 2, 4, 'Nolan_Ryan'),
#  ('0972-010', 0, 2, '--NME--'),
#  ('1159-004', 14, 16, '--NME--'),
#  ('0981-013', 0, 1, 'Ford_Motor_Company'),
#  ('1065-037', 0, 2, 'Ross_County_F.C.'),
#  ('1136-002', 23, 24, 'China'),
#  ('1156-002', 0, 1, 'Italy'),
#  ('1095-007', 0, 1, 'Milwaukee_Brewers'),
#  ('1147-003', 3, 6, 'Kurdistan_Democratic_Party'),
#  ('1010-002', 9, 10, 'United_States'),
#  ('1066-022', 0, 1, 'Oxford_United_F.C.'),
#  ('0977-001', 0, 1, 'Ottawa'),
#  ('1016-012', 9, 10, 'Israel'),
#  ('0966-096', 1, 3, 'Linda_Kisabaka'),
#  ('1065-026', 0, 1, 'Berwick_Rangers_F.C.'),
#  ('0985-002', 4, 6, 'Frank_Bruno'),
#  ('1146-002', 22, 24, 'Masoud_Barzani'),
#  ('1011-022', 15, 17, '--NME--'),
#  ('1056-030', 1, 3, 'Wendy_Everson'),
#  ('1001-003', 20, 21, '--NME--'),
#  ('1056-046', 3, 4, 'Australia'),
#  ('1128-011', 8, 9, '--NME--'),
#  ('1051-009', 15, 17, 'Philip_Walton'),
#  ('1058-017', 19, 21, 'Jim_Leyritz'),
#  ('0994-008', 27, 28, 'Reuters'),
#  ('1157-003', 5, 6, 'Reuters'),
#  ('0967-005', 38, 39, 'Roberto_Bisconti'),
#  ('1083-002', 19, 22, '--NME--'),
#  ('0994-002', 0, 1, 'Minsk'),
#  ('1033-008', 5, 6, 'Chechnya'),
#  ('1139-002', 5, 7, '--NME--'),
#  ('0969-001', 2, 3, 'France'),
#  ('1010-017', 44, 45, 'Joseph_Bernardin'),
#  ('1056-030', 4, 5, 'United_Kingdom'),
#  ('0949-005', 22, 23, 'Blackburn_Rovers_F.C.'),
#  ('1016-000', 0, 1, 'Bonn'),
#  ('1013-002', 22, 25, '--NME--'),
#  ('1039-010', 6, 7, '--NME--'),
#  ('0962-008', 10, 11, 'Sweden'),
#  ('0951-000', 2, 3, 'Romania_national_football_team'),
#  ('1067-011', 0, 1, 'Ayr_United_F.C.'),
#  ('0960-004', 8, 9, 'The_Championships,_Wimbledon'),
#  ('0949-004', 16, 17, 'Moldova_national_football_team'),
#  ('1068-031', 2, 3, 'Darlington_F.C.'),
#  ('1090-008', 27, 28, '--NME--'),
#  ('1160-007', 28, 30, 'Warner_Bros.'),
#  ('1022-018', 1, 3, '--NME--'),
#  ('0991-010', 4, 5, 'Alexander_Lebed'),
#  ('1128-002', 21, 22, 'Poland'),
#  ('0948-004', 8, 13, '--NME--'),
#  ('0966-006', 1, 3, 'Aliuska_López'),
#  ('1012-002', 20, 21, 'United_States'),
#  ('0992-002', 29, 30, 'United_States'),
#  ('1090-003', 12, 14, 'United_States_Fed_Cup_team'),
#  ('0966-058', 4, 5, 'Lithuania'),
#  ('1160-006', 0, 1, 'Neil_Jordan'),
#  ('0947-009', 2, 3, 'Sussex_County_Cricket_Club'),
#  ('1133-011', 6, 7, 'China'),
#  ('1062-002', 11, 13, 'FIFA_World_Cup'),
#  ('1116-029', 6, 8, 'Jackie_Stewart'),
#  ('1025-006', 16, 17, 'Israel'),
#  ('0957-033', 18, 19, 'Italy'),
#  ('1046-009', 15, 16, 'Brazil'),
#  ('0996-006', 5, 7, 'Slobodan_Milošević'),
#  ('0970-002', 9, 10, 'A.C._Milan'),
#  ('0953-001', 0, 2, 'Panama_City'),
#  ('1039-017', 0, 1, 'Republika_(Indonesian_newspaper)'),
#  ('1145-002', 10, 11, 'Bahrain'),
#  ('1116-033', 8, 9, 'Kuwait'),
#  ('0981-006', 5, 6, 'Markham,_Ontario'),
#  ('0959-011', 2, 3, 'Houston_Astros'),
#  ('0980-014', 12, 13, 'CNBC'),
#  ('1135-015', 1, 2, 'National_League_for_Democracy'),
#  ('1103-019', 5, 7, 'Wilfried_Van_Moer'),
#  ('1111-005', 1, 3, '--NME--'),
#  ('1160-010', 0, 1, 'Neil_Jordan'),
#  ('0946-002', 14, 15, 'Somerset_County_Cricket_Club'),
#  ('1039-018', 18, 19, 'Indonesian_Democratic_Party'),
#  ('1060-016', 4, 6, 'New_Zealand'),
#  ('0946-014', 12, 13, '--NME--'),
#  ('0957-020', 15, 17, 'Jiří_Novák'),
#  ('1139-005', 0, 1, '--NME--'),
#  ('1056-025', 4, 5, 'Russia'),
#  ('1049-001', 2, 3, 'Liechtenstein'),
#  ('1056-017', 16, 17, 'Germany'),
#  ('1016-002', 1, 2, 'Germany'),
#  ('0965-007', 19, 20, 'Donovan_Bailey'),
#  ('1073-007', 11, 13, 'Justin_Marshall'),
#  ('1118-007', 19, 20, 'Scotland'),
#  ('1127-000', 0, 1, '--NME--'),
#  ('0972-000', 4, 6, 'Sri_Lanka_national_cricket_team'),
#  ('1067-012', 0, 1, 'Clyde_F.C.'),
#  ('1106-006', 8, 10, 'Luís_Oliveira'),
#  ('1148-009', 18, 19, 'Libya'),
#  ('1058-031', 27, 28, '--NME--'),
#  ('1007-024', 11, 12, 'Bob_Dole'),
#  ('1161-007', 13, 15, '--NME--'),
#  ('0990-002', 29, 30, 'Chechnya'),
#  ('0966-116', 1, 3, '--NME--'),
#  ('1059-006', 24, 25, 'Derbyshire_County_Cricket_Club'),
#  ('1128-003', 10, 11, '--NME--'),
#  ('1152-017', 10, 14, '--NME--'),
#  ('0956-004', 2, 3, '--NME--'),
#  ('1103-012', 19, 21, 'Orhan_Çıkırıkçı'),
#  ('1066-063', 0, 1, 'Carlisle_United_F.C.'),
#  ('1121-002', 14, 15, 'Iraq'),
#  ('1072-005', 33, 35, 'South_Africa_national_rugby_union_team'),
#  ('1065-014', 0, 1, 'Stirling_Albion_F.C.'),
#  ('1160-004', 7, 9, 'Julia_Roberts'),
#  ('1070-016', 8, 10, '--NME--'),
#  ('1142-010', 19, 20, 'Iraq'),
#  ('1069-003', 5, 6, 'Hampshire_County_Cricket_Club'),
#  ('1152-015', 7, 9, 'United_States_Air_Force'),
#  ('1128-002', 26, 28, '--NME--'),
#  ('1054-003', 8, 12, 'Tour_of_the_Netherlands'),
#  ('1155-005', 5, 6, 'Germany'),
#  ('0992-003', 1, 2, 'Bosnia_and_Herzegovina'),
#  ('1000-014', 8, 9, 'Poland'),
#  ('1012-008', 19, 20, '--NME--'),
#  ('1031-011', 3, 4, 'Pirelli'),
#  ('1085-002', 10, 12, '1998_FIFA_World_Cup'),
#  ('1143-007', 17, 18, 'Israel'),
#  ('1146-002', 10, 11, 'Iraq'),
#  ('0948-041', 6, 7, 'Headingley'),
#  ('0958-045', 0, 2, 'San_Diego_Padres'),
#  ('1107-000', 6, 7, 'Scotland_national_football_team'),
#  ('1158-000', 5, 6, 'Belgium'),
#  ('1153-004', 9, 10, 'Liège'),
#  ('1027-016', 8, 9, 'Israel'),
#  ('1047-003', 0, 1, 'Wigan_Warriors'),
#  ('1157-004', 5, 7, '--NME--'),
#  ('0958-034', 0, 1, 'Montreal_Expos'),
#  ('1030-039', 2, 3, 'London'),
#  ('1037-004', 27, 28, 'Ericsson'),
#  ('1004-003', 22, 23, 'France'),
#  ('1072-018', 60, 62, '--NME--'),
#  ('1116-003', 3, 5, 'Elizabeth_I_of_England'),
#  ('1093-005', 0, 2, 'El_Salvador_national_football_team'),
#  ('1082-000', 4, 5, 'Switzerland_national_football_team'),
#  ('0991-002', 10, 12, 'Aslan_Maskhadov'),
#  ('1130-000', 2, 5, '--NME--'),
#  ('1007-002', 0, 2, 'New_York_City'),
#  ('1097-001', 0, 2, '--NME--'),
#  ('1047-000', 5, 6, 'Bradford_Bulls'),
#  ('0960-002', 0, 2, 'New_York_City'),
#  ('1028-011', 7, 8, 'Detroit'),
#  ('1046-004', 14, 15, 'AJ_Auxerre'),
#  ('1103-003', 22, 23, '--NME--'),
#  ('1122-001', 0, 1, 'London'),
#  ('0966-117', 4, 5, 'Russia'),
#  ('1155-009', 19, 20, 'Iran'),
#  ('0966-084', 4, 5, 'Italy'),
#  ('0966-110', 1, 3, 'Nico_Motchebon'),
#  ('1051-009', 8, 10, 'Robert_Coles_(golfer)'),
#  ('1101-011', 58, 60, 'Reynald_Pedros'),
#  ('1135-025', 6, 12, '--NME--'),
#  ('0965-003', 4, 5, 'Olympic_sports'),
#  ('1049-003', 24, 26, '--NME--'),
#  ('1027-014', 4, 6, 'Yasser_Arafat'),
#  ('1060-005', 1, 3, 'Ian_Woosnam'),
#  ('1115-005', 22, 23, '--NME--'),
#  ('1080-004', 0, 1, 'Romania_national_football_team'),
#  ('0949-010', 2, 4, 'UEFA_Euro_1996'),
#  ('1081-002', 7, 9, '1998_FIFA_World_Cup'),
#  ('1072-013', 11, 13, 'Sean_Fitzpatrick'),
#  ('1014-009', 13, 14, 'Bob_Dole'),
#  ('1058-016', 13, 15, 'Andy_Pettitte'),
#  ('1116-019', 1, 2, 'United_States'),
#  ('0954-005', 2, 4, 'Rodney_Eyles'),
#  ('1160-004', 28, 29, 'Republic_of_Ireland'),
#  ('1087-019', 0, 1, 'Rodney_Eyles'),
#  ('1096-005', 16, 17, 'Cincinnati_Reds'),
#  ('1003-003', 14, 15, '--NME--'),
#  ('1011-008', 10, 11, '--NME--'),
#  ('1052-000', 2, 3, 'Slovakia_national_football_team'),
#  ('1030-015', 21, 25, 'New_York_Stock_Exchange'),
#  ('1027-007', 2, 3, 'Yasser_Arafat'),
#  ('0966-140', 4, 5, 'Kenya'),
#  ('1116-025', 4, 6, 'Baudouin_of_Belgium'),
#  ('1025-006', 3, 5, '--NME--'),
#  ('1152-004', 19, 20, 'Persian_Gulf'),
#  ('1031-003', 25, 26, 'China'),
#  ('0946-011', 14, 15, 'Worcestershire_County_Cricket_Club'),
#  ('0949-006', 14, 15, 'Alan_Shearer'),
#  ('0966-141', 4, 5, 'Ethiopia'),
#  ('1014-002', 8, 9, 'Republican_Party_(United_States)'),
#  ('1055-038', 2, 3, 'Ronnie_Irani'),
#  ('1000-004', 14, 15, 'Budapest_Stock_Exchange'),
#  ('1056-043', 14, 15, 'United_States'),
#  ('1060-024', 1, 3, 'Paul_Broadhurst'),
#  ('1143-000', 6, 7, 'Lebanon'),
#  ('1096-022', 21, 23, 'Andruw_Jones'),
#  ('0975-005', 9, 10, 'Bistrița'),
#  ('1126-000', 0, 1, 'NATO'),
#  ('0966-047', 4, 5, 'Kenya'),
#  ('1039-000', 3, 4, 'Indonesia'),
#  ('1058-022', 24, 26, 'Seattle_Mariners'),
#  ('0957-010', 8, 10, 'Félix_Mantilla_(tennis)'),
#  ('1126-004', 14, 15, 'NATO'),
#  ('1136-007', 13, 14, 'Tianjin'),
#  ('1142-000', 0, 2, 'Iraqi_Kurdistan'),
#  ('1099-005', 10, 12, 'Stephan_Marasek'),
#  ('0946-003', 13, 14, 'Essex_County_Cricket_Club'),
#  ('0947-005', 0, 1, 'Leicestershire_County_Cricket_Club'),
#  ('1069-007', 0, 1, 'Glamorgan_County_Cricket_Club'),
#  ('1054-017', 6, 7, '7-Eleven_(cycling_team)'),
#  ('1116-009', 23, 24, 'Moscow'),
#  ('0957-030', 11, 12, 'Madagascar'),
#  ('1007-000', 3, 5, 'New_York_Stock_Exchange'),
#  ('1090-018', 17, 18, 'Spain_Fed_Cup_team'),
#  ('1109-007', 0, 1, 'Brazil_national_football_team'),
#  ('1057-003', 18, 20, 'Peter_Martin_(cricketer)'),
#  ('1060-020', 5, 6, 'Spain'),
#  ('1116-035', 2, 3, 'United_Kingdom'),
#  ('0966-063', 4, 5, 'United_States'),
#  ('0965-010', 6, 7, 'Olympic_sports'),
#  ('0948-025', 3, 4, 'Gloucestershire_County_Cricket_Club'),
#  ('1099-017', 5, 7, 'Markus_Schopp'),
#  ('1159-007', 12, 14, 'Marc_Dutroux'),
#  ('1055-000', 4, 5, 'Pakistan_national_cricket_team'),
#  ('1068-021', 2, 3, 'Chesterfield_F.C.'),
#  ('0956-014', 0, 1, '--NME--'),
#  ('0979-013', 4, 8, '--NME--'),
#  ('0992-009', 1, 2, 'Party_of_Democratic_Action'),
#  ('1040-000', 0, 3, '--NME--'),
#  ('1046-005', 0, 1, 'Real_Madrid_CF'),
#  ('1128-012', 13, 14, 'Switzerland'),
#  ('0979-002', 22, 23, 'United_States'),
#  ('1143-009', 2, 5, 'Hezbollah'),
#  ('1126-004', 21, 22, 'Sarajevo'),
#  ('1096-000', 2, 4, 'Kevin_Brown_(right-handed_pitcher)'),
#  ('0974-007', 11, 13, '--NME--'),
#  ('1039-006', 0, 1, 'Kompas'),
#  ('1074-004', 1, 3, '--NME--'),
#  ('1022-007', 13, 14, '--NME--'),
#  ('0957-018', 35, 36, 'Switzerland'),
#  ('0966-026', 1, 3, 'Steve_Brown_(athlete)'),
#  ('1116-001', 0, 1, 'London'),
#  ('1060-009', 4, 5, 'Italy'),
#  ('1031-003', 13, 14, 'China'),
#  ('1045-003', 15, 17, '--NME--'),
#  ('1094-053', 2, 3, 'Cincinnati_Reds'),
#  ('1096-036', 4, 6, 'Tom_Pagnozzi'),
#  ('1054-023', 7, 8, 'TVM_(cycling_team)'),
#  ('1103-020', 7, 9, 'Wilfried_Van_Moer'),
#  ('1058-016', 1, 2, 'California'),
#  ('1096-039', 0, 2, 'Ray_Lankford'),
#  ('1033-008', 9, 11, 'Aslan_Maskhadov'),
#  ('1092-002', 5, 8, '1997_Fed_Cup'),
#  ('1016-009', 0, 1, '--NME--'),
#  ('1101-002', 16, 17, 'France_national_football_team'),
#  ('1158-005', 17, 18, 'AK-47'),
#  ('1127-022', 5, 6, '--NME--'),
#  ('1156-008', 13, 15, 'Pierre_Buyoya'),
#  ('1065-021', 0, 1, 'Hamilton_Academical_F.C.'),
#  ('0997-005', 17, 18, 'Sergey_Yastrzhembsky'),
#  ('0993-003', 30, 32, '--NME--'),
#  ('0991-001', 0, 1, 'Khasavyurt'),
#  ('1099-011', 3, 5, 'Dietmar_Kühbauer'),
#  ('1143-003', 29, 30, 'Greenwich_Mean_Time'),
#  ('1098-001', 0, 1, 'Dublin'),
#  ('1134-007', 20, 21, 'Philippines'),
#  ('1115-010', 1, 2, 'United_States'),
#  ('1030-021', 0, 2, 'Wall_Street'),
#  ('0990-000', 0, 1, 'Boris_Yeltsin'),
#  ('1065-034', 0, 1, 'Montrose_F.C.'),
#  ('1096-031', 13, 15, 'Shawn_Estes'),
#  ('1016-003', 7, 8, 'Jews'),
#  ('0953-000', 2, 3, 'Panama'),
#  ('1090-000', 2, 3, 'Spain'),
#  ('1112-004', 21, 22, 'England'),
#  ('1085-002', 0, 1, 'Belarus_national_football_team'),
#  ('1103-009', 28, 29, 'Turkey_national_football_team'),
#  ('1155-003', 13, 15, 'Der_Spiegel'),
#  ('1156-003', 40, 41, 'Burundi'),
#  ('0998-004', 1, 2, 'Alexander_Lebed'),
#  ('1141-002', 1, 2, 'China'),
#  ('1027-000', 0, 1, 'Israel'),
#  ('1133-008', 0, 1, 'Xiao_Qiang'),
#  ('0971-003', 8, 10, 'Sri_Lanka_national_cricket_team'),
#  ('1027-009', 25, 26, 'Jews'),
#  ('0966-014', 4, 5, 'Portugal'),
#  ('0981-005', 0, 3, '--NME--'),
#  ('1130-003', 6, 8, '--NME--'),
#  ('1115-006', 0, 1, '--NME--'),
#  ('1068-017', 2, 3, 'Peterborough_United_F.C.'),
#  ('0995-000', 0, 1, 'Tajikistan'),
#  ('1009-010', 26, 27, 'Mexico'),
#  ('1066-050', 0, 1, 'Wycombe_Wanderers_F.C.'),
#  ('1056-017', 27, 29, '--NME--'),
#  ('1035-002', 11, 12, 'Germany'),
#  ('0953-012', 25, 30, '--NME--'),
#  ('1008-004', 1, 3, 'United_States_Department_of_Commerce'),
#  ('0957-026', 9, 10, 'Slovakia'),
#  ('1137-002', 0, 2, 'North_Korea'),
#  ('1131-006', 27, 28, 'Cochabamba'),
#  ('0994-014', 0, 1, 'Alexander_Lukashenko'),
#  ('1141-006', 0, 1, 'Wuhan'),
#  ('0978-002', 18, 19, '--NME--'),
#  ('1004-007', 5, 7, '--NME--'),
#  ('1119-006', 0, 1, 'Erbil'),
#  ('0970-004', 0, 1, 'Gianluigi_Lentini'),
#  ('1017-007', 34, 35, 'French_Democratic_Confederation_of_Labour'),
#  ('1068-038', 0, 1, 'Wigan_Athletic_F.C.'),
#  ('0991-011', 8, 9, 'Boris_Yeltsin'),
#  ('0966-055', 1, 3, 'Anthony_Washington'),
#  ('1076-039', 0, 1, 'FK_Sloboda_Tuzla'),
#  ('1148-003', 0, 1, 'Reuters'),
#  ('1091-003', 39, 40, 'Austria'),
#  ('1099-015', 2, 4, 'Herbert_Prohaska'),
#  ('1050-000', 7, 9, '1998_FIFA_World_Cup'),
#  ('1081-000', 2, 3, 'Armenia_national_football_team'),
#  ('0966-064', 4, 5, 'Jamaica'),
#  ('1138-008', 3, 4, '--NME--'),
#  ('1069-015', 6, 7, 'Yorkshire_County_Cricket_Club'),
#  ('0984-016', 34, 35, '--NME--'),
#  ('1022-010', 10, 11, 'Canada'),
#  ('1006-004', 38, 40, 'Pan_American_World_Airways'),
#  ('1037-002', 25, 26, 'Guangdong'),
#  ('1066-056', 0, 1, 'Wigan_Athletic_F.C.'),
#  ('1000-005', 2, 4, '--NME--'),
#  ('1030-032', 10, 11, 'Republican_Party_(United_States)'),
#  ('1138-011', 31, 32, '--NME--'),
#  ('0969-000', 5, 6, 'OGC_Nice'),
#  ('0960-017', 15, 16, 'MaliVai_Washington'),
#  ('1068-014', 3, 6, 'Queens_Park_Rangers_F.C.'),
#  ('1020-008', 1, 3, '--NME--'),
#  ('1066-039', 0, 1, 'Burnley_F.C.'),
#  ('1116-012', 5, 7, 'Henry_Campbell-Bannerman'),
#  ('1094-054', 3, 4, 'Philadelphia_Phillies'),
#  ('1142-006', 20, 21, 'Kurdistan_Democratic_Party'),
#  ('0983-005', 37, 38, 'Iraq'),
#  ('1131-006', 19, 21, 'Latin_America'),
#  ('0956-001', 0, 1, 'Seoul'),
#  ('1120-006', 12, 13, 'London_Stansted_Airport'),
#  ('1089-008', 14, 17, 'United_States_Amateur_Championship_(golf)'),
#  ('1103-015', 35, 38, 'Nico_Van_Kerckhoven'),
#  ('1055-023', 0, 2, '--NME--'),
#  ('1152-014', 23, 25, 'United_States_Air_Force'),
#  ('1150-006', 2, 3, 'Boston'),
#  ('1152-003', 29, 30, 'Iraq'),
#  ('1152-010', 16, 17, 'Iraq'),
#  ('1078-001', 0, 1, 'Belgrade'),
#  ('1043-000', 2, 3, 'Thailand'),
#  ('1068-025', 0, 1, 'Shrewsbury_Town_F.C.'),
#  ('1033-009', 7, 8, 'Russia'),
#  ('1055-006', 4, 6, 'Mushtaq_Ahmad'),
#  ('1152-014', 20, 21, 'USS_Enterprise_(CVN-65)'),
#  ('0959-012', 2, 3, 'Colorado_Rockies'),
#  ('0980-002', 36, 37, 'Chicago'),
#  ('1049-003', 6, 8, 'Mick_McCarthy'),
#  ('1090-011', 6, 8, 'Fed_Cup'),
#  ('1011-003', 22, 23, 'Missouri'),
#  ('0980-015', 5, 6, 'Federal_Reserve'),
#  ('1094-000', 2, 4, 'Major_League_Baseball'),
#  ('0966-139', 4, 5, 'Morocco'),
#  ('1121-007', 32, 33, 'Iraq'),
#  ('1116-032', 10, 11, 'Anglicanism'),
#  ('1056-017', 21, 23, 'Danilo_Hondo'),
#  ('0966-135', 4, 5, 'United_States'),
#  ('0998-001', 0, 1, 'Khasavyurt'),
#  ('1002-003', 32, 35, 'Casa_de_Nariño'),
#  ('1155-002', 13, 14, 'Tehran'),
#  ('1099-017', 40, 42, 'Andi_Herzog'),
#  ('1102-001', 0, 1, 'Paris'),
#  ('1104-002', 22, 24, 'Real_Madrid_CF'),
#  ('1090-017', 5, 6, 'Monica_Seles'),
#  ('0981-006', 7, 8, '--NME--'),
#  ('1051-009', 32, 34, 'Klas_Eriksson'),
#  ('1069-011', 0, 1, 'Derbyshire_County_Cricket_Club'),
#  ('1000-002', 0, 1, 'Budapest'),
#  ('0957-017', 0, 2, 'Amanda_Coetzer'),
#  ('1094-013', 0, 1, 'Cleveland_Indians'),
#  ('1157-004', 17, 18, 'Kurdistan_Democratic_Party'),
#  ('0980-016', 14, 15, 'Federal_Open_Market_Committee'),
#  ('1030-017', 17, 19, '--NME--'),
#  ('1066-015', 0, 1, 'Portsmouth_F.C.'),
#  ('1136-005', 0, 1, 'Tianjin'),
#  ('1027-009', 13, 14, 'Jerusalem'),
#  ('0975-005', 6, 7, 'Transylvania'),
#  ('1144-001', 0, 1, 'Baghdad'),
#  ('0966-035', 1, 3, 'Jon_Drummond'),
#  ('0969-002', 3, 5, 'Dominique_Baratelli'),
#  ('0949-002', 5, 7, 'Alan_Shearer'),
#  ('1061-003', 0, 1, 'Wales'),
#  ('1033-013', 17, 18, 'Flavio_Cotti'),
#  ('0985-007', 10, 11, 'The_Sun_(United_Kingdom)'),
#  ('0972-031', 0, 2, 'U._Chandana'),
#  ('0980-005', 3, 4, 'Japan'),
#  ('1073-000', 6, 8, 'New_Zealand_national_rugby_union_team'),
#  ('1061-007', 0, 1, 'Northampton_Saints'),
#  ('1039-014', 11, 14, '--NME--'),
#  ('1095-007', 2, 3, 'Minnesota_Twins'),
#  ('1129-003', 11, 13, 'Sergiyev_Posad'),
#  ('1055-023', 3, 4, 'Robert_Croft'),
#  ('1127-022', 31, 32, 'God'),
#  ('0948-021', 0, 1, 'Leeds'),
#  ('1075-003', 0, 1, 'Benin_national_football_team'),
#  ('0986-004', 0, 2, '--NME--'),
#  ('1130-005', 62, 64, '--NME--'),
#  ('1010-018', 0, 1, 'Joseph_Bernardin'),
#  ('1072-015', 11, 13, 'New_Zealand_national_rugby_union_team'),
#  ('1130-006', 3, 5, '--NME--'),
#  ('1056-038', 9, 10, 'United_States'),
#  ('0957-024', 6, 8, 'Thomas_Johansson'),
#  ('0957-030', 5, 6, 'United_States'),
#  ('0966-073', 1, 3, 'Gete_Wami'),
#  ('1150-005', 25, 28, '--NME--'),
#  ('1058-035', 3, 4, 'Boston_Red_Sox'),
#  ('0963-000', 2, 3, 'Nolan_Henke'),
#  ('0962-001', 0, 1, 'Milwaukee'),
#  ('1093-001', 0, 2, 'Los_Angeles'),
#  ('0961-005', 7, 8, 'Philadelphia_Eagles'),
#  ('1056-026', 1, 3, 'Tanya_Dubnicoff'),
#  ('1016-003', 0, 1, 'Israel'),
#  ('1076-020', 0, 1, 'FK_Zemun'),
#  ('1124-010', 5, 6, 'Constand_Viljoen'),
#  ('0951-002', 2, 3, 'Lithuania_national_under-21_football_team'),
#  ('1095-010', 2, 3, 'Boston_Red_Sox'),
#  ('0994-007', 5, 6, '--NME--'),
#  ('0978-002', 25, 26, '--NME--'),
#  ('1103-015', 25, 27, 'Geoffrey_Claeys'),
#  ('0976-002', 1, 5, 'National_Bank_of_Poland'),
#  ('0959-013', 0, 1, 'Atlanta_Braves'),
#  ('0978-005', 1, 2, 'Chicago'),
#  ('0985-007', 6, 7, 'Frank_Bruno'),
#  ('0974-007', 29, 31, 'Darren_Lehmann'),
#  ('0966-091', 4, 5, 'United_States'),
#  ('1007-001', 0, 2, '--NME--'),
#  ('1103-009', 10, 12, '--NME--'),
#  ('1088-002', 18, 20, 'Jansher_Khan'),
#  ('1128-013', 18, 19, '--NME--'),
#  ('1131-002', 13, 14, 'Chile'),
#  ('1036-005', 6, 7, 'Russia'),
#  ('1058-017', 0, 2, 'New_York_Yankees'),
#  ('0966-101', 1, 3, 'Donovan_Bailey'),
#  ('1039-015', 32, 33, 'Indonesia'),
#  ('1017-006', 8, 9, '--NME--'),
#  ('0981-007', 30, 32, '--NME--'),
#  ('0985-001', 0, 1, 'London'),
#  ('1046-010', 21, 22, 'Brazil_national_football_team'),
#  ('1072-018', 57, 59, '--NME--'),
#  ('0959-007', 2, 4, 'New_York_Yankees'),
#  ('0966-004', 4, 5, 'Jamaica'),
#  ('1051-006', 1, 3, 'Ian_Woosnam'),
#  ('1094-052', 3, 5, 'New_York_Yankees'),
#  ('0957-015', 11, 12, 'France'),
#  ('0966-005', 1, 3, 'Ludmila_Engquist'),
#  ('0966-093', 1, 3, 'Anja_Rücker'),
#  ('1058-019', 5, 6, 'New_York_Yankees'),
#  ('0983-004', 15, 16, 'Saddam_Hussein'),
#  ('1069-016', 1, 2, 'County_Cricket_Ground,_Hove'),
#  ('1114-002', 0, 1, 'Romania_national_football_team'),
#  ('1061-015', 2, 3, 'Caerphilly_RFC'),
#  ('1007-023', 34, 35, '--NME--'),
#  ('1094-028', 0, 1, 'Cleveland_Indians'),
#  ('1139-008', 20, 21, 'Beijing'),
#  ('1060-001', 0, 1, 'London'),
#  ('1087-017', 14, 16, 'Rodney_Eyles'),
#  ('1032-003', 14, 15, '--NME--'),
#  ('1034-004', 1, 2, 'Netherlands'),
#  ('0972-021', 2, 3, 'Muttiah_Muralitharan'),
#  ('1125-012', 6, 7, 'Hutu'),
#  ('1055-010', 0, 2, '--NME--'),
#  ('1068-029', 0, 2, 'Cambridge_United_F.C.'),
#  ('1053-003', 2, 3, 'England_cricket_team'),
#  ('0946-006', 26, 27, 'Yorkshire_County_Cricket_Club'),
#  ('0996-007', 24, 25, 'United_Nations'),
#  ('1008-006', 4, 5, 'Chicago'),
#  ('1007-012', 2, 3, 'Bob_Dole'),
#  ('1152-012', 15, 16, 'Iraq'),
#  ('0966-072', 4, 5, 'Romania'),
#  ('1090-017', 10, 11, 'Lindsay_Davenport'),
#  ('0981-004', 8, 12, 'New_York_Stock_Exchange'),
#  ('1028-000', 2, 6, '--NME--'),
#  ('1012-004', 5, 6, 'United_States'),
#  ('0979-013', 1, 3, '--NME--'),
#  ('1087-001', 0, 2, 'Hong_Kong'),
#  ('1031-006', 30, 31, 'Malaysia'),
#  ('1056-021', 4, 5, 'Germany'),
#  ('1130-001', 0, 1, 'Havana'),
#  ('1057-001', 2, 3, 'England'),
#  ('1012-007', 15, 16, 'Washington,_D.C.'),
#  ('0972-008', 3, 4, 'Chaminda_Vaas'),
#  ('1076-031', 5, 6, 'FK_Spartak_Subotica'),
#  ('0961-007', 1, 2, 'Randall_Cunningham'),
#  ('0966-010', 1, 3, 'Gillian_Russell'),
#  ('1070-008', 7, 10, '--NME--'),
#  ('0946-013', 24, 25, 'Nottinghamshire_County_Cricket_Club'),
#  ('1095-009', 0, 2, 'New_York_Yankees'),
#  ('1035-008', 0, 1, 'Azerbaijan'),
#  ('1056-046', 10, 11, 'Russia'),
#  ('1155-001', 0, 1, 'Bonn'),
#  ('0948-017', 3, 4, 'Northamptonshire_County_Cricket_Club'),
#  ('1069-016', 8, 9, 'Lancashire_County_Cricket_Club'),
#  ('1083-000', 4, 5, '--NME--'),
#  ('0966-127', 1, 3, 'Alina_Astafei'),
#  ('1148-001', 0, 1, 'Tunis'),
#  ('1101-011', 43, 45, 'Christian_Karembeu'),
#  ('1133-002', 8, 9, 'China'),
#  ('0960-009', 22, 23, 'The_Championships,_Wimbledon'),
#  ('1143-001', 0, 1, 'Jerusalem'),
#  ('1061-001', 0, 1, 'London'),
#  ('1088-000', 2, 5, '--NME--'),
#  ('1115-010', 3, 5, 'Ronald_Reagan'),
#  ('0971-002', 0, 2, 'Sri_Lanka_national_cricket_team'),
#  ('0949-011', 6, 7, 'Alan_Shearer'),
#  ('0959-015', 0, 1, 'Miami_Marlins'),
#  ('0972-028', 0, 2, '--NME--'),
#  ('0948-009', 0, 1, 'England'),
#  ('1118-006', 12, 13, 'England'),
#  ('1072-019', 77, 79, 'Olo_Brown'),
#  ('1127-004', 20, 21, '--NME--'),
#  ('0948-045', 3, 4, 'Kent_County_Cricket_Club'),
#  ('1126-010', 5, 6, 'Mahala'),
#  ('1068-035', 2, 3, 'Rochdale_A.F.C.'),
#  ('1101-012', 0, 1, 'Mexico_national_football_team'),
#  ('1116-026', 13, 15, 'Leopold_III_of_Belgium'),
#  ('1087-018', 14, 15, 'Scotland'),
#  ('0966-009', 1, 3, '--NME--'),
#  ('1022-012', 28, 29, 'Greenwich_Mean_Time'),
#  ('0960-011', 31, 32, '--NME--'),
#  ('1058-014', 0, 1, 'Cleveland_Indians'),
#  ('1025-002', 0, 1, 'Syria'),
#  ('0957-004', 9, 10, 'Argentina'),
#  ('1152-016', 14, 15, 'United_States_Marine_Corps'),
#  ('1055-004', 3, 5, 'Moin_Khan'),
#  ('1053-003', 12, 13, 'Pakistan_national_cricket_team'),
#  ('0948-040', 3, 4, 'Middlesex_County_Cricket_Club'),
#  ('1066-001', 0, 1, 'London'),
#  ('1010-019', 0, 1, 'Joseph_Bernardin'),
#  ('1052-000', 6, 8, '1998_FIFA_World_Cup'),
#  ('1087-004', 4, 5, 'Jansher_Khan'),
#  ('1142-002', 5, 6, '--NME--'),
#  ('1115-005', 1, 3, 'Bernard_Ingham'),
#  ('1058-032', 0, 1, 'Dave_Telgheder'),
#  ('1156-003', 0, 1, 'Julius_Nyerere'),
#  ('1149-012', 25, 26, '--NME--'),
#  ('0966-052', 4, 5, 'Republic_of_Ireland'),
#  ('0966-161', 4, 5, 'Canada'),
#  ('1011-010', 10, 11, '--NME--'),
#  ('0966-097', 4, 5, 'Germany'),
#  ('0957-033', 23, 25, 'Stefan_Edberg'),
#  ('0966-092', 4, 5, 'Nigeria'),
#  ('0966-111', 4, 5, 'Kenya'),
#  ('0962-004', 1, 6, 'Brown_Deer_Park_Golf_Course'),
#  ('1130-006', 6, 7, '--NME--'),
#  ('0957-028', 0, 2, 'Petr_Korda'),
#  ('1059-006', 6, 7, 'Surrey_County_Cricket_Club'),
#  ('1033-005', 22, 23, 'Switzerland'),
#  ('1121-004', 4, 5, 'Iraq'),
#  ('1050-003', 22, 24, 'Ian_Harte'),
#  ('1058-024', 0, 1, 'Baltimore_Orioles'),
#  ('1094-026', 0, 1, 'Chicago_White_Sox'),
#  ('1116-031', 10, 12, 'Cape_Town'),
#  ('1045-002', 23, 25, 'Middle_East'),
#  ('1115-008', 0, 1, '--NME--'),
#  ('0968-003', 1, 5, 'World_Athletics'),
#  ('1125-000', 0, 1, 'Rwanda'),
#  ('1058-002', 0, 2, 'Juan_González_(baseball)'),
#  ('1096-018', 7, 9, 'Los_Angeles_Dodgers'),
#  ('1137-002', 6, 8, 'South_Korea'),
#  ('1143-002', 25, 26, 'Islam'),
#  ('1160-015', 22, 23, 'Julia_Roberts'),
#  ('0948-033', 7, 8, 'Oxford'),
#  ('1118-003', 11, 12, 'Labour_Party_(UK)'),
#  ('1153-006', 8, 10, '--NME--'),
#  ('0958-021', 0, 1, 'Oakland_Athletics'),
#  ('0997-003', 0, 2, '--NME--'),
#  ('0976-001', 0, 1, 'Warsaw'),
#  ('0953-012', 22, 24, 'Puerto_Rico'),
#  ('1106-006', 0, 1, 'Belgium_national_football_team'),
#  ('0949-005', 24, 25, 'Southampton_F.C.'),
#  ('1006-007', 7, 8, '--NME--'),
#  ('1101-005', 13, 14, '--NME--'),
#  ('0958-030', 2, 3, 'Seattle_Mariners'),
#  ('0984-019', 5, 6, 'Norway'),
#  ('1098-002', 12, 13, 'Mexico'),
#  ('1010-000', 0, 1, 'United_States'),
#  ('0966-014', 1, 3, 'Carla_Sacramento'),
#  ('0958-052', 0, 2, 'San_Diego_Padres'),
#  ('1096-006', 22, 23, '--NME--'),
#  ('1131-002', 20, 22, 'United_Nations_Security_Council'),
#  ('1066-076', 0, 1, 'Swansea_City_A.F.C.'),
#  ('1069-006', 3, 4, 'Glamorgan_County_Cricket_Club'),
#  ('0967-005', 7, 8, '--NME--'),
#  ('1109-005', 0, 1, 'Netherlands_national_football_team'),
#  ('1056-016', 8, 10, 'Andrea_Collinelli'),
#  ('1109-005', 2, 5, 'Ronald_de_Boer'),
#  ('1030-031', 0, 2, 'Dick_Morris'),
#  ('1152-004', 29, 30, 'Mediterranean_Sea'),
#  ('1004-003', 10, 12, '--NME--'),
#  ('1090-017', 8, 9, '1996_Summer_Olympics'),
#  ('1125-002', 15, 16, 'Democratic_Republic_of_the_Congo'),
#  ('1011-008', 8, 9, '--NME--'),
#  ('1006-003', 6, 7, '--NME--'),
#  ('1019-000', 6, 7, 'Netherlands'),
#  ('1103-016', 69, 71, 'Saffet_Sancaklı'),
#  ('1041-001', 0, 1, 'Tokyo'),
#  ('1081-002', 10, 11, 'Europe'),
#  ('1127-026', 1, 2, '--NME--'),
#  ('1142-011', 6, 10, 'Patriotic_Union_of_Kurdistan'),
#  ('1078-007', 2, 3, 'Germany'),
#  ('1057-003', 2, 4, 'Adam_Hollioake'),
#  ('0957-004', 3, 4, 'France'),
#  ('1160-004', 14, 16, 'Michael_Collins_(Irish_leader)'),
#  ('1089-026', 30, 31, 'Greg_Kraft'),
#  ('1112-001', 0, 1, 'Bonn'),
#  ('0990-013', 0, 1, 'Boris_Yeltsin'),
#  ('0966-128', 4, 5, 'Russia'),
#  ('1155-010', 7, 8, 'Tehran'),
#  ('1116-006', 9, 10, 'Turin'),
#  ('1076-023', 0, 4, '--NME--'),
#  ('1131-005', 5, 6, 'Uruguay'),
#  ('1152-011', 9, 10, 'Erbil'),
#  ('0984-013', 7, 11, 'Chicago_Board_of_Trade'),
#  ('0951-004', 2, 4, 'Cosmin_Contra'),
#  ('1155-000', 3, 4, 'Germany'),
#  ('1097-012', 35, 37, 'Richard_Krajicek'),
#  ('1155-013', 1, 2, 'Germany'),
#  ('0956-005', 2, 3, '--NME--'),
#  ('0986-000', 2, 3, 'Mick_McCarthy'),
#  ('1099-017', 20, 22, 'Dieter_Ramusch'),
#  ('1061-016', 2, 3, 'Cardiff_RFC'),
#  ('0959-013', 2, 3, 'Pittsburgh_Pirates'),
#  ('1037-002', 0, 1, 'Sweden'),
#  ('0997-002', 14, 15, 'Interfax'),
#  ('1067-018', 0, 1, 'Arbroath_F.C.'),
#  ('1094-047', 0, 1, 'Colorado_Rockies'),
#  ('1130-005', 45, 49, '--NME--'),
#  ('0957-013', 0, 2, 'Jonas_Björkman'),
#  ('1094-001', 0, 2, 'New_York_City'),
#  ('0953-002', 3, 10, '--NME--'),
#  ('0960-007', 29, 30, 'India'),
#  ('0998-002', 0, 1, 'Russia'),
#  ('0992-006', 6, 7, 'Bosnia_and_Herzegovina'),
#  ('1055-038', 5, 6, 'Robert_Croft'),
#  ('1019-009', 0, 1, 'Germany'),
#  ('0966-137', 5, 6, 'Morocco'),
#  ('1146-004', 2, 6, 'Patriotic_Union_of_Kurdistan'),
#  ('1090-005', 15, 16, 'France_Fed_Cup_team'),
#  ('0972-035', 8, 9, 'Muttiah_Muralitharan'),
#  ('1110-002', 1, 3, 'Nate_Miller'),
#  ('1068-037', 0, 1, 'Torquay_United_F.C.'),
#  ('0966-161', 10, 11, 'United_States'),
#  ('1055-022', 5, 6, 'Darren_Gough'),
#  ('1068-012', 2, 3, 'Swindon_Town_F.C.'),
#  ('1011-004', 1, 2, 'NationsBank'),
#  ('1094-009', 0, 1, 'Boston_Red_Sox'),
#  ('1067-008', 2, 4, 'East_Fife_F.C.'),
#  ('0986-006', 8, 9, 'Jason_McAteer'),
#  ('1139-001', 0, 1, 'Beijing'),
#  ('1103-011', 13, 14, 'France'),
#  ('1135-021', 8, 10, 'Insein_Prison'),
#  ('1160-007', 21, 22, 'Neil_Jordan'),
#  ('1102-003', 9, 11, 'Youri_Djorkaeff'),
#  ('1096-041', 1, 2, 'Pittsburgh'),
#  ('0966-049', 1, 3, 'Marko_Koers'),
#  ('1058-021', 1, 3, 'Randy_Velarde'),
#  ('0966-121', 1, 3, 'Jean_Galfione'),
#  ('1083-000', 2, 3, 'Pallacanestro_Treviso'),
#  ('1013-001', 0, 2, 'New_York_City'),
#  ('0974-007', 8, 10, 'Michael_Bevan'),
#  ('1106-000', 2, 3, 'Belgium_national_football_team'),
#  ('1035-008', 10, 11, 'Republic_of_Artsakh'),
#  ('0957-033', 29, 31, 'Bernd_Karbacher'),
#  ('0984-009', 9, 10, 'Paris'),
#  ('1099-008', 1, 2, 'Scotland'),
#  ('1156-002', 9, 10, 'Tanzania'),
#  ('1048-001', 2, 3, 'Israel'),
#  ('0966-097', 1, 3, 'Karin_Janke'),
#  ('1127-009', 34, 35, '--NME--'),
#  ('0966-033', 1, 3, 'Geir_Moen'),
#  ('1160-022', 31, 32, 'United_Kingdom'),
#  ('0953-013', 8, 9, 'Panama'),
#  ('1019-012', 7, 8, 'Germany'),
#  ('1033-010', 18, 19, 'Russia'),
#  ('0948-025', 5, 6, 'Sussex_County_Cricket_Club'),
#  ('1103-016', 0, 1, 'Turkey_national_football_team'),
#  ('0985-002', 16, 17, 'The_Sun_(United_Kingdom)'),
#  ('0957-019', 7, 9, 'Linda_Wild'),
#  ('0980-006', 26, 27, 'France'),
#  ('1096-031', 1, 3, 'New_York_City'),
#  ('1076-014', 0, 1, 'FK_Partizan'),
#  ('0957-015', 8, 10, 'Anne-Gaëlle_Sidot'),
#  ('1063-000', 7, 9, '1998_FIFA_World_Cup'),
#  ('1016-007', 5, 6, 'Israel'),
#  ('1096-042', 8, 9, '--NME--'),
#  ('1096-006', 5, 7, 'John_Boles_(baseball)'),
#  ('1101-007', 20, 21, 'RCD_Espanyol'),
#  ('0985-010', 5, 6, 'United_Kingdom'),
#  ('0983-006', 18, 19, 'Khartoum'),
#  ('1082-002', 2, 3, 'Switzerland_national_football_team'),
#  ('0995-010', 4, 5, 'Afghanistan'),
#  ('1006-014', 19, 20, 'Egypt'),
#  ('1065-032', 0, 1, 'Alloa_Athletic_F.C.'),
#  ('1056-037', 9, 10, 'Latvia'),
#  ('1087-002', 20, 23, '--NME--'),
#  ('0985-009', 13, 14, 'United_States'),
#  ('0995-003', 15, 16, 'Islam'),
#  ('1036-009', 9, 10, 'Arctic'),
#  ('1008-010', 37, 38, '--NME--'),
#  ('0961-004', 6, 7, 'Randall_Cunningham'),
#  ('0987-003', 13, 17, '--NME--'),
#  ('1000-003', 16, 17, 'Budapest_Stock_Exchange'),
#  ('1028-002', 8, 9, '--NME--'),
#  ('1042-007', 10, 11, 'Xinhua_News_Agency'),
#  ('1094-055', 3, 4, 'Montreal_Expos'),
#  ('1005-004', 1, 3, 'Southeast_Asia'),
#  ('1119-007', 5, 6, 'United_States'),
#  ('0949-010', 6, 8, 'Teddy_Sheringham'),
#  ('1068-021', 0, 1, 'Gillingham_F.C.'),
#  ('1133-014', 2, 3, '--NME--'),
#  ('1091-001', 0, 2, 'New_York_City'),
#  ('0962-008', 4, 6, 'Duffy_Waldorf'),
#  ('0966-155', 1, 3, 'Heli_Rantanen'),
#  ('0957-020', 9, 11, 'Pete_Sampras'),
#  ('0966-090', 4, 5, 'Nigeria'),
#  ('1078-002', 3, 6, '--NME--'),
#  ('1154-001', 0, 1, 'Paris'),
#  ('0957-021', 7, 9, 'Lisa_Raymond'),
#  ('0960-019', 3, 4, 'The_Championships,_Wimbledon'),
#  ('1000-016', 5, 7, '--NME--'),
#  ('1070-013', 8, 10, '--NME--'),
#  ('1146-003', 13, 15, 'Masoud_Barzani'),
#  ('1099-018', 11, 13, 'Colin_Calderwood'),
#  ('1096-036', 13, 15, 'Alan_Benes'),
#  ('1045-006', 11, 12, 'Jerusalem'),
#  ('1087-005', 21, 22, '--NME--'),
#  ('1160-023', 18, 20, 'Michael_Collins_(film)'),
#  ('1101-006', 6, 7, 'France_national_football_team'),
#  ('1000-003', 2, 3, '--NME--'),
#  ('1158-003', 26, 27, '--NME--'),
#  ('1036-017', 9, 10, 'Barentsburg'),
#  ('1149-007', 8, 13, '--NME--'),
#  ('1158-002', 17, 18, 'Belgium'),
#  ('1103-001', 0, 2, '--NME--'),
#  ('1149-005', 35, 37, '--NME--'),
#  ('1008-023', 11, 13, 'Federal_Reserve'),
#  ('1126-004', 4, 5, 'Islam'),
#  ('1035-000', 7, 8, 'Germany'),
#  ('1068-013', 4, 5, 'Barnsley_F.C.'),
#  ('1146-005', 35, 37, 'Saddam_Hussein'),
#  ('1128-009', 23, 25, '--NME--'),
#  ('0948-001', 0, 1, 'London'),
#  ('1016-005', 11, 13, 'Benjamin_Netanyahu'),
#  ('0966-103', 1, 3, 'Davidson_Ezinwa'),
#  ('0947-007', 6, 8, '--NME--'),
#  ('1135-027', 6, 7, 'National_League_for_Democracy'),
#  ('1068-016', 0, 1, 'Blackpool_F.C.'),
#  ('1033-010', 10, 11, '--NME--'),
#  ('1087-020', 5, 6, 'Jansher_Khan'),
#  ('1135-026', 0, 2, 'Aung_San_Suu_Kyi'),
#  ('1134-002', 17, 18, 'Organisation_of_Islamic_Cooperation'),
#  ('0974-010', 6, 8, '--NME--'),
#  ('0965-003', 1, 3, 'Dennis_Mitchell'),
#  ('0957-028', 7, 9, 'Bohdan_Ulihrach'),
#  ('1095-002', 2, 4, 'Major_League_Baseball'),
#  ('0957-018', 18, 19, 'Spain'),
#  ('1124-000', 0, 2, '--NME--'),
#  ('1065-010', 0, 1, 'Airdrieonians_F.C.'),
#  ('1015-000', 0, 1, 'RMS_Titanic'),
#  ('1116-009', 6, 7, 'Mikhail_Kutuzov'),
#  ('1056-029', 1, 3, '--NME--'),
#  ('1128-006', 34, 35, 'Poland'),
#  ('1111-005', 5, 7, '--NME--'),
#  ('1128-010', 8, 9, '--NME--'),
#  ('1043-002', 3, 4, 'Thailand'),
#  ('1099-017', 2, 4, 'Michael_Konsel'),
#  ('1059-004', 29, 31, 'Royal_Tunbridge_Wells'),
#  ('0960-019', 23, 25, '--NME--'),
#  ('1083-002', 4, 5, '--NME--'),
#  ('0957-024', 3, 4, 'Germany'),
#  ('1066-060', 0, 1, 'Torquay_United_F.C.'),
#  ('1096-031', 26, 29, 'San_Francisco_Giants'),
#  ('0949-006', 23, 24, 'Glenn_Hoddle'),
#  ('1068-025', 2, 3, '--NME--'),
#  ('1137-003', 7, 9, '--NME--'),
#  ('1057-006', 26, 28, 'Robert_Croft'),
#  ('1155-014', 9, 11, '--NME--'),
#  ('1019-004', 17, 18, 'Netherlands'),
#  ('0966-145', 1, 3, 'Kenny_Harrison'),
#  ('1027-011', 12, 13, 'State_of_Palestine'),
#  ('1152-013', 9, 10, 'Iraq'),
#  ('1076-027', 0, 4, '--NME--'),
#  ('1116-027', 20, 21, 'London'),
#  ('1043-002', 0, 1, 'Singapore'),
#  ('0960-003', 7, 8, '1996_Wimbledon_Championships'),
#  ('1045-003', 18, 19, 'Germany'),
#  ('0948-006', 0, 1, 'Australia_national_cricket_team'),
#  ('0962-011', 6, 8, 'Tiger_Woods'),
#  ('1058-040', 21, 22, 'Milwaukee_Brewers'),
#  ...}

# %% [markdown]
# A naive baseline for entity linking on our data set is to link each mention span to the Wikipedia page name that we get when we join the tokens in the span by underscores, as is standard in Wikipedia page names. Suppose, for example, that a span contains the two tokens
#
#     Jimi Hendrix
#
# The baseline Wikipedia page name for this span would be
#
#     Jimi_Hendrix
#
# Implement this naive baseline and evaluate its performance. Print the evaluation measures that you implemented in Problem&nbsp;1.

# %% [markdown]
# **Here and in the remainder of this lab, you should base your entity predictions on the predicted spans that you computed in Problem&nbsp;3.**

# %%
# TODO: Write code here to implement the baseline
def baseline_predict_mentions(df):
    for row in df.itertuples():
        label = row.sentence.split(" ")[int(row.beg):int(row.end)]
        label = "_".join(label)
        yield row.sentence_id, row.beg, row.end, label
                    
predicted_mentions = set(baseline_predict_mentions(new_df_dev))
evaluation_report(gold_standard_mentions, predicted_mentions)
# Out:
# precission:  0.3035785288270378 , recall:  0.258069967889133 , F1_score:  0.2789805426144149

# %% [markdown]
# ## Problem 5: Extending the training data using the knowledge base

# %% [markdown]
# State-of-the-art approaches to entity linking exploit information in knowledge bases. In our case, where Wikipedia is the knowledge base, one particularly useful type of information are links to other Wikipedia pages. In particular, we can interpret the anchor texts (the highlighted texts that you click on) as mentions of the entities (pages) that they link to. This allows us to harvest long lists of mention–entity pairings.
#
# The following cell loads a data frame summarizing anchor texts and page references harvested from the first paragraphs of the English Wikipedia. The data frame also contains all entity mentions in the training data (but not the development or the test data).

# %%
with bz2.open('kb.tsv.bz2', 'rt') as source:
    df_kb = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# To understand what information is available in this data, the following cell shows the entry for the anchor text `Sweden`.

# %%
df_kb.loc[df_kb.mention == 'Sweden']
# Out:
#       mention                                 entity      prob
# 17436  Sweden                                 Sweden  0.985768
# 17437  Sweden          Sweden_national_football_team  0.014173
# 17438  Sweden  Sweden_men's_national_ice_hockey_team  0.000059

# %% [markdown]
# As you can see, each row of the data frame contains a pair $(m, e)$ of a mention $m$ and an entity $e$, as well as the conditional probability $P(e|m)$ for mention $m$ referring to entity $e$. These probabilities were estimated based on the frequencies of mention–entity pairs in the knowledge base. The example shows that the anchor text &lsquo;Sweden&rsquo; is most often used to refer to the entity [Sweden](http://en.wikipedia.org/wiki/Sweden), but in a few cases also to refer to Sweden&rsquo;s national football and ice hockey teams. Note that references are sorted in decreasing order of probability, so that the most probable pairing come first.
#
# Implement an entity linking method that resolves each mention to the most probable entity in the data frame. If the mention is not included in the data frame, you can predict the generic label `--NME--`. Print the precision, recall, and F1 of your method using the function that you implemented for Problem&nbsp;1.

# %%
# TODO: Write code here to implement the "most probable entity" method.

# %% [markdown]
# ## Problem 6: Context-sensitive disambiguation

# %% [markdown]
# Consider the entity mention &lsquo;Lincoln&rsquo;. The most probable entity for this mention turns out to be [Lincoln, Nebraska](http://en.wikipedia.org/Lincoln,_Nebraska); but in pages about American history, we would be better off to predict [Abraham Lincoln](http://en.wikipedia.org/Abraham_Lincoln). This suggests that we should try to disambiguate between different entity references based on the textual context on the page from which the mention was taken. Your task in this last problem is to implement this idea.
#
# Set up a dictionary that contains, for each mention $m$ that can refer to more than one entity $e$, a separate Naive Bayes classifier that is trained to predict the correct entity $e$, given the textual context of the mention. As the prior probabilities of the classifier, choose the probabilities $P(e|m)$ that you used in Problem&nbsp;5. To let you estimate the context-specific probabilities, we have compiled a data set with mention contexts:

# %%
with bz2.open('contexts.tsv.bz2') as source:
    df_contexts = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# This data frame contains, for each ambiguous mention $m$ and each knowledge base entity $e$ to which this mention can refer, up to 100 randomly selected contexts in which $m$ is used to refer to $e$. For this data, a **context** is defined as the 5 tokens to the left and the 5 tokens to the right of the mention. Here are a few examples:

# %%
df_contexts.head()
# Out:
#           mention                 entity  \
# 0            1970  UEFA_Champions_League
# 1            1970         FIFA_World_Cup
# 2  1990 World Cup    1990_FIFA_World_Cup
# 3  1990 World Cup    1990_FIFA_World_Cup
# 4  1990 World Cup    1990_FIFA_World_Cup
#
#                                              context
# 0    Cup twice the first in @ and the second in 1983
# 1  America 1975 and during the @ and 1978 World C...
# 2                 Manolo represented Spain at the @
# 3  Hašek represented Czechoslovakia at the @ and ...
# 4  renovations in 1989 for the @ The present capa...

# %% [markdown]
# Note that, in each context, the position of the mention is indicated by the `@` symbol.
#
# From this data frame, it is easy to select the data that you need to train the classifiers – the contexts and corresponding entities for all mentions. To illustrate this, the following cell shows how to select all contexts that belong to the mention &lsquo;Lincoln&rsquo;:

# %%
df_contexts.context[df_contexts.mention == 'Lincoln']
# Out:
# 41465    Nebraska Concealed Handgun Permit In @ municip...
# 41466    Lazlo restaurants are located in @ and Omaha C...
# 41467    California Washington Overland Park Kansas @ N...
# 41468    City Missouri Omaha Nebraska and @ Nebraska It...
# 41469    by Sandhills Publishing Company in @ Nebraska USA
#                                ...
# 41609                                      @ Leyton Orient
# 41610                    English division three Swansea @
# 41611    league membership narrowly edging out @ on goa...
# 41612                                          @ Cambridge
# 41613                                                   @
# Name: context, Length: 149, dtype: object

# %% [markdown]
# Implement the context-sensitive disambiguation method and evaluate its performance. Here are some more hints that may help you along the way:
#
# **Hint 1:** The prior probabilities for a Naive Bayes classifier can be specified using the `class_prior` option. You will have to provide the probabilities in the same order as the alphabetically sorted class (entity) names.
#
# **Hint 2:** Not all mentions in the knowledge base are ambiguous, and therefore not all mentions have context data. If a mention has only one possible entity, pick that one. If a mention has no entity at all, predict the `--NME--` label.

# %%
# TODO: Write code here to implement the context-sensitive disambiguation method

# TODO: Write code here to implement the context-sensitive disambiguation method
import math
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer

vectorizer1 = CountVectorizer()
vectorizer1.fit(np.append(df_contexts.context.values,df_contexts.mention.values))

dict_mention = dict()

for m in set(df_contexts.mention):
    contexts=df_contexts[df_contexts.mention==m]['context'].values
    entity=df_contexts[df_contexts.mention==m]['entity'].values
    #complete contexts by replacing the '@' 
    contexts_replace = [x[0].replace('@',x[1]) for x in zip(contexts,entity)]
    #compute prior probabilities
    prior_prob_list=[df_kb.prob[(df_kb.mention == m)&(df_kb.entity==x)].values[0] for x in sorted(set(entity))]
    #vectorize context as input data
    X=vectorizer1.transform(contexts_replace)
    model = MultinomialNB(class_prior=prior_prob_list)
    dict_mention[m]=model.fit(X,entity)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [22], line 9
#       6 from sklearn.feature_extraction.text import CountVectorizer
#       8 vectorizer1 = CountVectorizer()
# ----> 9 vectorizer1.fit(np.append(df_contexts.context.values,df_contexts.mention.values))
#      11 dict_mention = dict()
#      13 for m in set(df_contexts.mention):
#
# NameError: name 'np' is not defined

# %%
# prediction
def predict_cs(df):
    return_list = []
    for row in df.itertuples():
        # extract mentions from sentences
        mention =nlp(row[2])[row[3]:row[4]].text
        if mention in dict_mention.keys():
            context = [nlp(row[2])[row[3]-5:row[4]-5].text]
            #predict using the model stored in dictionary
            entity_pre = dict_mention[mention].predict(vectorizer1.transform(context))[0]
            return_list+=[(row[1],row[3],row[4],entity_pre)]
        
        else:
            # for the mentions which don't have contexts, use entity_link instead
            return_list+=[x for x in entity_link(pd.DataFrame([row[1:]]))]

    return set(return_list)

# %%
evaluation_report(set(gold_mentions(df_dev)), predict_cs(df_dev_pre))

# %% [markdown]
# You should expect to see a small (around 1&nbsp;unit) increase in both precision, recall, and F1.

# %% [markdown]
# ## Reflection questions

# %% [markdown]
# The following reflection questions will help you prepare for the diagnostic test. Answer each of them in the form of a short text and put your answers in the cell below. You will get feedback on your answers from your lab assistant.

# %% [markdown]
# **RQ 5.1:** In Problem&nbsp;3, you did an error analysis on the task of recognizing text spans mentioning named entities. Summarize your results. Pick one type of error that you observed. How could you improve the model&rsquo;s performance on this type of error? What resources (such as domain knowledge, data, compute) would you need to implement this improvement?
#
# **RQ 5.2:** Thinking back about Problem&nbsp;6, explain what the word *context* refers to in the task addressed there, and how context can help to disambiguate between different entities. Suggest other types of context that you could use for disambiguation.
#
# **RQ 5.3:** One type of entity mentions that we did not cover explicitly in this lab are pronouns. As an example, consider the sentence pair *Ruth Bader Ginsburg was an American jurist*. *She served as an associate justice of the Supreme Court from 1993 until her death in 2020*. What facts would you want to extract from this sentence pair? How do pronouns make fact extraction hard?

# %% [markdown]
# *TODO: Enter your answers here*

# %% [markdown]
# **This was the last lab in the Text Mining course. Congratulations! 🥳**
