# %% [markdown]
# # L5: Information extraction

# %% [markdown]
# Information extraction (IE) is the task of identifying named entities and semantic relations between these entities in text data. In this lab we will focus on two sub-tasks in IE, **named entity recognition** (identifying mentions of entities) and **entity linking** (matching these mentions to entities in a knowledge base).

# %% [markdown]
# **Reminder about our [Rules for hand-in assignments](https://www.ida.liu.se/~TDDE16/exam.en.shtml#handins) and the [Policy on cheating and plagiarism](https://www.ida.liu.se/~TDDE16/exam.en.shtml#cheating)**

# %% [markdown]
# We start by loading spaCy:

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# The data that we will be using has been tokenized following the conventions of the [Penn Treebank](ftp://ftp.cis.upenn.edu/pub/treebank/public_html/tokenization.html), and we need to prevent spaCy from using its own tokenizer on top of this. We therefore override spaCy&rsquo;s tokenizer with one that simply splits on space.

# %%
from spacy.tokens import Doc

class WhitespaceTokenizer(object):
    def __init__(self, vocab):
        self.vocab = vocab

    def __call__(self, text):
        return Doc(self.vocab, words=text.split(' '))

nlp.tokenizer = WhitespaceTokenizer(nlp.vocab)

# %% [markdown]
# ## Data set

# %% [markdown]
# The main data set for this lab is a collection of news wire articles in which mentions of named entities have been annotated with page names from the [English Wikipedia](https://en.wikipedia.org/wiki/). The next code cell loads the training and the development parts of the data into Pandas data frames.

# %%
import bz2
import csv
import pandas as pd

with bz2.open('ner-train.tsv.bz2', 'rt') as source:
    df_train = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

with bz2.open('ner-dev.tsv.bz2', 'rt') as source:
    df_dev = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# Each row in these two data frames corresponds to one mention of a named entity and has five columns:
#
# 1. a unique identifier for the sentence containing the entity mention
# 2. the pre-tokenized sentence, with tokens separated by spaces
# 3. the start position of the token span containing the entity mention
# 4. the end position of the token span (exclusive, as in Python list indexing)
# 5. the entity label; either a Wikipedia page name or the generic label `--NME--`
#
# The following cell prints the first five samples from the training data:

# %%
df_train.head()
type(df_train)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# In this sample, we see that the first sentence is annotated with three entity mentions:
#
# * the span 0–1 &lsquo;EU&rsquo; is annotated as a mention but only labelled with the generic `--NME--`
# * the span 2–3 &lsquo;German&rsquo; is annotated with the page [Germany](http://en.wikipedia.org/wiki/Germany)
# * the span 6–7 &lsquo;British&rsquo; is annotated with the page [United_Kingdom](http://en.wikipedia.org/wiki/United_Kingdom)

# %% [markdown]
# ## Problem 1: Evaluation measures

# %% [markdown]
# To warm up, we ask you to write code to print the three measures that you will be using for evaluation:

# %%
def evaluation_report(gold, pred):
    """Print precision, recall, and F1 score.
    
    Args:
        gold: The set with the gold-standard values.
        pred: The set with the predicted values.
    
    Returns:
        Nothing, but prints the precision, recall, and F1 values computed
        based on the specified sets.
    """
    # TODO: Replace the next line with your own code
    TP = len(gold & pred) # intersection
    TN = 0
    FP = len(pred - gold)
    FN = len(gold - pred)

    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    F1_score = (2 * precision * recall) / (precision + recall)
    
    print("precission: ",precision, ", recall: ", recall, ", F1_score: ", F1_score )

# %% [markdown]
# To test your code, you can run the following cell:

# %%
evaluation_report(set(range(3)), set(range(5)))
# Out:
# precission:  0.6 , recall:  1.0 , F1_score:  0.7499999999999999

# %% [markdown]
# This should give you a precision of 60%, a recall of 100%, and an F1-value of 75%.

# %% [markdown]
# ## Problem 2: Span recognition

# %% [markdown]
# One of the first tasks that an information extraction system has to solve is to locate and classify (mentions of) named entities, such as persons and organizations. Here we will tackle the simpler task of recognizing **spans** of tokens that contain an entity mention, without the actual entity label.
#
# The English language model in spaCy features a full-fledged [named entity recognizer](https://spacy.io/usage/linguistic-features#named-entities) that identifies a variety of entities, and can be updated with new entity types by the user. Your task in this problem is to evaluate the performance of this component when predicting entity spans in the development data.
#
# Start by implementing a generator function that yields the gold-standard spans in a given data frame.
#
# **Hint:** The Pandas method [`itertuples()`](https://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.DataFrame.itertuples.html) is useful when iterating over the rows in a DataFrame.

# %%
def gold_spans(df):
    """Yield the gold-standard mention spans in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        triples consisting of the sentence id, start position, and end
        position of each span.
    """
    # TODO: Replace the next line with your own code
    for row in df.itertuples():
        yield row.sentence_id, row.beg, row.end

# %% [markdown]
# To test your code, you can count the spans yielded by your function. When called on the development data, you should get a total of 5,917 unique triples. The first triple and the last triple should be
#
#     ('0946-000', 2, 3)
#     ('1161-010', 1, 3)

# %%
spans_dev_gold = set(gold_spans(df_dev))
print(len(spans_dev_gold))
# Out:
# 5917

# %% [markdown]
# Your next task is to write code that calls spaCy to predict the named entities in the development data, and to evaluate the accuracy of these predictions in terms of precision, recall, and F1. Print these scores using the function that you wrote for Problem&nbsp;1.

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Apple 0 5 ORG
# U.K. 27 31 GPE
# $1 billion 44 54 MONEY

# %%
# TODO: Write code here to run and evaluate the spaCy named entity recognizer on the development data
def spacy_pred(df):
    for row in df.itertuples():
        doc = nlp(row.sentence)
        for ent in doc.ents:
            yield row.sentence_id, ent.start, ent.end

# %%
pred = set(spacy_pred(df_dev))
evaluation_report(gold = spans_dev_gold, pred= pred)
# Out:
# precission:  0.5213954072029113 , recall:  0.702213959776914 , F1_score:  0.5984444764511019

# %%
print(len(spans_dev_gold))
print(len(pred))
# Out:
# 5917
# 7969

# %% [markdown]
# ## Problem 3: Error analysis

# %% [markdown]
# As you were able to see in Problem&nbsp;2, the span accuracy of the named entity recognizer is far from perfect. In particular, only slightly more than half of the predicted spans are correct according to the gold standard. Your next task is to analyse this result in more detail.
#
# Here is a function that prints the false positives as well as the false negatives spans for a data frame, given a reference set of gold-standard spans and a candidate set of predicted spans.

# %%
from collections import defaultdict

def error_report(df, spans_gold, spans_pred):
    false_pos = defaultdict(list)
    for s, b, e in spans_pred - spans_gold:
        false_pos[s].append((b, e))
    false_neg = defaultdict(list)
    for s, b, e in spans_gold - spans_pred:
        false_neg[s].append((b, e))
    for row in df.drop_duplicates('sentence_id').itertuples():
        if row.sentence_id in false_pos or row.sentence_id in false_neg:
            print('Sentence:', row.sentence)
            for b, e in false_pos[row.sentence_id]:
                print('  FP:', ' '.join(row.sentence.split()[b:e]))
            for b, e in false_neg[row.sentence_id]:
                print('  FN:', ' '.join(row.sentence.split()[b:e]))

# %% [markdown]
# Use this function to inspect and analyse the errors that the automated prediction makes. Can you see any patterns? Base your analysis on the first 500 rows of the training data. Summarize your observations in a short text.

# %%
# TODO: Write code here to do your analysis

# %% [markdown]
# *TODO: Write a short text that summarises the errors that you observed*

# %% [markdown]
# Now, use the insights from your error analysis to improve the automated prediction that you implemented in Problem&nbsp;2. While the best way to do this would be to [update spaCy&rsquo;s NER model](https://spacy.io/usage/linguistic-features#updating) using domain-specific training data, for this lab it suffices to write code to post-process the output produced by spaCy. To filter out specific labels it is useful to know the named entity label scheme, which can be found in the [model's documentation](https://spacy.io/models/en#en_core_web_sm). You should be able to improve the F1 score from Problem&nbsp;2 by at last 15 percentage points.

# %%
# TODO: Write code here to run and evaluate the spaCy named entity recognizer on the development data
def spacy_pred(df):
    for row in df.itertuples():
        doc = nlp(row.sentence)
        for ent in doc.ents:
            # if ent.label_ in ['CARDINAL', 'DATE', 'EVENT', 'FAC', 'GPE', 'LANGUAGE', 'LAW', 'LOC', 'MONEY', 'NORP', 'ORDINAL',
            #  'ORG', 'PERCENT', 'PERSON', 'PRODUCT', 'QUANTITY', 'TIME', 'WORK_OF_ART']:
            # here we removed time, date, cardinal, money, ORDINAL
            if ent.label_ not in ['TIME', 'DATE', 'MONEY', 'CARDINAL', 'QUANTITY', 'ORDINAL']:
                yield row.sentence_id, ent.start, ent.end

pred = set(spacy_pred(df_dev))
evaluation_report(gold = spans_dev_gold, pred = pred)
# Out:
# precission:  0.839231547017189 , recall:  0.701368936961298 , F1_score:  0.7641318357576873

# %% [markdown]
# Show that you achieve the performance goal by reporting the evaluation measures that you implemented in Problem&nbsp;1.

# %% [markdown]
# Before going on, we ask you to store the outputs of the improved named entity recognizer on the development data in a new data frame. This new frame should have the same layout as the original data frame for the development data that you loaded above, but should contain the *predicted* start and end positions for each token span, rather than the gold positions. As the `label` of each span, you can use the special value `--NME--`.

# %%
# TODO: Write code here to store the predicted spans in a new data frame

# remove data, keep titles
new_df_dev = df_dev.drop(index=df_dev.index)

#add new row to the end of DataFrame
for id, start, end in pred:
    new_df_dev.loc[len(new_df_dev.index)] = [id, df_dev[df_dev['sentence_id'] == id].iloc[0]['sentence'], start, end, '--NME--']

print(type(new_df_dev))
new_df_dev
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      sentence_id                                           sentence  beg  end  \
# 0       1094-030                             NEW YORK AT CALIFORNIA    0    2
# 1       0994-015  But nationalist groups , scared by the prospec...   10   11
# 2       1058-043  Matt Lawton hit a three-run homer off closer M...   18   19
# 3       0966-045  1. Noureddine Morceli ( Algeria ) 3 minutes 49...    1    3
# 4       1129-002  Three Russian servicemen were killed on Saturd...   19   20
# ...          ...                                                ...  ...  ...
# 4940    1051-009  290 Colin Montgomerie 68 76 77 69 , Robert Col...   25   27
# 4941    1025-005  Palestinian President Yasser Arafat described ...    0    1
# 4942    1090-004  Spain travels to Belgium , while the U.S. team...    3    4
# 4943    0947-011  Chesterfield : Worcestershire 238 and 133-5 , ...   23   26
# 4944    0996-006  Rosati will meet Serbian President Slobodan Mi...   15   16
#
#         label
# 0     --NME--
# 1     --NME--
# 2     --NME--
# 3     --NME--
# 4     --NME--
# ...       ...
# 4940  --NME--
# 4941  --NME--
# 4942  --NME--
# 4943  --NME--
# 4944  --NME--
#
# [4945 rows x 5 columns]

# %%
list_to_df = []
for s_id, start, end in pred:
    list_to_df.append([s_id, df_dev[df_dev['sentence_id'] == s_id].iloc[0]['sentence'], start, end, '--NME--'])
    
new_df_dev = pd.DataFrame(list_to_df, columns = df_dev.columns)
new_df_dev
# Out:
#      sentence_id                                           sentence  beg  end  \
# 0       1094-030                             NEW YORK AT CALIFORNIA    0    2
# 1       0994-015  But nationalist groups , scared by the prospec...   10   11
# 2       1058-043  Matt Lawton hit a three-run homer off closer M...   18   19
# 3       0966-045  1. Noureddine Morceli ( Algeria ) 3 minutes 49...    1    3
# 4       1129-002  Three Russian servicemen were killed on Saturd...   19   20
# ...          ...                                                ...  ...  ...
# 4940    1051-009  290 Colin Montgomerie 68 76 77 69 , Robert Col...   25   27
# 4941    1025-005  Palestinian President Yasser Arafat described ...    0    1
# 4942    1090-004  Spain travels to Belgium , while the U.S. team...    3    4
# 4943    0947-011  Chesterfield : Worcestershire 238 and 133-5 , ...   23   26
# 4944    0996-006  Rosati will meet Serbian President Slobodan Mi...   15   16
#
#         label
# 0     --NME--
# 1     --NME--
# 2     --NME--
# 3     --NME--
# 4     --NME--
# ...       ...
# 4940  --NME--
# 4941  --NME--
# 4942  --NME--
# 4943  --NME--
# 4944  --NME--
#
# [4945 rows x 5 columns]

# %% [markdown]
# ## Problem 4: Entity linking

# %% [markdown]
# Now that we have a method for predicting mention spans, we turn to the task of **entity linking**, which amounts to predicting the knowledge base entity that is referenced by a given mention. In our case, for each span we want to predict the Wikipedia page that this mention references.
#
# Start by extending the generator function that you implemented in Problem&nbsp;2 to labelled spans.

# %%
def gold_mentions(df):
    """Yield the gold-standard mentions in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        quadruples consisting of the sentence id, start position, end
        position and entity label of each span.
    """
    # TODO: Replace the next line with your own code
    # --just add one more label column
    for row in df.itertuples():
        yield row.sentence_id, row.beg, row.end, row.label

gold_standard_mentions = set(gold_mentions(df_dev))
gold_standard_mentions
# Out:
# {('1130-005', 20, 22, '--NME--'),
#  ('1046-007', 13, 14, 'Real_Madrid_CF'),
#  ('1115-002', 4, 6, 'Margaret_Thatcher'),
#  ('0947-008', 12, 14, '--NME--'),
#  ('1056-026', 1, 3, 'Tanya_Dubnicoff'),
#  ('0952-004', 12, 14, 'UEFA_Europa_League'),
#  ('0972-023', 0, 2, 'Sri_Lanka_national_cricket_team'),
#  ('0950-001', 0, 1, 'Belgrade'),
#  ('1090-015', 0, 1, 'Mary_Joe_Fernández'),
#  ('1066-007', 0, 1, 'Barnsley_F.C.'),
#  ('0958-050', 0, 1, 'Atlanta_Braves'),
#  ('0997-004', 22, 23, 'Boris_Yeltsin'),
#  ('1076-007', 0, 1, 'FK_Borac_Čačak'),
#  ('0957-010', 11, 12, 'Spain'),
#  ('1102-000', 2, 3, 'France_national_football_team'),
#  ('1011-006', 0, 2, '--NME--'),
#  ('1097-015', 0, 1, 'Stefan_Edberg'),
#  ('0981-006', 8, 9, 'Magna_International'),
#  ('1135-006', 26, 27, 'National_League_for_Democracy'),
#  ('0960-004', 8, 9, 'The_Championships,_Wimbledon'),
#  ('1141-001', 0, 1, 'Beijing'),
#  ('1152-005', 6, 9, 'United_States_Department_of_Defense'),
#  ('1031-005', 15, 16, 'Wuxi'),
#  ('0957-030', 2, 4, 'Monica_Seles'),
#  ('1156-002', 9, 10, 'Tanzania'),
#  ('1047-001', 2, 3, 'England'),
#  ('1031-013', 30, 32, '--NME--'),
#  ('1095-016', 3, 4, 'Montreal_Expos'),
#  ('0960-028', 0, 1, 'Marcelo_Ríos'),
#  ('1115-008', 24, 25, '--NME--'),
#  ('0947-006', 7, 9, '--NME--'),
#  ('1013-006', 1, 5, '--NME--'),
#  ('1099-011', 0, 2, '--NME--'),
#  ('1075-002', 4, 5, 'Benin_national_football_team'),
#  ('0994-005', 13, 14, 'Alexander_Lukashenko'),
#  ('1073-007', 11, 13, 'Justin_Marshall'),
#  ('1015-003', 26, 27, 'Canada'),
#  ('1017-003', 10, 11, '--NME--'),
#  ('1054-008', 6, 7, 'Team_Jumbo–Visma'),
#  ('0966-157', 4, 5, 'Cuba'),
#  ('1159-000', 7, 8, 'Belgium'),
#  ('1044-004', 3, 4, 'Israel'),
#  ('1065-011', 0, 1, 'Falkirk_F.C.'),
#  ('1056-021', 4, 5, 'Germany'),
#  ('1103-015', 15, 17, 'Dirk_Medved'),
#  ('0982-001', 0, 1, 'London'),
#  ('1155-011', 6, 7, 'Abolhassan_Banisadr'),
#  ('1160-011', 25, 26, 'Israel'),
#  ('1116-031', 10, 12, 'Cape_Town'),
#  ('1027-025', 24, 26, '--NME--'),
#  ('1048-000', 2, 3, 'Israel_national_football_team'),
#  ('1134-005', 0, 1, 'Jakarta'),
#  ('1135-002', 0, 1, 'Yangon'),
#  ('1064-003', 17, 18, 'Saracens_F.C.'),
#  ('0958-020', 0, 1, 'Seattle_Mariners'),
#  ('1060-003', 4, 6, 'British_Masters'),
#  ('1046-001', 0, 2, 'A_Coruña'),
#  ('0986-000', 7, 8, 'Liechtenstein_national_football_team'),
#  ('1131-002', 1, 2, 'United_States'),
#  ('1039-011', 20, 21, 'Philippines'),
#  ('1055-028', 5, 6, 'Adam_Hollioake'),
#  ('1076-039', 0, 1, 'FK_Sloboda_Tuzla'),
#  ('1057-003', 11, 12, 'Lancashire_County_Cricket_Club'),
#  ('1055-018', 6, 8, 'Waqar_Younis'),
#  ('1030-039', 2, 3, 'London'),
#  ('1096-036', 13, 15, 'Alan_Benes'),
#  ('1080-000', 2, 3, 'Romania_national_football_team'),
#  ('1116-006', 20, 21, 'France'),
#  ('1127-009', 34, 35, '--NME--'),
#  ('0994-015', 17, 18, 'Alexander_Lukashenko'),
#  ('0966-054', 4, 5, 'Germany'),
#  ('1076-024', 0, 1, 'FK_Borac_Čačak'),
#  ('0966-111', 1, 3, '--NME--'),
#  ('0981-005', 0, 3, '--NME--'),
#  ('0966-004', 1, 3, 'Michelle_Freeman'),
#  ('1068-013', 6, 8, 'Manchester_City_F.C.'),
#  ('1012-006', 1, 4, 'United_States_Department_of_the_Treasury'),
#  ('0986-002', 16, 18, '1998_FIFA_World_Cup'),
#  ('0966-013', 1, 3, '--NME--'),
#  ('0981-006', 24, 27, 'Johnson_Controls'),
#  ('1025-003', 4, 5, 'Israel'),
#  ('1032-006', 21, 22, '--NME--'),
#  ('1072-015', 11, 13, 'New_Zealand_national_rugby_union_team'),
#  ('0958-008', 0, 1, 'Baltimore_Orioles'),
#  ('1027-012', 3, 4, 'State_of_Palestine'),
#  ('1054-010', 4, 5, 'Russia'),
#  ('0946-011', 14, 15, 'Worcestershire_County_Cricket_Club'),
#  ('1096-022', 1, 2, 'Atlanta_Braves'),
#  ('1061-006', 0, 2, 'London_Irish'),
#  ('1097-004', 21, 22, 'Germany'),
#  ('0990-007', 28, 29, 'Chechnya'),
#  ('1096-014', 0, 2, 'Los_Angeles_Dodgers'),
#  ('1098-002', 2, 4, 'Naseem_Hamed'),
#  ('1104-002', 12, 14, '--NME--'),
#  ('0970-006', 4, 5, 'Atalanta_B.C.'),
#  ('0972-011', 5, 6, 'Upul_Chandana'),
#  ('0952-006', 8, 10, 'FC_Dynamo_Moscow'),
#  ('0994-007', 5, 6, '--NME--'),
#  ('0961-008', 24, 25, 'Philadelphia'),
#  ('0956-016', 0, 1, 'Hanwha_Eagles'),
#  ('1047-002', 2, 3, 'England'),
#  ('1124-009', 19, 20, 'Afrikaners'),
#  ('0966-022', 1, 3, 'Tony_Jarrett'),
#  ('0983-006', 7, 8, '--NME--'),
#  ('0957-009', 0, 2, 'Sjeng_Schalken'),
#  ('0966-068', 4, 5, 'The_Bahamas'),
#  ('1007-018', 15, 17, 'New_York_Stock_Exchange'),
#  ('1069-011', 4, 5, 'Worcestershire_County_Cricket_Club'),
#  ('1046-002', 6, 8, 'Roberto_Carlos'),
#  ('1146-002', 10, 11, 'Iraq'),
#  ('0963-018', 0, 1, 'Bob_Estes'),
#  ('0966-015', 1, 3, 'Yekaterina_Podkopayeva'),
#  ('1010-020', 0, 1, 'Joseph_Bernardin'),
#  ('1126-009', 9, 10, 'Serbia'),
#  ('1137-001', 0, 1, 'Seoul'),
#  ('1096-013', 34, 35, 'Philadelphia_Phillies'),
#  ('0986-002', 0, 1, 'Republic_of_Ireland'),
#  ('1092-004', 7, 9, '--NME--'),
#  ('1078-007', 2, 3, 'Germany'),
#  ('1016-015', 12, 14, 'Shimon_Peres'),
#  ('1089-000', 2, 3, 'Jesper_Parnevik'),
#  ('1124-000', 0, 2, '--NME--'),
#  ('0967-007', 11, 13, 'UEFA_Europa_League'),
#  ('1043-000', 0, 1, 'Singapore'),
#  ('1054-013', 1, 3, 'Michael_Andersson'),
#  ('0991-003', 24, 25, 'Alexander_Lebed'),
#  ('1068-029', 3, 4, 'Cardiff_City_F.C.'),
#  ('1160-015', 3, 5, 'Harry_Boland'),
#  ('1067-007', 0, 1, 'Stirling_Albion_F.C.'),
#  ('1016-002', 6, 7, 'State_of_Palestine'),
#  ('1047-003', 0, 1, 'Wigan_Warriors'),
#  ('1055-028', 3, 4, 'Nick_Knight'),
#  ('1067-014', 0, 1, 'Livingston_F.C.'),
#  ('1025-009', 18, 19, 'Israel'),
#  ('0962-009', 13, 15, 'Willie_Wood_(golfer)'),
#  ('0981-017', 5, 6, '--NME--'),
#  ('1020-001', 0, 1, 'Mumbai'),
#  ('1058-042', 0, 2, 'Bob_Wickman'),
#  ('1008-013', 1, 3, 'Dow_Jones_Industrial_Average'),
#  ('0981-006', 7, 8, '--NME--'),
#  ('1123-011', 0, 1, '--NME--'),
#  ('1160-005', 6, 7, 'United_Kingdom'),
#  ('1126-002', 21, 22, 'Serbia'),
#  ('1142-002', 7, 8, 'Iraq'),
#  ('0966-111', 4, 5, 'Kenya'),
#  ('1137-000', 0, 2, 'North_Korea'),
#  ('1011-012', 12, 13, '--NME--'),
#  ('1010-002', 0, 1, 'Chicago'),
#  ('1103-020', 15, 16, 'Russia_national_football_team'),
#  ('1000-005', 2, 4, '--NME--'),
#  ('0957-006', 5, 6, 'Croatia'),
#  ('1027-007', 0, 1, 'State_of_Palestine'),
#  ('1114-002', 0, 1, 'Romania_national_football_team'),
#  ('1132-007', 10, 13, 'Popular_Revolutionary_Army'),
#  ('1015-003', 38, 40, '--NME--'),
#  ('0948-046', 9, 10, 'London'),
#  ('0991-008', 21, 22, 'Chechnya'),
#  ('1009-012', 27, 28, 'United_States'),
#  ('1096-040', 0, 2, 'Eric_Anthony'),
#  ('1131-003', 5, 8, 'José_Miguel_Insulza'),
#  ('1065-017', 0, 1, 'Livingston_F.C.'),
#  ('0972-038', 2, 3, 'Michael_Bevan'),
#  ('0966-036', 4, 5, 'Denmark'),
#  ('1009-007', 16, 17, 'Mexico'),
#  ('1061-010', 2, 3, 'Leicester_Tigers'),
#  ('0976-005', 1, 3, '--NME--'),
#  ('1009-018', 31, 32, 'California'),
#  ('1058-028', 0, 1, 'Frank_Thomas_(designated_hitter)'),
#  ('1067-008', 7, 9, 'St_Johnstone_F.C.'),
#  ('1018-001', 0, 1, 'Berlin'),
#  ('1004-007', 15, 17, '--NME--'),
#  ('1120-005', 12, 13, 'Khartoum'),
#  ('1060-014', 1, 3, 'Paul_Lawrie'),
#  ('1124-003', 18, 19, 'Afrikaners'),
#  ('1066-024', 0, 2, 'West_Bromwich_Albion_F.C.'),
#  ('1143-003', 14, 15, 'Syria'),
#  ('1031-008', 15, 16, 'China'),
#  ('1072-001', 0, 2, '--NME--'),
#  ('0965-003', 17, 18, '--NME--'),
#  ('0954-001', 0, 2, 'Hong_Kong'),
#  ('1016-009', 3, 4, 'Bonn'),
#  ('0958-031', 0, 4, 'National_League_East'),
#  ('1155-015', 8, 9, 'Germany'),
#  ('0948-015', 4, 6, '--NME--'),
#  ('1061-020', 2, 3, 'Watsonian_FC'),
#  ('0983-006', 18, 19, 'Khartoum'),
#  ('1115-003', 14, 15, 'Margaret_Thatcher'),
#  ('1062-000', 7, 9, '1998_FIFA_World_Cup'),
#  ('1097-008', 17, 18, 'Bernd_Karbacher'),
#  ('0954-004', 10, 12, 'Chris_Walker_(squash_player)'),
#  ('1091-004', 17, 18, 'Ecuador'),
#  ('1072-018', 103, 105, 'Garry_Pagel'),
#  ('0966-153', 4, 5, 'Norway'),
#  ('0970-006', 24, 25, 'Torino_F.C.'),
#  ('1096-041', 13, 15, 'Donne_Wall'),
#  ('0997-005', 19, 20, 'Boris_Yeltsin'),
#  ('0966-065', 4, 5, 'United_States'),
#  ('0985-011', 13, 14, 'Mike_Tyson'),
#  ('1036-019', 3, 5, '--NME--'),
#  ('1045-002', 8, 9, 'Israel'),
#  ('1081-002', 2, 3, 'Portugal_national_football_team'),
#  ('1133-008', 14, 15, 'China'),
#  ('0966-034', 1, 3, 'Patrick_Stevens'),
#  ('1135-026', 0, 2, 'Aung_San_Suu_Kyi'),
#  ('1054-005', 6, 7, '--NME--'),
#  ('1058-013', 0, 2, 'Brian_Giles'),
#  ('1088-000', 2, 5, '--NME--'),
#  ('1014-008', 1, 3, 'Governor_of_South_Carolina'),
#  ('0986-004', 0, 2, '--NME--'),
#  ('1096-003', 9, 10, 'St._Louis_Cardinals'),
#  ('1056-046', 10, 11, 'Russia'),
#  ('1125-003', 12, 13, 'Republican_Rally_for_Democracy_in_Rwanda'),
#  ('1111-004', 1, 3, '--NME--'),
#  ('1033-008', 9, 11, 'Aslan_Maskhadov'),
#  ('1064-007', 32, 33, 'Bath_Rugby'),
#  ('1146-006', 49, 50, 'Jalal_Talabani'),
#  ('0963-023', 0, 2, 'Phil_Mickelson'),
#  ('0966-120', 4, 5, 'Kazakhstan'),
#  ('1022-018', 1, 3, '--NME--'),
#  ('1121-002', 14, 15, 'Iraq'),
#  ('1056-034', 21, 23, 'Philippe_Ermenault'),
#  ('0953-000', 2, 3, 'Panama'),
#  ('0957-013', 6, 8, '--NME--'),
#  ('1032-000', 6, 7, '--NME--'),
#  ('1033-010', 6, 7, 'Chechnya'),
#  ('1090-002', 0, 2, 'New_York_City'),
#  ('1072-013', 3, 4, '--NME--'),
#  ('1096-023', 2, 4, 'José_Hernández_(baseball)'),
#  ('0966-091', 1, 3, 'Jearl_Miles_Clark'),
#  ('0962-011', 6, 8, 'Tiger_Woods'),
#  ('1094-055', 3, 4, 'Montreal_Expos'),
#  ('1068-038', 0, 1, 'Wigan_Athletic_F.C.'),
#  ('1011-012', 21, 22, '--NME--'),
#  ('1035-003', 20, 22, '--NME--'),
#  ('1121-004', 8, 9, 'Greenwich_Mean_Time'),
#  ('1072-008', 12, 14, 'Walter_Little_(rugby_player)'),
#  ('0964-000', 2, 3, 'Mário_Silva'),
#  ('1076-014', 0, 1, 'FK_Partizan'),
#  ('1027-009', 13, 14, 'Jerusalem'),
#  ('0957-015', 8, 10, 'Anne-Gaëlle_Sidot'),
#  ('1097-012', 31, 32, 'The_Championships,_Wimbledon'),
#  ('0986-006', 6, 7, 'Denis_Irwin'),
#  ('0966-057', 1, 3, 'Vladimir_Dubrovshchik'),
#  ('0974-004', 5, 6, '--NME--'),
#  ('1072-013', 11, 13, 'Sean_Fitzpatrick'),
#  ('0991-009', 10, 11, 'Chechnya'),
#  ('1117-004', 7, 8, 'Netherlands'),
#  ('1154-006', 26, 27, 'Algeria'),
#  ('1009-011', 0, 1, 'Mexico'),
#  ('1130-006', 6, 7, '--NME--'),
#  ('1066-044', 0, 1, 'Preston_North_End_F.C.'),
#  ('1070-009', 7, 9, '--NME--'),
#  ('0995-007', 12, 13, 'Dushanbe'),
#  ('1091-003', 23, 25, 'Martina_Hingis'),
#  ('1094-045', 0, 2, 'San_Diego_Padres'),
#  ('1096-002', 10, 12, 'Devon_White_(baseball)'),
#  ('1046-000', 2, 3, 'Real_Madrid_CF'),
#  ('1151-001', 0, 1, 'Dallas'),
#  ('1138-002', 0, 1, 'China'),
#  ('1114-004', 8, 10, 'Mihai_Tararache'),
#  ('0958-056', 0, 1, 'Colorado_Rockies'),
#  ('1030-016', 7, 8, 'United_States_Department_of_the_Treasury'),
#  ('1057-006', 20, 22, 'Adam_Hollioake'),
#  ('1035-008', 0, 1, 'Azerbaijan'),
#  ('1065-032', 0, 1, 'Alloa_Athletic_F.C.'),
#  ('0951-002', 2, 3, 'Lithuania_national_under-21_football_team'),
#  ('1028-011', 3, 6, 'Michigan_National_Bank'),
#  ('0962-010', 16, 18, 'Tim_Simpson'),
#  ('1134-002', 9, 10, 'Suharto'),
#  ('1094-031', 0, 4, 'National_League_East'),
#  ('1097-003', 8, 10, 'Stefan_Edberg'),
#  ('1056-018', 0, 1, 'Germany'),
#  ('0999-000', 0, 1, 'Russia'),
#  ('0946-010', 13, 14, 'Surrey_County_Cricket_Club'),
#  ('1094-052', 3, 5, 'New_York_Yankees'),
#  ('1064-003', 0, 1, 'Michael_Lynagh'),
#  ('0947-008', 2, 4, 'The_Oval'),
#  ('1096-019', 1, 2, 'Chicago'),
#  ('0984-008', 0, 1, 'France'),
#  ('0980-005', 3, 4, 'Japan'),
#  ('1032-005', 25, 26, 'Reuters'),
#  ('1020-000', 0, 1, 'India'),
#  ('0962-010', 10, 12, 'Ken_Green_(golfer)'),
#  ('0953-002', 0, 1, 'Panama'),
#  ('0959-015', 2, 4, '--NME--'),
#  ('1072-018', 15, 17, 'Japie_Mulder'),
#  ('1101-012', 88, 90, 'Francisco_Palencia'),
#  ('1039-010', 3, 6, 'House_of_Representatives'),
#  ('0958-054', 2, 3, 'Pittsburgh_Pirates'),
#  ('0966-076', 1, 3, 'Tegla_Loroupe'),
#  ('1049-003', 22, 23, 'Norwich_City_F.C.'),
#  ('0996-003', 30, 32, 'Ministry_of_Foreign_Affairs_(Poland)'),
#  ('1016-013', 10, 12, 'Volker_Rühe'),
#  ('0966-049', 1, 3, 'Marko_Koers'),
#  ('1101-012', 21, 23, 'Claudio_Suárez'),
#  ('1056-039', 6, 8, 'Frédéric_Magné'),
#  ('0970-002', 4, 6, 'Gianluigi_Lentini'),
#  ('0972-037', 0, 1, '--NME--'),
#  ('0946-007', 5, 6, 'England_cricket_team'),
#  ('1037-003', 16, 17, '--NME--'),
#  ('1032-007', 2, 3, 'Netherlands'),
#  ('0966-069', 1, 3, 'Irina_Privalova'),
#  ('1058-001', 0, 1, 'Arlington,_Texas'),
#  ('0974-003', 4, 6, 'Sri_Lanka_national_cricket_team'),
#  ('0946-003', 35, 36, 'Nottinghamshire_County_Cricket_Club'),
#  ('1004-007', 0, 1, 'Norodom_Sihanouk'),
#  ('0962-000', 5, 8, '--NME--'),
#  ('1038-008', 1, 2, 'Wellington'),
#  ('1058-039', 0, 2, 'Kansas_City_Royals'),
#  ('1161-007', 10, 12, '--NME--'),
#  ('0960-006', 5, 6, '--NME--'),
#  ('1037-002', 0, 1, 'Sweden'),
#  ('1039-013', 0, 2, 'Media_Indonesia'),
#  ('0970-002', 9, 10, 'A.C._Milan'),
#  ('1152-005', 32, 33, 'The_Pentagon'),
#  ('1111-004', 8, 10, '--NME--'),
#  ('0981-011', 0, 3, '--NME--'),
#  ('1054-006', 4, 5, 'Italy'),
#  ('0958-014', 0, 1, 'Chicago_White_Sox'),
#  ('0958-055', 0, 2, 'San_Francisco_Giants'),
#  ('1125-006', 32, 33, 'Goma'),
#  ('1059-002', 30, 31, 'England'),
#  ('1008-029', 50, 51, 'Federal_Reserve'),
#  ('1149-005', 31, 33, 'Interstate_95'),
#  ('0985-012', 0, 1, 'Frank_Bruno'),
#  ('0960-003', 12, 14, 'Marcelo_Ríos'),
#  ('0966-008', 4, 5, 'Jamaica'),
#  ('1056-010', 4, 5, 'Russia'),
#  ('1089-002', 0, 2, 'Jesper_Parnevik'),
#  ('1103-015', 71, 73, 'Luís_Oliveira'),
#  ('0966-161', 7, 9, 'Michael_Johnson_(sprinter)'),
#  ('1036-011', 22, 23, 'Reuters'),
#  ('1103-016', 73, 75, 'Orhan_Çıkırıkçı'),
#  ('1077-004', 18, 20, 'Inter_Milan'),
#  ('1118-001', 0, 1, 'Stirling'),
#  ('1114-000', 4, 5, 'Lithuania_national_football_team'),
#  ('1128-003', 10, 11, '--NME--'),
#  ('1016-005', 3, 5, 'Yasser_Arafat'),
#  ('1027-016', 12, 13, 'Al-Ram'),
#  ('1096-013', 20, 22, 'Chad_Curtis'),
#  ('1143-007', 26, 27, 'Lebanon'),
#  ('1128-004', 17, 18, '--NME--'),
#  ('1025-006', 16, 17, 'Israel'),
#  ('0965-013', 7, 9, 'Gail_Devers'),
#  ('0966-002', 4, 7, '--NME--'),
#  ('1101-002', 6, 8, 'Youri_Djorkaeff'),
#  ('0947-008', 22, 24, '--NME--'),
#  ('0957-033', 12, 13, 'United_States'),
#  ('0978-005', 1, 2, 'Chicago'),
#  ('1014-002', 27, 28, 'Bill_Clinton'),
#  ('1045-002', 0, 2, 'United_Nations_Security_Council'),
#  ('0986-006', 12, 13, 'Alan_McLoughlin'),
#  ('1066-039', 0, 1, 'Burnley_F.C.'),
#  ('1137-006', 10, 11, 'Korea'),
#  ('1129-002', 1, 2, 'Russia'),
#  ('0957-012', 0, 2, 'Alexander_Volkov_(tennis)'),
#  ('1051-003', 4, 5, 'Australia'),
#  ('1096-043', 0, 1, 'Donne_Wall'),
#  ('1108-005', 0, 1, 'Nate_Miller'),
#  ('1128-003', 17, 18, 'Poland'),
#  ('1094-056', 0, 1, 'Colorado_Rockies'),
#  ('0958-052', 3, 4, 'Montreal_Expos'),
#  ('0963-003', 15, 17, 'Duffy_Waldorf'),
#  ('1027-014', 15, 16, 'Al-Aqsa_Mosque'),
#  ('0966-014', 4, 5, 'Portugal'),
#  ('0966-059', 1, 3, 'Jürgen_Schult'),
#  ('1000-003', 12, 15, 'Budapest_Stock_Exchange'),
#  ('0957-020', 9, 11, 'Pete_Sampras'),
#  ('1052-005', 8, 10, 'Peter_Dubovský'),
#  ('1062-002', 0, 1, 'Wales_national_football_team'),
#  ('1054-014', 6, 7, 'Cycle_Collstrop'),
#  ('1146-000', 2, 3, 'Tariq_Aziz'),
#  ('0960-028', 4, 5, 'Jeff_Tarango'),
#  ('1076-000', 2, 3, 'Yugoslavia'),
#  ('1058-026', 10, 12, 'American_League'),
#  ('1030-032', 10, 11, 'Republican_Party_(United_States)'),
#  ('1103-003', 22, 23, '--NME--'),
#  ('1006-007', 34, 35, 'Muammar_Gaddafi'),
#  ('0989-002', 6, 8, '--NME--'),
#  ('1011-006', 26, 27, 'Missouri'),
#  ('0960-009', 22, 23, 'The_Championships,_Wimbledon'),
#  ('1009-020', 14, 15, '--NME--'),
#  ('1094-024', 0, 2, 'Kansas_City_Royals'),
#  ('1143-008', 2, 3, 'Israel'),
#  ('1011-009', 0, 4, '--NME--'),
#  ('0984-017', 0, 1, '--NME--'),
#  ('1069-001', 0, 1, 'London'),
#  ('1142-009', 28, 29, 'Erbil'),
#  ('1160-001', 0, 2, '--NME--'),
#  ('1018-002', 0, 1, 'Germany'),
#  ('1038-003', 11, 13, '--NME--'),
#  ('1113-004', 0, 1, 'Karlsruher_SC'),
#  ('0954-003', 0, 2, '--NME--'),
#  ('0956-009', 0, 1, 'Hanwha_Eagles'),
#  ('1137-006', 0, 1, '--NME--'),
#  ('1090-004', 12, 13, 'Netherlands_Fed_Cup_team'),
#  ('1064-007', 40, 41, 'Northampton_Saints'),
#  ('0996-000', 5, 6, 'Yugoslavia'),
#  ('1066-047', 0, 2, 'Notts_County_F.C.'),
#  ('1016-010', 8, 10, 'David_Levy_(Israeli_politician)'),
#  ('0966-164', 1, 3, '--NME--'),
#  ('0946-014', 12, 13, '--NME--'),
#  ('1012-002', 1, 3, 'United_States_Department_of_State'),
#  ('1155-002', 9, 10, 'Germany'),
#  ('1066-067', 0, 1, 'Barnet_F.C.'),
#  ('0966-084', 1, 3, 'Fabrizio_Mori'),
#  ('1116-037', 9, 10, 'Belarus'),
#  ('0972-010', 0, 2, '--NME--'),
#  ('1010-019', 8, 9, 'HIV/AIDS'),
#  ('1011-002', 0, 1, 'Chicago'),
#  ('1152-013', 9, 10, 'Iraq'),
#  ('1055-023', 5, 6, 'Darren_Gough'),
#  ('0958-045', 0, 2, 'San_Diego_Padres'),
#  ('0966-088', 4, 5, 'Hungary'),
#  ('1071-000', 2, 3, '--NME--'),
#  ('1022-010', 29, 32, '--NME--'),
#  ('1069-011', 0, 1, 'Derbyshire_County_Cricket_Club'),
#  ('0949-011', 6, 7, 'Alan_Shearer'),
#  ('1035-000', 2, 3, 'Azerbaijan'),
#  ('1152-008', 19, 20, 'Tennessee'),
#  ('1160-000', 5, 6, 'Venice'),
#  ('1097-011', 0, 1, 'Stefan_Edberg'),
#  ('1140-005', 8, 9, 'China'),
#  ('1039-011', 24, 28, 'Moro_National_Liberation_Front'),
#  ('0966-010', 4, 5, 'Jamaica'),
#  ('1052-004', 0, 2, 'Faroe_Islands_national_football_team'),
#  ('1120-005', 17, 18, 'Amman'),
#  ('1009-014', 14, 15, 'Mexico'),
#  ('1072-018', 5, 7, 'André_Joubert'),
#  ('1101-004', 16, 18, 'Ricardo_Peláez'),
#  ('1054-006', 1, 3, 'Giovanni_Lombardi'),
#  ('1158-005', 21, 22, '--NME--'),
#  ('0953-011', 24, 26, '--NME--'),
#  ('1087-018', 11, 13, 'Peter_Nicol'),
#  ('1076-006', 2, 3, 'FK_Rad'),
#  ('1101-011', 87, 89, 'Zinedine_Zidane'),
#  ('1103-016', 41, 43, 'Tolunay_Kafkas'),
#  ('0970-003', 9, 10, 'Atalanta_B.C.'),
#  ('1039-014', 11, 14, '--NME--'),
#  ('1072-019', 41, 43, 'Justin_Marshall'),
#  ('0955-002', 2, 4, 'South_Korea'),
#  ('1128-005', 17, 18, '--NME--'),
#  ('1039-001', 17, 18, 'Reuters'),
#  ('1097-012', 35, 37, 'Richard_Krajicek'),
#  ('1019-000', 6, 7, 'Netherlands'),
#  ('1061-021', 2, 3, '--NME--'),
#  ('0972-021', 2, 3, 'Muttiah_Muralitharan'),
#  ('0982-002', 0, 1, '--NME--'),
#  ('1131-003', 23, 24, 'Chile'),
#  ('1126-007', 0, 1, 'Islam'),
#  ('1017-000', 2, 3, 'Africa'),
#  ('1039-015', 7, 8, 'Kia_Motors'),
#  ('1116-027', 3, 6, 'World_War_II'),
#  ('1059-002', 0, 1, 'Essex_County_Cricket_Club'),
#  ('1157-004', 13, 16, 'Kurdistan_Democratic_Party'),
#  ('0990-002', 31, 32, 'Interfax'),
#  ('1030-026', 3, 4, 'Federal_Reserve'),
#  ('1142-011', 25, 26, 'Iran'),
#  ('1116-019', 1, 2, 'United_States'),
#  ('1090-008', 30, 31, 'United_States'),
#  ('1076-015', 0, 4, '--NME--'),
#  ('1065-002', 0, 1, 'Scotland'),
#  ('0991-002', 2, 4, 'Alexander_Lebed'),
#  ('1068-014', 7, 8, 'Bolton_Wanderers_F.C.'),
#  ('1101-012', 16, 18, 'Pável_Pardo'),
#  ('1070-000', 7, 8, 'IndyCar_Series'),
#  ('0966-078', 1, 3, 'Pauline_Konga'),
#  ('1159-007', 12, 14, 'Marc_Dutroux'),
#  ('0957-007', 6, 8, 'Doug_Flach'),
#  ('0949-006', 14, 15, 'Alan_Shearer'),
#  ('1053-003', 15, 17, 'Ijaz_Ahmed_(cricketer,_born_1968)'),
#  ('1116-012', 5, 7, 'Henry_Campbell-Bannerman'),
#  ('1067-019', 0, 2, 'Inverness_Thistle_F.C.'),
#  ('1024-008', 2, 7, '--NME--'),
#  ('1098-000', 3, 4, 'Naseem_Hamed'),
#  ('1032-002', 31, 32, '--NME--'),
#  ('1130-003', 23, 25, 'Fidel_Castro'),
#  ('1070-015', 4, 5, 'Brazil'),
#  ('1027-017', 20, 21, 'Jordan'),
#  ('0991-011', 14, 15, 'Alexander_Lebed'),
#  ('0957-021', 16, 17, 'United_States'),
#  ('0993-005', 24, 25, 'Belgrade'),
#  ('0965-011', 27, 28, 'Summer_Olympic_Games'),
#  ('1060-017', 4, 5, 'Republic_of_Ireland'),
#  ('1155-010', 0, 1, 'Abolhassan_Banisadr'),
#  ('1094-027', 2, 3, 'Milwaukee_Brewers'),
#  ('0969-002', 3, 5, 'Dominique_Baratelli'),
#  ('1124-010', 5, 6, 'Constand_Viljoen'),
#  ('1132-007', 14, 15, '--NME--'),
#  ('0953-012', 0, 1, '--NME--'),
#  ('0980-006', 1, 2, 'United_States'),
#  ('1103-004', 0, 1, '--NME--'),
#  ('1148-006', 1, 2, 'Tunisia'),
#  ('1034-002', 34, 35, 'Amsterdam'),
#  ('1068-029', 0, 2, 'Cambridge_United_F.C.'),
#  ('0946-004', 14, 15, 'Leicestershire_County_Cricket_Club'),
#  ('1033-011', 4, 5, '--NME--'),
#  ('1069-018', 3, 4, 'Gloucestershire_County_Cricket_Club'),
#  ('1058-009', 29, 30, 'Cleveland_Indians'),
#  ('1103-017', 2, 5, 'Wilfried_Van_Moer'),
#  ('1102-003', 2, 4, 'Nicolas_Ouédec'),
#  ('0964-001', 0, 1, 'Madrid'),
#  ('1029-001', 0, 2, '--NME--'),
#  ('0959-005', 2, 4, 'Kansas_City_Royals'),
#  ('1016-010', 5, 6, 'Israel'),
#  ('1054-004', 1, 2, 'Roermond'),
#  ('1048-003', 11, 13, '--NME--'),
#  ('1061-014', 0, 1, 'Treorchy_RFC'),
#  ('1091-003', 17, 18, 'Belarus'),
#  ('1103-009', 41, 43, 'Ogün_Temizkanoğlu'),
#  ('0966-041', 4, 5, 'Russia'),
#  ('1068-028', 0, 1, 'Brighton_&_Hove_Albion_F.C.'),
#  ('1119-005', 5, 6, 'Kurdistan'),
#  ('1160-018', 4, 5, 'Michael_Collins_(Irish_leader)'),
#  ('1008-010', 31, 34, '--NME--'),
#  ('1067-020', 0, 1, 'Montrose_F.C.'),
#  ('0947-006', 20, 21, 'Durham_County_Cricket_Club'),
#  ('1100-001', 0, 1, 'Dublin'),
#  ('0994-010', 23, 24, 'Russia'),
#  ('0958-033', 0, 1, 'Atlanta_Braves'),
#  ('1076-016', 0, 1, 'FK_Vojvodina'),
#  ('1053-001', 2, 3, 'England'),
#  ('1137-003', 7, 9, '--NME--'),
#  ('1133-011', 6, 7, 'China'),
#  ('0957-006', 2, 4, 'Goran_Ivanišević'),
#  ('1056-014', 4, 5, 'Ukraine'),
#  ('0972-024', 3, 4, 'Ian_Healy'),
#  ('1140-001', 0, 2, 'Hong_Kong'),
#  ('1028-032', 4, 6, '--NME--'),
#  ('0957-013', 0, 2, 'Jonas_Björkman'),
#  ('0996-004', 12, 13, 'Yugoslavia'),
#  ('1142-006', 32, 33, 'Iran'),
#  ('1056-030', 4, 5, 'United_Kingdom'),
#  ('0984-019', 5, 6, 'Norway'),
#  ('1094-001', 0, 2, 'New_York_City'),
#  ('1127-015', 0, 1, 'Urus-Martan'),
#  ('1152-007', 7, 8, 'United_States'),
#  ('1034-004', 13, 14, 'Netherlands'),
#  ('1116-027', 20, 21, 'London'),
#  ('0956-014', 0, 1, '--NME--'),
#  ('1066-075', 0, 1, 'Hereford_United_F.C.'),
#  ('0957-026', 0, 2, 'Andriy_Medvedev'),
#  ('1127-021', 3, 4, 'God'),
#  ('1006-003', 20, 22, 'Muammar_Gaddafi'),
#  ('1061-011', 0, 1, 'Wales'),
#  ('0966-154', 4, 5, 'Cuba'),
#  ('0959-012', 0, 1, 'Cincinnati_Reds'),
#  ('1072-018', 42, 46, 'Joost_van_der_Westhuizen'),
#  ('0992-006', 6, 7, 'Bosnia_and_Herzegovina'),
#  ('1011-022', 15, 17, '--NME--'),
#  ('1058-013', 7, 8, 'Cleveland_Indians'),
#  ('1116-009', 6, 7, 'Mikhail_Kutuzov'),
#  ('1095-010', 2, 3, 'Boston_Red_Sox'),
#  ('0957-028', 0, 2, 'Petr_Korda'),
#  ('1138-011', 0, 1, 'China'),
#  ('0948-034', 3, 4, 'Hampshire_County_Cricket_Club'),
#  ('0949-003', 20, 22, 'Tony_Adams'),
#  ('0972-029', 4, 5, '--NME--'),
#  ('1066-061', 0, 1, 'Cardiff_City_F.C.'),
#  ('1083-000', 2, 3, 'Pallacanestro_Treviso'),
#  ('1009-010', 26, 27, 'Mexico'),
#  ('1070-010', 4, 5, 'United_States'),
#  ('1036-017', 23, 25, '--NME--'),
#  ('1008-023', 11, 13, 'Federal_Reserve'),
#  ('0966-070', 1, 3, 'Inger_Miller'),
#  ('1070-000', 6, 7, 'Vancouver'),
#  ('1051-005', 5, 6, 'Spain'),
#  ('1051-003', 11, 14, 'Miguel_Ángel_Martín_(golfer)'),
#  ('1069-016', 3, 4, 'Sussex_County_Cricket_Club'),
#  ('0985-006', 0, 1, 'Frank_Bruno'),
#  ('1152-014', 5, 8, '--NME--'),
#  ('1113-001', 0, 1, 'Bonn'),
#  ('1016-014', 5, 6, 'Israel'),
#  ('0953-011', 20, 21, 'Panama'),
#  ('1055-023', 3, 4, 'Robert_Croft'),
#  ('1069-013', 0, 1, 'Warwickshire_County_Cricket_Club'),
#  ('1072-014', 1, 2, '--NME--'),
#  ('1055-037', 8, 9, 'Dean_Headley'),
#  ('1011-008', 6, 7, '--NME--'),
#  ('0961-000', 0, 1, 'National_Football_League'),
#  ('1036-024', 4, 5, 'Ukraine'),
#  ('1055-026', 4, 5, 'Robert_Croft'),
#  ('0946-011', 0, 1, 'Derbyshire_County_Cricket_Club'),
#  ('1031-004', 16, 21, '--NME--'),
#  ('1160-007', 21, 22, 'Neil_Jordan'),
#  ('1095-000', 2, 4, 'Major_League_Baseball'),
#  ('1053-003', 2, 3, 'England_cricket_team'),
#  ('1061-000', 3, 4, 'England'),
#  ('0958-000', 2, 4, 'Major_League_Baseball'),
#  ('1007-017', 11, 12, 'Bill_Clinton'),
#  ('1049-002', 19, 20, '--NME--'),
#  ('1116-033', 6, 7, 'Saudi_Arabia'),
#  ('1116-022', 6, 10, 'Ice_Cold_in_Alex'),
#  ('1137-010', 6, 8, '--NME--'),
#  ('1016-007', 26, 28, '--NME--'),
#  ('1036-009', 12, 13, '--NME--'),
#  ('1076-030', 0, 1, 'FK_Sutjeska_Nikšić'),
#  ('1056-043', 11, 13, '--NME--'),
#  ('1153-002', 1, 2, 'Belgium'),
#  ('1131-006', 15, 16, 'Bolivia'),
#  ('1008-003', 10, 11, 'Midwestern_United_States'),
#  ('1049-004', 0, 1, 'Niall_Quinn'),
#  ('1161-007', 7, 9, '--NME--'),
#  ('1103-015', 44, 46, 'Enzo_Scifo'),
#  ('1088-002', 35, 37, 'Rodney_Eyles'),
#  ('1072-003', 16, 18, 'New_Zealand_national_rugby_union_team'),
#  ('1048-002', 2, 3, '--NME--'),
#  ('1034-004', 1, 2, 'Netherlands'),
#  ('1138-002', 10, 12, 'New_York'),
#  ('1025-008', 15, 16, '--NME--'),
#  ('1108-003', 0, 1, 'Nate_Miller'),
#  ('1148-009', 4, 6, 'Habib_Boularès'),
#  ('1018-004', 14, 15, 'Berlin'),
#  ('0968-003', 40, 41, '--NME--'),
#  ('1044-003', 3, 4, 'Yasser_Arafat'),
#  ('0966-090', 1, 3, 'Falilat_Ogunkoya'),
#  ('1057-006', 11, 13, 'Alec_Stewart'),
#  ('1006-006', 9, 11, '--NME--'),
#  ('1057-007', 5, 7, 'Saeed_Anwar'),
#  ('0980-004', 4, 5, 'Eurodollar'),
#  ('1014-003', 17, 19, '--NME--'),
#  ('1046-007', 2, 4, 'Roberto_Carlos'),
#  ('1016-012', 0, 1, '--NME--'),
#  ('1027-007', 30, 31, '--NME--'),
#  ('0984-011', 5, 6, '--NME--'),
#  ('1147-002', 17, 18, 'Kurdistan'),
#  ('1016-009', 10, 11, 'Israel'),
#  ('1133-014', 7, 9, '--NME--'),
#  ('1068-013', 2, 3, 'Birmingham_City_F.C.'),
#  ('0966-140', 1, 3, 'Tom_Nyariki'),
#  ('1076-026', 0, 1, 'FK_Sloboda_Tuzla'),
#  ('1072-012', 18, 20, '--NME--'),
#  ('1011-023', 40, 42, '--NME--'),
#  ('0957-007', 9, 10, 'United_States'),
#  ('1045-006', 42, 45, '--NME--'),
#  ('0966-094', 1, 3, 'Olabisi_Afolabi'),
#  ('1124-003', 6, 8, 'Freedom_Front_Plus'),
#  ('0960-019', 41, 42, 'Marcelo_Ríos'),
#  ('1021-000', 0, 1, 'Martela'),
#  ('1132-003', 24, 25, 'Morelia'),
#  ('1046-001', 3, 4, 'Spain'),
#  ('1116-023', 2, 6, 'James_Van_Allen'),
#  ('0965-005', 21, 22, 'United_States'),
#  ('1149-005', 46, 48, 'Interstate_5'),
#  ('1063-002', 14, 15, 'Europe'),
#  ('1106-002', 2, 3, 'Turkey_national_football_team'),
#  ('0953-003', 8, 10, '--NME--'),
#  ('1085-002', 13, 14, 'Europe'),
#  ('0984-005', 0, 1, 'United_Kingdom'),
#  ('1159-003', 15, 16, 'Liège'),
#  ('0963-002', 26, 28, 'Tiger_Woods'),
#  ('1016-009', 18, 20, '--NME--'),
#  ('1069-003', 1, 2, 'Portsmouth'),
#  ('1007-001', 0, 2, '--NME--'),
#  ('1076-007', 2, 6, '--NME--'),
#  ('1096-037', 0, 1, 'Alan_Benes'),
#  ('1152-004', 29, 30, 'Mediterranean_Sea'),
#  ('1137-002', 18, 19, 'South_Korea'),
#  ('1063-000', 2, 3, 'Ukraine_national_football_team'),
#  ('1096-002', 2, 3, '--NME--'),
#  ('1042-002', 24, 25, 'Xinhua_News_Agency'),
#  ('1054-007', 4, 5, 'Netherlands'),
#  ('1026-007', 27, 28, 'Islam'),
#  ('1156-003', 32, 33, 'Italy'),
#  ('1066-021', 0, 1, 'Huddersfield_Town_A.F.C.'),
#  ('0972-012', 5, 6, 'Muttiah_Muralitharan'),
#  ('1017-000', 0, 1, 'France'),
#  ('1094-011', 0, 1, 'Detroit_Tigers'),
#  ('1035-004', 6, 7, 'Republic_of_Artsakh'),
#  ('1160-004', 18, 21, 'Irish_Republican_Army'),
#  ('1138-002', 6, 8, '--NME--'),
#  ('0946-005', 14, 15, 'Phil_Simmons'),
#  ('1058-036', 26, 27, 'Detroit_Tigers'),
#  ('1027-007', 5, 6, 'Israel'),
#  ('1012-009', 10, 11, 'Libya'),
#  ('0993-003', 30, 32, '--NME--'),
#  ('1056-013', 4, 5, 'Lithuania'),
#  ('1056-012', 4, 5, 'United_States'),
#  ('0948-024', 10, 11, 'London'),
#  ('0960-010', 0, 1, '--NME--'),
#  ('1094-050', 2, 3, 'Chicago_White_Sox'),
#  ('1101-008', 16, 18, 'Inter_Milan'),
#  ('1008-019', 2, 3, 'Federal_Open_Market_Committee'),
#  ('1160-004', 4, 6, 'Liam_Neeson'),
#  ('1144-003', 7, 8, 'Iraq'),
#  ('1090-018', 26, 28, 'Conchita_Martínez'),
#  ('1103-007', 1, 2, '--NME--'),
#  ('1128-005', 2, 3, '--NME--'),
#  ('1135-027', 16, 17, 'Myanmar'),
#  ('1057-007', 14, 15, 'Inzamam-ul-Haq'),
#  ('1061-016', 2, 3, 'Cardiff_RFC'),
#  ('1053-001', 0, 1, 'Birmingham'),
#  ('1128-006', 19, 20, '--NME--'),
#  ('0984-018', 4, 5, '--NME--'),
#  ('1047-001', 0, 1, 'Wigan'),
#  ('0980-013', 7, 8, 'United_States'),
#  ('0978-002', 25, 26, '--NME--'),
#  ('0996-007', 35, 37, '--NME--'),
#  ('1044-002', 7, 9, '--NME--'),
#  ('1096-020', 5, 7, 'Ryne_Sandberg'),
#  ('0965-004', 6, 7, 'Olympic_sports'),
#  ('1031-003', 0, 1, 'Italy'),
#  ('1066-022', 0, 1, 'Oxford_United_F.C.'),
#  ('1058-014', 9, 12, 'American_League_Central'),
#  ('1046-004', 30, 31, 'Donato_(footballer)'),
#  ('0949-007', 17, 18, 'Alan_Shearer'),
#  ('0994-003', 6, 8, 'Alexander_Lukashenko'),
#  ('1114-002', 10, 11, '--NME--'),
#  ('1058-036', 29, 32, 'Kansas_City_Royals'),
#  ('1103-007', 36, 37, 'England'),
#  ('1046-004', 26, 27, 'Brazil'),
#  ('1053-002', 12, 13, 'Edgbaston_Cricket_Ground'),
#  ('1033-007', 16, 17, 'Chechnya'),
#  ('0997-008', 17, 18, 'Moscow'),
#  ('1022-014', 13, 14, '--NME--'),
#  ('1116-011', 14, 15, 'Empire_of_Brazil'),
#  ('1006-014', 17, 18, 'Sudan'),
#  ('1106-006', 8, 10, 'Luís_Oliveira'),
#  ('1056-044', 0, 2, '--NME--'),
#  ('1067-018', 2, 4, 'East_Stirlingshire_F.C.'),
#  ('1126-009', 7, 8, 'Islam'),
#  ('0959-005', 0, 1, 'Detroit_Tigers'),
#  ('1063-002', 11, 13, 'FIFA_World_Cup'),
#  ('1090-017', 8, 9, '1996_Summer_Olympics'),
#  ('1011-004', 19, 21, '--NME--'),
#  ('1160-010', 0, 1, 'Neil_Jordan'),
#  ('1000-014', 11, 13, 'Czech_Republic'),
#  ('1121-008', 35, 37, 'Iraqi_Kurdistan'),
#  ('0994-003', 2, 3, 'Belarus'),
#  ('0993-003', 24, 25, 'Tanjug'),
#  ('1157-003', 5, 6, 'Reuters'),
#  ('0966-113', 4, 5, 'Norway'),
#  ('0997-002', 2, 4, 'Boris_Yeltsin'),
#  ('1097-017', 12, 13, 'Stefan_Edberg'),
#  ('0949-005', 24, 25, 'Southampton_F.C.'),
#  ('1160-003', 16, 18, 'Michael_Collins_(film)'),
#  ('1060-003', 8, 10, 'Robert_Allenby'),
#  ('0984-012', 30, 32, 'Labor_Day'),
#  ('0966-010', 1, 3, 'Gillian_Russell'),
#  ('1054-008', 4, 5, 'Netherlands'),
#  ('1056-038', 6, 8, '--NME--'),
#  ('1011-008', 19, 23, 'A._G._Edwards'),
#  ('1075-003', 0, 1, 'Benin_national_football_team'),
#  ('1066-027', 0, 1, 'Grimsby_Town_F.C.'),
#  ('0966-077', 1, 3, 'Gunhild_Haugen'),
#  ('0994-016', 0, 1, 'Alexander_Lukashenko'),
#  ('1096-024', 8, 9, 'Atlanta_Braves'),
#  ('0948-033', 3, 5, 'British_Universities_cricket_team'),
#  ('1143-003', 12, 13, 'Lebanon'),
#  ('1147-000', 8, 9, 'Erbil'),
#  ('1157-003', 2, 3, 'NATO'),
#  ('1157-002', 1, 5, 'NATO'),
#  ('1064-005', 5, 6, 'Harlequin_F.C.'),
#  ('0968-002', 21, 25, '--NME--'),
#  ('1061-013', 0, 1, 'Dunvant_RFC'),
#  ('1120-006', 17, 18, 'London'),
#  ('1158-005', 19, 20, 'Uzi'),
#  ('0949-005', 0, 1, 'Alan_Shearer'),
#  ('1127-004', 20, 21, '--NME--'),
#  ('1035-002', 2, 3, 'Armenia'),
#  ('0981-008', 23, 24, '--NME--'),
#  ('1089-026', 30, 31, 'Greg_Kraft'),
#  ('1035-001', 0, 1, 'Bonn'),
#  ('0988-005', 17, 27, '--NME--'),
#  ('1059-003', 18, 20, 'Richard_Kettleborough'),
#  ('1133-011', 9, 10, 'Hangzhou'),
#  ('1072-019', 8, 10, 'Alama_Ieremia'),
#  ('1103-008', 26, 28, 'Dirk_Medved'),
#  ('0974-011', 0, 2, 'Chaminda_Vaas'),
#  ('1128-004', 26, 27, 'Warsaw'),
#  ('0960-020', 12, 13, '--NME--'),
#  ('0956-002', 2, 4, 'South_Korea'),
#  ('1016-010', 12, 13, 'Bonn'),
#  ('0956-008', 2, 3, '--NME--'),
#  ('1012-000', 7, 8, 'Louis_Farrakhan'),
#  ('1023-001', 0, 2, 'New_York_City'),
#  ('0948-044', 9, 10, 'Nottingham'),
#  ('0958-001', 0, 2, 'New_York_City'),
#  ('1156-003', 3, 4, 'Rome'),
#  ('0966-035', 1, 3, 'Jon_Drummond'),
#  ('0980-003', 3, 4, '--NME--'),
#  ('1134-003', 20, 21, 'Fidel_Ramos'),
#  ('0962-011', 9, 11, '--NME--'),
#  ('0966-022', 4, 5, 'United_Kingdom'),
#  ('0948-040', 3, 4, 'Middlesex_County_Cricket_Club'),
#  ('1136-002', 23, 24, 'China'),
#  ('1142-010', 13, 14, 'Persian_Gulf'),
#  ('0994-005', 18, 19, 'Europe'),
#  ('1100-002', 0, 1, 'United_States'),
#  ('0987-005', 5, 6, 'Uyo'),
#  ('0966-046', 4, 5, 'Burundi'),
#  ('1030-017', 17, 19, '--NME--'),
#  ('1099-018', 23, 25, 'Stuart_McCall'),
#  ('0954-002', 24, 26, 'Mark_Cairns_(squash_player)'),
#  ('1152-007', 27, 28, 'Kurdistan'),
#  ('1155-014', 9, 11, '--NME--'),
#  ('0966-065', 1, 3, 'Gwen_Torrence'),
#  ('1096-036', 11, 12, '--NME--'),
#  ('1068-023', 0, 1, 'Millwall_F.C.'),
#  ('1147-002', 13, 14, 'Iraq'),
#  ('1049-003', 18, 20, 'Andy_Townsend'),
#  ('0994-002', 0, 1, 'Minsk'),
#  ('0954-002', 21, 22, 'Pakistan'),
#  ('1124-009', 5, 7, 'South_Africa'),
#  ('1089-004', 7, 9, 'Loren_Roberts'),
#  ('0966-107', 4, 5, 'Denmark'),
#  ('0988-000', 0, 2, '--NME--'),
#  ('1161-000', 0, 1, 'Dhaka_Stock_Exchange'),
#  ('1056-034', 11, 13, '--NME--'),
#  ('1082-000', 4, 5, 'Switzerland_national_football_team'),
#  ('1138-008', 13, 15, 'Democracy_Wall'),
#  ('1051-010', 1, 3, 'Phillip_Price'),
#  ('0965-005', 15, 16, 'Atlanta'),
#  ('0957-012', 9, 10, 'Sweden'),
#  ('1064-005', 2, 3, 'France'),
#  ('1101-006', 16, 17, 'Juventus_F.C.'),
#  ('1103-015', 10, 12, 'Bertrand_Crasson'),
#  ('1033-000', 0, 1, '--NME--'),
#  ('1066-015', 0, 1, 'Portsmouth_F.C.'),
#  ('0963-018', 9, 11, 'Valero_Texas_Open'),
#  ('0960-001', 0, 2, '--NME--'),
#  ('1044-002', 2, 4, 'Yasser_Arafat'),
#  ('1155-006', 10, 11, 'Bonn'),
#  ('1096-023', 0, 1, 'Chicago_Cubs'),
#  ('1146-000', 6, 7, 'Kurdistan_Democratic_Party'),
#  ('1066-032', 0, 1, 'Brentford_F.C.'),
#  ('1059-006', 24, 25, 'Derbyshire_County_Cricket_Club'),
#  ('1096-026', 0, 1, '--NME--'),
#  ('1116-033', 8, 9, 'Kuwait'),
#  ('0981-014', 15, 19, '--NME--'),
#  ('1030-015', 21, 25, 'New_York_Stock_Exchange'),
#  ('1130-010', 7, 9, 'Prensa_Latina'),
#  ('0997-002', 14, 15, 'Interfax'),
#  ('0994-014', 5, 6, 'Moscow'),
#  ('1137-008', 18, 19, 'North_Korea'),
#  ('0980-014', 8, 9, 'United_States'),
#  ('1138-008', 3, 4, '--NME--'),
#  ('1022-012', 28, 29, 'Greenwich_Mean_Time'),
#  ('1056-047', 9, 11, '--NME--'),
#  ('1059-006', 6, 7, 'Surrey_County_Cricket_Club'),
#  ('1035-010', 36, 37, 'Finland'),
#  ('1101-011', 9, 11, 'Lilian_Thuram'),
#  ('0978-002', 11, 14, '--NME--'),
#  ('1120-008', 12, 13, 'United_Kingdom'),
#  ('1092-004', 0, 2, 'United_States_Fed_Cup_team'),
#  ('1131-007', 7, 8, 'Guatemala'),
#  ('1054-010', 1, 3, 'Viatcheslav_Ekimov'),
#  ('1000-015', 10, 11, 'France'),
#  ('1121-008', 5, 6, 'Iran'),
#  ('1058-023', 2, 3, 'Pete_Incaviglia'),
#  ('1152-002', 0, 1, 'Washington,_D.C.'),
#  ('1066-054', 0, 1, 'Walsall_F.C.'),
#  ('1087-017', 13, 14, 'Australia'),
#  ('0990-003', 1, 2, 'Alexander_Lebed'),
#  ('1007-004', 1, 2, 'Bill_Clinton'),
#  ('1099-007', 15, 16, 'Austria'),
#  ('1078-001', 0, 1, 'Belgrade'),
#  ('1119-004', 4, 5, 'Iraq'),
#  ('1072-018', 100, 102, '--NME--'),
#  ('1136-006', 14, 15, 'Tianjin'),
#  ('1014-004', 38, 39, 'Bill_Clinton'),
#  ('1148-003', 0, 1, 'Reuters'),
#  ('1067-005', 3, 4, 'Falkirk_F.C.'),
#  ('1148-005', 18, 19, 'Tunisia'),
#  ('0956-000', 4, 6, 'South_Korea'),
#  ('0976-001', 0, 1, 'Warsaw'),
#  ('0957-018', 35, 36, 'Switzerland'),
#  ('0990-009', 6, 7, 'Chechnya'),
#  ('1000-009', 10, 11, 'Budapest'),
#  ('1072-002', 0, 1, 'Johannesburg'),
#  ('1000-016', 5, 7, '--NME--'),
#  ('1013-002', 8, 10, '--NME--'),
#  ('1039-015', 32, 33, 'Indonesia'),
#  ('1143-008', 17, 18, 'Jews'),
#  ('1094-030', 0, 2, 'New_York_Yankees'),
#  ('1036-031', 14, 15, 'Norway'),
#  ('1057-006', 35, 37, 'Alan_Mullally'),
#  ('1068-030', 2, 3, 'Hereford_United_F.C.'),
#  ('1110-000', 4, 5, '--NME--'),
#  ('0995-003', 26, 27, 'Pamir_Mountains'),
#  ('0972-020', 5, 7, '--NME--'),
#  ('1059-006', 26, 27, 'Australia'),
#  ('1055-003', 0, 1, 'England_cricket_team'),
#  ('1072-019', 21, 23, 'Walter_Little_(rugby_player)'),
#  ('1131-002', 8, 10, 'Madeleine_Albright'),
#  ('1017-003', 25, 26, 'Conakry'),
#  ('0947-006', 2, 3, 'Glamorgan_County_Cricket_Club'),
#  ('1121-008', 25, 26, 'Iraq'),
#  ('0990-003', 13, 14, 'Viktor_Chernomyrdin'),
#  ('0996-004', 14, 15, 'Poles'),
#  ('0991-011', 8, 9, 'Boris_Yeltsin'),
#  ('1058-006', 0, 1, '--NME--'),
#  ('0971-003', 2, 3, 'Australia_national_cricket_team'),
#  ('0966-122', 1, 3, '--NME--'),
#  ('1145-003', 16, 17, '--NME--'),
#  ('1076-029', 0, 1, '--NME--'),
#  ('1099-018', 11, 13, 'Colin_Calderwood'),
#  ('0960-011', 31, 32, '--NME--'),
#  ('1127-006', 10, 12, 'Dzhokhar_Dudayev'),
#  ('1154-008', 4, 8, '--NME--'),
#  ('0987-001', 0, 1, 'Lagos'),
#  ('0966-031', 4, 5, 'United_States'),
#  ('1158-005', 17, 18, 'AK-47'),
#  ('0972-031', 0, 2, 'U._Chandana'),
#  ('1090-014', 0, 1, 'Monica_Seles'),
#  ('1106-000', 7, 9, '1998_FIFA_World_Cup'),
#  ('0985-000', 0, 1, '--NME--'),
#  ('0974-007', 0, 1, 'Australia_national_cricket_team'),
#  ('1132-003', 11, 12, 'Michoacán'),
#  ('1133-006', 18, 19, '--NME--'),
#  ('1091-004', 11, 12, 'Sweden'),
#  ('1009-004', 29, 31, 'Dan_Glickman'),
#  ('1095-018', 2, 3, 'Pittsburgh_Pirates'),
#  ('0980-002', 36, 37, 'Chicago'),
#  ('1068-005', 0, 1, 'Bradford_City_A.F.C.'),
#  ('1056-017', 18, 20, 'Guido_Fulst'),
#  ('0972-021', 8, 9, 'Upul_Chandana'),
#  ('1068-038', 2, 3, 'Chester_City_F.C.'),
#  ('1116-032', 10, 11, 'Anglicanism'),
#  ('1055-012', 3, 5, 'Waqar_Younis'),
#  ('1160-000', 1, 2, 'Irish_Republican_Army'),
#  ('1049-001', 0, 1, 'Eschen'),
#  ('1042-003', 5, 6, 'Huize_County'),
#  ('0952-006', 26, 27, 'Moscow'),
#  ('1150-003', 3, 4, 'Rochester,_New_Hampshire'),
#  ('1096-035', 24, 26, 'Bobby_Valentine'),
#  ('1014-009', 13, 14, 'Bob_Dole'),
#  ('0986-003', 0, 1, 'Birmingham_City_F.C.'),
#  ('1052-002', 15, 16, '--NME--'),
#  ('1034-003', 34, 36, 'Tel_Aviv'),
#  ('1120-009', 1, 2, 'United_Kingdom'),
#  ('0954-005', 2, 4, 'Rodney_Eyles'),
#  ('0966-016', 4, 5, 'Canada'),
#  ('0984-004', 14, 15, '--NME--'),
#  ('0966-150', 1, 3, '--NME--'),
#  ('0986-004', 3, 5, 'Norwich_City_F.C.'),
#  ('1031-007', 38, 39, '--NME--'),
#  ('0985-003', 6, 7, 'Frank_Bruno'),
#  ('1039-000', 3, 4, 'Indonesia'),
#  ('0948-038', 3, 4, 'Scotland'),
#  ('1011-008', 10, 11, '--NME--'),
#  ('1072-019', 90, 92, 'Craig_Dowd'),
#  ('1131-002', 24, 25, 'Chile'),
#  ('0966-051', 1, 3, 'John_Mayock'),
#  ('1072-011', 25, 26, 'South_Africa_national_rugby_union_team'),
#  ('1014-003', 9, 10, 'Bill_Clinton'),
#  ('0962-008', 7, 9, 'Jesper_Parnevik'),
#  ('0967-005', 21, 22, 'Karlsruher_SC'),
#  ('0952-000', 2, 3, 'FC_Rotor_Volgograd'),
#  ('1138-001', 0, 1, 'Beijing'),
#  ('1131-000', 5, 6, 'Chile'),
#  ('1099-000', 2, 3, 'Austria_national_football_team'),
#  ('0966-145', 4, 5, 'United_States'),
#  ('1058-015', 0, 1, 'Texas_Rangers_(baseball)'),
#  ('1099-004', 0, 1, 'Scotland_national_football_team'),
#  ('1128-009', 23, 25, '--NME--'),
#  ('1048-003', 3, 4, 'Bulgaria_national_under-21_football_team'),
#  ('0977-008', 0, 1, 'Canada'),
#  ('1149-000', 2, 3, 'United_States'),
#  ('0966-135', 1, 3, 'Bob_Kennedy_(runner)'),
#  ('1152-014', 46, 47, 'United_States'),
#  ('1008-002', 0, 1, 'Washington,_D.C.'),
#  ('0992-007', 6, 7, 'Party_of_Democratic_Action'),
#  ('1156-002', 3, 5, 'Lamberto_Dini'),
#  ('1035-009', 31, 32, 'Amsterdam'),
#  ('0991-010', 4, 5, 'Alexander_Lebed'),
#  ('1128-000', 0, 1, 'Poland'),
#  ('1025-000', 0, 1, 'Syria'),
#  ('1058-031', 30, 33, 'Boston_Red_Sox'),
#  ('1158-002', 7, 8, 'AK-47'),
#  ('0980-001', 0, 1, 'Chicago'),
#  ('0951-004', 8, 10, 'Mihai_Tararache'),
#  ('1012-008', 4, 5, 'Libya'),
#  ('1030-037', 5, 9, 'New_York_Mercantile_Exchange'),
#  ('1103-015', 20, 22, 'Pascal_Renier'),
#  ('1099-018', 5, 7, 'Craig_Burley'),
#  ('0947-008', 26, 28, '--NME--'),
#  ('1022-014', 10, 11, '--NME--'),
#  ('0965-006', 0, 1, 'Jamaica'),
#  ('1066-038', 0, 1, 'York_City_F.C.'),
#  ('1058-028', 2, 4, 'Harold_Baines'),
#  ('0957-018', 18, 19, 'Spain'),
#  ('0966-132', 4, 5, 'Russia'),
#  ('1144-001', 0, 1, 'Baghdad'),
#  ('0958-056', 2, 4, '--NME--'),
#  ('0983-004', 15, 16, 'Saddam_Hussein'),
#  ('0957-033', 18, 19, 'Italy'),
#  ('0957-033', 26, 27, 'Sweden'),
#  ('1156-003', 15, 16, 'United_States'),
#  ('1054-011', 6, 7, '--NME--'),
#  ('0992-003', 6, 7, 'United_States'),
#  ('1059-006', 20, 22, 'Dave_Gilbert_(cricketer)'),
#  ('1080-002', 10, 12, '1998_FIFA_World_Cup'),
#  ('1025-011', 7, 8, 'Benjamin_Netanyahu'),
#  ('0980-015', 5, 6, 'Federal_Reserve'),
#  ('1024-003', 0, 1, 'Nasdaq'),
#  ('1089-004', 13, 18, 'Brown_Deer_Park_Golf_Course'),
#  ('0960-004', 2, 3, '--NME--'),
#  ('1087-005', 21, 22, '--NME--'),
#  ('1087-019', 4, 5, 'Jansher_Khan'),
#  ...}

# %% [markdown]
# A naive baseline for entity linking on our data set is to link each mention span to the Wikipedia page name that we get when we join the tokens in the span by underscores, as is standard in Wikipedia page names. Suppose, for example, that a span contains the two tokens
#
#     Jimi Hendrix
#
# The baseline Wikipedia page name for this span would be
#
#     Jimi_Hendrix
#
# Implement this naive baseline and evaluate its performance. Print the evaluation measures that you implemented in Problem&nbsp;1.

# %% [markdown]
# **Here and in the remainder of this lab, you should base your entity predictions on the predicted spans that you computed in Problem&nbsp;3.**

# %%
# TODO: Write code here to implement the baseline
def baseline_predict_mentions(df):
    for row in df.itertuples():
        label = row.sentence.split(" ")[int(row.beg):int(row.end)]
        label = "_".join(label)
        yield row.sentence_id, row.beg, row.end, label
                    
predicted_mentions = set(baseline_predict_mentions(new_df_dev))
evaluation_report(gold_standard_mentions, predicted_mentions)
# Out:
# precission:  0.31102123356926187 , recall:  0.25992901808348823 , F1_score:  0.2831890996133309

# %% [markdown]
# ## Problem 5: Extending the training data using the knowledge base

# %% [markdown]
# State-of-the-art approaches to entity linking exploit information in knowledge bases. In our case, where Wikipedia is the knowledge base, one particularly useful type of information are links to other Wikipedia pages. In particular, we can interpret the anchor texts (the highlighted texts that you click on) as mentions of the entities (pages) that they link to. This allows us to harvest long lists of mention–entity pairings.
#
# The following cell loads a data frame summarizing anchor texts and page references harvested from the first paragraphs of the English Wikipedia. The data frame also contains all entity mentions in the training data (but not the development or the test data).

# %%
with bz2.open('kb.tsv.bz2', 'rt') as source:
    df_kb = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# To understand what information is available in this data, the following cell shows the entry for the anchor text `Sweden`.

# %%
df_kb.loc[df_kb.mention == 'Sweden']

# %% [markdown]
# As you can see, each row of the data frame contains a pair $(m, e)$ of a mention $m$ and an entity $e$, as well as the conditional probability $P(e|m)$ for mention $m$ referring to entity $e$. These probabilities were estimated based on the frequencies of mention–entity pairs in the knowledge base. The example shows that the anchor text &lsquo;Sweden&rsquo; is most often used to refer to the entity [Sweden](http://en.wikipedia.org/wiki/Sweden), but in a few cases also to refer to Sweden&rsquo;s national football and ice hockey teams. Note that references are sorted in decreasing order of probability, so that the most probable pairing come first.
#
# Implement an entity linking method that resolves each mention to the most probable entity in the data frame. If the mention is not included in the data frame, you can predict the generic label `--NME--`. Print the precision, recall, and F1 of your method using the function that you implemented for Problem&nbsp;1.

# %%
# TODO: Write code here to implement the "most probable entity" method.

# %% [markdown]
# ## Problem 6: Context-sensitive disambiguation

# %% [markdown]
# Consider the entity mention &lsquo;Lincoln&rsquo;. The most probable entity for this mention turns out to be [Lincoln, Nebraska](http://en.wikipedia.org/Lincoln,_Nebraska); but in pages about American history, we would be better off to predict [Abraham Lincoln](http://en.wikipedia.org/Abraham_Lincoln). This suggests that we should try to disambiguate between different entity references based on the textual context on the page from which the mention was taken. Your task in this last problem is to implement this idea.
#
# Set up a dictionary that contains, for each mention $m$ that can refer to more than one entity $e$, a separate Naive Bayes classifier that is trained to predict the correct entity $e$, given the textual context of the mention. As the prior probabilities of the classifier, choose the probabilities $P(e|m)$ that you used in Problem&nbsp;5. To let you estimate the context-specific probabilities, we have compiled a data set with mention contexts:

# %%
with bz2.open('contexts.tsv.bz2') as source:
    df_contexts = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# This data frame contains, for each ambiguous mention $m$ and each knowledge base entity $e$ to which this mention can refer, up to 100 randomly selected contexts in which $m$ is used to refer to $e$. For this data, a **context** is defined as the 5 tokens to the left and the 5 tokens to the right of the mention. Here are a few examples:

# %%
df_contexts.head()

# %% [markdown]
# Note that, in each context, the position of the mention is indicated by the `@` symbol.
#
# From this data frame, it is easy to select the data that you need to train the classifiers – the contexts and corresponding entities for all mentions. To illustrate this, the following cell shows how to select all contexts that belong to the mention &lsquo;Lincoln&rsquo;:

# %%
df_contexts.context[df_contexts.mention == 'Lincoln']

# %% [markdown]
# Implement the context-sensitive disambiguation method and evaluate its performance. Here are some more hints that may help you along the way:
#
# **Hint 1:** The prior probabilities for a Naive Bayes classifier can be specified using the `class_prior` option. You will have to provide the probabilities in the same order as the alphabetically sorted class (entity) names.
#
# **Hint 2:** Not all mentions in the knowledge base are ambiguous, and therefore not all mentions have context data. If a mention has only one possible entity, pick that one. If a mention has no entity at all, predict the `--NME--` label.

# %%
# TODO: Write code here to implement the context-sensitive disambiguation method

# %% [markdown]
# You should expect to see a small (around 1&nbsp;unit) increase in both precision, recall, and F1.

# %% [markdown]
# ## Reflection questions

# %% [markdown]
# The following reflection questions will help you prepare for the diagnostic test. Answer each of them in the form of a short text and put your answers in the cell below. You will get feedback on your answers from your lab assistant.

# %% [markdown]
# **RQ 5.1:** In Problem&nbsp;3, you did an error analysis on the task of recognizing text spans mentioning named entities. Summarize your results. Pick one type of error that you observed. How could you improve the model&rsquo;s performance on this type of error? What resources (such as domain knowledge, data, compute) would you need to implement this improvement?
#
# **RQ 5.2:** Thinking back about Problem&nbsp;6, explain what the word *context* refers to in the task addressed there, and how context can help to disambiguate between different entities. Suggest other types of context that you could use for disambiguation.
#
# **RQ 5.3:** One type of entity mentions that we did not cover explicitly in this lab are pronouns. As an example, consider the sentence pair *Ruth Bader Ginsburg was an American jurist*. *She served as an associate justice of the Supreme Court from 1993 until her death in 2020*. What facts would you want to extract from this sentence pair? How do pronouns make fact extraction hard?

# %% [markdown]
# *TODO: Enter your answers here*

# %% [markdown]
# **This was the last lab in the Text Mining course. Congratulations! 🥳**
